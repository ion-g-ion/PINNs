# %%
import fenics as fn
import matplotlib.pyplot as plt
from dolfin_utils.meshconvert import meshconvert
import os
from subprocess import call

import numpy as np
import jax
import jax.numpy as jnp
from jax.example_libraries import stax, optimizers
import matplotlib.pyplot as plt
import pinns 
import datetime
import jax.scipy.optimize
import jax.flatten_util
import scipy
import scipy.optimize
import chaospy as cp

# %%
def curl2D(v):
    return fn.as_vector((v.dx(1),-v.dx(0)))

class FEM():
            
    def __init__(self,J0=1000.0,mu0=1.0,mur=10.0, k1=0.001, k2=1.65, k3 = 0.5, meshsize = 0.001, verb = False):
        path='./quad/'
        
        with open(path + 'quad.geo', 'r') as file:
            data = file.read()
            
        s = "meshsize=%.18f;\n"%(meshsize)
        
        s = s + data
        
        with  open(path+"tmp.geo", "w") as file:
            file.write(s)
            file.close()
        if verb: print('geo file created',flush = True)
        
        if verb:
            os.system('gmsh %stmp.geo -nt 20 -3 -o %stmp.msh -format msh2 '%(path,path))
        else:
            os.system('gmsh %stmp.geo -nt 20 -3 -o %stmp.msh -format msh2 >/dev/null 2>&1'%(path,path))
        if verb: print('mesh file created',flush=True)

        if verb:
            os.system('dolfin-convert %stmp.msh %stmp.xml'%(path,path))
        else:
            os.system('dolfin-convert %stmp.msh %stmp.xml >/dev/null 2>&1'%(path,path))
        
        if verb: print('mesh file converted in fenics format',flush=True) 

        mesh = fn.Mesh(path+'tmp.xml')
        domains = fn.MeshFunction("size_t", mesh, path+'tmp_physical_region.xml')
        boundaries = fn.MeshFunction('size_t', mesh, path+'tmp_facet_region.xml')

        self.mesh = mesh
        ncells = [  mesh.num_vertices(), mesh.num_edges(), mesh.num_faces(), mesh.num_facets(), mesh.num_cells() ]
        
        def nu_lin(az):
            return 1/(mu0*mur)
        def nonlin_nu(az):
            tmp =  k1*fn.exp(k2*fn.dot(az.dx(1),az.dx(1)))+k3
            return tmp
        
        def nu_Bauer(B):
            x = fn.dot(B,B)
            return k1*fn.exp(k2*x)+k3
        
        # Coil
        def setup_coil(mesh,subdomains):
            DG = fn.FunctionSpace(mesh,"DG",0)
            J = fn.Function(DG)
            idx = []
            for cell_no in range(len(subdomains.array())):
                subdomain_no = subdomains.array()[cell_no]
                if subdomain_no == 3:
                    idx.append(cell_no)
            J.vector()[:] = 0
            J.vector()[idx] = J0
            return J
        
    
        
        """ define function space and boundary conditions"""
        
        CG = fn.FunctionSpace(mesh, 'CG', 1) # Continuous Galerkin
        
        # Define boundary condition
        bc = fn.DirichletBC(CG, fn.Constant(0.0), boundaries,16)
        
        # Define subdomain markers and integration measure
        dx = fn.Measure('dx', domain=mesh, subdomain_data=domains)
        
        J = setup_coil(mesh, domains)
        
        class Nu(fn.UserExpression): # UserExpression instead of Expression
            def __init__(self, markers, **kwargs):
                super().__init__(**kwargs) # This part is new!
                self.markers = markers
            def eval_cell(self, values, x, cell):
                if self.markers[cell.index] == 1:
                    values[0] = 0.0   # iron
                elif self.markers[cell.index] == 2:
                    values[0] = 1/mu0      # air
                elif self.markers[cell.index] == 3:
                    values[0] = 1/mu0      # air
                else:
                    print('no such domain',self.markers[cell.index] )
                    
        nus = Nu(domains, degree=1)
        
        
        """ weak formulation """
        
        az  = fn.Function(CG)
        u  = fn.Function(CG)
        v  = fn.TestFunction(CG)
        #az = Function(CG)
        #a  = (1/mu)*dot(grad(az), grad(v))*dx
        a = fn.inner(nus*curl2D(u), curl2D(v))*dx + fn.inner(nu_lin(curl2D(u))*curl2D(u),curl2D(v))*dx(1)
        L  = J*v*dx(3)
        
        F = a - L
        # solve variational problem
        fn.solve(F == 0, u, bc)
        az = u
        self.az = az
        # function space for H- and B- field allocated on faces of elements
        W = fn.VectorFunctionSpace(mesh, fn.FiniteElement("DP", fn.triangle, 0),1)
        B = fn.project(curl2D(az), W)
        H = None# project((1/mu)*curl(az), W)
        self.B = B
        self.H = H
    
    def call_A(self,x_eval,y_eval):
        
        
        Afem = 0 * x_eval
        for i in range(x_eval.size):
            try:
                Afem[i] = self.az(x_eval[i],y_eval[i])
            except:
                Afem[i] = np.nan
        return Afem
    
    def call_B(self,x_eval,y_eval):
        
        
        Bfem = []
        for i in range(x_eval.size):
            try:
                Bfem.append(self.B(x_eval[i],y_eval[i]))
            except:
                Bfem.append([ np.nan , np.nan])
        return np.array(Bfem)
    
    def call_H(self,x_eval,y_eval):
        Hfem = []
        for i in range(x_eval.size):
            try:
                Hfem.append(self.H(x_eval[i],y_eval[i]))
            except:
                Hfem.append([ np.nan , np.nan])
        return np.array(Hfem)

# %%
from jax.config import config
config.update("jax_enable_x64", True)
rnd_key = jax.random.PRNGKey(1234)

# %%
def create_geometry(key, scale = 1):
    scale = scale
    Nt = 24                                                                
    lz = 40e-3                                                             
    Do = 72e-3                                                            
    Di = 51e-3                                                            
    hi = 13e-3                                                             
    bli = 3e-3                                                             
    Dc = 3.27640e-2                                                           
    hc = 7.55176e-3                                                           
    ri = 20e-3                                                           
    ra = 18e-3                                                           
    blc = hi-hc                                                           
    rm = (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)                 
    R = rm-ri
    O = np.array([rm/np.sqrt(2),rm/np.sqrt(2)])
    alpha1 = -np.pi*3/4       
    alpha2 = np.math.asin((hc-rm/np.sqrt(2))/R)
    alpha = np.abs(alpha2-alpha1)
    
    A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
    b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
    C = np.linalg.solve(A,b)
    
    knots1 = np.array([[Do,Do * np.tan(np.pi/8)],[Do/np.sqrt(2),Do/np.sqrt(2)],[rm/np.sqrt(2),rm/np.sqrt(2)],[ri/np.sqrt(2),ri/np.sqrt(2)]])
    #knots2 = np.array([[Dc,hc],[Dc+blc,hi],[Di-bli,hi],[Di,hi-bli],[Di,0]])
    knots2 = np.array([[Di,hi-bli],[Di-bli,hi],[Dc+blc,hi],[Dc,hc]])
    knots3 = (knots1+knots2)/2
    knots3[-1,:] = C.flatten()
    knots = np.concatenate((knots1[None,...],knots3[None,...],knots2[None,...]),0)
    weights = np.ones(knots.shape[:2])
    weights[1,-1] = np.sin((np.pi-alpha)/2)
    basis2 = pinns.bspline.BSplineBasis(np.array([-1,-0.33,0.33,1]),1)
    basis1 = pinns.bspline.BSplineBasis(np.array([-1,1]),2)

    geom1 = pinns.geometry.PatchNURBS([basis1, basis2], knots, weights, key)
   
    knots2 = np.array([ [ [Dc,0],[Dc+blc,0],[Di-bli,0],[Di,0] ] , [[Dc,hc],[Dc+blc,hi],[Di-bli,hi],[Di,hi-bli]] ]) 
    knots2 = knots2[:,::-1,:]
    weights = np.ones(knots2.shape[:2])
    
    basis1 = pinns.bspline.BSplineBasis(np.linspace(-1,1,2),1)
    basis2 = pinns.bspline.BSplineBasis(np.array([-1,-0.33,0.33,1]),1)

    geom2 = pinns.geometry.PatchNURBS([basis1, basis2], knots2, weights, key)
   
    knots = np.array([ [ [0,0] , [Dc/2,0] , [Dc,0] ] , [ [ri/np.sqrt(2),ri/np.sqrt(2)] , [C[0,0],C[1,0]] , [Dc,hc] ]])
    
    basis1 = pinns.bspline.BSplineBasis(np.linspace(-1,1,2),1)
    basis2 = pinns.bspline.BSplineBasis(np.array([-1,1]),2)
    
    weights = np.ones(knots.shape[:2])
    weights[1,1] = np.sin((np.pi-alpha)/2)
    geom3 = pinns.geometry.PatchNURBS([basis1, basis2], knots, weights, key)

    knots1 = np.array([[Do,0],[Do,Do * np.tan(np.pi/8)]])
    knots2 = np.array([[Di,0],[Di,hi-bli]])
    knots3 = (knots1+knots2)/2
    knots = np.concatenate((knots1[None,...],knots3[None,...],knots2[None,...]),0)
    weights = np.ones(knots.shape[:2])

    basis2 = pinns.bspline.BSplineBasis(np.linspace(-1,1,2),1)
    basis1 = pinns.bspline.BSplineBasis(np.array([-1,1]),2)

    geom4 = pinns.geometry.PatchNURBS([basis1, basis2], knots, weights, key)
    return  geom1, geom3, geom2, geom4

# %%
geom1, geom2, geom3, geom4 = create_geometry(rnd_key)

pts,_ = geom1.importance_sampling(10000)

plt.figure()
plt.scatter(pts[:,0], pts[:,1], s = 1)

pts,_ = geom2.importance_sampling(10000)
plt.scatter(pts[:,0],pts[:,1], s = 1)

pts,_ = geom3.importance_sampling(10000)
plt.scatter(pts[:,0],pts[:,1], s = 1)

pts,_ = geom4.importance_sampling(10000)
plt.scatter(pts[:,0],pts[:,1], s = 1)
plt.show()

# %%
def interface_function2d(nd, endpositive, endzero, nn):

    faux = lambda x: ((x-endzero)**1/(endpositive-endzero)**1)
    if nd == 0:
        fret = lambda ws, x: (nn(ws, x[...,1][...,None]).flatten()*faux(x[...,0]))[...,None]
    else:
        fret = lambda ws, x: (nn(ws, x[...,0][...,None]).flatten()*faux(x[...,1]))[...,None]
    return fret

def jump_function2d(nd, pos_y, nn):

    faux = lambda x: jnp.exp(-4.0*jnp.abs(x-pos_y))
    if nd == 1:
        fret = lambda ws, x: (nn(ws, x[...,1][...,None]).flatten()*faux(x[...,0]))[...,None]
    else:
        fret = lambda ws, x: (nn(ws, x[...,0][...,None]).flatten()*faux(x[...,1]))[...,None]
    return fret

# def ExpHat(hidden_size, out_dim, W_init=glorot_normal(), b_init=normal()):
#   """Layer constructor function for a dense (fully-connected) layer."""
#   def init_fun(rng, input_shape):
#     output_shape = input_shape[:-1] + (out_dim,)
#     k1, k2 = random.split(rng)
#     W, b = W_init(k1, (input_shape[-1], out_dim)), b_init(k2, (out_dim,))
#     return output_shape, (W, b)
#   def apply_fun(params, inputs, **kwargs):
#     b, b = params
#     return jnp.dot(inputs, W) + b
#   return init_fun, apply_fun
def ExpHat(x, scale = 0.1):
    return jnp.exp(-jnp.abs(x)/scale)

class Model(pinns.PINN):
    def __init__(self, rand_key):
        super().__init__()
        self.key = rand_key

        N = [32,32]
        nl = 16
        acti = stax.Tanh
        # acti =  stax.elementwise(lambda x: jax.nn.leaky_relu(x)**2)
        acti1 = stax.elementwise(lambda x: jax.nn.leaky_relu(x+1)**2)
        acti2 = stax.elementwise(lambda x: jax.nn.leaky_relu(x+0.33)**2)
        acti3 = stax.elementwise(lambda x: jax.nn.leaky_relu(x-0.33)**2)
        acti4 = stax.elementwise(lambda x: jnp.exp(-1.0*jnp.abs(x)))
        
        block_first = stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(nl), acti, stax.Dense(nl), acti),stax.Dense(nl)),stax.FanInSum)
        block = stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(nl), acti, stax.Dense(nl), acti),stax.Dense(nl)),stax.FanInSum)
        block2 = lambda n: stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(n), acti, stax.Dense(n), acti),stax.Dense(n)),stax.FanInSum)
        block3 = stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(nl), acti3, stax.Dense(nl), acti2),stax.Dense(nl)),stax.FanInSum)
        
        self.add_neural_network('u1',stax.serial(block_first,block,block, block, stax.Dense(1)),(-1,2)) # iron
        self.add_neural_network('u4',stax.serial(block_first,block,block, block, stax.Dense(1)),(-1,2)) # iron 2
        self.add_neural_network('u2',stax.serial(block_first,block,block, block, stax.Dense(1)),(-1,2)) # air 
        self.add_neural_network('u3',stax.serial(block_first,block,block, block, stax.Dense(1)),(-1,2)) # copper
        self.add_neural_network('u12',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u13',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        # self.add_neural_network('u13',stax.serial(stax.Dense(1000), acti4, stax.Dense(1)),(-1,1))
        self.add_neural_network('u23',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u14',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u34',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u1_0.3',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u1_0.7',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_trainable_parameter('u123',(1,))
        self.add_trainable_parameter('u134',(1,))
        self.add_trainable_parameter('u13_p0.33',(1,))
        self.add_trainable_parameter('u13_n0.33',(1,))
        
        
        self.interface12 = interface_function2d(1,1.0,-1.0,self.neural_networks['u12'])
        self.interface21 = interface_function2d(0,1.0,-1.0,self.neural_networks['u12'])
        self.interface23 = interface_function2d(1,1.0,-1.0,self.neural_networks['u23'])
        self.interface32 = interface_function2d(1,1.0,-1.0,self.neural_networks['u23'])
        self.interface13 = interface_function2d(0,1.0,-1.0,self.neural_networks['u13'])
        self.interface31 = interface_function2d(0,1.0,-1.0,self.neural_networks['u13'])
        self.interface14 = interface_function2d(1,-1.0,1.0,self.neural_networks['u14'])
        self.interface41 = interface_function2d(1,1.0,-1.0,self.neural_networks['u14'])
        self.interface34 = interface_function2d(1,-1.0,1.0,self.neural_networks['u34'])
        self.interface43 = interface_function2d(0,1.0,-1.0,self.neural_networks['u34'])

        self.jump1 = jump_function2d(0, -0.33, self.neural_networks['u1_0.3'])
        self.jump2 = jump_function2d(0,  0.33, self.neural_networks['u1_0.7'])

        self.mu0 = 0.001
        self.mur = 1000
        self.J0 = 1000000

        self.points = self.get_points_MC(5000)
        
    # def get_points(self, N, quad = 'MC'):        

    #     points = {}

    #     if quad == 'MC':
    #         ys = np.random.rand(N,2)*2-1
    #         Weights = np.ones((N,))*4/ys.shape[0]

    #     # ys = np.meshgrid(np.polynomial.legendre.leggauss(N[0])[0], np.polynomial.legendre.leggauss(N[1])[0])
    #     # ys = np.concatenate((ys[0].flatten()[:,None], ys[1].flatten()[:,None]), -1)
    #     # Weights = np.kron(np.polynomial.legendre.leggauss(N[0])[1], np.polynomial.legendre.leggauss(N[1])[1]).flatten()
    #     if quad=='SG':
    #         ys,Weights = cp.quadrature.sparse_grid(10,cp.J(cp.Uniform(-1,1),cp.Uniform(-1,1)),rule=["fejer_2", "fejer_2"])
    #         Weights = Weights*4
    #         ys = np.transpose(ys)

    #     if quad == 'TP': ys, Weights = pinns.geometry.tensor_product_integration(geom1.basis, N)
    #     points['ys1'] = ys
    #     points['ws1'] = Weights
    #     DGys = geom1._eval_omega(ys)
    #     Inv = np.linalg.inv(DGys)
    #     det = np.abs(np.linalg.det(DGys))
    #     points['K1'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
    #     points['omega1'] = det
    #    
    #     if quad == 'TP': ys, Weights = pinns.geometry.tensor_product_integration(geom2.basis, N)
    #     points['ys2'] = ys
    #     points['ws2'] = Weights
    #     DGys = geom2._eval_omega(ys)
    #     Inv = np.linalg.inv(DGys)
    #     det = np.abs(np.linalg.det(DGys))
    #     points['K2'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
    #     points['omega2'] = det
    #     
    #     if quad == 'TP': ys, Weights = pinns.geometry.tensor_product_integration(geom3.basis, N)
    #     points['ys3'] = ys
    #     points['ws3'] = Weights
    #     DGys = geom3._eval_omega(ys)
    #     Inv = np.linalg.inv(DGys)
    #     det = np.abs(np.linalg.det(DGys))
    #     points['K3'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
    #     points['omega3'] = det
    #    
    #     if quad == 'TP': ys, Weights = pinns.geometry.tensor_product_integration(geom4.basis, N)
    #     points['ys4'] = ys
    #     points['ws4'] = Weights
    #     DGys = geom4._eval_omega(ys)
    #     Inv = np.linalg.inv(DGys)
    #     det = np.abs(np.linalg.det(DGys))
    #     points['K4'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
    #     points['omega4'] = det

    #     return points

    def get_points_MC(self, N):        

        points = {}


        ys = np.random.rand(N,2)*2-1
        Weights = np.ones((N,))*4/ys.shape[0]
        # ys = np.array(jax.random.uniform(self.key, (N,2)))*2-1
        # Weights = jnp.ones((N,))*4/ys.shape[0]


        points['ys1'] = ys
        points['ws1'] = Weights
        DGys = geom1._eval_omega(ys)
        Inv = np.linalg.inv(DGys)
        det = np.abs(np.linalg.det(DGys))
        points['K1'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
        points['omega1'] = det
       
        points['ys2'] = ys
        points['ws2'] = Weights
        DGys = geom2._eval_omega(ys)
        Inv = np.linalg.inv(DGys)
        det = np.abs(np.linalg.det(DGys))
        points['K2'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
        points['omega2'] = det
        
        points['ys3'] = ys
        points['ws3'] = Weights
        DGys = geom3._eval_omega(ys)
        Inv = np.linalg.inv(DGys)
        det = np.abs(np.linalg.det(DGys))
        points['K3'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
        points['omega3'] = det
       
        points['ys4'] = ys
        points['ws4'] = Weights
        DGys = geom4._eval_omega(ys)
        Inv = np.linalg.inv(DGys)
        det = np.abs(np.linalg.det(DGys))
        points['K4'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
        points['omega4'] = det

        return points


    def solution1(self, ws, x):
        # iron
        u = self.neural_networks['u1'](ws['u1'],x) + self.jump1(ws['u1_0.3'], x) + self.jump2(ws['u1_0.7'], x)
        v = ((1-x[...,0])*(x[...,0] + 1)*(1-x[...,1])*(x[...,1]+1))[...,None]
        w =  self.interface12(ws['u12'],x)*((1-x[...,0])*(x[...,0] + 1))[...,None] + (self.interface13(ws['u13'],x)+ExpHat(x[...,1]+0.33)[...,None]*ws['u13_n0.33']+ExpHat(x[...,1]-0.33)[...,None]*ws['u13_p0.33'])*(1-x[...,1])[...,None]*(x[...,1] + 1)[...,None] +  self.interface14(ws['u14'],x) * ((1-x[...,0])*(x[...,0] + 1))[...,None]
        w = w + ws['u123']*( (x[...,0]+1) * (x[...,1]+1) )[...,None]**2 + ws['u134'] *  ( (x[...,0] + 1)*(1-x[...,1]) )[...,None]**2
        return u*v+w

    def solution2(self, ws, x):
        
        u = self.neural_networks['u2'](ws['u2'],x)
        v = ((1-x[...,1])*(x[...,1] + 1)*(1-x[...,0]))[...,None]
        w = self.interface21(ws['u12'],x)*((1-x[...,1])*(x[...,1] + 1))[...,None] + self.interface23(ws['u23'],x)*(1-x[...,0])[...,None]
        w = w + ws['u123']*( (x[...,0]+1) * (x[...,1]+1) )[...,None]**2
        return u*v+w
    
    def solution3(self, ws, x):
        
        u = self.neural_networks['u3'](ws['u3'],x)
        v = ((1-x[...,1])*(x[...,1] + 1)*(1-x[...,0]))[...,None]
        w =  self.interface32(ws['u23'],x)*(1-x[...,0])[...,None]+(self.interface31(ws['u13'],x)+ExpHat(x[...,1]+0.33)[...,None]*ws['u13_n0.33']+ExpHat(x[...,1]-0.33)[...,None]*ws['u13_p0.33'])*((1-x[...,1])*(x[...,1] + 1))[...,None]+self.interface34(ws['u34'],x)*(1-x[...,0])[...,None]
        w = w + ws['u123']*( (x[...,0]+1) * (x[...,1]+1) )[...,None]**2 + ws['u134'] *  ( (x[...,0] +1)*(1-x[...,1]) )[...,None]**2
        return u*v + w
        
    def solution4(self, ws, x):
        u = self.neural_networks['u4'](ws['u4'],x)
        v = ((1-x[...,0])*(x[...,0] + 1)*(1-x[...,1]))[...,None]
        w = self.interface41(ws['u14'],x)*((1-x[...,0])*(x[...,0] + 1))[...,None]+self.interface43(ws['u34'],x)*((1-x[...,1]))[...,None]
        w = w + ws['u134'] *  ( (x[...,0]+1) * (x[...,1]+1) )[...,None]**2
        return u*v+w

    def loss_pde(self, ws, points):
        grad1 = pinns.operators.gradient(lambda x : self.solution1(ws,x))(points['ys1'])[...,0,:]
        grad2 = pinns.operators.gradient(lambda x : self.solution2(ws,x))(points['ys2'])[...,0,:]
        grad3 = pinns.operators.gradient(lambda x : self.solution3(ws,x))(points['ys3'])[...,0,:]
        grad4 = pinns.operators.gradient(lambda x : self.solution4(ws,x))(points['ys4'])[...,0,:]
        
        
        # lpde1 = 0.5*1/(self.mu0*self.mur)*jnp.dot(jnp.einsum('mi,mij,mj->m',grad1,self.points['K1'],grad1), self.points['ws1']) 
        # lpde2 = 0.5*1/self.mu0*jnp.dot(jnp.einsum('mi,mij,mj->m',grad2,self.points['K2'],grad2), self.points['ws2'])  
        # lpde3 = 0.5*1/self.mu0*jnp.dot(jnp.einsum('mi,mij,mj->m',grad3,self.points['K3'],grad3), self.points['ws3'])  - jnp.dot(self.J0*self.solution3(ws,self.points['ys3']).flatten()*self.points['omega3']  ,self.points['ws3'])
        # lpde4 = 0.5*1/(self.mu0*self.mur)*jnp.dot(jnp.einsum('mi,mij,mj->m',grad4,self.points['K4'],grad4), self.points['ws4']) 
        lpde1 = 0.5*1/(self.mur)*jnp.dot(jnp.einsum('mi,mij,mj->m',grad1,points['K1'],grad1), points['ws1']) 
        lpde2 = 0.5*jnp.dot(jnp.einsum('mi,mij,mj->m',grad2,points['K2'],grad2), points['ws2'])  
        lpde3 = 0.5*jnp.dot(jnp.einsum('mi,mij,mj->m',grad3,points['K3'],grad3), points['ws3'])  - self.mu0*jnp.dot(self.J0*self.solution3(ws,points['ys3']).flatten()*points['omega3']  ,points['ws3'])
        lpde4 = 0.5*1/(self.mur)*jnp.dot(jnp.einsum('mi,mij,mj->m',grad4,points['K4'],grad4), points['ws4'])
        return lpde1+lpde2+lpde3+lpde4

    def loss(self, ws, pts):
        lpde = self.loss_pde(ws, pts)
        return lpde

# %%
rnd_key = jax.random.PRNGKey(1235)
model = Model(rnd_key)
w0 = model.init_unravel()
weights = model.weights 

loss_compiled = jax.jit(model.loss_handle, device = jax.devices()[1])
lossgrad_compiled = jax.jit(model.lossgrad_handle, device = jax.devices()[1])

def loss_grad(w):
    l, gr = lossgrad_compiled(jnp.array(w))
    return np.array( l.to_py() ), np.array( gr.to_py() )

opt_type = 'ADAM'
batch_size = 5000

opt_init, opt_update, get_params = optimizers.adam(step_size=0.001)

opt_state = opt_init(weights)

# get initial parameters
params = get_params(opt_state)

loss_grad = jax.jit(lambda ws, pts: (model.loss(ws, pts), jax.grad(model.loss)(ws, pts)), device = jax.devices()[1])

def step(params, opt_state, points):
    # points = model.get_points_MC(5000)
    loss, grads = loss_grad(params, points)
    opt_state = opt_update(0, grads, opt_state)

    params = get_params(opt_state)
    
    return params, opt_state, loss

step_compiled = jax.jit(step, device = jax.devices()[1])
step_compiled(params, opt_state, model.get_points_MC(batch_size))

n_epochs = 5000

tme = datetime.datetime.now()
for k in range(n_epochs):    
    points = model.get_points_MC(batch_size)

    params, opt_state, loss = step_compiled(params, opt_state,points)
    
    print('Epoch %d/%d - loss value %e'%(k+1, n_epochs, loss))
# update params
model.weights = params
weights = params
tme = datetime.datetime.now() - tme
print('Elapsed time ', tme)
# Out:
# Epoch 1/5000 - loss value 5.185428e+01
# Epoch 2/5000 - loss value 4.237535e+01
# Epoch 3/5000 - loss value 3.607399e+01
# Epoch 4/5000 - loss value 3.154269e+01
# Epoch 5/5000 - loss value 2.557069e+01
# Epoch 6/5000 - loss value 2.131927e+01
# Epoch 7/5000 - loss value 2.004575e+01
# Epoch 8/5000 - loss value 1.844947e+01
# Epoch 9/5000 - loss value 1.728464e+01
# Epoch 10/5000 - loss value 1.620112e+01
# Epoch 11/5000 - loss value 1.493300e+01
# Epoch 12/5000 - loss value 1.503398e+01
# Epoch 13/5000 - loss value 1.386171e+01
# Epoch 14/5000 - loss value 1.249111e+01
# Epoch 15/5000 - loss value 1.139826e+01
# Epoch 16/5000 - loss value 1.091662e+01
# Epoch 17/5000 - loss value 1.034609e+01
# Epoch 18/5000 - loss value 9.286756e+00
# Epoch 19/5000 - loss value 8.921926e+00
# Epoch 20/5000 - loss value 8.247913e+00
# Epoch 21/5000 - loss value 7.827476e+00
# Epoch 22/5000 - loss value 7.253445e+00
# Epoch 23/5000 - loss value 7.088225e+00
# Epoch 24/5000 - loss value 6.899522e+00
# Epoch 25/5000 - loss value 6.448310e+00
# Epoch 26/5000 - loss value 6.421606e+00
# Epoch 27/5000 - loss value 6.257202e+00
# Epoch 28/5000 - loss value 6.058380e+00
# Epoch 29/5000 - loss value 5.767565e+00
# Epoch 30/5000 - loss value 5.611029e+00
# Epoch 31/5000 - loss value 5.574088e+00
# Epoch 32/5000 - loss value 5.056932e+00
# Epoch 33/5000 - loss value 5.252844e+00
# Epoch 34/5000 - loss value 5.162096e+00
# Epoch 35/5000 - loss value 4.918224e+00
# Epoch 36/5000 - loss value 4.799036e+00
# Epoch 37/5000 - loss value 4.704762e+00
# Epoch 38/5000 - loss value 4.663164e+00
# Epoch 39/5000 - loss value 4.550692e+00
# Epoch 40/5000 - loss value 4.467434e+00
# Epoch 41/5000 - loss value 4.406698e+00
# Epoch 42/5000 - loss value 4.348911e+00
# Epoch 43/5000 - loss value 4.360803e+00
# Epoch 44/5000 - loss value 4.353506e+00
# Epoch 45/5000 - loss value 4.167659e+00
# Epoch 46/5000 - loss value 4.319080e+00
# Epoch 47/5000 - loss value 4.276281e+00
# Epoch 48/5000 - loss value 4.134564e+00
# Epoch 49/5000 - loss value 4.150125e+00
# Epoch 50/5000 - loss value 4.123563e+00
# Epoch 51/5000 - loss value 4.044884e+00
# Epoch 52/5000 - loss value 4.079724e+00
# Epoch 53/5000 - loss value 4.031810e+00
# Epoch 54/5000 - loss value 3.922325e+00
# Epoch 55/5000 - loss value 3.967418e+00
# Epoch 56/5000 - loss value 4.050965e+00
# Epoch 57/5000 - loss value 3.964162e+00
# Epoch 58/5000 - loss value 3.993499e+00
# Epoch 59/5000 - loss value 3.909767e+00
# Epoch 60/5000 - loss value 3.887553e+00
# Epoch 61/5000 - loss value 3.930555e+00
# Epoch 62/5000 - loss value 3.903770e+00
# Epoch 63/5000 - loss value 3.803645e+00
# Epoch 64/5000 - loss value 3.828583e+00
# Epoch 65/5000 - loss value 3.808898e+00
# Epoch 66/5000 - loss value 3.787723e+00
# Epoch 67/5000 - loss value 3.800579e+00
# Epoch 68/5000 - loss value 3.713911e+00
# Epoch 69/5000 - loss value 3.702977e+00
# Epoch 70/5000 - loss value 3.697845e+00
# Epoch 71/5000 - loss value 3.690109e+00
# Epoch 72/5000 - loss value 3.636826e+00
# Epoch 73/5000 - loss value 3.683416e+00
# Epoch 74/5000 - loss value 3.653964e+00
# Epoch 75/5000 - loss value 3.698466e+00
# Epoch 76/5000 - loss value 3.655626e+00
# Epoch 77/5000 - loss value 3.539136e+00
# Epoch 78/5000 - loss value 3.617910e+00
# Epoch 79/5000 - loss value 3.565822e+00
# Epoch 80/5000 - loss value 3.568187e+00
# Epoch 81/5000 - loss value 3.529239e+00
# Epoch 82/5000 - loss value 3.539580e+00
# Epoch 83/5000 - loss value 3.534337e+00
# Epoch 84/5000 - loss value 3.552098e+00
# Epoch 85/5000 - loss value 3.524206e+00
# Epoch 86/5000 - loss value 3.465931e+00
# Epoch 87/5000 - loss value 3.462260e+00
# Epoch 88/5000 - loss value 3.487292e+00
# Epoch 89/5000 - loss value 3.395043e+00
# Epoch 90/5000 - loss value 3.389811e+00
# Epoch 91/5000 - loss value 3.515350e+00
# Epoch 92/5000 - loss value 3.463717e+00
# Epoch 93/5000 - loss value 3.445860e+00
# Epoch 94/5000 - loss value 3.398947e+00
# Epoch 95/5000 - loss value 3.394840e+00
# Epoch 96/5000 - loss value 3.368930e+00
# Epoch 97/5000 - loss value 3.385401e+00
# Epoch 98/5000 - loss value 3.318547e+00
# Epoch 99/5000 - loss value 3.362467e+00
# Epoch 100/5000 - loss value 3.380810e+00
# Epoch 101/5000 - loss value 3.342721e+00
# Epoch 102/5000 - loss value 3.292300e+00
# Epoch 103/5000 - loss value 3.322295e+00
# Epoch 104/5000 - loss value 3.264968e+00
# Epoch 105/5000 - loss value 3.271234e+00
# Epoch 106/5000 - loss value 3.266393e+00
# Epoch 107/5000 - loss value 3.226904e+00
# Epoch 108/5000 - loss value 3.209773e+00
# Epoch 109/5000 - loss value 3.248601e+00
# Epoch 110/5000 - loss value 3.258825e+00
# Epoch 111/5000 - loss value 3.176807e+00
# Epoch 112/5000 - loss value 3.206938e+00
# Epoch 113/5000 - loss value 3.149815e+00
# Epoch 114/5000 - loss value 3.201478e+00
# Epoch 115/5000 - loss value 3.145122e+00
# Epoch 116/5000 - loss value 3.132043e+00
# Epoch 117/5000 - loss value 3.166003e+00
# Epoch 118/5000 - loss value 3.107758e+00
# Epoch 119/5000 - loss value 3.071531e+00
# Epoch 120/5000 - loss value 3.100002e+00
# Epoch 121/5000 - loss value 3.117049e+00
# Epoch 122/5000 - loss value 3.095837e+00
# Epoch 123/5000 - loss value 3.116406e+00
# Epoch 124/5000 - loss value 3.074151e+00
# Epoch 125/5000 - loss value 3.067765e+00
# Epoch 126/5000 - loss value 3.054159e+00
# Epoch 127/5000 - loss value 3.022719e+00
# Epoch 128/5000 - loss value 3.041069e+00
# Epoch 129/5000 - loss value 3.008168e+00
# Epoch 130/5000 - loss value 3.006041e+00
# Epoch 131/5000 - loss value 2.991802e+00
# Epoch 132/5000 - loss value 2.948892e+00
# Epoch 133/5000 - loss value 3.001852e+00
# Epoch 134/5000 - loss value 2.958473e+00
# Epoch 135/5000 - loss value 2.991086e+00
# Epoch 136/5000 - loss value 2.962312e+00
# Epoch 137/5000 - loss value 2.959844e+00
# Epoch 138/5000 - loss value 2.914001e+00
# Epoch 139/5000 - loss value 2.942297e+00
# Epoch 140/5000 - loss value 2.897593e+00
# Epoch 141/5000 - loss value 2.915040e+00
# Epoch 142/5000 - loss value 2.892193e+00
# Epoch 143/5000 - loss value 2.898290e+00
# Epoch 144/5000 - loss value 2.949615e+00
# Epoch 145/5000 - loss value 2.882321e+00
# Epoch 146/5000 - loss value 2.824353e+00
# Epoch 147/5000 - loss value 2.848140e+00
# Epoch 148/5000 - loss value 2.837806e+00
# Epoch 149/5000 - loss value 2.830501e+00
# Epoch 150/5000 - loss value 2.779948e+00
# Epoch 151/5000 - loss value 2.865162e+00
# Epoch 152/5000 - loss value 2.839183e+00
# Epoch 153/5000 - loss value 2.790794e+00
# Epoch 154/5000 - loss value 2.770212e+00
# Epoch 155/5000 - loss value 2.792860e+00
# Epoch 156/5000 - loss value 2.799266e+00
# Epoch 157/5000 - loss value 2.747124e+00
# Epoch 158/5000 - loss value 2.745487e+00
# Epoch 159/5000 - loss value 2.738968e+00
# Epoch 160/5000 - loss value 2.757547e+00
# Epoch 161/5000 - loss value 2.703920e+00
# Epoch 162/5000 - loss value 2.748575e+00
# Epoch 163/5000 - loss value 2.689039e+00
# Epoch 164/5000 - loss value 2.664186e+00
# Epoch 165/5000 - loss value 2.674581e+00
# Epoch 166/5000 - loss value 2.662953e+00
# Epoch 167/5000 - loss value 2.653355e+00
# Epoch 168/5000 - loss value 2.678303e+00
# Epoch 169/5000 - loss value 2.638066e+00
# Epoch 170/5000 - loss value 2.688326e+00
# Epoch 171/5000 - loss value 2.623542e+00
# Epoch 172/5000 - loss value 2.628465e+00
# Epoch 173/5000 - loss value 2.627604e+00
# Epoch 174/5000 - loss value 2.592784e+00
# Epoch 175/5000 - loss value 2.621544e+00
# Epoch 176/5000 - loss value 2.615222e+00
# Epoch 177/5000 - loss value 2.643334e+00
# Epoch 178/5000 - loss value 2.566604e+00
# Epoch 179/5000 - loss value 2.554083e+00
# Epoch 180/5000 - loss value 2.578788e+00
# Epoch 181/5000 - loss value 2.584468e+00
# Epoch 182/5000 - loss value 2.539477e+00
# Epoch 247/5000 - loss value 2.104363e+00
# Epoch 248/5000 - loss value 2.113766e+00
# Epoch 249/5000 - loss value 2.090417e+00
# Epoch 250/5000 - loss value 2.102510e+00
# Epoch 251/5000 - loss value 2.109836e+00
# Epoch 252/5000 - loss value 2.102888e+00
# Epoch 253/5000 - loss value 2.069935e+00
# Epoch 254/5000 - loss value 2.069864e+00
# Epoch 255/5000 - loss value 2.082071e+00
# Epoch 256/5000 - loss value 2.073195e+00
# Epoch 257/5000 - loss value 2.068305e+00
# Epoch 258/5000 - loss value 2.058811e+00
# Epoch 259/5000 - loss value 2.037308e+00
# Epoch 260/5000 - loss value 2.056358e+00
# Epoch 261/5000 - loss value 2.038719e+00
# Epoch 262/5000 - loss value 2.018909e+00
# Epoch 263/5000 - loss value 2.005045e+00
# Epoch 264/5000 - loss value 2.012576e+00
# Epoch 265/5000 - loss value 2.012015e+00
# Epoch 266/5000 - loss value 1.989969e+00
# Epoch 267/5000 - loss value 2.020376e+00
# Epoch 268/5000 - loss value 1.980127e+00
# Epoch 269/5000 - loss value 1.962855e+00
# Epoch 270/5000 - loss value 1.995255e+00
# Epoch 271/5000 - loss value 1.957345e+00
# Epoch 272/5000 - loss value 1.956889e+00
# Epoch 273/5000 - loss value 1.937549e+00
# Epoch 274/5000 - loss value 1.951816e+00
# Epoch 275/5000 - loss value 1.954467e+00
# Epoch 276/5000 - loss value 1.960370e+00
# Epoch 277/5000 - loss value 1.930924e+00
# Epoch 278/5000 - loss value 1.908003e+00
# Epoch 279/5000 - loss value 1.922577e+00
# Epoch 280/5000 - loss value 1.896339e+00
# Epoch 281/5000 - loss value 1.909698e+00
# Epoch 282/5000 - loss value 1.912873e+00
# Epoch 283/5000 - loss value 1.923210e+00
# Epoch 284/5000 - loss value 1.871926e+00
# Epoch 285/5000 - loss value 1.893654e+00
# Epoch 286/5000 - loss value 1.907574e+00
# Epoch 287/5000 - loss value 1.865466e+00
# Epoch 288/5000 - loss value 1.868746e+00
# Epoch 289/5000 - loss value 1.853678e+00
# Epoch 290/5000 - loss value 1.861671e+00
# Epoch 291/5000 - loss value 1.866561e+00
# Epoch 292/5000 - loss value 1.871558e+00
# Epoch 293/5000 - loss value 1.841668e+00
# Epoch 294/5000 - loss value 1.831089e+00
# Epoch 295/5000 - loss value 1.836863e+00
# Epoch 296/5000 - loss value 1.821926e+00
# Epoch 297/5000 - loss value 1.849115e+00
# Epoch 298/5000 - loss value 1.812292e+00
# Epoch 299/5000 - loss value 1.810072e+00
# Epoch 300/5000 - loss value 1.823232e+00
# Epoch 301/5000 - loss value 1.804446e+00
# Epoch 302/5000 - loss value 1.805687e+00
# Epoch 303/5000 - loss value 1.803283e+00
# Epoch 304/5000 - loss value 1.785166e+00
# Epoch 305/5000 - loss value 1.782883e+00
# Epoch 306/5000 - loss value 1.786535e+00
# Epoch 307/5000 - loss value 1.794919e+00
# Epoch 308/5000 - loss value 1.763381e+00
# Epoch 309/5000 - loss value 1.780092e+00
# Epoch 310/5000 - loss value 1.770923e+00
# Epoch 311/5000 - loss value 1.789655e+00
# Epoch 312/5000 - loss value 1.756860e+00
# Epoch 313/5000 - loss value 1.744713e+00
# Epoch 314/5000 - loss value 1.735221e+00
# Epoch 315/5000 - loss value 1.724978e+00
# Epoch 316/5000 - loss value 1.731711e+00
# Epoch 317/5000 - loss value 1.732804e+00
# Epoch 318/5000 - loss value 1.722973e+00
# Epoch 319/5000 - loss value 1.709030e+00
# Epoch 320/5000 - loss value 1.715239e+00
# Epoch 321/5000 - loss value 1.701216e+00
# Epoch 322/5000 - loss value 1.708476e+00
# Epoch 323/5000 - loss value 1.693873e+00
# Epoch 324/5000 - loss value 1.715689e+00
# Epoch 325/5000 - loss value 1.697405e+00
# Epoch 326/5000 - loss value 1.668073e+00
# Epoch 327/5000 - loss value 1.684872e+00
# Epoch 328/5000 - loss value 1.690975e+00
# Epoch 329/5000 - loss value 1.662850e+00
# Epoch 330/5000 - loss value 1.662011e+00
# Epoch 331/5000 - loss value 1.637298e+00
# Epoch 332/5000 - loss value 1.653150e+00
# Epoch 333/5000 - loss value 1.643845e+00
# Epoch 334/5000 - loss value 1.639768e+00
# Epoch 335/5000 - loss value 1.649748e+00
# Epoch 336/5000 - loss value 1.618392e+00
# Epoch 337/5000 - loss value 1.638426e+00
# Epoch 338/5000 - loss value 1.648160e+00
# Epoch 339/5000 - loss value 1.613220e+00
# Epoch 340/5000 - loss value 1.602816e+00
# Epoch 341/5000 - loss value 1.630673e+00
# Epoch 342/5000 - loss value 1.584513e+00
# Epoch 343/5000 - loss value 1.607243e+00
# Epoch 344/5000 - loss value 1.603893e+00
# Epoch 345/5000 - loss value 1.602844e+00
# Epoch 346/5000 - loss value 1.589884e+00
# Epoch 347/5000 - loss value 1.592246e+00
# Epoch 348/5000 - loss value 1.562273e+00
# Epoch 349/5000 - loss value 1.587290e+00
# Epoch 350/5000 - loss value 1.547544e+00
# Epoch 351/5000 - loss value 1.565143e+00
# Epoch 352/5000 - loss value 1.563410e+00
# Epoch 353/5000 - loss value 1.534897e+00
# Epoch 354/5000 - loss value 1.552783e+00
# Epoch 355/5000 - loss value 1.557990e+00
# Epoch 356/5000 - loss value 1.545763e+00
# Epoch 357/5000 - loss value 1.540494e+00
# Epoch 358/5000 - loss value 1.537505e+00
# Epoch 359/5000 - loss value 1.536937e+00
# Epoch 360/5000 - loss value 1.530260e+00
# Epoch 361/5000 - loss value 1.535211e+00
# Epoch 362/5000 - loss value 1.522332e+00
# Epoch 363/5000 - loss value 1.513220e+00
# Epoch 364/5000 - loss value 1.522033e+00
# Epoch 365/5000 - loss value 1.487611e+00
# Epoch 366/5000 - loss value 1.506387e+00
# Epoch 367/5000 - loss value 1.493952e+00
# Epoch 368/5000 - loss value 1.514817e+00
# Epoch 369/5000 - loss value 1.470825e+00
# Epoch 370/5000 - loss value 1.501963e+00
# Epoch 371/5000 - loss value 1.481609e+00
# Epoch 372/5000 - loss value 1.462856e+00
# Epoch 373/5000 - loss value 1.475047e+00
# Epoch 374/5000 - loss value 1.452216e+00
# Epoch 375/5000 - loss value 1.465530e+00
# Epoch 376/5000 - loss value 1.470062e+00
# Epoch 377/5000 - loss value 1.436664e+00
# Epoch 378/5000 - loss value 1.441378e+00
# Epoch 379/5000 - loss value 1.456709e+00
# Epoch 380/5000 - loss value 1.423370e+00
# Epoch 381/5000 - loss value 1.451551e+00
# Epoch 382/5000 - loss value 1.430196e+00
# Epoch 383/5000 - loss value 1.413570e+00
# Epoch 384/5000 - loss value 1.436044e+00
# Epoch 385/5000 - loss value 1.433081e+00
# Epoch 386/5000 - loss value 1.422871e+00
# Epoch 387/5000 - loss value 1.403886e+00
# Epoch 388/5000 - loss value 1.396489e+00
# Epoch 389/5000 - loss value 1.405913e+00
# Epoch 390/5000 - loss value 1.378642e+00
# Epoch 391/5000 - loss value 1.386429e+00
# Epoch 392/5000 - loss value 1.405210e+00
# Epoch 393/5000 - loss value 1.381783e+00
# Epoch 394/5000 - loss value 1.377558e+00
# Epoch 395/5000 - loss value 1.370058e+00
# Epoch 396/5000 - loss value 1.382758e+00
# Epoch 397/5000 - loss value 1.372787e+00
# Epoch 398/5000 - loss value 1.357948e+00
# Epoch 399/5000 - loss value 1.371182e+00
# Epoch 400/5000 - loss value 1.363709e+00
# Epoch 401/5000 - loss value 1.355840e+00
# Epoch 402/5000 - loss value 1.354410e+00
# Epoch 403/5000 - loss value 1.359745e+00
# Epoch 404/5000 - loss value 1.334190e+00
# Epoch 405/5000 - loss value 1.322035e+00
# Epoch 406/5000 - loss value 1.339706e+00
# Epoch 407/5000 - loss value 1.348181e+00
# Epoch 408/5000 - loss value 1.341960e+00
# Epoch 409/5000 - loss value 1.313869e+00
# Epoch 410/5000 - loss value 1.305692e+00
# Epoch 411/5000 - loss value 1.317264e+00
# Epoch 412/5000 - loss value 1.319659e+00
# Epoch 413/5000 - loss value 1.309528e+00
# Epoch 414/5000 - loss value 1.313605e+00
# Epoch 415/5000 - loss value 1.283581e+00
# Epoch 416/5000 - loss value 1.309394e+00
# Epoch 417/5000 - loss value 1.310781e+00
# Epoch 418/5000 - loss value 1.283721e+00
# Epoch 419/5000 - loss value 1.295336e+00
# Epoch 420/5000 - loss value 1.300016e+00
# Epoch 421/5000 - loss value 1.284538e+00
# Epoch 422/5000 - loss value 1.292596e+00
# Epoch 423/5000 - loss value 1.265535e+00
# Epoch 424/5000 - loss value 1.263095e+00
# Epoch 425/5000 - loss value 1.283264e+00
# Epoch 426/5000 - loss value 1.267430e+00
# Epoch 427/5000 - loss value 1.245485e+00
# Epoch 428/5000 - loss value 1.272646e+00
# Epoch 429/5000 - loss value 1.259584e+00
# Epoch 430/5000 - loss value 1.246886e+00
# Epoch 431/5000 - loss value 1.237555e+00
# Epoch 432/5000 - loss value 1.232942e+00
# Epoch 433/5000 - loss value 1.228167e+00
# Epoch 434/5000 - loss value 1.242052e+00
# Epoch 435/5000 - loss value 1.224459e+00
# Epoch 436/5000 - loss value 1.224220e+00
# Epoch 437/5000 - loss value 1.230701e+00
# Epoch 438/5000 - loss value 1.208092e+00
# Epoch 439/5000 - loss value 1.213656e+00
# Epoch 440/5000 - loss value 1.204850e+00
# Epoch 441/5000 - loss value 1.213119e+00
# Epoch 442/5000 - loss value 1.186204e+00
# Epoch 443/5000 - loss value 1.204415e+00
# Epoch 444/5000 - loss value 1.194136e+00
# Epoch 445/5000 - loss value 1.201149e+00
# Epoch 446/5000 - loss value 1.202050e+00
# Epoch 447/5000 - loss value 1.179286e+00
# Epoch 448/5000 - loss value 1.177838e+00
# Epoch 449/5000 - loss value 1.172269e+00
# Epoch 450/5000 - loss value 1.179711e+00
# Epoch 451/5000 - loss value 1.169018e+00
# Epoch 452/5000 - loss value 1.171747e+00
# Epoch 453/5000 - loss value 1.187282e+00
# Epoch 454/5000 - loss value 1.168310e+00
# Epoch 455/5000 - loss value 1.170411e+00
# Epoch 456/5000 - loss value 1.155033e+00
# Epoch 457/5000 - loss value 1.137841e+00
# Epoch 458/5000 - loss value 1.152574e+00
# Epoch 459/5000 - loss value 1.149004e+00
# Epoch 460/5000 - loss value 1.161172e+00
# Epoch 461/5000 - loss value 1.145221e+00
# Epoch 462/5000 - loss value 1.155557e+00
# Epoch 463/5000 - loss value 1.130053e+00
# Epoch 464/5000 - loss value 1.132539e+00
# Epoch 465/5000 - loss value 1.135521e+00
# Epoch 466/5000 - loss value 1.114812e+00
# Epoch 467/5000 - loss value 1.120976e+00
# Epoch 468/5000 - loss value 1.108287e+00
# Epoch 469/5000 - loss value 1.116616e+00
# Epoch 470/5000 - loss value 1.113422e+00
# Epoch 471/5000 - loss value 1.107550e+00
# Epoch 472/5000 - loss value 1.100628e+00
# Epoch 473/5000 - loss value 1.107636e+00
# Epoch 474/5000 - loss value 1.097842e+00
# Epoch 475/5000 - loss value 1.099693e+00
# Epoch 476/5000 - loss value 1.100126e+00
# Epoch 477/5000 - loss value 1.071846e+00
# Epoch 478/5000 - loss value 1.063948e+00
# Epoch 479/5000 - loss value 1.068542e+00
# Epoch 480/5000 - loss value 1.079649e+00
# Epoch 481/5000 - loss value 1.073534e+00
# Epoch 482/5000 - loss value 1.077995e+00
# Epoch 483/5000 - loss value 1.082219e+00
# Epoch 484/5000 - loss value 1.059304e+00
# Epoch 485/5000 - loss value 1.069083e+00
# Epoch 486/5000 - loss value 1.056251e+00
# Epoch 487/5000 - loss value 1.055435e+00
# Epoch 488/5000 - loss value 1.041620e+00
# Epoch 489/5000 - loss value 1.050777e+00
# Epoch 490/5000 - loss value 1.038327e+00
# Epoch 491/5000 - loss value 1.061067e+00
# Epoch 492/5000 - loss value 1.041430e+00
# Epoch 493/5000 - loss value 1.036158e+00
# Epoch 494/5000 - loss value 1.031780e+00
# Epoch 495/5000 - loss value 1.037397e+00
# Epoch 496/5000 - loss value 1.014369e+00
# Epoch 497/5000 - loss value 1.022751e+00
# Epoch 498/5000 - loss value 1.025520e+00
# Epoch 499/5000 - loss value 1.005716e+00
# Epoch 500/5000 - loss value 1.005679e+00
# Epoch 501/5000 - loss value 9.950075e-01
# Epoch 502/5000 - loss value 1.008409e+00
# Epoch 503/5000 - loss value 1.002935e+00
# Epoch 504/5000 - loss value 9.975474e-01
# Epoch 505/5000 - loss value 9.966790e-01
# Epoch 506/5000 - loss value 1.000749e+00
# Epoch 507/5000 - loss value 1.006174e+00
# Epoch 508/5000 - loss value 9.905000e-01
# Epoch 509/5000 - loss value 9.832482e-01
# Epoch 510/5000 - loss value 1.000746e+00
# Epoch 511/5000 - loss value 9.906568e-01
# Epoch 512/5000 - loss value 9.761740e-01
# Epoch 513/5000 - loss value 9.788246e-01
# Epoch 514/5000 - loss value 9.815494e-01
# Epoch 515/5000 - loss value 9.678923e-01
# Epoch 516/5000 - loss value 9.907808e-01
# Epoch 517/5000 - loss value 9.661519e-01
# Epoch 518/5000 - loss value 9.696690e-01
# Epoch 519/5000 - loss value 9.628692e-01
# Epoch 520/5000 - loss value 9.640734e-01
# Epoch 521/5000 - loss value 9.461938e-01
# Epoch 522/5000 - loss value 9.514658e-01
# Epoch 523/5000 - loss value 9.461140e-01
# Epoch 524/5000 - loss value 9.428200e-01
# Epoch 525/5000 - loss value 9.310795e-01
# Epoch 526/5000 - loss value 9.340641e-01
# Epoch 527/5000 - loss value 9.305525e-01
# Epoch 528/5000 - loss value 9.388131e-01
# Epoch 529/5000 - loss value 9.292151e-01
# Epoch 530/5000 - loss value 9.234641e-01
# Epoch 531/5000 - loss value 9.317075e-01
# Epoch 532/5000 - loss value 9.286576e-01
# Epoch 533/5000 - loss value 9.253059e-01
# Epoch 534/5000 - loss value 9.187215e-01
# Epoch 535/5000 - loss value 9.147935e-01
# Epoch 536/5000 - loss value 9.254099e-01
# Epoch 537/5000 - loss value 9.095460e-01
# Epoch 538/5000 - loss value 9.101525e-01
# Epoch 539/5000 - loss value 8.974359e-01
# Epoch 540/5000 - loss value 9.050116e-01
# Epoch 541/5000 - loss value 8.931414e-01
# Epoch 542/5000 - loss value 8.995322e-01
# Epoch 543/5000 - loss value 8.972523e-01
# Epoch 544/5000 - loss value 9.028221e-01
# Epoch 545/5000 - loss value 8.839684e-01
# Epoch 546/5000 - loss value 8.841052e-01
# Epoch 547/5000 - loss value 8.852070e-01
# Epoch 548/5000 - loss value 8.842383e-01
# Epoch 549/5000 - loss value 8.748673e-01
# Epoch 550/5000 - loss value 8.762572e-01
# Epoch 551/5000 - loss value 8.692874e-01
# Epoch 552/5000 - loss value 8.673729e-01
# Epoch 553/5000 - loss value 8.625197e-01
# Epoch 554/5000 - loss value 8.712264e-01
# Epoch 555/5000 - loss value 8.577272e-01
# Epoch 556/5000 - loss value 8.529915e-01
# Epoch 557/5000 - loss value 8.599353e-01
# Epoch 558/5000 - loss value 8.648155e-01
# Epoch 559/5000 - loss value 8.466704e-01
# Epoch 560/5000 - loss value 8.370440e-01
# Epoch 561/5000 - loss value 8.498946e-01
# Epoch 562/5000 - loss value 8.509455e-01
# Epoch 563/5000 - loss value 8.414148e-01
# Epoch 564/5000 - loss value 8.372695e-01
# Epoch 565/5000 - loss value 8.384094e-01
# Epoch 566/5000 - loss value 8.276279e-01
# Epoch 567/5000 - loss value 8.460630e-01
# Epoch 568/5000 - loss value 8.341670e-01
# Epoch 569/5000 - loss value 8.289699e-01
# Epoch 570/5000 - loss value 8.319695e-01
# Epoch 571/5000 - loss value 8.276398e-01
# Epoch 572/5000 - loss value 8.173289e-01
# Epoch 573/5000 - loss value 8.209632e-01
# Epoch 574/5000 - loss value 8.221376e-01
# Epoch 575/5000 - loss value 8.143206e-01
# Epoch 576/5000 - loss value 8.120257e-01
# Epoch 577/5000 - loss value 8.093406e-01
# Epoch 578/5000 - loss value 7.939389e-01
# Epoch 579/5000 - loss value 8.062625e-01
# Epoch 580/5000 - loss value 8.132150e-01
# Epoch 581/5000 - loss value 7.989903e-01
# Epoch 582/5000 - loss value 7.970825e-01
# Epoch 583/5000 - loss value 7.888092e-01
# Epoch 584/5000 - loss value 7.966060e-01
# Epoch 585/5000 - loss value 7.800529e-01
# Epoch 586/5000 - loss value 7.855368e-01
# Epoch 587/5000 - loss value 7.867414e-01
# Epoch 588/5000 - loss value 7.841750e-01
# Epoch 589/5000 - loss value 7.815014e-01
# Epoch 590/5000 - loss value 7.749952e-01
# Epoch 591/5000 - loss value 7.806860e-01
# Epoch 592/5000 - loss value 7.564718e-01
# Epoch 593/5000 - loss value 7.735131e-01
# Epoch 594/5000 - loss value 7.742813e-01
# Epoch 595/5000 - loss value 7.620715e-01
# Epoch 596/5000 - loss value 7.699725e-01
# Epoch 597/5000 - loss value 7.554881e-01
# Epoch 598/5000 - loss value 7.644806e-01
# Epoch 599/5000 - loss value 7.491310e-01
# Epoch 600/5000 - loss value 7.576222e-01
# Epoch 601/5000 - loss value 7.505922e-01
# Epoch 602/5000 - loss value 7.503795e-01
# Epoch 603/5000 - loss value 7.430021e-01
# Epoch 604/5000 - loss value 7.461165e-01
# Epoch 605/5000 - loss value 7.533066e-01
# Epoch 606/5000 - loss value 7.365528e-01
# Epoch 607/5000 - loss value 7.311393e-01
# Epoch 608/5000 - loss value 7.476352e-01
# Epoch 609/5000 - loss value 7.324522e-01
# Epoch 610/5000 - loss value 7.320717e-01
# Epoch 611/5000 - loss value 7.240866e-01
# Epoch 612/5000 - loss value 7.218600e-01
# Epoch 613/5000 - loss value 7.236037e-01
# Epoch 614/5000 - loss value 7.210510e-01
# Epoch 615/5000 - loss value 7.192576e-01
# Epoch 616/5000 - loss value 7.126281e-01
# Epoch 617/5000 - loss value 7.071308e-01
# Epoch 618/5000 - loss value 7.114676e-01
# Epoch 619/5000 - loss value 7.089463e-01
# Epoch 620/5000 - loss value 7.023224e-01
# Epoch 621/5000 - loss value 7.077440e-01
# Epoch 622/5000 - loss value 7.040571e-01
# Epoch 623/5000 - loss value 6.900165e-01
# Epoch 624/5000 - loss value 6.948464e-01
# Epoch 625/5000 - loss value 6.975159e-01
# Epoch 626/5000 - loss value 6.923832e-01
# Epoch 627/5000 - loss value 6.934431e-01
# Epoch 628/5000 - loss value 6.836652e-01
# Epoch 629/5000 - loss value 6.916415e-01
# Epoch 630/5000 - loss value 6.855782e-01
# Epoch 631/5000 - loss value 6.862877e-01
# Epoch 632/5000 - loss value 6.720763e-01
# Epoch 633/5000 - loss value 6.842300e-01
# Epoch 634/5000 - loss value 6.701008e-01
# Epoch 635/5000 - loss value 6.801595e-01
# Epoch 636/5000 - loss value 6.751929e-01
# Epoch 637/5000 - loss value 6.672803e-01
# Epoch 638/5000 - loss value 6.644260e-01
# Epoch 639/5000 - loss value 6.700118e-01
# Epoch 640/5000 - loss value 6.685792e-01
# Epoch 641/5000 - loss value 6.544756e-01
# Epoch 642/5000 - loss value 6.615453e-01
# Epoch 643/5000 - loss value 6.578878e-01
# Epoch 644/5000 - loss value 6.503673e-01
# Epoch 645/5000 - loss value 6.596236e-01
# Epoch 646/5000 - loss value 6.580334e-01
# Epoch 647/5000 - loss value 6.416956e-01
# Epoch 648/5000 - loss value 6.495952e-01
# Epoch 649/5000 - loss value 6.423537e-01
# Epoch 650/5000 - loss value 6.453844e-01
# Epoch 651/5000 - loss value 6.444794e-01
# Epoch 652/5000 - loss value 6.313532e-01
# Epoch 653/5000 - loss value 6.304835e-01
# Epoch 654/5000 - loss value 6.398237e-01
# Epoch 655/5000 - loss value 6.348363e-01
# Epoch 656/5000 - loss value 6.382918e-01
# Epoch 657/5000 - loss value 6.299867e-01
# Epoch 658/5000 - loss value 6.301125e-01
# Epoch 659/5000 - loss value 6.183889e-01
# Epoch 660/5000 - loss value 6.223814e-01
# Epoch 661/5000 - loss value 6.210444e-01
# Epoch 662/5000 - loss value 6.184630e-01
# Epoch 663/5000 - loss value 6.147564e-01
# Epoch 664/5000 - loss value 6.131368e-01
# Epoch 665/5000 - loss value 6.186688e-01
# Epoch 666/5000 - loss value 6.188543e-01
# Epoch 667/5000 - loss value 6.101003e-01
# Epoch 668/5000 - loss value 6.107148e-01
# Epoch 669/5000 - loss value 6.077626e-01
# Epoch 670/5000 - loss value 6.038173e-01
# Epoch 671/5000 - loss value 6.009751e-01
# Epoch 672/5000 - loss value 5.904756e-01
# Epoch 673/5000 - loss value 5.877187e-01
# Epoch 674/5000 - loss value 5.950753e-01
# Epoch 675/5000 - loss value 5.957678e-01
# Epoch 676/5000 - loss value 5.944047e-01
# Epoch 677/5000 - loss value 5.884359e-01
# Epoch 678/5000 - loss value 5.982444e-01
# Epoch 679/5000 - loss value 5.857236e-01
# Epoch 680/5000 - loss value 5.868507e-01
# Epoch 681/5000 - loss value 5.900938e-01
# Epoch 682/5000 - loss value 5.756752e-01
# Epoch 683/5000 - loss value 5.798134e-01
# Epoch 684/5000 - loss value 5.839687e-01
# Epoch 685/5000 - loss value 5.777310e-01
# Epoch 686/5000 - loss value 5.809269e-01
# Epoch 687/5000 - loss value 5.722086e-01
# Epoch 688/5000 - loss value 5.681857e-01
# Epoch 689/5000 - loss value 5.632573e-01
# Epoch 690/5000 - loss value 5.631638e-01
# Epoch 691/5000 - loss value 5.648857e-01
# Epoch 692/5000 - loss value 5.602791e-01
# Epoch 693/5000 - loss value 5.539613e-01
# Epoch 694/5000 - loss value 5.577909e-01
# Epoch 759/5000 - loss value 4.526479e-01
# Epoch 760/5000 - loss value 4.468972e-01
# Epoch 761/5000 - loss value 4.442712e-01
# Epoch 762/5000 - loss value 4.497429e-01
# Epoch 763/5000 - loss value 4.398491e-01
# Epoch 764/5000 - loss value 4.395703e-01
# Epoch 765/5000 - loss value 4.381671e-01
# Epoch 766/5000 - loss value 4.467797e-01
# Epoch 767/5000 - loss value 4.374758e-01
# Epoch 768/5000 - loss value 4.365155e-01
# Epoch 769/5000 - loss value 4.391751e-01
# Epoch 770/5000 - loss value 4.305700e-01
# Epoch 771/5000 - loss value 4.365459e-01
# Epoch 772/5000 - loss value 4.262483e-01
# Epoch 773/5000 - loss value 4.315054e-01
# Epoch 774/5000 - loss value 4.267280e-01
# Epoch 775/5000 - loss value 4.241317e-01
# Epoch 776/5000 - loss value 4.188170e-01
# Epoch 777/5000 - loss value 4.195911e-01
# Epoch 778/5000 - loss value 4.164937e-01
# Epoch 779/5000 - loss value 4.261868e-01
# Epoch 780/5000 - loss value 4.201845e-01
# Epoch 781/5000 - loss value 4.143861e-01
# Epoch 782/5000 - loss value 4.152838e-01
# Epoch 783/5000 - loss value 4.132816e-01
# Epoch 784/5000 - loss value 4.148056e-01
# Epoch 785/5000 - loss value 4.150543e-01
# Epoch 786/5000 - loss value 4.062484e-01
# Epoch 787/5000 - loss value 4.101087e-01
# Epoch 788/5000 - loss value 4.153970e-01
# Epoch 789/5000 - loss value 4.025081e-01
# Epoch 790/5000 - loss value 4.086550e-01
# Epoch 791/5000 - loss value 3.949340e-01
# Epoch 792/5000 - loss value 4.058222e-01
# Epoch 793/5000 - loss value 3.981137e-01
# Epoch 794/5000 - loss value 3.985071e-01
# Epoch 795/5000 - loss value 3.990741e-01
# Epoch 796/5000 - loss value 3.928637e-01
# Epoch 797/5000 - loss value 3.867780e-01
# Epoch 798/5000 - loss value 3.981128e-01
# Epoch 799/5000 - loss value 3.939528e-01
# Epoch 800/5000 - loss value 3.883746e-01
# Epoch 801/5000 - loss value 3.939235e-01
# Epoch 802/5000 - loss value 3.895634e-01
# Epoch 803/5000 - loss value 3.833555e-01
# Epoch 804/5000 - loss value 3.818884e-01
# Epoch 805/5000 - loss value 3.875994e-01
# Epoch 806/5000 - loss value 3.790943e-01
# Epoch 807/5000 - loss value 3.760891e-01
# Epoch 808/5000 - loss value 3.823749e-01
# Epoch 809/5000 - loss value 3.830389e-01
# Epoch 810/5000 - loss value 3.718914e-01
# Epoch 811/5000 - loss value 3.711636e-01
# Epoch 812/5000 - loss value 3.794393e-01
# Epoch 813/5000 - loss value 3.715510e-01
# Epoch 814/5000 - loss value 3.740570e-01
# Epoch 815/5000 - loss value 3.707138e-01
# Epoch 816/5000 - loss value 3.727799e-01
# Epoch 817/5000 - loss value 3.672202e-01
# Epoch 818/5000 - loss value 3.660565e-01
# Epoch 819/5000 - loss value 3.649152e-01
# Epoch 820/5000 - loss value 3.639479e-01
# Epoch 821/5000 - loss value 3.619290e-01
# Epoch 822/5000 - loss value 3.582507e-01
# Epoch 823/5000 - loss value 3.598013e-01
# Epoch 824/5000 - loss value 3.596715e-01
# Epoch 825/5000 - loss value 3.582789e-01
# Epoch 826/5000 - loss value 3.560242e-01
# Epoch 827/5000 - loss value 3.550229e-01
# Epoch 828/5000 - loss value 3.509900e-01
# Epoch 829/5000 - loss value 3.556992e-01
# Epoch 830/5000 - loss value 3.530435e-01
# Epoch 831/5000 - loss value 3.509605e-01
# Epoch 832/5000 - loss value 3.462418e-01
# Epoch 833/5000 - loss value 3.462799e-01
# Epoch 834/5000 - loss value 3.398423e-01
# Epoch 835/5000 - loss value 3.459659e-01
# Epoch 836/5000 - loss value 3.442040e-01
# Epoch 837/5000 - loss value 3.433717e-01
# Epoch 838/5000 - loss value 3.411431e-01
# Epoch 839/5000 - loss value 3.420473e-01
# Epoch 840/5000 - loss value 3.331217e-01
# Epoch 841/5000 - loss value 3.360577e-01
# Epoch 842/5000 - loss value 3.328267e-01
# Epoch 843/5000 - loss value 3.367499e-01
# Epoch 844/5000 - loss value 3.316637e-01
# Epoch 845/5000 - loss value 3.284758e-01
# Epoch 846/5000 - loss value 3.286780e-01
# Epoch 847/5000 - loss value 3.290862e-01
# Epoch 848/5000 - loss value 3.288319e-01
# Epoch 849/5000 - loss value 3.242950e-01
# Epoch 850/5000 - loss value 3.242963e-01
# Epoch 851/5000 - loss value 3.273092e-01
# Epoch 852/5000 - loss value 3.211165e-01
# Epoch 853/5000 - loss value 3.206219e-01
# Epoch 854/5000 - loss value 3.220464e-01
# Epoch 855/5000 - loss value 3.146713e-01
# Epoch 856/5000 - loss value 3.173803e-01
# Epoch 857/5000 - loss value 3.129282e-01
# Epoch 858/5000 - loss value 3.161931e-01
# Epoch 859/5000 - loss value 3.134697e-01
# Epoch 860/5000 - loss value 3.141769e-01
# Epoch 861/5000 - loss value 3.139651e-01
# Epoch 862/5000 - loss value 3.128581e-01
# Epoch 863/5000 - loss value 3.120495e-01
# Epoch 864/5000 - loss value 3.024767e-01
# Epoch 865/5000 - loss value 3.051002e-01
# Epoch 866/5000 - loss value 3.093510e-01
# Epoch 867/5000 - loss value 3.014480e-01
# Epoch 868/5000 - loss value 3.062686e-01
# Epoch 869/5000 - loss value 3.012177e-01
# Epoch 870/5000 - loss value 3.048624e-01
# Epoch 871/5000 - loss value 2.967629e-01
# Epoch 872/5000 - loss value 2.982890e-01
# Epoch 873/5000 - loss value 2.966939e-01
# Epoch 874/5000 - loss value 2.993486e-01
# Epoch 875/5000 - loss value 2.980214e-01
# Epoch 876/5000 - loss value 2.968900e-01
# Epoch 877/5000 - loss value 2.934521e-01
# Epoch 878/5000 - loss value 2.917813e-01
# Epoch 879/5000 - loss value 2.918068e-01
# Epoch 880/5000 - loss value 2.907166e-01
# Epoch 881/5000 - loss value 2.867384e-01
# Epoch 882/5000 - loss value 2.875933e-01
# Epoch 883/5000 - loss value 2.883272e-01
# Epoch 884/5000 - loss value 2.878793e-01
# Epoch 885/5000 - loss value 2.831638e-01
# Epoch 886/5000 - loss value 2.865235e-01
# Epoch 887/5000 - loss value 2.823268e-01
# Epoch 888/5000 - loss value 2.810151e-01
# Epoch 889/5000 - loss value 2.776695e-01
# Epoch 890/5000 - loss value 2.797070e-01
# Epoch 891/5000 - loss value 2.808075e-01
# Epoch 892/5000 - loss value 2.778093e-01
# Epoch 893/5000 - loss value 2.749765e-01
# Epoch 894/5000 - loss value 2.749094e-01
# Epoch 895/5000 - loss value 2.746971e-01
# Epoch 896/5000 - loss value 2.733119e-01
# Epoch 897/5000 - loss value 2.770754e-01
# Epoch 898/5000 - loss value 2.707527e-01
# Epoch 899/5000 - loss value 2.656048e-01
# Epoch 900/5000 - loss value 2.685052e-01
# Epoch 901/5000 - loss value 2.690407e-01
# Epoch 902/5000 - loss value 2.653090e-01
# Epoch 903/5000 - loss value 2.634912e-01
# Epoch 904/5000 - loss value 2.653074e-01
# Epoch 905/5000 - loss value 2.678462e-01
# Epoch 906/5000 - loss value 2.643218e-01
# Epoch 907/5000 - loss value 2.622050e-01
# Epoch 908/5000 - loss value 2.602791e-01
# Epoch 909/5000 - loss value 2.578084e-01
# Epoch 910/5000 - loss value 2.566383e-01
# Epoch 911/5000 - loss value 2.556011e-01
# Epoch 912/5000 - loss value 2.520697e-01
# Epoch 913/5000 - loss value 2.556683e-01
# Epoch 914/5000 - loss value 2.529569e-01
# Epoch 915/5000 - loss value 2.513554e-01
# Epoch 916/5000 - loss value 2.516256e-01
# Epoch 917/5000 - loss value 2.496965e-01
# Epoch 918/5000 - loss value 2.490065e-01
# Epoch 919/5000 - loss value 2.502665e-01
# Epoch 920/5000 - loss value 2.497273e-01
# Epoch 921/5000 - loss value 2.464979e-01
# Epoch 922/5000 - loss value 2.437670e-01
# Epoch 923/5000 - loss value 2.438271e-01
# Epoch 924/5000 - loss value 2.439866e-01
# Epoch 925/5000 - loss value 2.419446e-01
# Epoch 926/5000 - loss value 2.452061e-01
# Epoch 927/5000 - loss value 2.442446e-01
# Epoch 928/5000 - loss value 2.430537e-01
# Epoch 929/5000 - loss value 2.384776e-01
# Epoch 930/5000 - loss value 2.370989e-01
# Epoch 931/5000 - loss value 2.383970e-01
# Epoch 932/5000 - loss value 2.358484e-01
# Epoch 933/5000 - loss value 2.364454e-01
# Epoch 934/5000 - loss value 2.326476e-01
# Epoch 935/5000 - loss value 2.336838e-01
# Epoch 936/5000 - loss value 2.305896e-01
# Epoch 937/5000 - loss value 2.309016e-01
# Epoch 938/5000 - loss value 2.320928e-01
# Epoch 939/5000 - loss value 2.277292e-01
# Epoch 940/5000 - loss value 2.285349e-01
# Epoch 941/5000 - loss value 2.259379e-01
# Epoch 942/5000 - loss value 2.260638e-01
# Epoch 943/5000 - loss value 2.219357e-01
# Epoch 944/5000 - loss value 2.243833e-01
# Epoch 945/5000 - loss value 2.210026e-01
# Epoch 946/5000 - loss value 2.212116e-01
# Epoch 947/5000 - loss value 2.178387e-01
# Epoch 948/5000 - loss value 2.232622e-01
# Epoch 949/5000 - loss value 2.196801e-01
# Epoch 950/5000 - loss value 2.187110e-01
# Epoch 951/5000 - loss value 2.168196e-01
# Epoch 952/5000 - loss value 2.150669e-01
# Epoch 953/5000 - loss value 2.174267e-01
# Epoch 954/5000 - loss value 2.140132e-01
# Epoch 955/5000 - loss value 2.151702e-01
# Epoch 956/5000 - loss value 2.141317e-01
# Epoch 957/5000 - loss value 2.140353e-01
# Epoch 958/5000 - loss value 2.123233e-01
# Epoch 959/5000 - loss value 2.077090e-01
# Epoch 960/5000 - loss value 2.118423e-01
# Epoch 961/5000 - loss value 2.104846e-01
# Epoch 962/5000 - loss value 2.109821e-01
# Epoch 963/5000 - loss value 2.084477e-01
# Epoch 964/5000 - loss value 2.055304e-01
# Epoch 965/5000 - loss value 2.059340e-01
# Epoch 966/5000 - loss value 2.069265e-01
# Epoch 967/5000 - loss value 2.034898e-01
# Epoch 968/5000 - loss value 2.010755e-01
# Epoch 969/5000 - loss value 1.975533e-01
# Epoch 970/5000 - loss value 2.022786e-01
# Epoch 971/5000 - loss value 2.006428e-01
# Epoch 972/5000 - loss value 2.018184e-01
# Epoch 973/5000 - loss value 1.968389e-01
# Epoch 974/5000 - loss value 1.955649e-01
# Epoch 975/5000 - loss value 1.959828e-01
# Epoch 976/5000 - loss value 1.961946e-01
# Epoch 977/5000 - loss value 1.932450e-01
# Epoch 978/5000 - loss value 1.904899e-01
# Epoch 979/5000 - loss value 1.904225e-01
# Epoch 980/5000 - loss value 1.918696e-01
# Epoch 981/5000 - loss value 1.913985e-01
# Epoch 982/5000 - loss value 1.878740e-01
# Epoch 983/5000 - loss value 1.895740e-01
# Epoch 984/5000 - loss value 1.886456e-01
# Epoch 985/5000 - loss value 1.927846e-01
# Epoch 986/5000 - loss value 1.893522e-01
# Epoch 987/5000 - loss value 1.854897e-01
# Epoch 988/5000 - loss value 1.862512e-01
# Epoch 989/5000 - loss value 1.827755e-01
# Epoch 990/5000 - loss value 1.791816e-01
# Epoch 991/5000 - loss value 1.808863e-01
# Epoch 992/5000 - loss value 1.802808e-01
# Epoch 993/5000 - loss value 1.801247e-01
# Epoch 994/5000 - loss value 1.795646e-01
# Epoch 995/5000 - loss value 1.842712e-01
# Epoch 996/5000 - loss value 1.779852e-01
# Epoch 997/5000 - loss value 1.782006e-01
# Epoch 998/5000 - loss value 1.767048e-01
# Epoch 999/5000 - loss value 1.751857e-01
# Epoch 1000/5000 - loss value 1.757926e-01
# Epoch 1001/5000 - loss value 1.746595e-01
# Epoch 1002/5000 - loss value 1.743992e-01
# Epoch 1003/5000 - loss value 1.696522e-01
# Epoch 1004/5000 - loss value 1.714272e-01
# Epoch 1005/5000 - loss value 1.714971e-01
# Epoch 1006/5000 - loss value 1.686601e-01
# Epoch 1007/5000 - loss value 1.659071e-01
# Epoch 1008/5000 - loss value 1.686646e-01
# Epoch 1009/5000 - loss value 1.673345e-01
# Epoch 1010/5000 - loss value 1.663415e-01
# Epoch 1011/5000 - loss value 1.698120e-01
# Epoch 1012/5000 - loss value 1.663699e-01
# Epoch 1013/5000 - loss value 1.610202e-01
# Epoch 4965/5000 - loss value -7.401228e-02
# Epoch 4966/5000 - loss value -7.452401e-02
# Epoch 4967/5000 - loss value -7.594899e-02
# Epoch 4968/5000 - loss value -7.328629e-02
# Epoch 4969/5000 - loss value -7.675738e-02
# Epoch 4970/5000 - loss value -7.530380e-02
# Epoch 4971/5000 - loss value -7.937251e-02
# Epoch 4972/5000 - loss value -7.648872e-02
# Epoch 4973/5000 - loss value -7.645620e-02
# Epoch 4974/5000 - loss value -7.666983e-02
# Epoch 4975/5000 - loss value -7.383951e-02
# Epoch 4976/5000 - loss value -7.692158e-02
# Epoch 4977/5000 - loss value -7.620953e-02
# Epoch 4978/5000 - loss value -7.663865e-02
# Epoch 4979/5000 - loss value -7.620372e-02
# Epoch 4980/5000 - loss value -7.518426e-02
# Epoch 4981/5000 - loss value -7.592538e-02
# Epoch 4982/5000 - loss value -7.879504e-02
# Epoch 4983/5000 - loss value -7.597748e-02
# Epoch 4984/5000 - loss value -7.580050e-02
# Epoch 4985/5000 - loss value -7.724506e-02
# Epoch 4986/5000 - loss value -7.687916e-02
# Epoch 4987/5000 - loss value -7.685958e-02
# Epoch 4988/5000 - loss value -7.814023e-02
# Epoch 4989/5000 - loss value -7.490574e-02
# Epoch 4990/5000 - loss value -7.810126e-02
# Epoch 4991/5000 - loss value -7.636367e-02
# Epoch 4992/5000 - loss value -7.510033e-02
# Epoch 4993/5000 - loss value -7.613808e-02
# Epoch 4994/5000 - loss value -7.411403e-02
# Epoch 4995/5000 - loss value -7.378138e-02
# Epoch 4996/5000 - loss value -7.588295e-02
# Epoch 4997/5000 - loss value -7.597397e-02
# Epoch 4998/5000 - loss value -7.786975e-02
# Epoch 4999/5000 - loss value -7.394376e-02
# Epoch 5000/5000 - loss value -7.607065e-02
# Elapsed time  0:09:41.744705

# %%
x,y = np.meshgrid(np.linspace(-1,1,100),np.linspace(-1,1,100))
ys = np.concatenate((x.flatten()[:,None],y.flatten()[:,None]),1)
xy1 = geom1(ys)
xy2 = geom2(ys)
xy3 = geom3(ys)
xy4 = geom4(ys)

u1 = model.solution1(weights, ys).reshape(x.shape)
u2 = model.solution2(weights, ys).reshape(x.shape)
u3 = model.solution3(weights, ys).reshape(x.shape)
u4 = model.solution4(weights, ys).reshape(x.shape)

plt.figure(figsize = (20,12))
ax = plt.gca()
plt.contourf(xy1[:,0].reshape(x.shape), xy1[:,1].reshape(x.shape), u1, levels = 100, vmin = min([u1.min(),u2.min(),u3.min(),u4.min()]), vmax = max([u1.max(),u2.max(),u3.max(),u4.max()]))
plt.contourf(xy2[:,0].reshape(x.shape), xy2[:,1].reshape(x.shape), u2, levels = 100, vmin = min([u1.min(),u2.min(),u3.min(),u4.min()]), vmax = max([u1.max(),u2.max(),u3.max(),u4.max()]))
plt.contourf(xy3[:,0].reshape(x.shape), xy3[:,1].reshape(x.shape), u3, levels = 100, vmin = min([u1.min(),u2.min(),u3.min(),u4.min()]), vmax = max([u1.max(),u2.max(),u3.max(),u4.max()]))
plt.contourf(xy4[:,0].reshape(x.shape), xy4[:,1].reshape(x.shape), u4, levels = 100, vmin = min([u1.min(),u2.min(),u3.min(),u4.min()]), vmax = max([u1.max(),u2.max(),u3.max(),u4.max()]))
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
# Out:
# Text(0, 0.5, '$x_2$')

# %%
fem = FEM(mu0=model.mu0,mur=model.mur,J0 = model.J0,meshsize = 0.0005)

u1_ref = fem.call_A(xy1[:,0],xy1[:,1]).reshape(x.shape)
u2_ref = fem.call_A(xy2[:,0],xy2[:,1]).reshape(x.shape)
u3_ref = fem.call_A(xy3[:,0],xy3[:,1]).reshape(x.shape)
u4_ref = fem.call_A(xy4[:,0],xy4[:,1]).reshape(x.shape)

plt.figure()
ax = plt.gca()
plt.contourf(xy1[:,0].reshape(x.shape), xy1[:,1].reshape(x.shape), u1_ref, levels = 100, vmin = min([u1_ref.min(),u2_ref.min(),u3_ref.min(),u4_ref.min()]), vmax = max([u1_ref.max(),u2_ref.max(),u3_ref.max(),u4_ref.max()]))
plt.contourf(xy2[:,0].reshape(x.shape), xy2[:,1].reshape(x.shape), u2_ref, levels = 100, vmin = min([u1_ref.min(),u2_ref.min(),u3_ref.min(),u4_ref.min()]), vmax = max([u1_ref.max(),u2_ref.max(),u3_ref.max(),u4_ref.max()]))
plt.contourf(xy3[:,0].reshape(x.shape), xy3[:,1].reshape(x.shape), u3_ref, levels = 100, vmin = min([u1_ref.min(),u2_ref.min(),u3_ref.min(),u4_ref.min()]), vmax = max([u1_ref.max(),u2_ref.max(),u3_ref.max(),u4_ref.max()]))
plt.contourf(xy4[:,0].reshape(x.shape), xy4[:,1].reshape(x.shape), u4_ref, levels = 100, vmin = min([u1_ref.min(),u2_ref.min(),u3_ref.min(),u4_ref.min()]), vmax = max([u1_ref.max(),u2_ref.max(),u3_ref.max(),u4_ref.max()]))
plt.colorbar()

delta1 = np.abs(u1-u1_ref)
delta2 = np.abs(u2-u2_ref)
delta3 = np.abs(u3-u3_ref)
delta4 = np.abs(u4-u4_ref)

plt.figure()
ax = plt.gca()
plt.contourf(xy2[:,0].reshape(x.shape), xy2[:,1].reshape(x.shape), delta2, levels = 100, vmin = min([delta1.min(),delta2.min(),delta3.min(),delta4.min()]), vmax = max([delta1.max(),delta2.max(),delta3.max(),delta4.max()]))
plt.contourf(xy3[:,0].reshape(x.shape), xy3[:,1].reshape(x.shape), delta3, levels = 100, vmin = min([delta1.min(),delta2.min(),delta3.min(),delta4.min()]), vmax = max([delta1.max(),delta2.max(),delta3.max(),delta4.max()]))
plt.contourf(xy4[:,0].reshape(x.shape), xy4[:,1].reshape(x.shape), delta4, levels = 100, vmin = min([delta1.min(),delta2.min(),delta3.min(),delta4.min()]), vmax = max([delta1.max(),delta2.max(),delta3.max(),delta4.max()]))
plt.contourf(xy1[:,0].reshape(x.shape), xy1[:,1].reshape(x.shape), delta1, levels = 100, vmin = min([delta1.min(),delta2.min(),delta3.min(),delta4.min()]), vmax = max([delta1.max(),delta2.max(),delta3.max(),delta4.max()]))
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
print(max([np.max(delta1),np.max(delta2),np.max(delta3),np.max(delta4)])/max([np.max(u1),np.max(u2),np.max(u3),np.max(u4)]))
# Out:
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.636e+00 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 6.891e-11 (tol = 1.000e-10) r (rel) = 2.614e-11 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 202207 nodes for 101104 points.
# 0.043543570071128246

# %%
xs1 = geom1(model.points['ys1'])
xs2 = geom2(model.points['ys2'])
xs3 = geom3(model.points['ys3'])
xs4 = geom4(model.points['ys4'])

u1_ref = fem.call_A(xs1[:,0],xs1[:,1]).flatten()
u2_ref = fem.call_A(xs2[:,0],xs2[:,1]).flatten()
u3_ref = fem.call_A(xs3[:,0],xs3[:,1]).flatten()
u4_ref = fem.call_A(xs4[:,0],xs4[:,1]).flatten()

u1 = model.solution1(weights, model.points['ys1']).flatten()
u2 = model.solution2(weights, model.points['ys2']).flatten()
u3 = model.solution3(weights, model.points['ys3']).flatten()
u4 = model.solution4(weights, model.points['ys4']).flatten()

int1 = jnp.dot((u1-u1_ref)**2,model.points['omega1']*model.points['ws1']) / jnp.dot((u1_ref)**2,model.points['omega1']*model.points['ws1'])
int2 = jnp.dot((u2-u2_ref)**2,model.points['omega2']*model.points['ws2']) / jnp.dot((u2_ref)**2,model.points['omega2']*model.points['ws2'])
int3 = jnp.dot((u3-u3_ref)**2,model.points['omega3']*model.points['ws3']) / jnp.dot((u3_ref)**2,model.points['omega3']*model.points['ws3'])
int4 = jnp.dot((u4-u4_ref)**2,model.points['omega4']*model.points['ws4']) / jnp.dot((u4_ref)**2,model.points['omega4']*model.points['ws4'])

print(int1, int2, int3, int4)
# Out:
# 0.003623974694840886 0.00017958640445884226 7.919500350764945e-06 0.0008857774664582631

# %%
print(np.mean(delta1)/np.max(u1))
print('Surface copper', np.sum(model.points['omega3']*model.points['ws3']))
print('J0 ',50/np.sum(model.points['omega3']*model.points['ws3'])*24)
# Out:
# 0.016990632372293073
# Surface copper 0.0002164095597219368
# J0  5545041.547803489

# %%
plt.figure()
plt.scatter(xs1[:,0],xs1[:,1], s= 1)
plt.scatter(xs2[:,0],xs2[:,1], s= 1)
plt.scatter(xs3[:,0],xs3[:,1], s= 1)
plt.scatter(xs4[:,0],xs4[:,1], s= 1)

plt.figure()
fn.plot(fem.mesh)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbb642eeb90>,
#  <matplotlib.lines.Line2D at 0x7fbb642eeb60>]

# %%
plt.figure()
t = np.linspace(-1,1,1000).reshape([-1,1])
plt.plot(t.flatten(),model.solution3(weights,np.concatenate((t*0+1,t),-1)))

xy = geom3(np.concatenate((t*0+1,t),-1))
plt.plot(t.flatten(),fem.call_A(xy[:,0],xy[:,1]))
plt.legend(['PINN', 'FEM'])

# %%
model.points['ys1'].max(), np.sum(model.points['ys1'][:,1]*model.points['ws1'])
jax.devices()[0]
# Out:
# GpuDevice(id=0, process_index=0)
