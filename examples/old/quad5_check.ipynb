# %%
import fenics as fn
import matplotlib.pyplot as plt
from dolfin_utils.meshconvert import meshconvert
import os
from subprocess import call

import numpy as np
import jax
import jax.numpy as jnp
from jax.example_libraries import stax, optimizers
import matplotlib.pyplot as plt
import pinns 
import datetime
import jax.scipy.optimize
import jax.flatten_util
import scipy
import scipy.optimize
import chaospy as cp

# %%
def curl2D(v):
    return fn.as_vector((v.dx(1),-v.dx(0)))

class FEM():
            
    def __init__(self,J0=1000.0,mu0=1.0,mur=10.0, k1=0.001, k2=1.65, k3 = 0.5, meshsize = 0.001, verb = False):
        path='./quad/'
        
        with open(path + 'quad.geo', 'r') as file:
            data = file.read()
            
        s = "meshsize=%.18f;\n"%(meshsize)
        
        s = s + data
        
        with  open(path+"tmp.geo", "w") as file:
            file.write(s)
            file.close()
        if verb: print('geo file created',flush = True)
        
        if verb:
            os.system('gmsh %stmp.geo -nt 20 -3 -o %stmp.msh -format msh2 '%(path,path))
        else:
            os.system('gmsh %stmp.geo -nt 20 -3 -o %stmp.msh -format msh2 >/dev/null 2>&1'%(path,path))
        if verb: print('mesh file created',flush=True)

        if verb:
            os.system('dolfin-convert %stmp.msh %stmp.xml'%(path,path))
        else:
            os.system('dolfin-convert %stmp.msh %stmp.xml >/dev/null 2>&1'%(path,path))
        
        if verb: print('mesh file converted in fenics format',flush=True) 

        mesh = fn.Mesh(path+'tmp.xml')
        domains = fn.MeshFunction("size_t", mesh, path+'tmp_physical_region.xml')
        boundaries = fn.MeshFunction('size_t', mesh, path+'tmp_facet_region.xml')

        self.mesh = mesh
        ncells = [  mesh.num_vertices(), mesh.num_edges(), mesh.num_faces(), mesh.num_facets(), mesh.num_cells() ]
        
        def nu_lin(az):
            return 1/(mu0*mur)
        def nonlin_nu(az):
            tmp =  k1*fn.exp(k2*fn.dot(az.dx(1),az.dx(1)))+k3
            return tmp
        
        def nu_Bauer(B):
            x = fn.dot(B,B)
            return k1*fn.exp(k2*x)+k3
        
        # Coil
        def setup_coil(mesh,subdomains):
            DG = fn.FunctionSpace(mesh,"DG",0)
            J = fn.Function(DG)
            idx = []
            for cell_no in range(len(subdomains.array())):
                subdomain_no = subdomains.array()[cell_no]
                if subdomain_no == 3:
                    idx.append(cell_no)
            J.vector()[:] = 0
            J.vector()[idx] = J0
            return J
        
    
        
        """ define function space and boundary conditions"""
        
        CG = fn.FunctionSpace(mesh, 'CG', 1) # Continuous Galerkin
        
        # Define boundary condition
        bc = fn.DirichletBC(CG, fn.Constant(0.0), boundaries,16)
        
        # Define subdomain markers and integration measure
        dx = fn.Measure('dx', domain=mesh, subdomain_data=domains)
        
        J = setup_coil(mesh, domains)
        
        class Nu(fn.UserExpression): # UserExpression instead of Expression
            def __init__(self, markers, **kwargs):
                super().__init__(**kwargs) # This part is new!
                self.markers = markers
            def eval_cell(self, values, x, cell):
                if self.markers[cell.index] == 1:
                    values[0] = 0.0   # iron
                elif self.markers[cell.index] == 2:
                    values[0] = 1/mu0      # air
                elif self.markers[cell.index] == 3:
                    values[0] = 1/mu0      # air
                else:
                    print('no such domain',self.markers[cell.index] )
                    
        nus = Nu(domains, degree=1)
        
        
        """ weak formulation """
        
        az  = fn.Function(CG)
        u  = fn.Function(CG)
        v  = fn.TestFunction(CG)
        #az = Function(CG)
        #a  = (1/mu)*dot(grad(az), grad(v))*dx
        a = fn.inner(nus*curl2D(u), curl2D(v))*dx + fn.inner(nu_lin(curl2D(u))*curl2D(u),curl2D(v))*dx(1)
        L  = J*v*dx(3)
        
        F = a - L
        # solve variational problem
        fn.solve(F == 0, u, bc)
        az = u
        self.az = az
        # function space for H- and B- field allocated on faces of elements
        W = fn.VectorFunctionSpace(mesh, fn.FiniteElement("DP", fn.triangle, 0),1)
        B = fn.project(curl2D(az), W)
        H = None# project((1/mu)*curl(az), W)
        self.B = B
        self.H = H
    
    def call_A(self,x_eval,y_eval):
        
        
        Afem = 0 * x_eval
        for i in range(x_eval.size):
            try:
                Afem[i] = self.az(x_eval[i],y_eval[i])
            except:
                Afem[i] = np.nan
        return Afem
    
    def call_B(self,x_eval,y_eval):
        
        
        Bfem = []
        for i in range(x_eval.size):
            try:
                Bfem.append(self.B(x_eval[i],y_eval[i]))
            except:
                Bfem.append([ np.nan , np.nan])
        return np.array(Bfem)
    
    def call_H(self,x_eval,y_eval):
        Hfem = []
        for i in range(x_eval.size):
            try:
                Hfem.append(self.H(x_eval[i],y_eval[i]))
            except:
                Hfem.append([ np.nan , np.nan])
        return np.array(Hfem)

# %%
from jax.config import config
config.update("jax_enable_x64", True)
rnd_key = jax.random.PRNGKey(1234)

# %%
def create_geometry(key, scale = 1):
    scale = scale
    Nt = 24                                                                
    lz = 40e-3                                                             
    Do = 72e-3                                                            
    Di = 51e-3                                                            
    hi = 13e-3                                                             
    bli = 3e-3                                                             
    Dc = 3.27640e-2                                                           
    hc = 7.55176e-3                                                           
    ri = 20e-3                                                           
    ra = 18e-3                                                           
    blc = hi-hc                                                           
    rm = (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)                 
    R = rm-ri
    O = np.array([rm/np.sqrt(2),rm/np.sqrt(2)])
    alpha1 = -np.pi*3/4       
    alpha2 = np.math.asin((hc-rm/np.sqrt(2))/R)
    alpha = np.abs(alpha2-alpha1)
    
    A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
    b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
    C = np.linalg.solve(A,b)
    
    knots1 = np.array([[Do,Do * np.tan(np.pi/8)],[Do/np.sqrt(2),Do/np.sqrt(2)],[rm/np.sqrt(2),rm/np.sqrt(2)],[ri/np.sqrt(2),ri/np.sqrt(2)]])
    #knots2 = np.array([[Dc,hc],[Dc+blc,hi],[Di-bli,hi],[Di,hi-bli],[Di,0]])
    knots2 = np.array([[Di,hi-bli],[Di-bli,hi],[Dc+blc,hi],[Dc,hc]])
    knots3 = (knots1+knots2)/2
    knots3[-1,:] = C.flatten()
    knots = np.concatenate((knots1[None,...],knots3[None,...],knots2[None,...]),0)
    weights = np.ones(knots.shape[:2])
    weights[1,-1] = np.sin((np.pi-alpha)/2)
    basis2 = pinns.bspline.BSplineBasisJAX(np.array([-1,-0.33,0.33,1]),1)
    basis1 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),2)

    geom1 = pinns.geometry.PatchNURBSParam([basis1, basis2], knots, weights, 0, 2, key)
   
    knots2 = np.array([ [ [Dc,0],[Dc+blc,0],[Di-bli,0],[Di,0] ] , [[Dc,hc],[Dc+blc,hi],[Di-bli,hi],[Di,hi-bli]] ]) 
    knots2 = knots2[:,::-1,:]
    weights = np.ones(knots2.shape[:2])
    
    basis1 = pinns.bspline.BSplineBasisJAX(np.linspace(-1,1,2),1)
    basis2 = pinns.bspline.BSplineBasisJAX(np.array([-1,-0.33,0.33,1]),1)

    geom2 = pinns.geometry.PatchNURBSParam([basis1, basis2], knots2, weights, 0, 2, key)
   
    knots = np.array([ [ [0,0] , [Dc/2,0] , [Dc,0] ] , [ [ri/np.sqrt(2),ri/np.sqrt(2)] , [C[0,0],C[1,0]] , [Dc,hc] ]])
    
    basis1 = pinns.bspline.BSplineBasisJAX(np.linspace(-1,1,2),1)
    basis2 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),2)
    
    weights = np.ones(knots.shape[:2])
    weights[1,1] = np.sin((np.pi-alpha)/2)
    geom3 = pinns.geometry.PatchNURBSParam([basis1, basis2], knots, weights, 0, 2, key)

    knots1 = np.array([[Do,0],[Do,Do * np.tan(np.pi/8)]])
    knots2 = np.array([[Di,0],[Di,hi-bli]])
    knots3 = (knots1+knots2)/2
    knots = np.concatenate((knots1[None,...],knots3[None,...],knots2[None,...]),0)
    weights = np.ones(knots.shape[:2])

    basis2 = pinns.bspline.BSplineBasisJAX(np.linspace(-1,1,2),1)
    basis1 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),2)

    geom4 = pinns.geometry.PatchNURBSParam([basis1, basis2], knots, weights, 0, 2, key)
    return  geom1, geom3, geom2, geom4

# %%
geom1, geom2, geom3, geom4 = create_geometry(rnd_key)


pts,_ = geom1.importance_sampling(10000)

plt.figure()
plt.scatter(pts[:,0], pts[:,1], s = 1)

pts,_ = geom2.importance_sampling(10000)
plt.scatter(pts[:,0],pts[:,1], s = 1)

pts,_ = geom3.importance_sampling(10000)
plt.scatter(pts[:,0],pts[:,1], s = 1)

pts,_ = geom4.importance_sampling(10000)
plt.scatter(pts[:,0],pts[:,1], s = 1)
plt.show()

# %%
def interface_function2d(nd, endpositive, endzero, nn):

    faux = lambda x: ((x-endzero)**1/(endpositive-endzero)**1)
    if nd == 0:
        fret = lambda ws, x: (nn(ws, x[...,1][...,None]).flatten()*faux(x[...,0]))[...,None]
    else:
        fret = lambda ws, x: (nn(ws, x[...,0][...,None]).flatten()*faux(x[...,1]))[...,None]
    return fret

def jump_function2d(nd, pos_y, nn):

    faux = lambda x: jnp.exp(-4.0*jnp.abs(x-pos_y))
    if nd == 1:
        fret = lambda ws, x: (nn(ws, x[...,1][...,None]).flatten()*faux(x[...,0]))[...,None]
    else:
        fret = lambda ws, x: (nn(ws, x[...,0][...,None]).flatten()*faux(x[...,1]))[...,None]
    return fret

# def ExpHat(hidden_size, out_dim, W_init=glorot_normal(), b_init=normal()):
#   """Layer constructor function for a dense (fully-connected) layer."""
#   def init_fun(rng, input_shape):
#     output_shape = input_shape[:-1] + (out_dim,)
#     k1, k2 = random.split(rng)
#     W, b = W_init(k1, (input_shape[-1], out_dim)), b_init(k2, (out_dim,))
#     return output_shape, (W, b)
#   def apply_fun(params, inputs, **kwargs):
#     b, b = params
#     return jnp.dot(inputs, W) + b
#   return init_fun, apply_fun
def ExpHat(x, scale = 0.1):
    return jnp.exp(-jnp.abs(x)/scale)

class Model(pinns.PINN):
    def __init__(self, rand_key):
        super().__init__()
        self.key = rand_key

        N = [32,32]
        nl = 16
        acti = stax.Tanh
        acti =  stax.elementwise(lambda x: jax.nn.leaky_relu(x)**2)
        acti1 = stax.elementwise(lambda x: jax.nn.leaky_relu(x+1)**2)
        acti2 = stax.elementwise(lambda x: jax.nn.leaky_relu(x+0.33)**2)
        acti3 = stax.elementwise(lambda x: jax.nn.leaky_relu(x-0.33)**2)
        acti4 = stax.elementwise(lambda x: jnp.exp(-1.0*jnp.abs(x)))
        
        block_first = stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(nl), acti, stax.Dense(nl), acti),stax.Dense(nl)),stax.FanInSum)
        block = stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(nl), acti, stax.Dense(nl), acti),stax.Dense(nl)),stax.FanInSum)
        block2 = lambda n: stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(n), acti, stax.Dense(n), acti),stax.Dense(n)),stax.FanInSum)
        block3 = stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(nl), acti3, stax.Dense(nl), acti2),stax.Dense(nl)),stax.FanInSum)
        
        self.add_neural_network('u1',stax.serial(block_first,block,block, block, stax.Dense(1)),(-1,2)) # iron
        self.add_neural_network('u4',stax.serial(block_first,block,block, block, stax.Dense(1)),(-1,2)) # iron 2
        self.add_neural_network('u2',stax.serial(block_first,block,block, block, stax.Dense(1)),(-1,2)) # air 
        self.add_neural_network('u3',stax.serial(block_first,block,block, block, stax.Dense(1)),(-1,2)) # copper
        self.add_neural_network('u12',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u13',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        # self.add_neural_network('u13',stax.serial(stax.Dense(1000), acti4, stax.Dense(1)),(-1,1))
        self.add_neural_network('u23',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u14',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u34',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u1_0.3',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u1_0.7',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_trainable_parameter('u123',(1,))
        self.add_trainable_parameter('u134',(1,))
        self.add_trainable_parameter('u13_p0.33',(1,))
        self.add_trainable_parameter('u13_n0.33',(1,))
        
        
        self.interface12 = interface_function2d(1,1.0,-1.0,self.neural_networks['u12'])
        self.interface21 = interface_function2d(0,1.0,-1.0,self.neural_networks['u12'])
        self.interface23 = interface_function2d(1,1.0,-1.0,self.neural_networks['u23'])
        self.interface32 = interface_function2d(1,1.0,-1.0,self.neural_networks['u23'])
        self.interface13 = interface_function2d(0,1.0,-1.0,self.neural_networks['u13'])
        self.interface31 = interface_function2d(0,1.0,-1.0,self.neural_networks['u13'])
        self.interface14 = interface_function2d(1,-1.0,1.0,self.neural_networks['u14'])
        self.interface41 = interface_function2d(1,1.0,-1.0,self.neural_networks['u14'])
        self.interface34 = interface_function2d(1,-1.0,1.0,self.neural_networks['u34'])
        self.interface43 = interface_function2d(0,1.0,-1.0,self.neural_networks['u34'])

        self.jump1 = jump_function2d(0, -0.33, self.neural_networks['u1_0.3'])
        self.jump2 = jump_function2d(0,  0.33, self.neural_networks['u1_0.7'])

        self.mu0 = 0.001
        self.mur = 2000
        self.J0 =  1000000

        self.points = self.get_points_MC(100000, self.key)
        
    # def get_points(self, N, quad = 'MC'):        

    #     points = {}

    #     if quad == 'MC':
    #         ys = np.random.rand(N,2)*2-1
    #         Weights = np.ones((N,))*4/ys.shape[0]

    #     # ys = np.meshgrid(np.polynomial.legendre.leggauss(N[0])[0], np.polynomial.legendre.leggauss(N[1])[0])
    #     # ys = np.concatenate((ys[0].flatten()[:,None], ys[1].flatten()[:,None]), -1)
    #     # Weights = np.kron(np.polynomial.legendre.leggauss(N[0])[1], np.polynomial.legendre.leggauss(N[1])[1]).flatten()
    #     if quad=='SG':
    #         ys,Weights = cp.quadrature.sparse_grid(10,cp.J(cp.Uniform(-1,1),cp.Uniform(-1,1)),rule=["fejer_2", "fejer_2"])
    #         Weights = Weights*4
    #         ys = np.transpose(ys)

    #     if quad == 'TP': ys, Weights = pinns.geometry.tensor_product_integration(geom1.basis, N)
    #     points['ys1'] = ys
    #     points['ws1'] = Weights
    #     DGys = geom1._eval_omega(ys)
    #     Inv = np.linalg.inv(DGys)
    #     det = np.abs(np.linalg.det(DGys))
    #     points['K1'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
    #     points['omega1'] = det
    #    
    #     if quad == 'TP': ys, Weights = pinns.geometry.tensor_product_integration(geom2.basis, N)
    #     points['ys2'] = ys
    #     points['ws2'] = Weights
    #     DGys = geom2._eval_omega(ys)
    #     Inv = np.linalg.inv(DGys)
    #     det = np.abs(np.linalg.det(DGys))
    #     points['K2'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
    #     points['omega2'] = det
    #     
    #     if quad == 'TP': ys, Weights = pinns.geometry.tensor_product_integration(geom3.basis, N)
    #     points['ys3'] = ys
    #     points['ws3'] = Weights
    #     DGys = geom3._eval_omega(ys)
    #     Inv = np.linalg.inv(DGys)
    #     det = np.abs(np.linalg.det(DGys))
    #     points['K3'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
    #     points['omega3'] = det
    #    
    #     if quad == 'TP': ys, Weights = pinns.geometry.tensor_product_integration(geom4.basis, N)
    #     points['ys4'] = ys
    #     points['ws4'] = Weights
    #     DGys = geom4._eval_omega(ys)
    #     Inv = np.linalg.inv(DGys)
    #     det = np.abs(np.linalg.det(DGys))
    #     points['K4'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
    #     points['omega4'] = det

    #     return points

    def get_points_MC(self, N, key):        

        points = {}


        ys = jax.random.uniform(key ,(N,2))*2-1
        Weights = jnp.ones((N,))*4/ys.shape[0]
        # ys = np.array(jax.random.uniform(self.key, (N,2)))*2-1
        # Weights = jnp.ones((N,))*4/ys.shape[0]


        points['ys1'] = ys
        points['ws1'] = Weights
        points['omega1'], points['K1'] = geom1.GetMetricTensors(ys)
       
        points['ys2'] = ys
        points['ws2'] = Weights
        points['omega2'], points['K2'] = geom2.GetMetricTensors(ys)
        
        points['ys3'] = ys
        points['ws3'] = Weights
        points['omega3'], points['K3'] = geom3.GetMetricTensors(ys)
       
        points['ys4'] = ys
        points['ws4'] = Weights
        points['omega4'], points['K4'] = geom4.GetMetricTensors(ys)

        return points


    def solution1(self, ws, x):
        # iron
        u = self.neural_networks['u1'](ws['u1'],x) + self.jump1(ws['u1_0.3'], x) + self.jump2(ws['u1_0.7'], x)
        v = ((1-x[...,0])*(x[...,0] + 1)*(1-x[...,1])*(x[...,1]+1))[...,None]
        w =  self.interface12(ws['u12'],x)*((1-x[...,0])*(x[...,0] + 1))[...,None] + (self.interface13(ws['u13'],x)+ExpHat(x[...,1]+0.33)[...,None]*ws['u13_n0.33']+ExpHat(x[...,1]-0.33)[...,None]*ws['u13_p0.33'])*(1-x[...,1])[...,None]*(x[...,1] + 1)[...,None] +  self.interface14(ws['u14'],x) * ((1-x[...,0])*(x[...,0] + 1))[...,None]
        w = w + ws['u123']*( (x[...,0]+1) * (x[...,1]+1) )[...,None]**2 + ws['u134'] *  ( (x[...,0] + 1)*(1-x[...,1]) )[...,None]**2
        return u*v+w

    def solution2(self, ws, x):
        
        u = self.neural_networks['u2'](ws['u2'],x)
        v = ((1-x[...,1])*(x[...,1] + 1)*(1-x[...,0]))[...,None]
        w = self.interface21(ws['u12'],x)*((1-x[...,1])*(x[...,1] + 1))[...,None] + self.interface23(ws['u23'],x)*(1-x[...,0])[...,None]
        w = w + ws['u123']*( (x[...,0]+1) * (x[...,1]+1) )[...,None]**2
        return u*v+w
    
    def solution3(self, ws, x):
        
        u = self.neural_networks['u3'](ws['u3'],x)
        v = ((1-x[...,1])*(x[...,1] + 1)*(1-x[...,0]))[...,None]
        w =  self.interface32(ws['u23'],x)*(1-x[...,0])[...,None]+(self.interface31(ws['u13'],x)+ExpHat(x[...,1]+0.33)[...,None]*ws['u13_n0.33']+ExpHat(x[...,1]-0.33)[...,None]*ws['u13_p0.33'])*((1-x[...,1])*(x[...,1] + 1))[...,None]+self.interface34(ws['u34'],x)*(1-x[...,0])[...,None]
        w = w + ws['u123']*( (x[...,0]+1) * (x[...,1]+1) )[...,None]**2 + ws['u134'] *  ( (x[...,0] +1)*(1-x[...,1]) )[...,None]**2
        return u*v + w
        
    def solution4(self, ws, x):
        u = self.neural_networks['u4'](ws['u4'],x)
        v = ((1-x[...,0])*(x[...,0] + 1)*(1-x[...,1]))[...,None]
        w = self.interface41(ws['u14'],x)*((1-x[...,0])*(x[...,0] + 1))[...,None]+self.interface43(ws['u34'],x)*((1-x[...,1]))[...,None]
        w = w + ws['u134'] *  ( (x[...,0]+1) * (x[...,1]+1) )[...,None]**2
        return u*v+w

    def loss_pde(self, ws, points):
        grad1 = pinns.operators.gradient(lambda x : self.solution1(ws,x))(points['ys1'])[...,0,:]
        grad2 = pinns.operators.gradient(lambda x : self.solution2(ws,x))(points['ys2'])[...,0,:]
        grad3 = pinns.operators.gradient(lambda x : self.solution3(ws,x))(points['ys3'])[...,0,:]
        grad4 = pinns.operators.gradient(lambda x : self.solution4(ws,x))(points['ys4'])[...,0,:]
        
        
        # lpde1 = 0.5*1/(self.mu0*self.mur)*jnp.dot(jnp.einsum('mi,mij,mj->m',grad1,self.points['K1'],grad1), self.points['ws1']) 
        # lpde2 = 0.5*1/self.mu0*jnp.dot(jnp.einsum('mi,mij,mj->m',grad2,self.points['K2'],grad2), self.points['ws2'])  
        # lpde3 = 0.5*1/self.mu0*jnp.dot(jnp.einsum('mi,mij,mj->m',grad3,self.points['K3'],grad3), self.points['ws3'])  - jnp.dot(self.J0*self.solution3(ws,self.points['ys3']).flatten()*self.points['omega3']  ,self.points['ws3'])
        # lpde4 = 0.5*1/(self.mu0*self.mur)*jnp.dot(jnp.einsum('mi,mij,mj->m',grad4,self.points['K4'],grad4), self.points['ws4']) 
        lpde1 = 0.5*1/(self.mur)*jnp.dot(jnp.einsum('mi,mij,mj->m',grad1,points['K1'],grad1), points['ws1']) 
        lpde2 = 0.5*jnp.dot(jnp.einsum('mi,mij,mj->m',grad2,points['K2'],grad2), points['ws2'])  
        lpde3 = 0.5*jnp.dot(jnp.einsum('mi,mij,mj->m',grad3,points['K3'],grad3), points['ws3'])  - self.mu0*jnp.dot(self.J0*self.solution3(ws,points['ys3']).flatten()*points['omega3']  ,points['ws3'])
        lpde4 = 0.5*1/(self.mur)*jnp.dot(jnp.einsum('mi,mij,mj->m',grad4,points['K4'],grad4), points['ws4'])
        return lpde1+lpde2+lpde3+lpde4

    def loss(self, ws, pts):
        lpde = self.loss_pde(ws, pts)
        return lpde

# %%
rnd_key = jax.random.PRNGKey(1235)
model = Model(rnd_key)
w0 = model.init_unravel()
weights = model.weights 

dev = jax.devices()[1]

# loss_compiled = jax.jit(model.loss_handle, device = jax.devices()[0])
# lossgrad_compiled = jax.jit(model.lossgrad_handle, device = jax.devices()[0])
# 
# def loss_grad(w):
#     l, gr = lossgrad_compiled(jnp.array(w))
#     return np.array( l.to_py() ), np.array( gr.to_py() )

opt_type = 'ADAM'
batch_size = 2000

get_compiled = jax.jit(lambda key: model.get_points_MC(batch_size, key), device = dev)
# %time pts = get_compiled(rnd_key)
# %time pts = get_compiled(rnd_key)

opt_init, opt_update, get_params = optimizers.adam(step_size=0.001)

opt_state = opt_init(weights)

# get initial parameters
params = get_params(opt_state)

loss_grad = jax.jit(lambda ws, pts: (model.loss(ws, pts), jax.grad(model.loss)(ws, pts)), device = dev)

def step(params, opt_state, key):
    # points = model.get_points_MC(5000)
    points = model.get_points_MC(batch_size, key)
    loss, grads = loss_grad(params, points)
    opt_state = opt_update(0, grads, opt_state)

    params = get_params(opt_state)
    
    return params, opt_state, loss

step_compiled = jax.jit(step, device = dev)
step_compiled(params, opt_state, rnd_key)

n_epochs = 5000

tme = datetime.datetime.now()
for k in range(n_epochs):    
    params, opt_state, loss = step_compiled(params, opt_state, jax.random.PRNGKey(np.random.randint(32131233123)))
    
    print('Epoch %d/%d - loss value %e'%(k+1, n_epochs, loss))
# update params
model.weights = params
weights = params
tme = datetime.datetime.now() - tme
print('Elapsed time ', tme)
# Out:
# CPU times: user 17.5 s, sys: 150 ms, total: 17.7 s
# Wall time: 15.2 s
# CPU times: user 2.01 ms, sys: 0 ns, total: 2.01 ms
# Wall time: 1.69 ms
# Epoch 1/5000 - loss value 4.236484e+01
# Epoch 2/5000 - loss value 3.540159e+01
# Epoch 3/5000 - loss value 3.404606e+01
# Epoch 4/5000 - loss value 3.381409e+01
# Epoch 5/5000 - loss value 3.139461e+01
# Epoch 6/5000 - loss value 2.910807e+01
# Epoch 7/5000 - loss value 2.579595e+01
# Epoch 8/5000 - loss value 2.664584e+01
# Epoch 9/5000 - loss value 2.373601e+01
# Epoch 10/5000 - loss value 2.214845e+01
# Epoch 11/5000 - loss value 2.329925e+01
# Epoch 12/5000 - loss value 2.032980e+01
# Epoch 13/5000 - loss value 1.891709e+01
# Epoch 14/5000 - loss value 1.851235e+01
# Epoch 15/5000 - loss value 1.709262e+01
# Epoch 16/5000 - loss value 1.707979e+01
# Epoch 17/5000 - loss value 1.507715e+01
# Epoch 18/5000 - loss value 1.456367e+01
# Epoch 19/5000 - loss value 1.415743e+01
# Epoch 20/5000 - loss value 1.291852e+01
# Epoch 21/5000 - loss value 1.237539e+01
# Epoch 22/5000 - loss value 1.178826e+01
# Epoch 23/5000 - loss value 1.081614e+01
# Epoch 24/5000 - loss value 1.057724e+01
# Epoch 25/5000 - loss value 1.037952e+01
# Epoch 26/5000 - loss value 9.807926e+00
# Epoch 27/5000 - loss value 9.299960e+00
# Epoch 28/5000 - loss value 8.770168e+00
# Epoch 29/5000 - loss value 8.307476e+00
# Epoch 30/5000 - loss value 8.945642e+00
# Epoch 31/5000 - loss value 7.581100e+00
# Epoch 32/5000 - loss value 7.487271e+00
# Epoch 33/5000 - loss value 7.667708e+00
# Epoch 34/5000 - loss value 6.704042e+00
# Epoch 35/5000 - loss value 6.820622e+00
# Epoch 36/5000 - loss value 7.553608e+00
# Epoch 37/5000 - loss value 6.815439e+00
# Epoch 167/5000 - loss value 2.443837e+00
# Epoch 168/5000 - loss value 2.538533e+00
# Epoch 169/5000 - loss value 2.485866e+00
# Epoch 170/5000 - loss value 2.555785e+00
# Epoch 171/5000 - loss value 2.493553e+00
# Epoch 172/5000 - loss value 2.483537e+00
# Epoch 173/5000 - loss value 2.508876e+00
# Epoch 174/5000 - loss value 2.518347e+00
# Epoch 175/5000 - loss value 2.513682e+00
# Epoch 176/5000 - loss value 2.481567e+00
# Epoch 177/5000 - loss value 2.413239e+00
# Epoch 178/5000 - loss value 2.475974e+00
# Epoch 179/5000 - loss value 2.417070e+00
# Epoch 180/5000 - loss value 2.419255e+00
# Epoch 181/5000 - loss value 2.366125e+00
# Epoch 182/5000 - loss value 2.415827e+00
# Epoch 183/5000 - loss value 2.412280e+00
# Epoch 184/5000 - loss value 2.455627e+00
# Epoch 185/5000 - loss value 2.471712e+00
# Epoch 186/5000 - loss value 2.379216e+00
# Epoch 187/5000 - loss value 2.428469e+00
# Epoch 188/5000 - loss value 2.436797e+00
# Epoch 189/5000 - loss value 2.383474e+00
# Epoch 190/5000 - loss value 2.369297e+00
# Epoch 191/5000 - loss value 2.411544e+00
# Epoch 192/5000 - loss value 2.349464e+00
# Epoch 193/5000 - loss value 2.374335e+00
# Epoch 194/5000 - loss value 2.349594e+00
# Epoch 195/5000 - loss value 2.300427e+00
# Epoch 196/5000 - loss value 2.353491e+00
# Epoch 197/5000 - loss value 2.343069e+00
# Epoch 198/5000 - loss value 2.312172e+00
# Epoch 199/5000 - loss value 2.378149e+00
# Epoch 200/5000 - loss value 2.315077e+00
# Epoch 201/5000 - loss value 2.303858e+00
# Epoch 202/5000 - loss value 2.344647e+00
# Epoch 203/5000 - loss value 2.348288e+00
# Epoch 204/5000 - loss value 2.296309e+00
# Epoch 205/5000 - loss value 2.253865e+00
# Epoch 206/5000 - loss value 2.308100e+00
# Epoch 207/5000 - loss value 2.307993e+00
# Epoch 208/5000 - loss value 2.310262e+00
# Epoch 209/5000 - loss value 2.294075e+00
# Epoch 210/5000 - loss value 2.253395e+00
# Epoch 211/5000 - loss value 2.246507e+00
# Epoch 212/5000 - loss value 2.208947e+00
# Epoch 213/5000 - loss value 2.283847e+00
# Epoch 214/5000 - loss value 2.197413e+00
# Epoch 215/5000 - loss value 2.229044e+00
# Epoch 216/5000 - loss value 2.283390e+00
# Epoch 217/5000 - loss value 2.207370e+00
# Epoch 218/5000 - loss value 2.232310e+00
# Epoch 219/5000 - loss value 2.287934e+00
# Epoch 220/5000 - loss value 2.190356e+00
# Epoch 221/5000 - loss value 2.194286e+00
# Epoch 222/5000 - loss value 2.151629e+00
# Epoch 223/5000 - loss value 2.204120e+00
# Epoch 224/5000 - loss value 2.229197e+00
# Epoch 225/5000 - loss value 2.202588e+00
# Epoch 226/5000 - loss value 2.177327e+00
# Epoch 227/5000 - loss value 2.173042e+00
# Epoch 228/5000 - loss value 2.169793e+00
# Epoch 229/5000 - loss value 2.144015e+00
# Epoch 230/5000 - loss value 2.156165e+00
# Epoch 231/5000 - loss value 2.152540e+00
# Epoch 232/5000 - loss value 2.157644e+00
# Epoch 233/5000 - loss value 2.102406e+00
# Epoch 234/5000 - loss value 2.139640e+00
# Epoch 235/5000 - loss value 2.099523e+00
# Epoch 236/5000 - loss value 2.082934e+00
# Epoch 237/5000 - loss value 2.138008e+00
# Epoch 238/5000 - loss value 2.122123e+00
# Epoch 239/5000 - loss value 2.105904e+00
# Epoch 240/5000 - loss value 2.051321e+00
# Epoch 241/5000 - loss value 2.097802e+00
# Epoch 242/5000 - loss value 2.061107e+00
# Epoch 243/5000 - loss value 2.098125e+00
# Epoch 244/5000 - loss value 2.054563e+00
# Epoch 245/5000 - loss value 2.075422e+00
# Epoch 246/5000 - loss value 2.051343e+00
# Epoch 247/5000 - loss value 2.063986e+00
# Epoch 248/5000 - loss value 2.052304e+00
# Epoch 249/5000 - loss value 2.085222e+00
# Epoch 250/5000 - loss value 2.049105e+00
# Epoch 251/5000 - loss value 2.032612e+00
# Epoch 252/5000 - loss value 2.023623e+00
# Epoch 253/5000 - loss value 2.051083e+00
# Epoch 254/5000 - loss value 2.048136e+00
# Epoch 255/5000 - loss value 2.033325e+00
# Epoch 256/5000 - loss value 2.039140e+00
# Epoch 257/5000 - loss value 2.022697e+00
# Epoch 258/5000 - loss value 1.996036e+00
# Epoch 259/5000 - loss value 1.988452e+00
# Epoch 260/5000 - loss value 2.015028e+00
# Epoch 261/5000 - loss value 1.955165e+00
# Epoch 262/5000 - loss value 1.993113e+00
# Epoch 263/5000 - loss value 2.023636e+00
# Epoch 264/5000 - loss value 2.010878e+00
# Epoch 265/5000 - loss value 1.937586e+00
# Epoch 266/5000 - loss value 1.963875e+00
# Epoch 267/5000 - loss value 2.027211e+00
# Epoch 268/5000 - loss value 1.988191e+00
# Epoch 269/5000 - loss value 1.978311e+00
# Epoch 270/5000 - loss value 1.965777e+00
# Epoch 271/5000 - loss value 1.930691e+00
# Epoch 272/5000 - loss value 1.945726e+00
# Epoch 273/5000 - loss value 1.980391e+00
# Epoch 274/5000 - loss value 1.953416e+00
# Epoch 275/5000 - loss value 1.952469e+00
# Epoch 276/5000 - loss value 1.936626e+00
# Epoch 277/5000 - loss value 1.976726e+00
# Epoch 278/5000 - loss value 1.936001e+00
# Epoch 279/5000 - loss value 1.931265e+00
# Epoch 280/5000 - loss value 1.938759e+00
# Epoch 281/5000 - loss value 1.899074e+00
# Epoch 282/5000 - loss value 1.875871e+00
# Epoch 283/5000 - loss value 1.924692e+00
# Epoch 284/5000 - loss value 1.882653e+00
# Epoch 285/5000 - loss value 1.893810e+00
# Epoch 286/5000 - loss value 1.901907e+00
# Epoch 287/5000 - loss value 1.892617e+00
# Epoch 288/5000 - loss value 1.924899e+00
# Epoch 289/5000 - loss value 1.871754e+00
# Epoch 290/5000 - loss value 1.873248e+00
# Epoch 291/5000 - loss value 1.856663e+00
# Epoch 292/5000 - loss value 1.857071e+00
# Epoch 293/5000 - loss value 1.865255e+00
# Epoch 294/5000 - loss value 1.879878e+00
# Epoch 295/5000 - loss value 1.820852e+00
# Epoch 296/5000 - loss value 1.828171e+00
# Epoch 297/5000 - loss value 1.820331e+00
# Epoch 298/5000 - loss value 1.803192e+00
# Epoch 299/5000 - loss value 1.830168e+00
# Epoch 300/5000 - loss value 1.811520e+00
# Epoch 301/5000 - loss value 1.808927e+00
# Epoch 302/5000 - loss value 1.799160e+00
# Epoch 303/5000 - loss value 1.824290e+00
# Epoch 304/5000 - loss value 1.810515e+00
# Epoch 305/5000 - loss value 1.812766e+00
# Epoch 306/5000 - loss value 1.832988e+00
# Epoch 307/5000 - loss value 1.786220e+00
# Epoch 308/5000 - loss value 1.761905e+00
# Epoch 309/5000 - loss value 1.774460e+00
# Epoch 310/5000 - loss value 1.768043e+00
# Epoch 311/5000 - loss value 1.772720e+00
# Epoch 312/5000 - loss value 1.731359e+00
# Epoch 313/5000 - loss value 1.780991e+00
# Epoch 314/5000 - loss value 1.766425e+00
# Epoch 315/5000 - loss value 1.755737e+00
# Epoch 316/5000 - loss value 1.751416e+00
# Epoch 317/5000 - loss value 1.719925e+00
# Epoch 318/5000 - loss value 1.757031e+00
# Epoch 319/5000 - loss value 1.708784e+00
# Epoch 320/5000 - loss value 1.766230e+00
# Epoch 321/5000 - loss value 1.769297e+00
# Epoch 322/5000 - loss value 1.746485e+00
# Epoch 323/5000 - loss value 1.726678e+00
# Epoch 324/5000 - loss value 1.722368e+00
# Epoch 325/5000 - loss value 1.728755e+00
# Epoch 326/5000 - loss value 1.756797e+00
# Epoch 327/5000 - loss value 1.702687e+00
# Epoch 328/5000 - loss value 1.707011e+00
# Epoch 329/5000 - loss value 1.738416e+00
# Epoch 330/5000 - loss value 1.697632e+00
# Epoch 331/5000 - loss value 1.675694e+00
# Epoch 332/5000 - loss value 1.712321e+00
# Epoch 333/5000 - loss value 1.662805e+00
# Epoch 334/5000 - loss value 1.676833e+00
# Epoch 335/5000 - loss value 1.694271e+00
# Epoch 336/5000 - loss value 1.706873e+00
# Epoch 337/5000 - loss value 1.684938e+00
# Epoch 338/5000 - loss value 1.696322e+00
# Epoch 339/5000 - loss value 1.683098e+00
# Epoch 340/5000 - loss value 1.663934e+00
# Epoch 341/5000 - loss value 1.669199e+00
# Epoch 342/5000 - loss value 1.639024e+00
# Epoch 343/5000 - loss value 1.634737e+00
# Epoch 344/5000 - loss value 1.659707e+00
# Epoch 345/5000 - loss value 1.627041e+00
# Epoch 346/5000 - loss value 1.632173e+00
# Epoch 347/5000 - loss value 1.591313e+00
# Epoch 348/5000 - loss value 1.635875e+00
# Epoch 349/5000 - loss value 1.672687e+00
# Epoch 350/5000 - loss value 1.600525e+00
# Epoch 351/5000 - loss value 1.619213e+00
# Epoch 352/5000 - loss value 1.634450e+00
# Epoch 353/5000 - loss value 1.559561e+00
# Epoch 354/5000 - loss value 1.604985e+00
# Epoch 355/5000 - loss value 1.614371e+00
# Epoch 356/5000 - loss value 1.587234e+00
# Epoch 357/5000 - loss value 1.594507e+00
# Epoch 358/5000 - loss value 1.616579e+00
# Epoch 359/5000 - loss value 1.582206e+00
# Epoch 360/5000 - loss value 1.604655e+00
# Epoch 361/5000 - loss value 1.570732e+00
# Epoch 362/5000 - loss value 1.525376e+00
# Epoch 363/5000 - loss value 1.525449e+00
# Epoch 364/5000 - loss value 1.545088e+00
# Epoch 365/5000 - loss value 1.566641e+00
# Epoch 366/5000 - loss value 1.561029e+00
# Epoch 367/5000 - loss value 1.543473e+00
# Epoch 368/5000 - loss value 1.521380e+00
# Epoch 369/5000 - loss value 1.550285e+00
# Epoch 370/5000 - loss value 1.563698e+00
# Epoch 371/5000 - loss value 1.605876e+00
# Epoch 372/5000 - loss value 1.535704e+00
# Epoch 373/5000 - loss value 1.550166e+00
# Epoch 374/5000 - loss value 1.522907e+00
# Epoch 375/5000 - loss value 1.556871e+00
# Epoch 376/5000 - loss value 1.559042e+00
# Epoch 377/5000 - loss value 1.514488e+00
# Epoch 378/5000 - loss value 1.538530e+00
# Epoch 379/5000 - loss value 1.519249e+00
# Epoch 380/5000 - loss value 1.535307e+00
# Epoch 381/5000 - loss value 1.502042e+00
# Epoch 382/5000 - loss value 1.491584e+00
# Epoch 383/5000 - loss value 1.500284e+00
# Epoch 384/5000 - loss value 1.497195e+00
# Epoch 385/5000 - loss value 1.499982e+00
# Epoch 386/5000 - loss value 1.496076e+00
# Epoch 387/5000 - loss value 1.472087e+00
# Epoch 388/5000 - loss value 1.475959e+00
# Epoch 389/5000 - loss value 1.480445e+00
# Epoch 390/5000 - loss value 1.506511e+00
# Epoch 391/5000 - loss value 1.439065e+00
# Epoch 392/5000 - loss value 1.477231e+00
# Epoch 393/5000 - loss value 1.468811e+00
# Epoch 394/5000 - loss value 1.486964e+00
# Epoch 395/5000 - loss value 1.502166e+00
# Epoch 396/5000 - loss value 1.469374e+00
# Epoch 397/5000 - loss value 1.452260e+00
# Epoch 398/5000 - loss value 1.446016e+00
# Epoch 399/5000 - loss value 1.432625e+00
# Epoch 400/5000 - loss value 1.450122e+00
# Epoch 401/5000 - loss value 1.428410e+00
# Epoch 402/5000 - loss value 1.442547e+00
# Epoch 403/5000 - loss value 1.444427e+00
# Epoch 404/5000 - loss value 1.434692e+00
# Epoch 405/5000 - loss value 1.427628e+00
# Epoch 406/5000 - loss value 1.441958e+00
# Epoch 407/5000 - loss value 1.405303e+00
# Epoch 408/5000 - loss value 1.472558e+00
# Epoch 409/5000 - loss value 1.400823e+00
# Epoch 410/5000 - loss value 1.416467e+00
# Epoch 411/5000 - loss value 1.418676e+00
# Epoch 412/5000 - loss value 1.407979e+00
# Epoch 413/5000 - loss value 1.441689e+00
# Epoch 414/5000 - loss value 1.424014e+00
# Epoch 415/5000 - loss value 1.396892e+00
# Epoch 416/5000 - loss value 1.383789e+00
# Epoch 417/5000 - loss value 1.416345e+00
# Epoch 418/5000 - loss value 1.388398e+00
# Epoch 419/5000 - loss value 1.385534e+00
# Epoch 420/5000 - loss value 1.365296e+00
# Epoch 421/5000 - loss value 1.381420e+00
# Epoch 422/5000 - loss value 1.357053e+00
# Epoch 423/5000 - loss value 1.362058e+00
# Epoch 424/5000 - loss value 1.386444e+00
# Epoch 425/5000 - loss value 1.379907e+00
# Epoch 426/5000 - loss value 1.387328e+00
# Epoch 427/5000 - loss value 1.366808e+00
# Epoch 428/5000 - loss value 1.352453e+00
# Epoch 429/5000 - loss value 1.343105e+00
# Epoch 430/5000 - loss value 1.348239e+00
# Epoch 431/5000 - loss value 1.346289e+00
# Epoch 432/5000 - loss value 1.337620e+00
# Epoch 433/5000 - loss value 1.328054e+00
# Epoch 434/5000 - loss value 1.372071e+00
# Epoch 435/5000 - loss value 1.344468e+00
# Epoch 436/5000 - loss value 1.306025e+00
# Epoch 437/5000 - loss value 1.343702e+00
# Epoch 438/5000 - loss value 1.318348e+00
# Epoch 439/5000 - loss value 1.324715e+00
# Epoch 440/5000 - loss value 1.363015e+00
# Epoch 441/5000 - loss value 1.334765e+00
# Epoch 442/5000 - loss value 1.332315e+00
# Epoch 443/5000 - loss value 1.307102e+00
# Epoch 444/5000 - loss value 1.341662e+00
# Epoch 445/5000 - loss value 1.329756e+00
# Epoch 446/5000 - loss value 1.324381e+00
# Epoch 447/5000 - loss value 1.300125e+00
# Epoch 448/5000 - loss value 1.300326e+00
# Epoch 449/5000 - loss value 1.328642e+00
# Epoch 450/5000 - loss value 1.288788e+00
# Epoch 451/5000 - loss value 1.282695e+00
# Epoch 452/5000 - loss value 1.316637e+00
# Epoch 453/5000 - loss value 1.279570e+00
# Epoch 454/5000 - loss value 1.266928e+00
# Epoch 455/5000 - loss value 1.300514e+00
# Epoch 456/5000 - loss value 1.300886e+00
# Epoch 457/5000 - loss value 1.244839e+00
# Epoch 458/5000 - loss value 1.249288e+00
# Epoch 459/5000 - loss value 1.281049e+00
# Epoch 460/5000 - loss value 1.273052e+00
# Epoch 461/5000 - loss value 1.253097e+00
# Epoch 462/5000 - loss value 1.248394e+00
# Epoch 463/5000 - loss value 1.261965e+00
# Epoch 464/5000 - loss value 1.246351e+00
# Epoch 465/5000 - loss value 1.241302e+00
# Epoch 466/5000 - loss value 1.251952e+00
# Epoch 467/5000 - loss value 1.263503e+00
# Epoch 468/5000 - loss value 1.257831e+00
# Epoch 469/5000 - loss value 1.229131e+00
# Epoch 470/5000 - loss value 1.215908e+00
# Epoch 471/5000 - loss value 1.242948e+00
# Epoch 472/5000 - loss value 1.232006e+00
# Epoch 473/5000 - loss value 1.225893e+00
# Epoch 474/5000 - loss value 1.241257e+00
# Epoch 475/5000 - loss value 1.210118e+00
# Epoch 476/5000 - loss value 1.226152e+00
# Epoch 477/5000 - loss value 1.208286e+00
# Epoch 478/5000 - loss value 1.196825e+00
# Epoch 479/5000 - loss value 1.221076e+00
# Epoch 480/5000 - loss value 1.230912e+00
# Epoch 481/5000 - loss value 1.203210e+00
# Epoch 482/5000 - loss value 1.212235e+00
# Epoch 483/5000 - loss value 1.200750e+00
# Epoch 484/5000 - loss value 1.202160e+00
# Epoch 485/5000 - loss value 1.199351e+00
# Epoch 486/5000 - loss value 1.175593e+00
# Epoch 487/5000 - loss value 1.173005e+00
# Epoch 488/5000 - loss value 1.184925e+00
# Epoch 489/5000 - loss value 1.174083e+00
# Epoch 490/5000 - loss value 1.187475e+00
# Epoch 491/5000 - loss value 1.178621e+00
# Epoch 492/5000 - loss value 1.179846e+00
# Epoch 493/5000 - loss value 1.186172e+00
# Epoch 494/5000 - loss value 1.178982e+00
# Epoch 495/5000 - loss value 1.149638e+00
# Epoch 496/5000 - loss value 1.149653e+00
# Epoch 497/5000 - loss value 1.144144e+00
# Epoch 498/5000 - loss value 1.158540e+00
# Epoch 499/5000 - loss value 1.164866e+00
# Epoch 500/5000 - loss value 1.178131e+00
# Epoch 501/5000 - loss value 1.140417e+00
# Epoch 502/5000 - loss value 1.143270e+00
# Epoch 503/5000 - loss value 1.132063e+00
# Epoch 504/5000 - loss value 1.173549e+00
# Epoch 505/5000 - loss value 1.169170e+00
# Epoch 506/5000 - loss value 1.121662e+00
# Epoch 507/5000 - loss value 1.118118e+00
# Epoch 508/5000 - loss value 1.102029e+00
# Epoch 509/5000 - loss value 1.152296e+00
# Epoch 510/5000 - loss value 1.141895e+00
# Epoch 511/5000 - loss value 1.140334e+00
# Epoch 512/5000 - loss value 1.121325e+00
# Epoch 513/5000 - loss value 1.113229e+00
# Epoch 514/5000 - loss value 1.117014e+00
# Epoch 515/5000 - loss value 1.121479e+00
# Epoch 516/5000 - loss value 1.133433e+00
# Epoch 517/5000 - loss value 1.122631e+00
# Epoch 518/5000 - loss value 1.090438e+00
# Epoch 519/5000 - loss value 1.096812e+00
# Epoch 520/5000 - loss value 1.072639e+00
# Epoch 521/5000 - loss value 1.101036e+00
# Epoch 522/5000 - loss value 1.089558e+00
# Epoch 523/5000 - loss value 1.087161e+00
# Epoch 524/5000 - loss value 1.094515e+00
# Epoch 525/5000 - loss value 1.120976e+00
# Epoch 526/5000 - loss value 1.090255e+00
# Epoch 527/5000 - loss value 1.071286e+00
# Epoch 528/5000 - loss value 1.077768e+00
# Epoch 529/5000 - loss value 1.085952e+00
# Epoch 530/5000 - loss value 1.089079e+00
# Epoch 531/5000 - loss value 1.070508e+00
# Epoch 532/5000 - loss value 1.044446e+00
# Epoch 533/5000 - loss value 1.054980e+00
# Epoch 534/5000 - loss value 1.105250e+00
# Epoch 535/5000 - loss value 1.069527e+00
# Epoch 536/5000 - loss value 1.060421e+00
# Epoch 537/5000 - loss value 1.046208e+00
# Epoch 538/5000 - loss value 1.058105e+00
# Epoch 539/5000 - loss value 1.075700e+00
# Epoch 540/5000 - loss value 1.080774e+00
# Epoch 541/5000 - loss value 1.043705e+00
# Epoch 542/5000 - loss value 1.036972e+00
# Epoch 543/5000 - loss value 1.059806e+00
# Epoch 544/5000 - loss value 1.044389e+00
# Epoch 545/5000 - loss value 1.041857e+00
# Epoch 546/5000 - loss value 1.029383e+00
# Epoch 547/5000 - loss value 1.026940e+00
# Epoch 548/5000 - loss value 1.037791e+00
# Epoch 549/5000 - loss value 1.051537e+00
# Epoch 550/5000 - loss value 1.010525e+00
# Epoch 551/5000 - loss value 1.020395e+00
# Epoch 552/5000 - loss value 1.023131e+00
# Epoch 553/5000 - loss value 1.009688e+00
# Epoch 554/5000 - loss value 1.020850e+00
# Epoch 555/5000 - loss value 9.954372e-01
# Epoch 556/5000 - loss value 1.022397e+00
# Epoch 557/5000 - loss value 1.002737e+00
# Epoch 558/5000 - loss value 1.005618e+00
# Epoch 559/5000 - loss value 9.991757e-01
# Epoch 560/5000 - loss value 1.009607e+00
# Epoch 561/5000 - loss value 1.023702e+00
# Epoch 562/5000 - loss value 1.002689e+00
# Epoch 563/5000 - loss value 1.005213e+00
# Epoch 564/5000 - loss value 9.958048e-01
# Epoch 565/5000 - loss value 9.829842e-01
# Epoch 566/5000 - loss value 9.787685e-01
# Epoch 567/5000 - loss value 9.862110e-01
# Epoch 568/5000 - loss value 9.830808e-01
# Epoch 569/5000 - loss value 1.006674e+00
# Epoch 570/5000 - loss value 9.887267e-01
# Epoch 571/5000 - loss value 9.826260e-01
# Epoch 572/5000 - loss value 9.984151e-01
# Epoch 573/5000 - loss value 1.010967e+00
# Epoch 574/5000 - loss value 9.766494e-01
# Epoch 575/5000 - loss value 1.000174e+00
# Epoch 576/5000 - loss value 9.865154e-01
# Epoch 577/5000 - loss value 9.636412e-01
# Epoch 578/5000 - loss value 9.647384e-01
# Epoch 579/5000 - loss value 9.791300e-01
# Epoch 580/5000 - loss value 9.779340e-01
# Epoch 581/5000 - loss value 9.680758e-01
# Epoch 582/5000 - loss value 9.563673e-01
# Epoch 583/5000 - loss value 9.580858e-01
# Epoch 584/5000 - loss value 9.333462e-01
# Epoch 585/5000 - loss value 9.610475e-01
# Epoch 586/5000 - loss value 9.554986e-01
# Epoch 587/5000 - loss value 9.364070e-01
# Epoch 588/5000 - loss value 9.298443e-01
# Epoch 589/5000 - loss value 9.662544e-01
# Epoch 590/5000 - loss value 9.234589e-01
# Epoch 591/5000 - loss value 9.424512e-01
# Epoch 592/5000 - loss value 9.270857e-01
# Epoch 593/5000 - loss value 9.430592e-01
# Epoch 594/5000 - loss value 9.154181e-01
# Epoch 595/5000 - loss value 9.238945e-01
# Epoch 596/5000 - loss value 9.296598e-01
# Epoch 597/5000 - loss value 9.200406e-01
# Epoch 598/5000 - loss value 9.362565e-01
# Epoch 599/5000 - loss value 9.209778e-01
# Epoch 600/5000 - loss value 9.088236e-01
# Epoch 601/5000 - loss value 9.220173e-01
# Epoch 602/5000 - loss value 9.057022e-01
# Epoch 603/5000 - loss value 9.107951e-01
# Epoch 604/5000 - loss value 9.082697e-01
# Epoch 605/5000 - loss value 9.167868e-01
# Epoch 606/5000 - loss value 8.992370e-01
# Epoch 607/5000 - loss value 9.025658e-01
# Epoch 608/5000 - loss value 8.837156e-01
# Epoch 609/5000 - loss value 8.846647e-01
# Epoch 610/5000 - loss value 8.953632e-01
# Epoch 611/5000 - loss value 8.953732e-01
# Epoch 612/5000 - loss value 9.359009e-01
# Epoch 613/5000 - loss value 9.133441e-01
# Epoch 614/5000 - loss value 8.804187e-01
# Epoch 615/5000 - loss value 8.801141e-01
# Epoch 616/5000 - loss value 8.853307e-01
# Epoch 617/5000 - loss value 8.821780e-01
# Epoch 618/5000 - loss value 8.929605e-01
# Epoch 619/5000 - loss value 8.743868e-01
# Epoch 620/5000 - loss value 8.887840e-01
# Epoch 621/5000 - loss value 8.924670e-01
# Epoch 622/5000 - loss value 8.544232e-01
# Epoch 623/5000 - loss value 8.682628e-01
# Epoch 624/5000 - loss value 8.548935e-01
# Epoch 625/5000 - loss value 8.642744e-01
# Epoch 626/5000 - loss value 8.696616e-01
# Epoch 627/5000 - loss value 8.692744e-01
# Epoch 628/5000 - loss value 8.725227e-01
# Epoch 629/5000 - loss value 8.422973e-01
# Epoch 630/5000 - loss value 8.464574e-01
# Epoch 631/5000 - loss value 8.431796e-01
# Epoch 632/5000 - loss value 8.424811e-01
# Epoch 633/5000 - loss value 8.348478e-01
# Epoch 634/5000 - loss value 8.527028e-01
# Epoch 635/5000 - loss value 8.487016e-01
# Epoch 636/5000 - loss value 8.294683e-01
# Epoch 637/5000 - loss value 8.367870e-01
# Epoch 638/5000 - loss value 8.442234e-01
# Epoch 639/5000 - loss value 8.162445e-01
# Epoch 640/5000 - loss value 8.403025e-01
# Epoch 641/5000 - loss value 8.175513e-01
# Epoch 642/5000 - loss value 8.284433e-01
# Epoch 643/5000 - loss value 8.275610e-01
# Epoch 644/5000 - loss value 8.205216e-01
# Epoch 645/5000 - loss value 8.114583e-01
# Epoch 646/5000 - loss value 8.519991e-01
# Epoch 647/5000 - loss value 8.077545e-01
# Epoch 648/5000 - loss value 8.017038e-01
# Epoch 649/5000 - loss value 8.049124e-01
# Epoch 650/5000 - loss value 8.199117e-01
# Epoch 651/5000 - loss value 8.290303e-01
# Epoch 652/5000 - loss value 8.166871e-01
# Epoch 653/5000 - loss value 8.151244e-01
# Epoch 654/5000 - loss value 7.961220e-01
# Epoch 655/5000 - loss value 7.951302e-01
# Epoch 656/5000 - loss value 8.028164e-01
# Epoch 657/5000 - loss value 7.996962e-01
# Epoch 658/5000 - loss value 7.769134e-01
# Epoch 659/5000 - loss value 7.943571e-01
# Epoch 660/5000 - loss value 7.802384e-01
# Epoch 661/5000 - loss value 8.062639e-01
# Epoch 662/5000 - loss value 7.981810e-01
# Epoch 663/5000 - loss value 7.667598e-01
# Epoch 664/5000 - loss value 8.059736e-01
# Epoch 665/5000 - loss value 8.086009e-01
# Epoch 666/5000 - loss value 7.803729e-01
# Epoch 667/5000 - loss value 7.537003e-01
# Epoch 668/5000 - loss value 7.642619e-01
# Epoch 669/5000 - loss value 7.770375e-01
# Epoch 670/5000 - loss value 7.863334e-01
# Epoch 671/5000 - loss value 7.672374e-01
# Epoch 672/5000 - loss value 7.527517e-01
# Epoch 673/5000 - loss value 7.641987e-01
# Epoch 674/5000 - loss value 7.700401e-01
# Epoch 675/5000 - loss value 7.645114e-01
# Epoch 676/5000 - loss value 7.513121e-01
# Epoch 677/5000 - loss value 7.668986e-01
# Epoch 678/5000 - loss value 7.641982e-01
# Epoch 679/5000 - loss value 7.806684e-01
# Epoch 680/5000 - loss value 7.735920e-01
# Epoch 681/5000 - loss value 7.326452e-01
# Epoch 682/5000 - loss value 7.553094e-01
# Epoch 683/5000 - loss value 7.488076e-01
# Epoch 684/5000 - loss value 7.424625e-01
# Epoch 685/5000 - loss value 7.491254e-01
# Epoch 686/5000 - loss value 7.501810e-01
# Epoch 687/5000 - loss value 7.671835e-01
# Epoch 688/5000 - loss value 7.182071e-01
# Epoch 689/5000 - loss value 7.514904e-01
# Epoch 690/5000 - loss value 7.314711e-01
# Epoch 691/5000 - loss value 7.451515e-01
# Epoch 692/5000 - loss value 7.468483e-01
# Epoch 693/5000 - loss value 7.279558e-01
# Epoch 694/5000 - loss value 7.319924e-01
# Epoch 695/5000 - loss value 7.345321e-01
# Epoch 696/5000 - loss value 7.236034e-01
# Epoch 697/5000 - loss value 7.121908e-01
# Epoch 698/5000 - loss value 7.391824e-01
# Epoch 699/5000 - loss value 7.039091e-01
# Epoch 700/5000 - loss value 7.165755e-01
# Epoch 701/5000 - loss value 7.210677e-01
# Epoch 702/5000 - loss value 7.121113e-01
# Epoch 703/5000 - loss value 7.031926e-01
# Epoch 704/5000 - loss value 7.163920e-01
# Epoch 705/5000 - loss value 7.250365e-01
# Epoch 706/5000 - loss value 7.049464e-01
# Epoch 707/5000 - loss value 6.949367e-01
# Epoch 708/5000 - loss value 7.060822e-01
# Epoch 709/5000 - loss value 7.117724e-01
# Epoch 710/5000 - loss value 7.103700e-01
# Epoch 711/5000 - loss value 7.047717e-01
# Epoch 712/5000 - loss value 6.888608e-01
# Epoch 713/5000 - loss value 6.983653e-01
# Epoch 714/5000 - loss value 6.810550e-01
# Epoch 715/5000 - loss value 6.863561e-01
# Epoch 716/5000 - loss value 7.119697e-01
# Epoch 717/5000 - loss value 6.923328e-01
# Epoch 718/5000 - loss value 7.081276e-01
# Epoch 719/5000 - loss value 6.897002e-01
# Epoch 720/5000 - loss value 6.942023e-01
# Epoch 721/5000 - loss value 6.933112e-01
# Epoch 722/5000 - loss value 6.787364e-01
# Epoch 723/5000 - loss value 6.917205e-01
# Epoch 724/5000 - loss value 6.814799e-01
# Epoch 725/5000 - loss value 6.773965e-01
# Epoch 726/5000 - loss value 6.618852e-01
# Epoch 727/5000 - loss value 6.677210e-01
# Epoch 728/5000 - loss value 6.781755e-01
# Epoch 729/5000 - loss value 6.770196e-01
# Epoch 730/5000 - loss value 6.626931e-01
# Epoch 731/5000 - loss value 6.666757e-01
# Epoch 732/5000 - loss value 6.833258e-01
# Epoch 733/5000 - loss value 6.439644e-01
# Epoch 734/5000 - loss value 6.645300e-01
# Epoch 735/5000 - loss value 6.615972e-01
# Epoch 736/5000 - loss value 6.409551e-01
# Epoch 737/5000 - loss value 6.405918e-01
# Epoch 738/5000 - loss value 6.426747e-01
# Epoch 739/5000 - loss value 6.408006e-01
# Epoch 740/5000 - loss value 6.547026e-01
# Epoch 741/5000 - loss value 6.653514e-01
# Epoch 742/5000 - loss value 6.583351e-01
# Epoch 743/5000 - loss value 6.481007e-01
# Epoch 744/5000 - loss value 6.566821e-01
# Epoch 745/5000 - loss value 6.503729e-01
# Epoch 746/5000 - loss value 6.347403e-01
# Epoch 747/5000 - loss value 6.342783e-01
# Epoch 748/5000 - loss value 6.467412e-01
# Epoch 749/5000 - loss value 6.493627e-01
# Epoch 750/5000 - loss value 6.413558e-01
# Epoch 751/5000 - loss value 6.374543e-01
# Epoch 752/5000 - loss value 6.193112e-01
# Epoch 753/5000 - loss value 6.133891e-01
# Epoch 754/5000 - loss value 6.395552e-01
# Epoch 755/5000 - loss value 6.175502e-01
# Epoch 756/5000 - loss value 6.478276e-01
# Epoch 757/5000 - loss value 6.145507e-01
# Epoch 758/5000 - loss value 6.262711e-01
# Epoch 759/5000 - loss value 6.192312e-01
# Epoch 760/5000 - loss value 6.511981e-01
# Epoch 761/5000 - loss value 5.979657e-01
# Epoch 762/5000 - loss value 6.186161e-01
# Epoch 763/5000 - loss value 6.455841e-01
# Epoch 764/5000 - loss value 6.089394e-01
# Epoch 765/5000 - loss value 6.136047e-01
# Epoch 766/5000 - loss value 6.005354e-01
# Epoch 767/5000 - loss value 6.296486e-01
# Epoch 768/5000 - loss value 6.103459e-01
# Epoch 769/5000 - loss value 5.987996e-01
# Epoch 770/5000 - loss value 5.971188e-01
# Epoch 771/5000 - loss value 6.011786e-01
# Epoch 772/5000 - loss value 6.364883e-01
# Epoch 773/5000 - loss value 6.046213e-01
# Epoch 774/5000 - loss value 6.044224e-01
# Epoch 775/5000 - loss value 5.997983e-01
# Epoch 776/5000 - loss value 6.193274e-01
# Epoch 777/5000 - loss value 5.993697e-01
# Epoch 778/5000 - loss value 6.017502e-01
# Epoch 779/5000 - loss value 5.728952e-01
# Epoch 780/5000 - loss value 5.898996e-01
# Epoch 781/5000 - loss value 5.751223e-01
# Epoch 782/5000 - loss value 6.044107e-01
# Epoch 783/5000 - loss value 5.859341e-01
# Epoch 784/5000 - loss value 5.789198e-01
# Epoch 785/5000 - loss value 5.729350e-01
# Epoch 786/5000 - loss value 5.674741e-01
# Epoch 787/5000 - loss value 5.842794e-01
# Epoch 788/5000 - loss value 5.792094e-01
# Epoch 789/5000 - loss value 5.820424e-01
# Epoch 790/5000 - loss value 5.722286e-01
# Epoch 791/5000 - loss value 5.765722e-01
# Epoch 792/5000 - loss value 5.683364e-01
# Epoch 793/5000 - loss value 5.734024e-01
# Epoch 794/5000 - loss value 5.576019e-01
# Epoch 795/5000 - loss value 5.719002e-01
# Epoch 796/5000 - loss value 5.873976e-01
# Epoch 797/5000 - loss value 5.667921e-01
# Epoch 798/5000 - loss value 5.645388e-01
# Epoch 799/5000 - loss value 5.557410e-01
# Epoch 800/5000 - loss value 5.609700e-01
# Epoch 801/5000 - loss value 5.562037e-01
# Epoch 802/5000 - loss value 5.621968e-01
# Epoch 803/5000 - loss value 5.729908e-01
# Epoch 804/5000 - loss value 5.410697e-01
# Epoch 805/5000 - loss value 5.615843e-01
# Epoch 806/5000 - loss value 5.541419e-01
# Epoch 807/5000 - loss value 5.599854e-01
# Epoch 808/5000 - loss value 5.456423e-01
# Epoch 809/5000 - loss value 5.515826e-01
# Epoch 810/5000 - loss value 5.451304e-01
# Epoch 811/5000 - loss value 5.581939e-01
# Epoch 941/5000 - loss value 3.742524e-01
# Epoch 942/5000 - loss value 3.868464e-01
# Epoch 943/5000 - loss value 3.900828e-01
# Epoch 944/5000 - loss value 3.690001e-01
# Epoch 945/5000 - loss value 3.850869e-01
# Epoch 946/5000 - loss value 3.801718e-01
# Epoch 947/5000 - loss value 3.662103e-01
# Epoch 948/5000 - loss value 3.645727e-01
# Epoch 949/5000 - loss value 3.691508e-01
# Epoch 950/5000 - loss value 3.659697e-01
# Epoch 951/5000 - loss value 3.699349e-01
# Epoch 952/5000 - loss value 3.773181e-01
# Epoch 953/5000 - loss value 3.665215e-01
# Epoch 954/5000 - loss value 3.781282e-01
# Epoch 955/5000 - loss value 3.699905e-01
# Epoch 956/5000 - loss value 3.476365e-01
# Epoch 957/5000 - loss value 3.523535e-01
# Epoch 958/5000 - loss value 3.719237e-01
# Epoch 959/5000 - loss value 3.655606e-01
# Epoch 960/5000 - loss value 3.665804e-01
# Epoch 961/5000 - loss value 3.639998e-01
# Epoch 962/5000 - loss value 3.636975e-01
# Epoch 963/5000 - loss value 3.478652e-01
# Epoch 964/5000 - loss value 3.466503e-01
# Epoch 965/5000 - loss value 3.694622e-01
# Epoch 966/5000 - loss value 3.436411e-01
# Epoch 967/5000 - loss value 3.626072e-01
# Epoch 968/5000 - loss value 3.421619e-01
# Epoch 969/5000 - loss value 3.528656e-01
# Epoch 970/5000 - loss value 3.398910e-01
# Epoch 971/5000 - loss value 3.398592e-01
# Epoch 972/5000 - loss value 3.372170e-01
# Epoch 973/5000 - loss value 3.520667e-01
# Epoch 974/5000 - loss value 3.244592e-01
# Epoch 975/5000 - loss value 3.377507e-01
# Epoch 976/5000 - loss value 3.352870e-01
# Epoch 977/5000 - loss value 3.531747e-01
# Epoch 978/5000 - loss value 3.481156e-01
# Epoch 979/5000 - loss value 3.376877e-01
# Epoch 980/5000 - loss value 3.438959e-01
# Epoch 981/5000 - loss value 3.418842e-01
# Epoch 982/5000 - loss value 3.293657e-01
# Epoch 983/5000 - loss value 3.262752e-01
# Epoch 984/5000 - loss value 3.275088e-01
# Epoch 985/5000 - loss value 3.296303e-01
# Epoch 986/5000 - loss value 3.278924e-01
# Epoch 987/5000 - loss value 3.313747e-01
# Epoch 988/5000 - loss value 3.255462e-01
# Epoch 989/5000 - loss value 3.351268e-01
# Epoch 990/5000 - loss value 3.209086e-01
# Epoch 991/5000 - loss value 3.120646e-01
# Epoch 992/5000 - loss value 3.222196e-01
# Epoch 993/5000 - loss value 3.269635e-01
# Epoch 994/5000 - loss value 3.250781e-01
# Epoch 995/5000 - loss value 3.023339e-01
# Epoch 996/5000 - loss value 3.228486e-01
# Epoch 997/5000 - loss value 3.108503e-01
# Epoch 998/5000 - loss value 3.306389e-01
# Epoch 999/5000 - loss value 3.086652e-01
# Epoch 1000/5000 - loss value 3.090883e-01
# Epoch 1001/5000 - loss value 3.157984e-01
# Epoch 1002/5000 - loss value 3.235695e-01
# Epoch 1003/5000 - loss value 3.018119e-01
# Epoch 1004/5000 - loss value 3.181887e-01
# Epoch 1005/5000 - loss value 3.033672e-01
# Epoch 4965/5000 - loss value -7.569239e-02
# Epoch 4966/5000 - loss value -7.531686e-02
# Epoch 4967/5000 - loss value -7.535129e-02
# Epoch 4968/5000 - loss value -7.369918e-02
# Epoch 4969/5000 - loss value -7.544561e-02
# Epoch 4970/5000 - loss value -7.255166e-02
# Epoch 4971/5000 - loss value -7.612006e-02
# Epoch 4972/5000 - loss value -7.726900e-02
# Epoch 4973/5000 - loss value -7.647217e-02
# Epoch 4974/5000 - loss value -7.785702e-02
# Epoch 4975/5000 - loss value -7.728290e-02
# Epoch 4976/5000 - loss value -7.959050e-02
# Epoch 4977/5000 - loss value -7.948072e-02
# Epoch 4978/5000 - loss value -7.700675e-02
# Epoch 4979/5000 - loss value -7.298356e-02
# Epoch 4980/5000 - loss value -7.290034e-02
# Epoch 4981/5000 - loss value -7.680651e-02
# Epoch 4982/5000 - loss value -7.782498e-02
# Epoch 4983/5000 - loss value -7.682028e-02
# Epoch 4984/5000 - loss value -7.166055e-02
# Epoch 4985/5000 - loss value -7.795987e-02
# Epoch 4986/5000 - loss value -7.631195e-02
# Epoch 4987/5000 - loss value -7.361298e-02
# Epoch 4988/5000 - loss value -7.654109e-02
# Epoch 4989/5000 - loss value -7.507607e-02
# Epoch 4990/5000 - loss value -7.917961e-02
# Epoch 4991/5000 - loss value -7.636796e-02
# Epoch 4992/5000 - loss value -7.651560e-02
# Epoch 4993/5000 - loss value -7.256807e-02
# Epoch 4994/5000 - loss value -7.784556e-02
# Epoch 4995/5000 - loss value -7.500928e-02
# Epoch 4996/5000 - loss value -7.471827e-02
# Epoch 4997/5000 - loss value -7.852640e-02
# Epoch 4998/5000 - loss value -7.555671e-02
# Epoch 4999/5000 - loss value -7.684646e-02
# Epoch 5000/5000 - loss value -7.921178e-02
# Elapsed time  0:03:46.272362

# %%
# %time params, opt_state, loss = step_compiled(params, opt_state, jax.random.PRNGKey(np.random.randint(32131233123)))
# Out:
# CPU times: user 29.1 ms, sys: 3.91 ms, total: 33 ms
# Wall time: 29.9 ms

# %%
x,y = np.meshgrid(np.linspace(-1,1,100),np.linspace(-1,1,100))
ys = np.concatenate((x.flatten()[:,None],y.flatten()[:,None]),1)
xy1 = geom1(ys)
xy2 = geom2(ys)
xy3 = geom3(ys)
xy4 = geom4(ys)

u1 = model.solution1(weights, ys).reshape(x.shape)
u2 = model.solution2(weights, ys).reshape(x.shape)
u3 = model.solution3(weights, ys).reshape(x.shape)
u4 = model.solution4(weights, ys).reshape(x.shape)

plt.figure(figsize = (20,12))
ax = plt.gca()
plt.contourf(xy1[:,0].reshape(x.shape), xy1[:,1].reshape(x.shape), u1, levels = 100, vmin = min([u1.min(),u2.min(),u3.min(),u4.min()]), vmax = max([u1.max(),u2.max(),u3.max(),u4.max()]))
plt.contourf(xy2[:,0].reshape(x.shape), xy2[:,1].reshape(x.shape), u2, levels = 100, vmin = min([u1.min(),u2.min(),u3.min(),u4.min()]), vmax = max([u1.max(),u2.max(),u3.max(),u4.max()]))
plt.contourf(xy3[:,0].reshape(x.shape), xy3[:,1].reshape(x.shape), u3, levels = 100, vmin = min([u1.min(),u2.min(),u3.min(),u4.min()]), vmax = max([u1.max(),u2.max(),u3.max(),u4.max()]))
plt.contourf(xy4[:,0].reshape(x.shape), xy4[:,1].reshape(x.shape), u4, levels = 100, vmin = min([u1.min(),u2.min(),u3.min(),u4.min()]), vmax = max([u1.max(),u2.max(),u3.max(),u4.max()]))
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
# Out:
# Text(0, 0.5, '$x_2$')

# %%
fem = FEM(mu0=model.mu0,mur=model.mur,J0 = model.J0,meshsize = 0.0005)

u1_ref = fem.call_A(np.array(xy1[:,0]), np.array(xy1[:,1])).reshape(x.shape)
u2_ref = fem.call_A(np.array(xy2[:,0]), np.array(xy2[:,1])).reshape(x.shape)
u3_ref = fem.call_A(np.array(xy3[:,0]), np.array(xy3[:,1])).reshape(x.shape)
u4_ref = fem.call_A(np.array(xy4[:,0]), np.array(xy4[:,1])).reshape(x.shape)

plt.figure()
ax = plt.gca()
plt.contourf(xy1[:,0].reshape(x.shape), xy1[:,1].reshape(x.shape), u1_ref, levels = 100, vmin = min([u1_ref.min(),u2_ref.min(),u3_ref.min(),u4_ref.min()]), vmax = max([u1_ref.max(),u2_ref.max(),u3_ref.max(),u4_ref.max()]))
plt.contourf(xy2[:,0].reshape(x.shape), xy2[:,1].reshape(x.shape), u2_ref, levels = 100, vmin = min([u1_ref.min(),u2_ref.min(),u3_ref.min(),u4_ref.min()]), vmax = max([u1_ref.max(),u2_ref.max(),u3_ref.max(),u4_ref.max()]))
plt.contourf(xy3[:,0].reshape(x.shape), xy3[:,1].reshape(x.shape), u3_ref, levels = 100, vmin = min([u1_ref.min(),u2_ref.min(),u3_ref.min(),u4_ref.min()]), vmax = max([u1_ref.max(),u2_ref.max(),u3_ref.max(),u4_ref.max()]))
plt.contourf(xy4[:,0].reshape(x.shape), xy4[:,1].reshape(x.shape), u4_ref, levels = 100, vmin = min([u1_ref.min(),u2_ref.min(),u3_ref.min(),u4_ref.min()]), vmax = max([u1_ref.max(),u2_ref.max(),u3_ref.max(),u4_ref.max()]))
plt.colorbar()

delta1 = np.abs(u1-u1_ref)
delta2 = np.abs(u2-u2_ref)
delta3 = np.abs(u3-u3_ref)
delta4 = np.abs(u4-u4_ref)

plt.figure()
ax = plt.gca()
plt.contourf(xy2[:,0].reshape(x.shape), xy2[:,1].reshape(x.shape), delta2, levels = 100, vmin = min([delta1.min(),delta2.min(),delta3.min(),delta4.min()]), vmax = max([delta1.max(),delta2.max(),delta3.max(),delta4.max()]))
plt.contourf(xy3[:,0].reshape(x.shape), xy3[:,1].reshape(x.shape), delta3, levels = 100, vmin = min([delta1.min(),delta2.min(),delta3.min(),delta4.min()]), vmax = max([delta1.max(),delta2.max(),delta3.max(),delta4.max()]))
plt.contourf(xy4[:,0].reshape(x.shape), xy4[:,1].reshape(x.shape), delta4, levels = 100, vmin = min([delta1.min(),delta2.min(),delta3.min(),delta4.min()]), vmax = max([delta1.max(),delta2.max(),delta3.max(),delta4.max()]))
plt.contourf(xy1[:,0].reshape(x.shape), xy1[:,1].reshape(x.shape), delta1, levels = 100, vmin = min([delta1.min(),delta2.min(),delta3.min(),delta4.min()]), vmax = max([delta1.max(),delta2.max(),delta3.max(),delta4.max()]))
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')

print()
print('Linf relative error',max([np.max(delta1),np.max(delta2),np.max(delta3),np.max(delta4)])/max([np.max(u1),np.max(u2),np.max(u3),np.max(u4)])*100, '%')
# Out:
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.666e+00 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 6.831e-11 (tol = 1.000e-10) r (rel) = 2.563e-11 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 202083 nodes for 101042 points.
#
# Linf relative error 1.2343950442132319 %

# %%
xs1 = geom1(model.points['ys1'])
xs2 = geom2(model.points['ys2'])
xs3 = geom3(model.points['ys3'])
xs4 = geom4(model.points['ys4'])

u1_ref = fem.call_A(np.array(xs1[:,0]),np.array(xs1[:,1])).flatten()
u2_ref = fem.call_A(np.array(xs2[:,0]),np.array(xs2[:,1])).flatten()
u3_ref = fem.call_A(np.array(xs3[:,0]),np.array(xs3[:,1])).flatten()
u4_ref = fem.call_A(np.array(xs4[:,0]),np.array(xs4[:,1])).flatten()

u1 = model.solution1(weights, model.points['ys1']).flatten()
u2 = model.solution2(weights, model.points['ys2']).flatten()
u3 = model.solution3(weights, model.points['ys3']).flatten()
u4 = model.solution4(weights, model.points['ys4']).flatten()

int1 = jnp.dot((u1-u1_ref)**2,model.points['omega1']*model.points['ws1']) / jnp.dot((u1_ref)**2,model.points['omega1']*model.points['ws1'])
int2 = jnp.dot((u2-u2_ref)**2,model.points['omega2']*model.points['ws2']) / jnp.dot((u2_ref)**2,model.points['omega2']*model.points['ws2'])
int3 = jnp.dot((u3-u3_ref)**2,model.points['omega3']*model.points['ws3']) / jnp.dot((u3_ref)**2,model.points['omega3']*model.points['ws3'])
int4 = jnp.dot((u4-u4_ref)**2,model.points['omega4']*model.points['ws4']) / jnp.dot((u4_ref)**2,model.points['omega4']*model.points['ws4'])

print(int1, int2, int3, int4)
# Out:
# 0.00012504056871473306 3.997714640159553e-05 3.233852404618361e-06 7.435704904964243e-05

# %%
print(np.mean(delta1)/np.max(u1))
print('Surface copper', np.sum(model.points['omega3']*model.points['ws3']))
print('J0 ',50/np.sum(model.points['omega3']*model.points['ws3'])*24)
# Out:
# 0.003004968830155174
# Surface copper 0.00021723624488131148
# J0  5523940.080328806

# %%
plt.figure()
plt.scatter(xs1[:,0],xs1[:,1], s= 1)
plt.scatter(xs2[:,0],xs2[:,1], s= 1)
plt.scatter(xs3[:,0],xs3[:,1], s= 1)
plt.scatter(xs4[:,0],xs4[:,1], s= 1)

plt.figure()
fn.plot(fem.mesh)
# Out:
# [<matplotlib.lines.Line2D at 0x7f215c79ad70>,
#  <matplotlib.lines.Line2D at 0x7f21f844b550>]

# %%
model.points['ys1'].max(), np.sum(model.points['ys1'][:,1]*model.points['ws1'])
jax.devices()[0]
