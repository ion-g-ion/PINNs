# %% [markdown]
# Imports:

# %%
import numpy as np
import jax
import jax.numpy as jnp
from jax.example_libraries import stax, optimizers
import matplotlib.pyplot as plt
import pyvista as pv
import pinns 
import datetime
import jax.scipy.optimize
import jax.flatten_util
import scipy
import scipy.optimize
import random

from pygccx import model as ccx_model
from pygccx import model_keywords as mk
from pygccx import step_keywords as sk
from pygccx import enums

rnd_key = jax.random.PRNGKey(1234)
np.random.seed(14124)
# Out:
# 2024-05-16 17:51:28.475840: E external/xla/xla/stream_executor/cuda/cuda_driver.cc:280] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %% [markdown]
# Set the default precision and the execution device.

# %%
jax.config.update("jax_enable_x64", False)
# print("GPU devices: ", jax.devices('gpu'))
dev = jax.devices('gpu')[0] if jax.device_count()>1 and len(jax.devices('gpu'))>0 else jax.devices('cpu')[0]
print(dev)
# Out:
# TFRT_CPU_0

# %% [markdown]
# ### Geometry definition
#
# Define the geometry patches:

# %%
def get_domain(r0: float, r1: float, R: float, h: float, H: float):

    basis1 = pinns.functions.BSplineBasisJAX(np.array([-1, 0, 1]), 2)
    basis2 = pinns.functions.BSplineBasisJAX(np.array([-1, 1]), 2)
    basis3 = pinns.functions.BSplineBasisJAX(np.array([-1, 1]), 1)

    def tmp_gen(angle, r_0, r_1):
        pts = np.zeros([4, 3, 2, 3])
        weights = np.ones([4, 3, 2])

        a = np.pi/2-angle/2
        rs = np.linspace(r_0, r_1, 4)
        pts[-1, 0, 0, :] = [np.cos(-angle/2), np.sin(-angle/2), 0]
        pts[-1, 1, 0, :] = [1/np.sin(a), 0, 0]
        pts[-1, 2, 0, :] = [np.cos(angle/2), np.sin(angle/2), 0]
        pts[0, :, 0, :2] = rs[0] * pts[-1, :, 0, :2]
        pts[1, :, 0, :2] = rs[1] * pts[-1, :, 0, :2]
        pts[2, :, 0, :2] = rs[2] * pts[-1, :, 0, :2]
        pts[3, :, 0, :2] = rs[3] * pts[-1, :, 0, :2]
        pts[0, :, 0, 2] = -1
        pts[1, :, 0, 2] = -1
        pts[2, :, 0, 2] = -1
        pts[3, :, 0, 2] = -1
        pts[:, :, 1, :] = pts[:, :, 0, :]
        pts[:, :, 1, 2] = -pts[:, :, 1, 2]
        weights[:, 1, :] = np.sin(a)

        return pts, weights

    geoms = dict()

    pts, weights = tmp_gen(np.pi/2, r0, r1)
    pts[:, :, :, 2] *= h/2
    # pts[2:,:,:,2] *= h/2
    pts[3, 1, :, 0] = pts[3, 0, :, 0]
    pts[1, 1, :, 0] = 2*pts[0, 1, :, 0]/3+pts[-1, 1, :, 0]/3
    pts[2, 1, :, 0] = pts[0, 1, :, 0]/3+2*pts[-1, 1, :, 0]/3
    weights[-1, 1, :] = 1.0

    geoms['flat'] = pinns.geometry.PatchNURBS(
        [basis1, basis2, basis3], pts.copy(), weights.copy(), 0, 3)

    pts2 = pts[-1, :, :, :]
    weights[...] = 1.0
    linsp = np.linspace(0, 1, basis1.n)

    pts[0, :, :, :] = pts2
    pts[-1, :, :, :] = pts2
    pts[-1, :, :, 0] *= R/r1
    pts[-1, :, :, 1] *= H/h
    # pts[0, :, :, 2] *= H/h

    for i in range(1, basis1.n-1):
        pts[i, :, :, 2] = (1-linsp[i]**0.25)*pts[0, :, :, 2] + \
            linsp[i]**0.25*pts[-1, :, :, 2]
        pts[i, :, :, 0] = (1-linsp[i])*pts[0, :, :, 0] + \
            linsp[i]*pts[-1, :, :, 0]
        pts[i, :, :, 1] = (1-linsp[i]**4)*pts[0, :, :, 1] + \
            linsp[i]**4*pts[-1, :, :, 1]
        pts[i, :, :, 1] *= 2*(linsp[i]-1/2)**2+0.5
        pts[i, :, :, 2] *= 2*(linsp[i]-1/2)**2+0.5

    geoms['spoke'] = pinns.geometry.PatchNURBS(
        [basis1, basis2, basis3], pts, weights, 0, 3)

    pts, weights = tmp_gen(np.pi/2, r0, r1)
    pts[:, :, :, 2] *= h/2
    # pts[2:,:,:,2] *= h/2

    geoms['round_0'] = pinns.geometry.PatchNURBS(
        [basis1, basis2, basis3], pts, weights, 0, 3)
    geoms['round_0'].rotate((0, 0, np.pi/2))

    pts, weights = tmp_gen(np.pi/2, r0, r1)
    pts[:, :, :, 2] *= h/2
    # pts[2:,:,:,2] *= h/2

    geoms['round_1'] = pinns.geometry.PatchNURBS(
        [basis1, basis2, basis3], pts, weights, 0, 3)
    geoms['round_1'].rotate((0, 0, 2*np.pi/2))

    pts, weights = tmp_gen(np.pi/2, r0, r1)
    pts[:, :, :, 2] *= h/2
    # pts[2:,:,:,2] *= h/2

    geoms['round_2'] = pinns.geometry.PatchNURBS(
        [basis1, basis2, basis3], pts, weights, 0, 3)
    geoms['round_2'].rotate((0, 0, 3*np.pi/2))

    return geoms


geoms = get_domain(0.4, 0.8, 3.0, 1.0, 1.5)
names = list(geoms.keys())

# %% [markdown]
# Determine the connectivity of the patches:

# %%
with jax.disable_jit(True):
    connectivity = pinns.geometry.match_patches(geoms, eps=1e-4, verbose=False)

for c in connectivity:
    print(c)
# Out:
# {'first': 'flat', 'second': 'spoke', 'axis_first': (0,), 'axis_second': (0,), 'end_first': (-1,), 'end_second': (0,), 'axis_permutation': (None, (1, 1), (2, 1))}
# {'first': 'flat', 'second': 'round_0', 'axis_first': (1,), 'axis_second': (1,), 'end_first': (-1,), 'end_second': (0,), 'axis_permutation': ((0, 1), None, (2, 1))}
# {'first': 'flat', 'second': 'round_2', 'axis_first': (1,), 'axis_second': (1,), 'end_first': (0,), 'end_second': (-1,), 'axis_permutation': ((0, 1), None, (2, 1))}
# {'first': 'spoke', 'second': 'round_0', 'axis_first': (0, 1), 'axis_second': (0, 1), 'end_first': (0, -1), 'end_second': (-1, 0), 'axis_permutation': (None, None, (2, 1))}
# {'first': 'spoke', 'second': 'round_2', 'axis_first': (0, 1), 'axis_second': (0, 1), 'end_first': (0, 0), 'end_second': (-1, -1), 'axis_permutation': (None, None, (2, 1))}
# {'first': 'round_0', 'second': 'round_1', 'axis_first': (1,), 'axis_second': (1,), 'end_first': (-1,), 'end_second': (0,), 'axis_permutation': ((0, 1), None, (2, 1))}
# {'first': 'round_1', 'second': 'round_2', 'axis_first': (1,), 'axis_second': (1,), 'end_first': (-1,), 'end_second': (0,), 'axis_permutation': ((0, 1), None, (2, 1))}

# %%
def construct_inp(geoms: dict, E: float, mu: float, dens: float, n: int, meshsize: float, contact_low=None, contact_up=None):
    
    with ccx_model.Model("/usr/bin/ccx", "/usr/bin/cgx", jobname='holder', working_dir="./") as model:

        gmsh = model.get_gmsh()
        
        surfaces = dict()
        
        for name in geoms:
            print(name)
            meshgrid = np.meshgrid(np.linspace(-1,1,n), np.linspace(-1,1,n))
            positions = geoms[name][:,:,-1](np.concatenate((meshgrid[0].reshape([-1,1]), meshgrid[1].reshape([-1,1])),-1))
            indices = []
            for i in range(positions.shape[0]):
                tag = gmsh.model.occ.addPoint(positions[i,0], positions[i,1], positions[i,2], tag = -1, meshSize = meshsize)
                indices.append(tag)
            tag = gmsh.model.occ.addBSplineSurface(indices, n, -1, 2, 2)
            surfaces[(name, 2, 0)] = tag 
            
            meshgrid = np.meshgrid(np.linspace(-1,1,n), np.linspace(-1,1,n))
            positions = geoms[name][:,:,1](np.concatenate((meshgrid[0].reshape([-1,1]), meshgrid[1].reshape([-1,1])),-1))
            indices = []
            for i in range(positions.shape[0]):
                tag = gmsh.model.occ.addPoint(positions[i,0], positions[i,1], positions[i,2], tag = -1, meshSize = meshsize)
                indices.append(tag)
            tag = gmsh.model.occ.addBSplineSurface(indices, n, -1, 2, 2)
            surfaces[(name, 2, -1)] = tag
            
            meshgrid = np.meshgrid(np.linspace(-1,1,n), np.linspace(-1,1,n))
            positions = geoms[name][:,-1,:](np.concatenate((meshgrid[0].reshape([-1,1]), meshgrid[1].reshape([-1,1])),-1))
            indices = []
            for i in range(positions.shape[0]):
                tag = gmsh.model.occ.addPoint(positions[i,0], positions[i,1], positions[i,2], tag = -1, meshSize = meshsize)
                indices.append(tag)
            tag = gmsh.model.occ.addBSplineSurface(indices, n, -1, 2, 2)
            surfaces[(name, 1, 0)] = tag
            
            meshgrid = np.meshgrid(np.linspace(-1,1,n), np.linspace(-1,1,n))
            positions = geoms[name][:,1,:](np.concatenate((meshgrid[0].reshape([-1,1]), meshgrid[1].reshape([-1,1])),-1))
            indices = []
            for i in range(positions.shape[0]):
                tag = gmsh.model.occ.addPoint(positions[i,0], positions[i,1], positions[i,2], tag = -1, meshSize = meshsize)
                indices.append(tag)
            tag = gmsh.model.occ.addBSplineSurface(indices, n, -1, 2, 2)
            surfaces[(name, 1, -1)] = tag
            
            meshgrid = np.meshgrid(np.linspace(-1,1,n), np.linspace(-1,1,n))
            positions = geoms[name][-1,:,:](np.concatenate((meshgrid[0].reshape([-1,1]), meshgrid[1].reshape([-1,1])),-1))
            indices = []
            for i in range(positions.shape[0]):
                tag = gmsh.model.occ.addPoint(positions[i,0], positions[i,1], positions[i,2], tag = -1, meshSize = meshsize)
                indices.append(tag)
            tag = gmsh.model.occ.addBSplineSurface(indices, n, -1, 2, 2)
            surfaces[(name, 0, 0)] = tag
            
            meshgrid = np.meshgrid(np.linspace(-1,1,n), np.linspace(-1,1,n))
            positions = geoms[name][1,:,:](np.concatenate((meshgrid[0].reshape([-1,1]), meshgrid[1].reshape([-1,1])),-1))
            indices = []
            for i in range(positions.shape[0]):
                tag = gmsh.model.occ.addPoint(positions[i,0], positions[i,1], positions[i,2], tag = -1, meshSize = meshsize)
                indices.append(tag)
            tag = gmsh.model.occ.addBSplineSurface(indices, n, -1, 2, 2)
            surfaces[(name, 0, -1)] = tag
            
       
        #tag = gmsh.model.occ.add_curve_loop([surfaces[('spoke', 0, -1)], surfaces[('spoke', 1, -1)], surfaces[('spoke', 1, 0)], surfaces[('spoke', 2, -1)], surfaces[('spoke', 2, 0)],
        #                                     surfaces[('flat', 0, 0)], surfaces[('flat', 2, 0)], surfaces[('flat', 2, -1)],
        #                                     surfaces[('round_0', 0, -1)], surfaces[('round_0', 0, 0)], surfaces[('round_0', 2, -1)], surfaces[('round_0', 2, 0)],
        #                                     surfaces[('round_1', 0, -1)], surfaces[('round_1', 0, 0)], surfaces[('round_1', 2, -1)], surfaces[('round_1', 2, 0)],
        #                                     surfaces[('round_2', 0, -1)], surfaces[('round_2', 0, 0)], surfaces[('round_2', 2, -1)], surfaces[('round_2', 2, 0)],
        #                                     ])
        
        gmsh.model.occ.remove_all_duplicates()
        closed_surface_loop = [surfaces[('spoke', 0, -1)], surfaces[('spoke', 1, 0)], surfaces[('spoke', 1, -1)], surfaces[('spoke', 2, -1)], surfaces[('spoke', 2, 0)]]
        closed_surface_loop += [surfaces[('flat',0,0)], surfaces[('flat',2,0)], surfaces[('flat',2,-1)]]
        closed_surface_loop += [surfaces[('round_0',0,0)], surfaces[('round_0',0,-1)], surfaces[('round_0',2,0)], surfaces[('round_0',2,-1)]]
        closed_surface_loop += [surfaces[('round_1',0,0)], surfaces[('round_1',0,-1)], surfaces[('round_1',2,0)], surfaces[('round_1',2,-1)]]
        closed_surface_loop += [surfaces[('round_2',0,0)], surfaces[('round_2',0,-1)], surfaces[('round_2',2,0)], surfaces[('round_2',2,-1)]]
        
        tag = gmsh.model.occ.add_surface_loop(closed_surface_loop)
        
        tag_volume = gmsh.model.occ.add_volume([tag])
        
        OFFSET = 1.0
        if contact_low is not None:
            tag_lower_surface = gmsh.model.occ.add_rectangle(-1, -1, 0, 1.5, 2)
            gmsh.model.occ.rotate([(2,tag_lower_surface)], 0, 0, 0, 1, 0, 0, -np.pi/2)
            gmsh.model.occ.translate([(2,tag_lower_surface)], 0, contact_low-OFFSET, 0)
            tags_lower_volume = gmsh.model.occ.extrude([(2, tag_lower_surface)], 0, -0.1, 0)
            tags_lower_volume = [t[1] for t in tags_lower_volume if t[0]==3][0]
            
        if contact_up is not None:
            tag_up_surface = gmsh.model.occ.add_rectangle(-1, -1, 0, 1.5, 2)
            gmsh.model.occ.rotate([(2,tag_up_surface)], 0, 0, 0, 1, 0, 0, -np.pi/2)
            gmsh.model.occ.translate([(2,tag_up_surface)], 0, contact_up+OFFSET, 0)
            tags_up_volume = gmsh.model.occ.extrude([(2, tag_up_surface)], 0, 0.1, 0)
            tags_up_volume = [t[1] for t in tags_up_volume if t[0]==3][0]
            
        gmsh.model.occ.synchronize()
       

        if contact_up is not None: 
            gmsh.model.add_physical_group(2, [surfaces[('round_0', 0, -1)]], name="UPPER_SURFACE")
            gmsh.model.add_physical_group(2, [tag_up_surface], name="UPPER_PRESS_SURFACE")
            gmsh.model.add_physical_group(3, [tags_up_volume], name="UPPER_PRESS")

        if contact_low is not None: 
            gmsh.model.add_physical_group(2, [surfaces[('round_2', 0, -1)]], name="LOWER_SURFACE")
            gmsh.model.add_physical_group(2, [tag_lower_surface], name="LOWER_PRESS_SURFACE")
            gmsh.model.add_physical_group(3, [tags_lower_volume], name="LOWER_PRESS")
            
        gmsh.model.add_physical_group(3, [tag_volume], name='HOLDER')
        gmsh.model.add_physical_group(2, [surfaces[('spoke', 0, -1)]], name='FIX')
        closed_surface_loop.remove(surfaces[('spoke', 0, -1)])
        gmsh.model.add_physical_group(2, closed_surface_loop, name='NOT_FIX')
        
        gmsh.model.mesh.set_size_callback(lambda dim, tag, x, y, z, lc: meshsize)
        gmsh.model.mesh.generate(3)
        
        gmsh.write("test.geo_unrolled")
        gmsh.write("test.msh")
        
        print("meshed")
        
        model.update_mesh_from_gmsh()
        mesh = model.mesh

        
        # fix the left end
        fix_set = model.mesh.get_node_set_by_name('FIX')
        model.add_model_keywords(
            mk.Boundary(fix_set, first_dof=1, last_dof=3)
        )
        if contact_up is not None:
            model.add_model_keywords(mk.Boundary(model.mesh.get_node_set_by_name("UPPER_PRESS_SURFACE"), first_dof=3))
            model.add_model_keywords(mk.Boundary(model.mesh.get_node_set_by_name("UPPER_PRESS_SURFACE"), first_dof=1))
       
        if contact_low is not None:
            model.add_model_keywords(mk.Boundary(model.mesh.get_node_set_by_name("LOWER_PRESS_SURFACE"), first_dof=1))
            model.add_model_keywords(mk.Boundary(model.mesh.get_node_set_by_name("LOWER_PRESS_SURFACE"), first_dof=3))

        mat = mk.Material('ELASTIC')
        el = mk.Elastic((E, mu))
        dens = mk.Density(dens)
        sos = mk.SolidSection(
            elset=mesh.get_el_set_by_name('HOLDER'),
            material = mat
        )
        model.add_model_keywords(mat, el, dens, sos)
        
        if contact_up:
            
            upper_press_surface = mesh.add_surface_from_node_set("UPPER_PRESS_SURFACE_SET", mesh.get_node_set_by_name("UPPER_PRESS_SURFACE"), enums.ESurfTypes.EL_FACE)
            upper_contact_surface = mesh.add_surface_from_node_set("UPPER_SURFACE_SET", mesh.get_node_set_by_name("UPPER_SURFACE"), enums.ESurfTypes.EL_FACE)
            
            mat = mk.Material('ELASTIC')
            el = mk.Elastic((300000., 0.3))
            
            sos = mk.SolidSection(
                elset=mesh.get_el_set_by_name('UPPER_PRESS'),
                material = mat
            )
            model.add_model_keywords(mat, el, sos)
            
            interact = mk.SurfaceInteraction("up")
            behavior = mk.SurfaceBehavior(enums.EPressureOverclosures.LINEAR, k=1e4, sig_inf=1e5)
            pair = mk.ContactPair(interact, enums.EContactTypes.NODE_TO_SURFACE, upper_contact_surface, upper_press_surface)

            model.add_model_keywords(pair, interact, behavior)
            
        if contact_low:
            lower_press_surface = mesh.add_surface_from_node_set("LOWER_PRESS_SURFACE_SET", mesh.get_node_set_by_name("LOWER_PRESS_SURFACE"), enums.ESurfTypes.EL_FACE)
            lower_contact_surface = mesh.add_surface_from_node_set("LOWER_SURFACE_SET", mesh.get_node_set_by_name("LOWER_SURFACE"), enums.ESurfTypes.EL_FACE)
            
            mat = mk.Material('ELASTIC')
            el = mk.Elastic((300000., 0.3))
            
            sos = mk.SolidSection(
                elset=mesh.get_el_set_by_name('LOWER_PRESS'),
                material = mat
            )
            model.add_model_keywords(mat, el, sos)
            
            interact = mk.SurfaceInteraction("low")
            behavior = mk.SurfaceBehavior(enums.EPressureOverclosures.LINEAR, k=1e4, sig_inf=1e5)
            pair = mk.ContactPair(interact, enums.EContactTypes.NODE_TO_SURFACE, lower_contact_surface, lower_press_surface)

            model.add_model_keywords(pair, interact, behavior)
             
        step = sk.Step(nlgeom=True) 
        model.add_steps(step)       
        
        step.add_step_keywords(
            sk.Static(),                # step is a static one
            sk.Dload(mesh.get_el_set_by_name('HOLDER'), enums.EDloadType.GRAV, (9.810, 0, -1, 0)),
            sk.Boundary(model.mesh.get_node_set_by_name("UPPER_PRESS_SURFACE"), 2, -OFFSET),
            sk.Boundary(model.mesh.get_node_set_by_name("LOWER_PRESS_SURFACE"), 2, OFFSET),
            sk.NodeFile([enums.ENodeFileResults.U,
                         enums.ENodeFileResults.RF]), # request deformations in frd file
            sk.ElFile([enums.EElFileResults.S]), # request stresses in frd file
            sk.NodePrint(mesh.get_node_set_by_name('HOLDER'),[enums.ENodePrintResults.U,
                                                            enums.ENodePrintResults.RF]),
            sk.ElPrint(mesh.get_el_set_by_name('HOLDER'),[enums.EElPrintResults.S,
                                                        enums.EElPrintResults.EVOL,
                                                        enums.EElPrintResults.COORD,
                                                        enums.EElPrintResults.E,
                                                        enums.EElPrintResults.ME,
                                                        enums.EElPrintResults.ENER,
                                                        enums.EElPrintResults.ELKE,
                                                        enums.EElPrintResults.ELSE,
                                                        enums.EElPrintResults.EMAS])
        )
        
        model.write_ccx_input_file()
        model.solve(no_cpu=8)
        #model.show_results_in_cgx()
        

        
        # gmsh.write('holder.msh')
        # gmsh.write('holder.inp')

# %%
with jax.disable_jit(True):
    construct_inp(geoms, 2000, 0.3, 0.2, 16, 0.1, -0.75, 0.75)
# Out:
# flat
# spoke
# round_0
# round_1
# round_2
# Info    : Cannot bind existing OpenCASCADE surface 6 to second tag 11
# Info    : Could not preserve tag of 2D object 11 (->6)
# Info    : Cannot bind existing OpenCASCADE surface 4 to second tag 15
# Info    : Could not preserve tag of 2D object 15 (->4)
# Info    : Cannot bind existing OpenCASCADE surface 16 to second tag 21
# Info    : Could not preserve tag of 2D object 21 (->16)
# Info    : Cannot bind existing OpenCASCADE surface 22 to second tag 27
# Info    : Could not preserve tag of 2D object 27 (->22)
# Info    : Cannot bind existing OpenCASCADE surface 3 to second tag 28
# Info    : Could not preserve tag of 2D object 28 (->3)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (BSpline)
# Info    : [ 10%] Meshing curve 2 (BSpline)
# Info    : [ 10%] Meshing curve 3 (BSpline)
# Info    : [ 10%] Meshing curve 4 (BSpline)
# Info    : [ 10%] Meshing curve 5 (BSpline)
# Info    : [ 10%] Meshing curve 6 (BSpline)
# Info    : [ 10%] Meshing curve 7 (BSpline)
# Info    : [ 20%] Meshing curve 8 (BSpline)
# Info    : [ 20%] Meshing curve 9 (BSpline)
# Info    : [ 20%] Meshing curve 10 (BSpline)
# Info    : [ 20%] Meshing curve 11 (BSpline)
# Info    : [ 20%] Meshing curve 12 (BSpline)
# Info    : [ 20%] Meshing curve 13 (BSpline)
# Info    : [ 30%] Meshing curve 14 (BSpline)
# Info    : [ 30%] Meshing curve 15 (BSpline)
# Info    : [ 30%] Meshing curve 16 (BSpline)
# Info    : [ 30%] Meshing curve 17 (BSpline)
# Info    : [ 30%] Meshing curve 18 (BSpline)
# Info    : [ 30%] Meshing curve 19 (BSpline)
# Info    : [ 30%] Meshing curve 20 (BSpline)
# Info    : [ 40%] Meshing curve 21 (BSpline)
# Info    : [ 40%] Meshing curve 22 (BSpline)
# Info    : [ 40%] Meshing curve 23 (BSpline)
# Info    : [ 40%] Meshing curve 24 (BSpline)
# Info    : [ 40%] Meshing curve 25 (BSpline)
# Info    : [ 40%] Meshing curve 26 (BSpline)
# Info    : [ 50%] Meshing curve 27 (BSpline)
# Info    : [ 50%] Meshing curve 28 (BSpline)
# Info    : [ 50%] Meshing curve 29 (BSpline)
# Info    : [ 50%] Meshing curve 30 (BSpline)
# Info    : [ 50%] Meshing curve 31 (BSpline)
# Info    : [ 50%] Meshing curve 32 (BSpline)
# Info    : [ 50%] Meshing curve 33 (BSpline)
# Info    : [ 60%] Meshing curve 34 (BSpline)
# Info    : [ 60%] Meshing curve 35 (BSpline)
# Info    : [ 60%] Meshing curve 36 (BSpline)
# Info    : [ 60%] Meshing curve 37 (BSpline)
# Info    : [ 60%] Meshing curve 38 (BSpline)
# Info    : [ 60%] Meshing curve 39 (BSpline)
# Info    : [ 70%] Meshing curve 40 (BSpline)
# Info    : [ 70%] Meshing curve 41 (Line)
# Info    : [ 70%] Meshing curve 42 (Line)
# Info    : [ 70%] Meshing curve 43 (Line)
# Info    : [ 70%] Meshing curve 44 (Line)
# Info    : [ 70%] Meshing curve 45 (Line)
# Info    : [ 80%] Meshing curve 46 (Line)
# Info    : [ 80%] Meshing curve 47 (Line)
# Info    : [ 80%] Meshing curve 48 (Line)
# Info    : [ 80%] Meshing curve 49 (Line)
# Info    : [ 80%] Meshing curve 50 (Line)
# Info    : [ 80%] Meshing curve 51 (Line)
# Info    : [ 80%] Meshing curve 52 (Line)
# Info    : [ 90%] Meshing curve 53 (Line)
# Info    : [ 90%] Meshing curve 54 (Line)
# Info    : [ 90%] Meshing curve 55 (Line)
# Info    : [ 90%] Meshing curve 56 (Line)
# Info    : [ 90%] Meshing curve 57 (Line)
# Info    : [ 90%] Meshing curve 58 (Line)
# Info    : [100%] Meshing curve 59 (Line)
# Info    : [100%] Meshing curve 60 (Line)
# Info    : [100%] Meshing curve 61 (Line)
# Info    : [100%] Meshing curve 62 (Line)
# Info    : [100%] Meshing curve 63 (Line)
# Info    : [100%] Meshing curve 64 (Line)
# Info    : Done meshing 1D (Wall 0.211882s, CPU 0.216148s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 2 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 3 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 4 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 5 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 6 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 7 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 8 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 9 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 10 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 12 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 13 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 14 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 16 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 17 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 18 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 19 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 20 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 22 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 23 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 24 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 25 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 26 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 29 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 30 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 31 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 32 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 33 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 34 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 35 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 36 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 37 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 38 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 39 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 40 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 41 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 42 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.533596s, CPU 0.538234s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 3 volumes with 3 connected components
# Info    : Tetrahedrizing 2184 nodes...
# Info    : Done tetrahedrizing 2192 nodes (Wall 0.083842s, CPU 0.083687s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.17191s, CPU 0.169385s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 3.86958 (nodes removed 0 0)
# Info    : It. 500 - 500 nodes created - worst tet radius 1.24147 (nodes removed 0 0)
# Info    : It. 1000 - 1000 nodes created - worst tet radius 1.02695 (nodes removed 0 0)
# Info    : 3D refinement terminated (5296 nodes total):
# Info    :  - 2 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 13393 tetrahedra created in 0.167529 sec. (79944 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 870 nodes...
# Info    : Done tetrahedrizing 878 nodes (Wall 0.0332565s, CPU 0.033808s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 6 Steiner points
# Info    : Done reconstructing mesh (Wall 0.0786613s, CPU 0.079546s)
# Info    : Found volume 2
# Info    : It. 0 - 0 nodes created - worst tet radius 1.09917 (nodes removed 0 0)
# Info    : 3D refinement terminated (4226 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 2 nodes could not be inserted
# Info    :  - 2572 tetrahedra created in 0.00439575 sec. (585110 tets/s)
# Info    : 1 node relocations
# Info    : Tetrahedrizing 870 nodes...
# Info    : Done tetrahedrizing 878 nodes (Wall 0.0349145s, CPU 0.034843s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 4 Steiner points
# Info    : Done reconstructing mesh (Wall 0.0834591s, CPU 0.085132s)
# Info    : Found volume 3
# Info    : It. 0 - 0 nodes created - worst tet radius 1.07761 (nodes removed 0 0)
# Info    : 3D refinement terminated (4220 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 2561 tetrahedra created in 0.00415704 sec. (616062 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 0.906105s, CPU 0.909733s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 2.45913) with worst = 0.012078 / average = 0.759016:
# Info    : 0.00 < quality < 0.10 :        39 elements
# Info    : 0.10 < quality < 0.20 :       124 elements
# Info    : 0.20 < quality < 0.30 :       172 elements
# Info    : 0.30 < quality < 0.40 :       229 elements
# Info    : 0.40 < quality < 0.50 :       376 elements
# Info    : 0.50 < quality < 0.60 :       712 elements
# Info    : 0.60 < quality < 0.70 :      1786 elements
# Info    : 0.70 < quality < 0.80 :      3528 elements
# Info    : 0.80 < quality < 0.90 :      4490 elements
# Info    : 0.90 < quality < 1.00 :      1937 elements
# Info    : 332 edge swaps, 9 node relocations (volume = 2.45913): worst = 0.108307 / average = 0.774317 (Wall 0.0175193s, CPU 0.01824s)
# Info    : 336 edge swaps, 9 node relocations (volume = 2.45913): worst = 0.149109 / average = 0.774489 (Wall 0.0209356s, CPU 0.021726s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         1 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :       233 elements
# Info    : 0.40 < quality < 0.50 :       351 elements
# Info    : 0.50 < quality < 0.60 :       706 elements
# Info    : 0.60 < quality < 0.70 :      1774 elements
# Info    : 0.70 < quality < 0.80 :      3545 elements
# Info    : 0.80 < quality < 0.90 :      4537 elements
# Info    : 0.90 < quality < 1.00 :      1944 elements
# Info    : Optimizing volume 2
# Info    : Optimization starts (volume = 0.3) with worst = 0.0131484 / average = 0.7455:
# Info    : 0.00 < quality < 0.10 :         2 elements
# Info    : 0.10 < quality < 0.20 :         1 elements
# Info    : 0.20 < quality < 0.30 :         5 elements
# Info    : 0.30 < quality < 0.40 :         7 elements
# Info    : 0.40 < quality < 0.50 :        49 elements
# Info    : 0.50 < quality < 0.60 :       249 elements
# Info    : 0.60 < quality < 0.70 :       231 elements
# Info    : 0.70 < quality < 0.80 :       844 elements
# Info    : 0.80 < quality < 0.90 :      1142 elements
# Info    : 0.90 < quality < 1.00 :        42 elements
# Info    : 7 edge swaps, 0 node relocations (volume = 0.3): worst = 0.31434 / average = 0.746803 (Wall 0.00125331s, CPU 0.001356s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         7 elements
# Info    : 0.40 < quality < 0.50 :        50 elements
# Info    : 0.50 < quality < 0.60 :       250 elements
# Info    : 0.60 < quality < 0.70 :       234 elements
# Info    : 0.70 < quality < 0.80 :       845 elements
# Info    : 0.80 < quality < 0.90 :      1138 elements
# Info    : 0.90 < quality < 1.00 :        42 elements
# Info    : Optimizing volume 3
# Info    : Optimization starts (volume = 0.3) with worst = 0.000191524 / average = 0.744157:
# Info    : 0.00 < quality < 0.10 :        20 elements
# Info    : 0.10 < quality < 0.20 :         6 elements
# Info    : 0.20 < quality < 0.30 :         9 elements
# Info    : 0.30 < quality < 0.40 :         6 elements
# Info    : 0.40 < quality < 0.50 :        46 elements
# Info    : 0.50 < quality < 0.60 :       248 elements
# Info    : 0.60 < quality < 0.70 :       212 elements
# Info    : 0.70 < quality < 0.80 :       764 elements
# Info    : 0.80 < quality < 0.90 :      1180 elements
# Info    : 0.90 < quality < 1.00 :        70 elements
# Info    : 30 edge swaps, 1 node relocations (volume = 0.3): worst = 0.000191524 / average = 0.751485 (Wall 0.00198098s, CPU 0.0021s)
# Info    : 32 edge swaps, 1 node relocations (volume = 0.3): worst = 0.000191524 / average = 0.752057 (Wall 0.00268004s, CPU 0.002885s)
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         6 elements
# Info    : 0.40 < quality < 0.50 :        48 elements
# Info    : 0.50 < quality < 0.60 :       250 elements
# Info    : 0.60 < quality < 0.70 :       212 elements
# Info    : 0.70 < quality < 0.80 :       762 elements
# Info    : 0.80 < quality < 0.90 :      1191 elements
# Info    : 0.90 < quality < 1.00 :        63 elements
# Info    : Done optimizing mesh (Wall 0.080466s, CPU 0.080859s)
# Info    : 13012 nodes 35144 elements
# Info    : Writing 'test.geo_unrolled'...
# Info    : Done writing 'test.geo_unrolled'
# Info    : Writing 'test.msh'...
# Warning : 1 ill-shaped tets are still in the mesh
# Warning : ------------------------------
# Warning : Mesh generation error summary
# Warning :     1 warning
# Warning :     0 errors
# Warning : Check the full log for details
# Warning : ------------------------------
# meshed
# Info    : Done writing 'test.msh'
#
# ************************************************************
#
# CalculiX Version 2.21, Copyright(C) 1998-2023 Guido Dhondt
# CalculiX comes with ABSOLUTELY NO WARRANTY. This is free
# software, and you are welcome to redistribute it under
# certain conditions, see gpl.htm
#
# ************************************************************
#
# You are using an executable made on Mi 3. Apr 21:56:04 CEST 2024
#
#   The numbers below are estimated upper bounds
#
#   number of:
#
#    nodes:        13012
#    elements:        24016
#    one-dimensional elements:            0
#    two-dimensional elements:            0
#    integration points per element:            1
#    degrees of freedom per node:            3
#    layers per element:            1
#
#    distributed facial loads:            0
#    distributed volumetric loads:            1
#    concentrated loads:            0
#    single point constraints:         3102
#    multiple point constraints:            1
#    terms in all multiple point constraints:            1
#    tie constraints:            2
#    dependent nodes tied by cyclic constraints:            0
#    dependent nodes in pre-tension constraints:            0
#
#    sets:           16
#    terms in all sets:        41860
#
#    materials:            5
#    constants per material and temperature:            4
#    temperature points per material:            1
#    plastic data points per material:            0
#
#    orientations:            0
#    amplitudes:            8
#    data points in all amplitudes:            8
#    print requests:           11
#    transformations:            0
#    property cards:            0
#
#
#  STEP            1
#
#  *INFO reading *STEP: nonlinear geometric
#        effects are turned on
#
#  *WARNING reading *STATIC:
#           the minimum increment    0.0000000000000000
#           is smaller then 1.e-6 times the
#           step time;
#           the minimum increment is changed
#           to    9.9999999999999995E-007
#           which is the minimum of the initial
#           increment time and 1.e-6 times the step time
#
#  *WARNING in calinput: no density was assigned
#           to material ELASTIC in a dynamic
#           calculation or a calculation with
#           centrifugal or gravitational loads
#           or an incompressible CFD calculation
#
#  *WARNING in calinput: no density was assigned
#           to material ELASTIC in a dynamic
#           calculation or a calculation with
#           centrifugal or gravitational loads
#           or an incompressible CFD calculation
#
#  Static analysis was selected
#
#  Newton-Raphson iterative procedure is active
#
#  Nonlinear geometric effects are taken into account
#
#  Decascading the MPC's
#
#  Determining the structure of the matrix:
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  increment 1 attempt 1
#  increment size= 1.000000e+00
#  sum of previous increments=0.000000e+00
#  actual step time=1.000000e+00
#  actual total time=1.000000e+00
#
#  iteration 1
#
#  Number of contact spring elements=0
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.012989
#  time avg. forc= 0.012989
#  largest residual force= 0.242600 in node 1827 and dof 2
#  largest increment of disp= 1.000000e+00
#  largest correction to disp= 1.000000e+00 in node 3681 and dof 2
#
#  no convergence
#
#  iteration 2
#
#  Number of contact spring elements=127
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 2.986170
#  time avg. forc= 2.986170
#  largest residual force= 84113.369210 in node 385 and dof 2
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 1.007220e+00 in node 385 and dof 2
#
#  no convergence
#
#  iteration 3
#
#  Number of contact spring elements=78
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 1.046018
#  time avg. forc= 1.046018
#  largest residual force= 24905.849944 in node 385 and dof 2
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 5.372901e-01 in node 2235 and dof 2
#
#  no convergence
#
#  iteration 4
#
#  Number of contact spring elements=61
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.337028
#  time avg. forc= 0.337028
#  largest residual force= 7367.962647 in node 385 and dof 2
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 2.412934e-01 in node 385 and dof 2
#
#  no convergence
#
#  iteration 5
#
#  Number of contact spring elements=64
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.119676
#  time avg. forc= 0.119676
#  largest residual force= 2175.506802 in node 385 and dof 2
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 1.795012e-01 in node 20 and dof 1
#
#  no convergence
#
#  iteration 6
#
#  Number of contact spring elements=59
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.054522
#  time avg. forc= 0.054522
#  largest residual force= 639.860273 in node 385 and dof 2
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 1.245457e-01 in node 385 and dof 2
#
#  no convergence
#
#  iteration 7
#
#  Number of contact spring elements=75
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.029816
#  time avg. forc= 0.029816
#  largest residual force= 185.897963 in node 385 and dof 2
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 9.020185e-02 in node 385 and dof 2
#
#  no convergence
#
#  iteration 8
#
#  Number of contact spring elements=81
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.023425
#  time avg. forc= 0.023425
#  largest residual force= 121.630087 in node 386 and dof 3
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 1.210437e-01 in node 386 and dof 3
#
#  no convergence
#
#  iteration 9
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.014638
#  time avg. forc= 0.014638
#  largest residual force= 34.603470 in node 386 and dof 3
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 5.956324e-02 in node 20 and dof 1
#
#  no convergence
#
#  iteration 10
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.011224
#  time avg. forc= 0.011224
#  largest residual force= 10.109536 in node 386 and dof 3
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 1.204479e-01 in node 20 and dof 3
#
#  no convergence
#
#  iteration 11
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.009788
#  time avg. forc= 0.009788
#  largest residual force= 4.076342 in node 2246 and dof 2
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 3.475094e-02 in node 2246 and dof 2
#
#  no convergence
#
#  iteration 12
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.009587
#  time avg. forc= 0.009587
#  largest residual force= 0.733573 in node 385 and dof 2
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 1.961613e-02 in node 20 and dof 2
#
#  no convergence
#
#  iteration 13
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.009594
#  time avg. forc= 0.009594
#  largest residual force= 0.640282 in node 385 and dof 2
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 3.222753e-02 in node 385 and dof 3
#
#  no convergence
#
#  iteration 14
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.009666
#  time avg. forc= 0.009666
#  largest residual force= 0.217984 in node 251 and dof 2
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 3.046679e-02 in node 2024 and dof 3
#
#  no convergence
#
#  iteration 15
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.009586
#  time avg. forc= 0.009586
#  largest residual force= 0.220842 in node 2435 and dof 2
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 3.489880e-02 in node 2054 and dof 3
#
#  no convergence
#
#  iteration 16
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.009700
#  time avg. forc= 0.009700
#  largest residual force= 0.264953 in node 372 and dof 2
#  largest increment of disp= 1.007220e+00
#  largest correction to disp= 3.752298e-02 in node 2024 and dof 3
#
#  divergence; the increment size is decreased to 2.500000e-01
#  the increment is reattempted
#
#  increment 1 attempt 2
#  increment size= 2.500000e-01
#  sum of previous increments=0.000000e+00
#  actual step time=2.500000e-01
#  actual total time=2.500000e-01
#
#  iteration 1
#
#  Number of contact spring elements=0
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.001590
#  time avg. forc= 0.001590
#  largest residual force= 0.014737 in node 1827 and dof 2
#  largest increment of disp= 2.500000e-01
#  largest correction to disp= 2.500000e-01 in node 3681 and dof 2
#
#  no convergence
#
#  iteration 2
#
#  Number of contact spring elements=0
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.001270
#  time avg. forc= 0.001270
#  largest residual force= 0.000008 in node 1801 and dof 2
#  largest increment of disp= 2.500000e-01
#  largest correction to disp= 7.137240e-04 in node 2024 and dof 1
#
#  no convergence
#
#  iteration 3
#
#  Number of contact spring elements=0
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.001270
#  time avg. forc= 0.001270
#  largest residual force= 0.000000 in node 1801 and dof 2
#  largest increment of disp= 2.500000e-01
#  largest correction to disp= 5.612214e-07 in node 368 and dof 1
#
#  convergence
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  increment 2 attempt 1
#  increment size= 2.500000e-01
#  sum of previous increments=2.500000e-01
#  actual step time=5.000000e-01
#  actual total time=5.000000e-01
#
#  iteration 1
#
#  Number of contact spring elements=0
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.002538
#  time avg. forc= 0.001904
#  largest residual force= 0.000034 in node 1827 and dof 2
#  largest increment of disp= 2.500000e-01
#  largest correction to disp= 1.424643e-03 in node 312 and dof 1
#
#  no convergence
#
#  iteration 2
#
#  Number of contact spring elements=0
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.002538
#  time avg. forc= 0.001904
#  largest residual force= 0.000000 in node 2338 and dof 1
#  largest increment of disp= 2.500000e-01
#  largest correction to disp= 3.306056e-06 in node 317 and dof 2
#
#  convergence; the increment size is increased to 3.750000e-01
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  increment 3 attempt 1
#  increment size= 3.750000e-01
#  sum of previous increments=5.000000e-01
#  actual step time=8.750000e-01
#  actual total time=8.750000e-01
#
#  iteration 1
#
#  Number of contact spring elements=0
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.004436
#  time avg. forc= 0.002748
#  largest residual force= 0.000121 in node 1827 and dof 2
#  largest increment of disp= 3.750000e-01
#  largest correction to disp= 2.655532e-03 in node 2116 and dof 1
#
#  no convergence
#
#  iteration 2
#
#  Number of contact spring elements=64
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.004939
#  time avg. forc= 0.002916
#  largest residual force= 0.642686 in node 2400 and dof 2
#  largest increment of disp= 3.750000e-01
#  largest correction to disp= 4.832753e-02 in node 332 and dof 2
#
#  no convergence
#
#  iteration 3
#
#  Number of contact spring elements=42
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.003279
#  time avg. forc= 0.002362
#  largest residual force= 0.133517 in node 2382 and dof 2
#  largest increment of disp= 3.750000e-01
#  largest correction to disp= 2.305715e-02 in node 313 and dof 2
#
#  no convergence
#
#  iteration 4
#
#  Number of contact spring elements=21
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.002833
#  time avg. forc= 0.002214
#  largest residual force= 0.014528 in node 2400 and dof 2
#  largest increment of disp= 3.750000e-01
#  largest correction to disp= 7.867255e-03 in node 334 and dof 2
#
#  no convergence
#
#  iteration 5
#
#  Number of contact spring elements=20
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.002822
#  time avg. forc= 0.002210
#  largest residual force= 0.000083 in node 373 and dof 2
#  largest increment of disp= 3.750000e-01
#  largest correction to disp= 8.176525e-04 in node 311 and dof 3
#
#  no convergence
#
#  iteration 6
#
#  Number of contact spring elements=21
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.002821
#  time avg. forc= 0.002210
#  largest residual force= 0.000051 in node 372 and dof 2
#  largest increment of disp= 3.750000e-01
#  largest correction to disp= 2.258787e-04 in node 373 and dof 2
#
#  no convergence
#
#  iteration 7
#
#  Number of contact spring elements=21
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.002821
#  time avg. forc= 0.002210
#  largest residual force= 0.000000 in node 372 and dof 2
#  largest increment of disp= 3.750000e-01
#  largest correction to disp= 2.851822e-06 in node 335 and dof 3
#
#  convergence
#
#  the increment size exceeds the remainder of the step and is decreased to 1.250000e-01
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  increment 4 attempt 1
#  increment size= 1.250000e-01
#  sum of previous increments=8.750000e-01
#  actual step time=1.000000e+00
#  actual total time=1.000000e+00
#
#  iteration 1
#
#  Number of contact spring elements=21
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.448888
#  time avg. forc= 0.113879
#  largest residual force= 23428.651928 in node 2363 and dof 2
#  largest increment of disp= 8.319916e-01
#  largest correction to disp= 8.319916e-01 in node 2363 and dof 2
#
#  no convergence
#
#  iteration 2
#
#  Number of contact spring elements=119
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.142845
#  time avg. forc= 0.037369
#  largest residual force= 6901.049480 in node 2363 and dof 2
#  largest increment of disp= 8.319916e-01
#  largest correction to disp= 2.146616e-01 in node 2363 and dof 2
#
#  no convergence
#
#  iteration 3
#
#  Number of contact spring elements=89
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.050419
#  time avg. forc= 0.014262
#  largest residual force= 2018.443083 in node 2363 and dof 2
#  largest increment of disp= 8.319916e-01
#  largest correction to disp= 1.437867e-01 in node 2363 and dof 2
#
#  no convergence
#
#  iteration 4
#
#  Number of contact spring elements=74
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.022605
#  time avg. forc= 0.007308
#  largest residual force= 583.331076 in node 2363 and dof 2
#  largest increment of disp= 8.319916e-01
#  largest correction to disp= 9.140206e-02 in node 2363 and dof 2
#
#  no convergence
#
#  iteration 5
#
#  Number of contact spring elements=81
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.014271
#  time avg. forc= 0.005225
#  largest residual force= 167.875287 in node 2363 and dof 2
#  largest increment of disp= 8.319916e-01
#  largest correction to disp= 6.379961e-02 in node 2363 and dof 2
#
#  no convergence
#
#  iteration 6
#
#  Number of contact spring elements=81
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.011567
#  time avg. forc= 0.004549
#  largest residual force= 51.751353 in node 2363 and dof 2
#  largest increment of disp= 8.319916e-01
#  largest correction to disp= 5.734912e-02 in node 2363 and dof 2
#
#  no convergence
#
#  iteration 7
#
#  Number of contact spring elements=83
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.010375
#  time avg. forc= 0.004251
#  largest residual force= 22.724797 in node 2363 and dof 2
#  largest increment of disp= 8.319916e-01
#  largest correction to disp= 5.762230e-02 in node 2363 and dof 2
#
#  no convergence
#
#  iteration 8
#
#  Number of contact spring elements=84
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.009896
#  time avg. forc= 0.004131
#  largest residual force= 11.115278 in node 2363 and dof 2
#  largest increment of disp= 8.319916e-01
#  largest correction to disp= 5.211507e-02 in node 2363 and dof 2
#
#  no convergence
#
#  iteration 9
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.009591
#  time avg. forc= 0.004055
#  largest residual force= 1.617895 in node 2350 and dof 2
#  largest increment of disp= 8.319916e-01
#  largest correction to disp= 3.745853e-02 in node 2363 and dof 2
#
#  no convergence
#
#  iteration 10
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.009485
#  time avg. forc= 0.004028
#  largest residual force= 0.197496 in node 2363 and dof 2
#  largest increment of disp= 8.319916e-01
#  largest correction to disp= 4.042797e-03 in node 2363 and dof 2
#
#  no convergence
#
#  iteration 11
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.009487
#  time avg. forc= 0.004029
#  largest residual force= 0.002633 in node 2350 and dof 2
#  largest increment of disp= 8.319916e-01
#  largest correction to disp= 5.580683e-04 in node 2363 and dof 2
#
#  no convergence
#
#  iteration 12
#
#  Determining the structure of the matrix:
#
#  Using up to 8 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  12051
#  number of nonzero lower triangular matrix elements
#  194544
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  Using up to 8 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 8 cpu(s) for spooles.
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#  average force= 0.009487
#  time avg. forc= 0.004029
#  largest residual force= 0.000009 in node 2358 and dof 2
#  largest increment of disp= 8.319916e-01
#  largest correction to disp= 6.609960e-06 in node 2350 and dof 2
#
#  convergence; the increment size is decreased to 9.375000e-02
#
#  the increment size exceeds the remainder of the step and is decreased to 0.000000e+00
#
#  Using up to 8 cpu(s) for the stress calculation.
#
#
#  Job finished
#
# ________________________________________
#
# Total CalculiX Time: 21.487227
# ________________________________________
