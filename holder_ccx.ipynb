# %% [markdown]
# Imports:

# %%
import numpy as np
import jax
import jax.numpy as jnp
from jax.example_libraries import stax, optimizers
import matplotlib.pyplot as plt
import pyvista as pv
import pinns 
import datetime
import jax.scipy.optimize
import jax.flatten_util
import scipy
import scipy.optimize
import random

from pygccx import model as ccx_model
from pygccx import model_keywords as mk
from pygccx import step_keywords as sk
from pygccx import enums

rnd_key = jax.random.PRNGKey(1234)
np.random.seed(14124)

# %% [markdown]
# Set the default precision and the execution device.

# %%
jax.config.update("jax_enable_x64", False)
# print("GPU devices: ", jax.devices('gpu'))
dev = jax.devices('gpu')[0] if jax.device_count()>1 and len(jax.devices('gpu'))>0 else jax.devices('cpu')[0]
print(dev)
# Out:
# TFRT_CPU_0

# %% [markdown]
# ### Geometry definition
#
# Define the geometry patches:

# %%
def get_domain(r0: float, r1: float, R: float, h: float, H: float):

    angle = np.pi/4
    basis1 = pinns.functions.BSplineBasisJAX(np.array([-1, 0, 1]), 2)
    basis2 = pinns.functions.BSplineBasisJAX(np.array([-1, 1]), 2)
    basis3 = pinns.functions.BSplineBasisJAX(np.array([-1, 1]), 1)

    def tmp_gen(angle, r_0, r_1):
        pts = np.zeros([4, 3, 2, 3])
        weights = np.ones([4, 3, 2])

        a = np.pi/2-angle/2
        rs = np.linspace(r_0, r_1, 4)
        pts[-1, 0, 0, :] = [np.cos(-angle/2), np.sin(-angle/2), 0]
        pts[-1, 1, 0, :] = [1/np.sin(a), 0, 0]
        pts[-1, 2, 0, :] = [np.cos(angle/2), np.sin(angle/2), 0]
        pts[0, :, 0, :2] = rs[0] * pts[-1, :, 0, :2]
        pts[1, :, 0, :2] = rs[1] * pts[-1, :, 0, :2]
        pts[2, :, 0, :2] = rs[2] * pts[-1, :, 0, :2]
        pts[3, :, 0, :2] = rs[3] * pts[-1, :, 0, :2]
        pts[0, :, 0, 2] = -1
        pts[1, :, 0, 2] = -1
        pts[2, :, 0, 2] = -1
        pts[3, :, 0, 2] = -1
        pts[:, :, 1, :] = pts[:, :, 0, :]
        pts[:, :, 1, 2] = -pts[:, :, 1, 2]
        weights[:, 1, :] = np.sin(a)

        return pts, weights

    geoms = dict()

    pts, weights = tmp_gen(angle, r0, r1)
    pts[:, :, :, 2] *= h/2
    # pts[2:,:,:,2] *= h/2
    pts[3, 1, :, 0] = pts[3, 0, :, 0]
    pts[1, 1, :, 0] = 2*pts[0, 1, :, 0]/3+pts[-1, 1, :, 0]/3
    pts[2, 1, :, 0] = pts[0, 1, :, 0]/3+2*pts[-1, 1, :, 0]/3
    weights[-1, 1, :] = 1.0

    geoms['flat'] = pinns.geometry.PatchNURBS(
        [basis1, basis2, basis3], pts.copy(), weights.copy(), 0, 3)

    pts2 = pts[-1, :, :, :]
    weights[...] = 1.0
    linsp = np.linspace(0, 1, basis1.n)

    pts[0, :, :, :] = pts2
    pts[-1, :, :, :] = pts2
    pts[-1, :, :, 0] *= R/r1
    pts[-1, :, :, 1] *= H/h
    # pts[0, :, :, 2] *= H/h

    for i in range(1, basis1.n-1):
        pts[i, :, :, 2] = (1-linsp[i]**0.25)*pts[0, :, :, 2] + \
            linsp[i]**0.25*pts[-1, :, :, 2]
        pts[i, :, :, 0] = (1-linsp[i])*pts[0, :, :, 0] + \
            linsp[i]*pts[-1, :, :, 0]
        pts[i, :, :, 1] = (1-linsp[i]**4)*pts[0, :, :, 1] + \
            linsp[i]**4*pts[-1, :, :, 1]
        pts[i, :, :, 1] *= 2*(linsp[i]-1/2)**2+0.5
        pts[i, :, :, 2] *= 2*(linsp[i]-1/2)**2+0.5

    geoms['spoke'] = pinns.geometry.PatchNURBS(
        [basis1, basis2, basis3], pts, weights, 0, 3)

    pts, weights = tmp_gen((2*np.pi-angle)/3, r0, r1)
    pts[:, :, :, 2] *= h/2
    # pts[2:,:,:,2] *= h/2

    geoms['round_0'] = pinns.geometry.PatchNURBS(
        [basis1, basis2, basis3], pts, weights, 0, 3)
    geoms['round_0'].rotate((0, 0, angle/2 + (2*np.pi-angle)/3/2))

    pts, weights = tmp_gen((2*np.pi-angle)/3, r0, r1)
    pts[:, :, :, 2] *= h/2
    # pts[2:,:,:,2] *= h/2

    geoms['round_1'] = pinns.geometry.PatchNURBS(
        [basis1, basis2, basis3], pts, weights, 0, 3)
    geoms['round_1'].rotate((0, 0, np.pi))

    pts, weights = tmp_gen((2*np.pi-angle)/3, r0, r1)
    pts[:, :, :, 2] *= h/2
    # pts[2:,:,:,2] *= h/2

    geoms['round_2'] = pinns.geometry.PatchNURBS(
        [basis1, basis2, basis3], pts, weights, 0, 3)
    geoms['round_2'].rotate((0, 0, (2*np.pi-angle)/3 + np.pi))

    return geoms


geoms = get_domain(0.5, 0.8, 3.0, 1.0, 1.5)
names = list(geoms.keys())

# %% [markdown]
# Determine the connectivity of the patches:

# %%
with jax.disable_jit(True):
    connectivity = pinns.geometry.match_patches(geoms, eps=1e-4, verbose=False)

for c in connectivity:
    print(c)
# Out:
# {'first': 'flat', 'second': 'spoke', 'axis_first': (0,), 'axis_second': (0,), 'end_first': (-1,), 'end_second': (0,), 'axis_permutation': (None, (1, 1), (2, 1))}
# {'first': 'flat', 'second': 'round_0', 'axis_first': (1,), 'axis_second': (1,), 'end_first': (-1,), 'end_second': (0,), 'axis_permutation': ((0, 1), None, (2, 1))}
# {'first': 'flat', 'second': 'round_2', 'axis_first': (1,), 'axis_second': (1,), 'end_first': (0,), 'end_second': (-1,), 'axis_permutation': ((0, 1), None, (2, 1))}
# {'first': 'spoke', 'second': 'round_0', 'axis_first': (0, 1), 'axis_second': (0, 1), 'end_first': (0, -1), 'end_second': (-1, 0), 'axis_permutation': (None, None, (2, 1))}
# {'first': 'spoke', 'second': 'round_2', 'axis_first': (0, 1), 'axis_second': (0, 1), 'end_first': (0, 0), 'end_second': (-1, -1), 'axis_permutation': (None, None, (2, 1))}
# {'first': 'round_0', 'second': 'round_1', 'axis_first': (1,), 'axis_second': (1,), 'end_first': (-1,), 'end_second': (0,), 'axis_permutation': ((0, 1), None, (2, 1))}
# {'first': 'round_1', 'second': 'round_2', 'axis_first': (1,), 'axis_second': (1,), 'end_first': (-1,), 'end_second': (0,), 'axis_permutation': ((0, 1), None, (2, 1))}

# %%
def construct_inp(geoms: dict, E: float, mu: float, dens: float, n: int, meshsize: float, contact_low=None, contact_up=None):
    
    with ccx_model.Model("/usr/bin/ccx", "/usr/bin/cgx", jobname='holder', working_dir="./") as model:

        gmsh = model.get_gmsh()
        
        surfaces = dict()
        
        for name in geoms:
            print(name)
            meshgrid = np.meshgrid(np.linspace(-1,1,n), np.linspace(-1,1,n))
            positions = geoms[name][:,:,-1](np.concatenate((meshgrid[0].reshape([-1,1]), meshgrid[1].reshape([-1,1])),-1))
            indices = []
            for i in range(positions.shape[0]):
                tag = gmsh.model.occ.addPoint(positions[i,0], positions[i,1], positions[i,2], tag = -1, meshSize = meshsize)
                indices.append(tag)
            tag = gmsh.model.occ.addBSplineSurface(indices, n, -1, 2, 2)
            surfaces[(name, 2, 0)] = tag 
            
            meshgrid = np.meshgrid(np.linspace(-1,1,n), np.linspace(-1,1,n))
            positions = geoms[name][:,:,1](np.concatenate((meshgrid[0].reshape([-1,1]), meshgrid[1].reshape([-1,1])),-1))
            indices = []
            for i in range(positions.shape[0]):
                tag = gmsh.model.occ.addPoint(positions[i,0], positions[i,1], positions[i,2], tag = -1, meshSize = meshsize)
                indices.append(tag)
            tag = gmsh.model.occ.addBSplineSurface(indices, n, -1, 2, 2)
            surfaces[(name, 2, -1)] = tag
            
            meshgrid = np.meshgrid(np.linspace(-1,1,n), np.linspace(-1,1,n))
            positions = geoms[name][:,-1,:](np.concatenate((meshgrid[0].reshape([-1,1]), meshgrid[1].reshape([-1,1])),-1))
            indices = []
            for i in range(positions.shape[0]):
                tag = gmsh.model.occ.addPoint(positions[i,0], positions[i,1], positions[i,2], tag = -1, meshSize = meshsize)
                indices.append(tag)
            tag = gmsh.model.occ.addBSplineSurface(indices, n, -1, 2, 2)
            surfaces[(name, 1, 0)] = tag
            
            meshgrid = np.meshgrid(np.linspace(-1,1,n), np.linspace(-1,1,n))
            positions = geoms[name][:,1,:](np.concatenate((meshgrid[0].reshape([-1,1]), meshgrid[1].reshape([-1,1])),-1))
            indices = []
            for i in range(positions.shape[0]):
                tag = gmsh.model.occ.addPoint(positions[i,0], positions[i,1], positions[i,2], tag = -1, meshSize = meshsize)
                indices.append(tag)
            tag = gmsh.model.occ.addBSplineSurface(indices, n, -1, 2, 2)
            surfaces[(name, 1, -1)] = tag
            
            meshgrid = np.meshgrid(np.linspace(-1,1,n), np.linspace(-1,1,n))
            positions = geoms[name][-1,:,:](np.concatenate((meshgrid[0].reshape([-1,1]), meshgrid[1].reshape([-1,1])),-1))
            indices = []
            for i in range(positions.shape[0]):
                tag = gmsh.model.occ.addPoint(positions[i,0], positions[i,1], positions[i,2], tag = -1, meshSize = meshsize)
                indices.append(tag)
            tag = gmsh.model.occ.addBSplineSurface(indices, n, -1, 2, 2)
            surfaces[(name, 0, 0)] = tag
            
            meshgrid = np.meshgrid(np.linspace(-1,1,n), np.linspace(-1,1,n))
            positions = geoms[name][1,:,:](np.concatenate((meshgrid[0].reshape([-1,1]), meshgrid[1].reshape([-1,1])),-1))
            indices = []
            for i in range(positions.shape[0]):
                tag = gmsh.model.occ.addPoint(positions[i,0], positions[i,1], positions[i,2], tag = -1, meshSize = meshsize)
                indices.append(tag)
            tag = gmsh.model.occ.addBSplineSurface(indices, n, -1, 2, 2)
            surfaces[(name, 0, -1)] = tag
            
       
        #tag = gmsh.model.occ.add_curve_loop([surfaces[('spoke', 0, -1)], surfaces[('spoke', 1, -1)], surfaces[('spoke', 1, 0)], surfaces[('spoke', 2, -1)], surfaces[('spoke', 2, 0)],
        #                                     surfaces[('flat', 0, 0)], surfaces[('flat', 2, 0)], surfaces[('flat', 2, -1)],
        #                                     surfaces[('round_0', 0, -1)], surfaces[('round_0', 0, 0)], surfaces[('round_0', 2, -1)], surfaces[('round_0', 2, 0)],
        #                                     surfaces[('round_1', 0, -1)], surfaces[('round_1', 0, 0)], surfaces[('round_1', 2, -1)], surfaces[('round_1', 2, 0)],
        #                                     surfaces[('round_2', 0, -1)], surfaces[('round_2', 0, 0)], surfaces[('round_2', 2, -1)], surfaces[('round_2', 2, 0)],
        #                                     ])
        
        gmsh.model.occ.remove_all_duplicates()
        closed_surface_loop = [surfaces[('spoke', 0, -1)], surfaces[('spoke', 1, 0)], surfaces[('spoke', 1, -1)], surfaces[('spoke', 2, -1)], surfaces[('spoke', 2, 0)]]
        closed_surface_loop += [surfaces[('flat',0,0)], surfaces[('flat',2,0)], surfaces[('flat',2,-1)]]
        closed_surface_loop += [surfaces[('round_0',0,0)], surfaces[('round_0',0,-1)], surfaces[('round_0',2,0)], surfaces[('round_0',2,-1)]]
        closed_surface_loop += [surfaces[('round_1',0,0)], surfaces[('round_1',0,-1)], surfaces[('round_1',2,0)], surfaces[('round_1',2,-1)]]
        closed_surface_loop += [surfaces[('round_2',0,0)], surfaces[('round_2',0,-1)], surfaces[('round_2',2,0)], surfaces[('round_2',2,-1)]]
        
        tag = gmsh.model.occ.add_surface_loop(closed_surface_loop)
        
        tag_volume = gmsh.model.occ.add_volume([tag])
        
        OFFSET = 1.0
        if contact_low is not None:
            tag_lower_surface = gmsh.model.occ.add_rectangle(-1, -1, 0, 1.5, 2)
            gmsh.model.occ.rotate([(2,tag_lower_surface)], 0, 0, 0, 1, 0, 0, -np.pi/2)
            gmsh.model.occ.translate([(2,tag_lower_surface)], 0, contact_low-OFFSET, 0)
            tags_lower_volume = gmsh.model.occ.extrude([(2, tag_lower_surface)], 0, -0.1, 0)
            tags_lower_volume = [t[1] for t in tags_lower_volume if t[0]==3][0]
            
        if contact_up is not None:
            tag_up_surface = gmsh.model.occ.add_rectangle(-1, -1, 0, 1.5, 2)
            gmsh.model.occ.rotate([(2,tag_up_surface)], 0, 0, 0, 1, 0, 0, -np.pi/2)
            gmsh.model.occ.translate([(2,tag_up_surface)], 0, contact_up+OFFSET, 0)
            tags_up_volume = gmsh.model.occ.extrude([(2, tag_up_surface)], 0, 0.1, 0)
            tags_up_volume = [t[1] for t in tags_up_volume if t[0]==3][0]
            
        gmsh.model.occ.synchronize()
       

        if contact_up is not None: 
            gmsh.model.add_physical_group(2, [surfaces[('round_0', 0, -1)]], name="UPPER_SURFACE")
            gmsh.model.add_physical_group(2, [tag_up_surface], name="UPPER_PRESS_SURFACE")
            gmsh.model.add_physical_group(3, [tags_up_volume], name="UPPER_PRESS")

        if contact_low is not None: 
            gmsh.model.add_physical_group(2, [surfaces[('round_2', 0, -1)]], name="LOWER_SURFACE")
            gmsh.model.add_physical_group(2, [tag_lower_surface], name="LOWER_PRESS_SURFACE")
            gmsh.model.add_physical_group(3, [tags_lower_volume], name="LOWER_PRESS")
            
        gmsh.model.add_physical_group(3, [tag_volume], name='HOLDER')
        gmsh.model.add_physical_group(2, [surfaces[('spoke', 0, -1)]], name='FIX')
        closed_surface_loop.remove(surfaces[('spoke', 0, -1)])
        gmsh.model.add_physical_group(2, closed_surface_loop, name='NOT_FIX')
        
        gmsh.model.mesh.set_size_callback(lambda dim, tag, x, y, z, lc: meshsize)
        gmsh.model.mesh.generate(3)
        
        gmsh.write("test.geo_unrolled")
        gmsh.write("test.msh")
        
        print("meshed")
        
        model.update_mesh_from_gmsh()
        mesh = model.mesh

        
        # fix the left end
        fix_set = model.mesh.get_node_set_by_name('FIX')
        model.add_model_keywords(
            mk.Boundary(fix_set, first_dof=1, last_dof=3)
        )
        if contact_up is not None:
            model.add_model_keywords(mk.Boundary(model.mesh.get_node_set_by_name("UPPER_PRESS_SURFACE"), first_dof=3))
            model.add_model_keywords(mk.Boundary(model.mesh.get_node_set_by_name("UPPER_PRESS_SURFACE"), first_dof=1))
       
        if contact_low is not None:
            model.add_model_keywords(mk.Boundary(model.mesh.get_node_set_by_name("LOWER_PRESS_SURFACE"), first_dof=1))
            model.add_model_keywords(mk.Boundary(model.mesh.get_node_set_by_name("LOWER_PRESS_SURFACE"), first_dof=3))

        mat = mk.Material('ELASTIC')
        el = mk.Elastic((E, mu))
        dens = mk.Density(dens)
        sos = mk.SolidSection(
            elset=mesh.get_el_set_by_name('HOLDER'),
            material = mat
        )
        model.add_model_keywords(mat, el, dens, sos)
        
        if contact_up is not None:
            
            upper_press_surface = mesh.add_surface_from_node_set("UPPER_PRESS_SURFACE_SET", mesh.get_node_set_by_name("UPPER_PRESS_SURFACE"), enums.ESurfTypes.EL_FACE)
            upper_contact_surface = mesh.add_surface_from_node_set("UPPER_SURFACE_SET", mesh.get_node_set_by_name("UPPER_SURFACE"), enums.ESurfTypes.EL_FACE)
            
            mat = mk.Material('ELASTIC')
            el = mk.Elastic((100000., 0.3))
            
            sos = mk.SolidSection(
                elset=mesh.get_el_set_by_name('UPPER_PRESS'),
                material = mat
            )
            model.add_model_keywords(mat, el, sos)
            
            interact = mk.SurfaceInteraction("up")
            behavior = mk.SurfaceBehavior(enums.EPressureOverclosures.LINEAR, k=1e5, sig_inf=1e6)
            pair = mk.ContactPair(interact, enums.EContactTypes.NODE_TO_SURFACE, upper_contact_surface, upper_press_surface)

            model.add_model_keywords(pair, interact, behavior)
            
        if contact_low is not None:
            lower_press_surface = mesh.add_surface_from_node_set("LOWER_PRESS_SURFACE_SET", mesh.get_node_set_by_name("LOWER_PRESS_SURFACE"), enums.ESurfTypes.EL_FACE)
            lower_contact_surface = mesh.add_surface_from_node_set("LOWER_SURFACE_SET", mesh.get_node_set_by_name("LOWER_SURFACE"), enums.ESurfTypes.EL_FACE)
            
            mat = mk.Material('ELASTIC')
            el = mk.Elastic((100000., 0.3))
            
            sos = mk.SolidSection(
                elset=mesh.get_el_set_by_name('LOWER_PRESS'),
                material = mat
            )
            model.add_model_keywords(mat, el, sos)
            
            interact = mk.SurfaceInteraction("low")
            behavior = mk.SurfaceBehavior(enums.EPressureOverclosures.LINEAR, k=1e5, sig_inf=1e6)
            pair = mk.ContactPair(interact, enums.EContactTypes.NODE_TO_SURFACE, lower_contact_surface, lower_press_surface)

            model.add_model_keywords(pair, interact, behavior)
             
        step = sk.Step(nlgeom=True) 
        model.add_steps(step)       
        
        step.add_step_keywords(
            sk.Static(),                # step is a static one
            sk.Dload(mesh.get_el_set_by_name('HOLDER'), enums.EDloadType.GRAV, (9.810, 0, -1, 0)),
            sk.Boundary(model.mesh.get_node_set_by_name("UPPER_PRESS_SURFACE"), 2, -OFFSET),
            sk.Boundary(model.mesh.get_node_set_by_name("LOWER_PRESS_SURFACE"), 2, OFFSET),
            sk.NodeFile([enums.ENodeFileResults.U,
                         enums.ENodeFileResults.RF]), # request deformations in frd file
            sk.ElFile([enums.EElFileResults.S]), # request stresses in frd file
            sk.NodePrint(mesh.get_node_set_by_name('HOLDER'),[enums.ENodePrintResults.U,
                                                            enums.ENodePrintResults.RF]),
            sk.ElPrint(mesh.get_el_set_by_name('HOLDER'),[enums.EElPrintResults.S,
                                                        enums.EElPrintResults.EVOL,
                                                        enums.EElPrintResults.COORD,
                                                        enums.EElPrintResults.E,
                                                        enums.EElPrintResults.ME,
                                                        enums.EElPrintResults.ENER,
                                                        enums.EElPrintResults.ELKE,
                                                        enums.EElPrintResults.ELSE,
                                                        enums.EElPrintResults.EMAS])
        )
        
        model.write_ccx_input_file()
        model.solve(no_cpu=12)
        #model.show_results_in_cgx()
       

        
        # gmsh.write('holder.msh')
        # gmsh.write('holder.inp')

# %%
with jax.disable_jit(True):
    #construct_inp(geoms, 2000, 0.3, 0.2, 16, 0.075, None, None)
    construct_inp(geoms, 2000, 0.3, 0.1, 16, 0.025, -10.7, 10.7)
# Out:
# flat
# spoke
# round_0
# round_1
# round_2
# Info    : Cannot bind existing OpenCASCADE surface 6 to second tag 11
# Info    : Could not preserve tag of 2D object 11 (->6)
# Info    : Cannot bind existing OpenCASCADE surface 4 to second tag 15
# Info    : Could not preserve tag of 2D object 15 (->4)
# Info    : Cannot bind existing OpenCASCADE surface 16 to second tag 21
# Info    : Could not preserve tag of 2D object 21 (->16)
# Info    : Cannot bind existing OpenCASCADE surface 22 to second tag 27
# Info    : Could not preserve tag of 2D object 27 (->22)
# Info    : Cannot bind existing OpenCASCADE surface 3 to second tag 28
# Info    : Could not preserve tag of 2D object 28 (->3)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (BSpline)
# Info    : [ 10%] Meshing curve 2 (BSpline)
# Info    : [ 10%] Meshing curve 3 (BSpline)
# Info    : [ 10%] Meshing curve 4 (BSpline)
# Info    : [ 10%] Meshing curve 5 (BSpline)
# Info    : [ 10%] Meshing curve 6 (BSpline)
# Info    : [ 10%] Meshing curve 7 (BSpline)
# Info    : [ 20%] Meshing curve 8 (BSpline)
# Info    : [ 20%] Meshing curve 9 (BSpline)
# Info    : [ 20%] Meshing curve 10 (BSpline)
# Info    : [ 20%] Meshing curve 11 (BSpline)
# Info    : [ 20%] Meshing curve 12 (BSpline)
# Info    : [ 20%] Meshing curve 13 (BSpline)
# Info    : [ 30%] Meshing curve 14 (BSpline)
# Info    : [ 30%] Meshing curve 15 (BSpline)
# Info    : [ 30%] Meshing curve 16 (BSpline)
# Info    : [ 30%] Meshing curve 17 (BSpline)
# Info    : [ 30%] Meshing curve 18 (BSpline)
# Info    : [ 30%] Meshing curve 19 (BSpline)
# Info    : [ 30%] Meshing curve 20 (BSpline)
# Info    : [ 40%] Meshing curve 21 (BSpline)
# Info    : [ 40%] Meshing curve 22 (BSpline)
# Info    : [ 40%] Meshing curve 23 (BSpline)
# Info    : [ 40%] Meshing curve 24 (BSpline)
# Info    : [ 40%] Meshing curve 25 (BSpline)
# Info    : [ 40%] Meshing curve 26 (BSpline)
# Info    : [ 50%] Meshing curve 27 (BSpline)
# Info    : [ 50%] Meshing curve 28 (BSpline)
# Info    : [ 50%] Meshing curve 29 (BSpline)
# Info    : [ 50%] Meshing curve 30 (BSpline)
# Info    : [ 50%] Meshing curve 31 (BSpline)
# Info    : [ 50%] Meshing curve 32 (BSpline)
# Info    : [ 60%] Meshing curve 33 (BSpline)
# Info    : [ 60%] Meshing curve 34 (BSpline)
# Info    : [ 60%] Meshing curve 35 (BSpline)
# Info    : [ 60%] Meshing curve 36 (BSpline)
# Info    : [ 60%] Meshing curve 37 (BSpline)
# Info    : [ 60%] Meshing curve 38 (BSpline)
# Info    : [ 60%] Meshing curve 39 (BSpline)
# Info    : [ 70%] Meshing curve 40 (BSpline)
# Info    : [ 70%] Meshing curve 41 (Line)
# Info    : [ 70%] Meshing curve 42 (Line)
# Info    : [ 70%] Meshing curve 43 (Line)
# Info    : [ 70%] Meshing curve 44 (Line)
# Info    : [ 70%] Meshing curve 45 (Line)
# Info    : [ 80%] Meshing curve 46 (Line)
# Info    : [ 80%] Meshing curve 47 (Line)
# Info    : [ 80%] Meshing curve 48 (Line)
# Info    : [ 80%] Meshing curve 49 (Line)
# Info    : [ 80%] Meshing curve 50 (Line)
# Info    : [ 80%] Meshing curve 51 (Line)
# Info    : [ 80%] Meshing curve 52 (Line)
# Info    : [ 90%] Meshing curve 53 (Line)
# Info    : [ 90%] Meshing curve 54 (Line)
# Info    : [ 90%] Meshing curve 55 (Line)
# Info    : [ 90%] Meshing curve 56 (Line)
# Info    : [ 90%] Meshing curve 57 (Line)
# Info    : [ 90%] Meshing curve 58 (Line)
# Info    : [100%] Meshing curve 59 (Line)
# Info    : [100%] Meshing curve 60 (Line)
# Info    : [100%] Meshing curve 61 (Line)
# Info    : [100%] Meshing curve 62 (Line)
# Info    : [100%] Meshing curve 63 (Line)
# Info    : [100%] Meshing curve 64 (Line)
# Info    : Done meshing 1D (Wall 0.592883s, CPU 0.590356s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 2 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 3 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 4 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 5 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 6 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 7 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 8 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 9 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 10 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 12 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 13 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 14 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 16 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 17 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 18 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 19 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 20 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 22 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 23 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 24 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 25 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 26 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 29 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 30 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 31 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 32 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 33 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 34 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 35 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 36 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 37 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 38 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 39 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 40 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 41 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 42 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 7.25112s, CPU 7.2593s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 3 volumes with 3 connected components
# Info    : Tetrahedrizing 30668 nodes...
# Info    : Done tetrahedrizing 30676 nodes (Wall 1.84798s, CPU 1.80285s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 3.30987s, CPU 3.18576s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 12.8901 (nodes removed 0 0)
# Info    : It. 500 - 500 nodes created - worst tet radius 4.28586 (nodes removed 0 0)
# Info    : It. 1000 - 1000 nodes created - worst tet radius 3.72832 (nodes removed 0 0)
# Info    : It. 1500 - 1500 nodes created - worst tet radius 3.2772 (nodes removed 0 0)
# Info    : It. 2000 - 2000 nodes created - worst tet radius 3.01676 (nodes removed 0 0)
# Info    : It. 2500 - 2500 nodes created - worst tet radius 2.83042 (nodes removed 0 0)
# Info    : It. 3000 - 3000 nodes created - worst tet radius 2.6974 (nodes removed 0 0)
# Info    : It. 3500 - 3500 nodes created - worst tet radius 2.58133 (nodes removed 0 0)
# Info    : It. 4000 - 4000 nodes created - worst tet radius 2.48167 (nodes removed 0 0)
# Info    : It. 4500 - 4500 nodes created - worst tet radius 2.39593 (nodes removed 0 0)
# Info    : It. 5000 - 5000 nodes created - worst tet radius 2.31532 (nodes removed 0 0)
# Info    : It. 5500 - 5500 nodes created - worst tet radius 2.25224 (nodes removed 0 0)
# Info    : It. 6000 - 6000 nodes created - worst tet radius 2.20159 (nodes removed 0 0)
# Info    : It. 6500 - 6500 nodes created - worst tet radius 2.15439 (nodes removed 0 0)
# Info    : It. 7000 - 7000 nodes created - worst tet radius 2.111 (nodes removed 0 0)
# Info    : It. 7500 - 7500 nodes created - worst tet radius 2.0701 (nodes removed 0 0)
# Info    : It. 8000 - 8000 nodes created - worst tet radius 2.03209 (nodes removed 0 0)
# Info    : It. 8500 - 8500 nodes created - worst tet radius 1.99165 (nodes removed 0 0)
# Info    : It. 9000 - 9000 nodes created - worst tet radius 1.95706 (nodes removed 0 0)
# Info    : It. 9500 - 9500 nodes created - worst tet radius 1.92389 (nodes removed 0 0)
tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 12700 nodes...
# Info    : Done tetrahedrizing 12708 nodes (Wall 0.542196s, CPU 0.528398s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 2 Steiner points
# Info    : Done reconstructing mesh (Wall 1.60862s, CPU 1.57858s)
# Info    : Found volume 2
# Info    : It. 0 - 0 nodes created - worst tet radius 5.95934 (nodes removed 0 0)
# Info    : It. 500 - 485 nodes created - worst tet radius 2.08167 (nodes removed 0 15)
# Info    : It. 1000 - 985 nodes created - worst tet radius 1.77083 (nodes removed 0 15)
# Info    : It. 1500 - 1485 nodes created - worst tet radius 1.50473 (nodes removed 0 15)
# Info    : It. 2000 - 1985 nodes created - worst tet radius 1.43279 (nodes removed 0 15)
# Info    : It. 2500 - 2485 nodes created - worst tet radius 1.38647 (nodes removed 0 15)
# Info    : It. 3000 - 2985 nodes created - worst tet radius 1.3534 (nodes removed 0 15)
# Info    : It. 3500 - 3485 nodes created - worst tet radius 1.33065 (nodes removed 0 15)
# Info    : It. 4000 - 3985 nodes created - worst tet radius 1.29744 (nodes removed 0 15)
# Info    : It. 4500 - 4485 nodes created - worst tet radius 1.23726 (nodes removed 0 15)
# Info    : It. 5000 - 4985 nodes created - worst tet radius 1.18386 (nodes removed 0 15)
# Info    : It. 5500 - 5485 nodes created - worst tet radius 1.14649 (nodes removed 0 15)
# Info    : It. 6000 - 5985 nodes created - worst tet radius 1.1135 (nodes removed 0 15)
# Info    : It. 6500 - 6485 nodes created - worst tet radius 1.09325 (nodes removed 0 15)
# Info    : It. 7000 - 6985 nodes created - worst tet radius 1.07784 (nodes removed 0 15)
# Info    : It. 7500 - 7485 nodes created - worst tet radius 1.05256 (nodes removed 0 15)
# Info    : It. 8000 - 7985 nodes created - worst tet radius 1.02722 (nodes removed 0 15)
# Info    : It. 8500 - 8485 nodes created - worst tet radius 1.00714 (nodes removed 0 15)
# Info    : 3D refinement terminated (67918 nodes total):
# Info    :  - 3 Delaunay cavities modified for star shapeness
# Info    :  - 15 nodes could not be inserted
# Info    :  - 93237 tetrahedra created in 2.21973 sec. (42003 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 12703 nodes...
# Info    : Done tetrahedrizing 12711 nodes (Wall 0.609311s, CPU 0.606986s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 2 Steiner points
# Info    : Done reconstructing mesh (Wall 1.62822s, CPU 1.62663s)
# Info    : Found volume 3
# Info    : It. 0 - 0 nodes created - worst tet radius 5.95737 (nodes removed 0 0)
# Info    : It. 500 - 478 nodes created - worst tet radius 2.08167 (nodes removed 0 22)
# Info    : It. 1000 - 978 nodes created - worst tet radius 1.78067 (nodes removed 0 22)
# Info    : It. 1500 - 1478 nodes created - worst tet radius 1.50473 (nodes removed 0 22)
# Info    : It. 2000 - 1978 nodes created - worst tet radius 1.43363 (nodes removed 0 22)
# Info    : It. 2500 - 2478 nodes created - worst tet radius 1.38862 (nodes removed 0 22)
# Info    : It. 3000 - 2978 nodes created - worst tet radius 1.35358 (nodes removed 0 22)
# Info    : It. 3500 - 3478 nodes created - worst tet radius 1.33058 (nodes removed 0 22)
# Info    : It. 4000 - 3978 nodes created - worst tet radius 1.29602 (nodes removed 0 22)
# Info    : It. 4500 - 4478 nodes created - worst tet radius 1.23716 (nodes removed 0 22)
# Info    : It. 5000 - 4978 nodes created - worst tet radius 1.18434 (nodes removed 0 22)
# Info    : It. 5500 - 5478 nodes created - worst tet radius 1.14338 (nodes removed 0 22)
# Info    : It. 6000 - 5978 nodes created - worst tet radius 1.11308 (nodes removed 0 22)
# Info    : It. 6500 - 6478 nodes created - worst tet radius 1.09309 (nodes removed 0 22)
# Info    : It. 7000 - 6978 nodes created - worst tet radius 1.07806 (nodes removed 0 22)
# Info    : It. 7500 - 7478 nodes created - worst tet radius 1.05353 (nodes removed 0 22)
# Info    : It. 8000 - 7978 nodes created - worst tet radius 1.02646 (nodes removed 0 22)
# Info    : It. 8500 - 8478 nodes created - worst tet radius 1.00646 (nodes removed 0 22)
# Info    : 3D refinement terminated (67896 nodes total):
# Info    :  - 4 Delaunay cavities modified for star shapeness
# Info    :  - 22 nodes could not be inserted
# Info    :  - 93133 tetrahedra created in 2.23436 sec. (41682 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 47.85s, CPU 47.7125s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 1.99821) with worst = 0.00180069 / average = 0.782739:
# Info    : 0.00 < quality < 0.10 :      1258 elements
# Info    : 0.10 < quality < 0.20 :      3753 elements
# Info    : 0.20 < quality < 0.30 :      6399 elements
# Info    : 0.30 < quality < 0.40 :     10342 elements
# Info    : 0.40 < quality < 0.50 :     16226 elements
# Info    : 0.50 < quality < 0.60 :     26827 elements
# Info    : 0.60 < quality < 0.70 :     56139 elements
# Info    : 0.70 < quality < 0.80 :    134147 elements
# Info    : 0.80 < quality < 0.90 :    226847 elements
# Info    : 0.90 < quality < 1.00 :    115991 elements
# Info    : 11298 edge swaps, 359 node relocations (volume = 1.99821): worst = 0.166401 / average = 0.79479 (Wall 0.77175s, CPU 0.773167s)
# Info    : 11364 edge swaps, 362 node relocations (volume = 1.99821): worst = 0.196384 / average = 0.79486 (Wall 1.02531s, CPU 1.02964s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         1 elements
# Info    : 0.20 < quality < 0.30 :         7 elements
# Info    : 0.30 < quality < 0.40 :     10279 elements
# Info    : 0.40 < quality < 0.50 :     15579 elements
# Info    : 0.50 < quality < 0.60 :     25792 elements
# Info    : 0.60 < quality < 0.70 :     55839 elements
# Info    : 0.70 < quality < 0.80 :    135949 elements
# Info    : 0.80 < quality < 0.90 :    228871 elements
# Info    : 0.90 < quality < 1.00 :    115376 elements
# Info    : Optimizing volume 2
# Info    : Optimization starts (volume = 0.3) with worst = 0.0115379 / average = 0.784417:
# Info    : 0.00 < quality < 0.10 :       208 elements
# Info    : 0.10 < quality < 0.20 :       555 elements
# Info    : 0.20 < quality < 0.30 :       915 elements
# Info    : 0.30 < quality < 0.40 :      1410 elements
# Info    : 0.40 < quality < 0.50 :      2183 elements
# Info    : 0.50 < quality < 0.60 :      3765 elements
# Info    : 0.60 < quality < 0.70 :      8983 elements
# Info    : 0.70 < quality < 0.80 :     22360 elements
# Info    : 0.80 < quality < 0.90 :     35333 elements
# Info    : 0.90 < quality < 1.00 :     17523 elements
# Info    : 1664 edge swaps, 29 node relocations (volume = 0.3): worst = 0.165181 / average = 0.796033 (Wall 0.108464s, CPU 0.108203s)
# Info    : 1680 edge swaps, 30 node relocations (volume = 0.3): worst = 0.276292 / average = 0.796135 (Wall 0.14148s, CPU 0.141328s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         4 elements
# Info    : 0.30 < quality < 0.40 :      1411 elements
# Info    : 0.40 < quality < 0.50 :      2055 elements
# Info    : 0.50 < quality < 0.60 :      3592 elements
# Info    : 0.60 < quality < 0.70 :      8965 elements
# Info    : 0.70 < quality < 0.80 :     22572 elements
# Info    : 0.80 < quality < 0.90 :     35602 elements
# Info    : 0.90 < quality < 1.00 :     17506 elements
# Info    : Optimizing volume 3
# Info    : Optimization starts (volume = 0.3) with worst = 0.00789684 / average = 0.784274:
# Info    : 0.00 < quality < 0.10 :       223 elements
# Info    : 0.10 < quality < 0.20 :       542 elements
# Info    : 0.20 < quality < 0.30 :       913 elements
# Info    : 0.30 < quality < 0.40 :      1394 elements
# Info    : 0.40 < quality < 0.50 :      2173 elements
# Info    : 0.50 < quality < 0.60 :      3782 elements
# Info    : 0.60 < quality < 0.70 :      8866 elements
# Info    : 0.70 < quality < 0.80 :     22325 elements
# Info    : 0.80 < quality < 0.90 :     35678 elements
# Info    : 0.90 < quality < 1.00 :     17236 elements
# Info    : 1675 edge swaps, 31 node relocations (volume = 0.3): worst = 0.129382 / average = 0.796035 (Wall 0.142526s, CPU 0.143334s)
# Info    : 1687 edge swaps, 34 node relocations (volume = 0.3): worst = 0.238121 / average = 0.796097 (Wall 0.184916s, CPU 0.185766s)
# Info    : 1688 edge swaps, 34 node relocations (volume = 0.3): worst = 0.297753 / average = 0.796103 (Wall 0.224456s, CPU 0.22552s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :      1408 elements
# Info    : 0.40 < quality < 0.50 :      2057 elements
# Info    : 0.50 < quality < 0.60 :      3603 elements
# Info    : 0.60 < quality < 0.70 :      8832 elements
# Info    : 0.70 < quality < 0.80 :     22405 elements
# Info    : 0.80 < quality < 0.90 :     36069 elements
# Info    : 0.90 < quality < 1.00 :     17219 elements
# Info    : Done optimizing mesh (Wall 5.19004s, CPU 5.07966s)
# Info    : 162951 nodes 900437 elements
# Info    : Writing 'test.geo_unrolled'...
# Info    : Done writing 'test.geo_unrolled'
# Info    : Writing 'test.msh'...
# meshed
# Info    : Done writing 'test.msh'
#
# ************************************************************
#
# CalculiX Version 2.21, Copyright(C) 1998-2023 Guido Dhondt
# CalculiX comes with ABSOLUTELY NO WARRANTY. This is free
# software, and you are welcome to redistribute it under
# certain conditions, see gpl.htm
#
# ************************************************************
#
# You are using an executable made on Sat Jul 29 10:52:01 CEST 2023
#
#   The numbers below are estimated upper bounds
#
#   number of:
#
#    nodes:       162951
#    elements:       854813
#    one-dimensional elements:            0
#    two-dimensional elements:            0
#    integration points per element:            1
#    degrees of freedom per node:            3
#    layers per element:            1
#
#    distributed facial loads:            0
#    distributed volumetric loads:            1
#    concentrated loads:            0
#    single point constraints:        39978
#    multiple point constraints:            1
#    terms in all multiple point constraints:            1
#    tie constraints:            2
#    dependent nodes tied by cyclic constraints:            0
#    dependent nodes in pre-tension constraints:            0
#
#    sets:           16
#    terms in all sets:      1592470
#
#    materials:            5
#    constants per material and temperature:            4
#    temperature points per material:            1
#    plastic data points per material:            0
#
#    orientations:            0
#    amplitudes:            8
#    data points in all amplitudes:            8
#    print requests:           11
#    transformations:            0
#    property cards:            0
#
#
#  STEP            1
#
#  *INFO reading *STEP: nonlinear geometric
#        effects are turned on
#
#  *WARNING reading *STATIC:
#           the minimum increment    0.0000000000000000
#           is smaller then 1.e-6 times the
#           step time;
#           the minimum increment is changed
#           to    9.9999999999999995E-007
#           which is the minimum of the initial
#           increment time and 1.e-6 times the step time
#
#  *WARNING in calinput: no density was assigned
#           to material ELASTIC in a dynamic
#           calculation or a calculation with
#           centrifugal or gravitational loads
#           or an incompressible CFD calculation
#
#  *WARNING in calinput: no density was assigned
#           to material ELASTIC in a dynamic
#           calculation or a calculation with
#           centrifugal or gravitational loads
#           or an incompressible CFD calculation
#
#  Static analysis was selected
#
#  Newton-Raphson iterative procedure is active
#
#  Nonlinear geometric effects are taken into account
#
#  Decascading the MPC's
#
#  Determining the structure of the matrix:
#  Using up to 12 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  416340
#  number of nonzero lower triangular matrix elements
#  8467758
#
#  increment 1 attempt 1
#  increment size= 1.000000e+00
#  sum of previous increments=0.000000e+00
#  actual step time=1.000000e+00
#  actual total time=1.000000e+00
#
#  iteration 1
#
#  Number of contact spring elements=0
#
#  Determining the structure of the matrix:
#
#  Using up to 12 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  416340
#  number of nonzero lower triangular matrix elements
#  8467758
#
#  Using up to 12 cpu(s) for the stress calculation.
#
#  Using up to 12 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 12 cpu(s) for spooles.
#
#  Using up to 12 cpu(s) for the stress calculation.
#
#  average force= 0.015302
#  time avg. forc= 0.015302
#  largest residual force= 0.313204 in node 17964 and dof 2
#  largest increment of disp= 1.146478e+00
#  largest correction to disp= 1.146478e+00 in node 25915 and dof 2
#
#  no convergence
#
#  iteration 2
#
#  Number of contact spring elements=0
#
#  Determining the structure of the matrix:
#
#  Using up to 12 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  416340
#  number of nonzero lower triangular matrix elements
#  8467758
#
#  Using up to 12 cpu(s) for the stress calculation.
#
#  Using up to 12 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 12 cpu(s) for spooles.
#
#  Using up to 12 cpu(s) for the stress calculation.
#
#  average force= 0.001603
#  time avg. forc= 0.001603
#  largest residual force= 0.032858 in node 17964 and dof 2
#  largest increment of disp= 1.146478e+00
#  largest correction to disp= 1.864766e-01 in node 24976 and dof 1
#
#  no convergence
#
#  iteration 3
#
#  Number of contact spring elements=0
#
#  Determining the structure of the matrix:
#
#  Using up to 12 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  416340
#  number of nonzero lower triangular matrix elements
#  8467758
#
#  Using up to 12 cpu(s) for the stress calculation.
#
#  Using up to 12 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 12 cpu(s) for spooles.
#
#  Using up to 12 cpu(s) for the stress calculation.
#
#  average force= 0.000441
#  time avg. forc= 0.000441
#  largest residual force= 0.000753 in node 17964 and dof 2
#  largest increment of disp= 1.146478e+00
#  largest correction to disp= 2.588062e-02 in node 24691 and dof 1
#
#  no convergence
#
#  iteration 4
#
#  Number of contact spring elements=0
#
#  Determining the structure of the matrix:
#
#  Using up to 12 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  416340
#  number of nonzero lower triangular matrix elements
#  8467758
#
#  Using up to 12 cpu(s) for the stress calculation.
#
#  Using up to 12 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 12 cpu(s) for spooles.
#
#  Using up to 12 cpu(s) for the stress calculation.
#
#  average force= 0.000437
#  time avg. forc= 0.000437
#  largest residual force= 0.000007 in node 27504 and dof 1
#  largest increment of disp= 1.146478e+00
#  largest correction to disp= 4.713150e-03 in node 25684 and dof 2
#
#  no convergence
#
#  iteration 5
#
#  Number of contact spring elements=0
#
#  Determining the structure of the matrix:
#
#  Using up to 12 cpu(s) for setting up the structure of the matrix.
#  number of equations
#  416340
#  number of nonzero lower triangular matrix elements
#  8467758
#
#  Using up to 12 cpu(s) for the stress calculation.
#
#  Using up to 12 cpu(s) for the symmetric stiffness/mass contributions.
#
#  Factoring the system of equations using the symmetric spooles solver
#  Using up to 12 cpu(s) for spooles.
#
#  Using up to 12 cpu(s) for the stress calculation.
#
#  average force= 0.000436
#  time avg. forc= 0.000436
#  largest residual force= 0.000000 in node 17964 and dof 2
#  largest increment of disp= 1.146478e+00
#  largest correction to disp= 1.816683e-03 in node 25886 and dof 2
#
#  convergence
#
#  the increment size exceeds the remainder of the step and is decreased to 0.000000e+00
#
#  Using up to 12 cpu(s) for the stress calculation.
#
#
#  Job finished
#
# ________________________________________
#
# Total CalculiX Time: 381.655750
# ________________________________________

# %%
import ccx2paraview.ccx2paraview

c = ccx2paraview.ccx2paraview.Converter("holder.frd", ['vtk'])
c.run()
