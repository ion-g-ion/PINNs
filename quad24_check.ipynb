# %%
import fenics as fn
import matplotlib.pyplot as plt
from dolfin_utils.meshconvert import meshconvert
import os
from subprocess import call

import numpy as np
import jax
import jax.numpy as jnp
from jax.example_libraries import stax, optimizers
import matplotlib.pyplot as plt
import pinns 
import datetime
import jax.scipy.optimize
import jax.flatten_util
import scipy
import scipy.optimize
import chaospy as cp

# %%
def curl2D(v):
    return fn.as_vector((v.dx(1),-v.dx(0)))

class FEM():
            
    def __init__(self,J0=1000.0,mu0=1.0,mur=10.0, k1=0.001, k2=1.65, k3 = 0.5, meshsize = 0.001, verb = False):
        path='./quad/'
        
        with open(path + 'quad.geo', 'r') as file:
            data = file.read()
            
        s = "meshsize=%.18f;\n"%(meshsize)
        
        s = s + data
        
        with  open(path+"tmp.geo", "w") as file:
            file.write(s)
            file.close()
        if verb: print('geo file created',flush = True)
        
        if verb:
            os.system('gmsh %stmp.geo -nt 20 -3 -o %stmp.msh -format msh2 '%(path,path))
        else:
            os.system('gmsh %stmp.geo -nt 20 -3 -o %stmp.msh -format msh2 >/dev/null 2>&1'%(path,path))
        if verb: print('mesh file created',flush=True)

        if verb:
            os.system('dolfin-convert %stmp.msh %stmp.xml'%(path,path))
        else:
            os.system('dolfin-convert %stmp.msh %stmp.xml >/dev/null 2>&1'%(path,path))
        
        if verb: print('mesh file converted in fenics format',flush=True) 

        mesh = fn.Mesh(path+'tmp.xml')
        domains = fn.MeshFunction("size_t", mesh, path+'tmp_physical_region.xml')
        boundaries = fn.MeshFunction('size_t', mesh, path+'tmp_facet_region.xml')

        self.mesh = mesh
        ncells = [  mesh.num_vertices(), mesh.num_edges(), mesh.num_faces(), mesh.num_facets(), mesh.num_cells() ]
        
        def nu_lin(az):
            return 1/(mu0*mur)
        def nonlin_nu(az):
            tmp =  k1*fn.exp(k2*fn.dot(az.dx(1),az.dx(1)))+k3
            return tmp
        
        def nu_Bauer(B):
            x = fn.dot(B,B)
            return k1*fn.exp(k2*x)+k3
        
        # Coil
        def setup_coil(mesh,subdomains):
            DG = fn.FunctionSpace(mesh,"DG",0)
            J = fn.Function(DG)
            idx = []
            for cell_no in range(len(subdomains.array())):
                subdomain_no = subdomains.array()[cell_no]
                if subdomain_no == 3:
                    idx.append(cell_no)
            J.vector()[:] = 0
            J.vector()[idx] = J0
            return J
        
    
        
        """ define function space and boundary conditions"""
        
        CG = fn.FunctionSpace(mesh, 'CG', 1) # Continuous Galerkin
        
        # Define boundary condition
        bc = fn.DirichletBC(CG, fn.Constant(0.0), boundaries,16)
        
        # Define subdomain markers and integration measure
        dx = fn.Measure('dx', domain=mesh, subdomain_data=domains)
        
        J = setup_coil(mesh, domains)
        
        class Nu(fn.UserExpression): # UserExpression instead of Expression
            def __init__(self, markers, **kwargs):
                super().__init__(**kwargs) # This part is new!
                self.markers = markers
            def eval_cell(self, values, x, cell):
                if self.markers[cell.index] == 1:
                    values[0] = 0.0   # iron
                elif self.markers[cell.index] == 2:
                    values[0] = 1/mu0      # air
                elif self.markers[cell.index] == 3:
                    values[0] = 1/mu0      # air
                else:
                    print('no such domain',self.markers[cell.index] )
                    
        nus = Nu(domains, degree=1)
        
        
        """ weak formulation """
        
        az  = fn.Function(CG)
        u  = fn.Function(CG)
        v  = fn.TestFunction(CG)
        #az = Function(CG)
        #a  = (1/mu)*dot(grad(az), grad(v))*dx
        a = fn.inner(nus*curl2D(u), curl2D(v))*dx + fn.inner(nu_lin(curl2D(u))*curl2D(u),curl2D(v))*dx(1)
        L  = J*v*dx(3)
        
        F = a - L
        # solve variational problem
        fn.solve(F == 0, u, bc)
        az = u
        self.az = az
        # function space for H- and B- field allocated on faces of elements
        W = fn.VectorFunctionSpace(mesh, fn.FiniteElement("DP", fn.triangle, 0),1)
        B = fn.project(curl2D(az), W)
        H = None# project((1/mu)*curl(az), W)
        self.B = B
        self.H = H
    
    def call_A(self,x_eval,y_eval):
        
        
        Afem = 0 * x_eval
        for i in range(x_eval.size):
            try:
                Afem[i] = self.az(x_eval[i],y_eval[i])
            except:
                Afem[i] = np.nan
        return Afem
    
    def call_B(self,x_eval,y_eval):
        
        
        Bfem = []
        for i in range(x_eval.size):
            try:
                Bfem.append(self.B(x_eval[i],y_eval[i]))
            except:
                Bfem.append([ np.nan , np.nan])
        return np.array(Bfem)
    
    def call_H(self,x_eval,y_eval):
        Hfem = []
        for i in range(x_eval.size):
            try:
                Hfem.append(self.H(x_eval[i],y_eval[i]))
            except:
                Hfem.append([ np.nan , np.nan])
        return np.array(Hfem)

# %%
from jax.config import config
config.update("jax_enable_x64", True)
rnd_key = jax.random.PRNGKey(1234)

# %%
def create_geometry(key, scale = 1):
    scale = scale
    Nt = 24                                                                
    lz = 40e-3                                                             
    Do = 72e-3                                                            
    Di = 51e-3                                                            
    hi = 13e-3                                                             
    bli = 3e-3                                                             
    Dc = 3.27640e-2                                                           
    hc = 7.55176e-3                                                           
    ri = 20e-3                                                           
    ra = 18e-3                                                           
    blc = hi-hc                                                           
    rm = (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)                 
    R = rm-ri
    O = np.array([rm/np.sqrt(2),rm/np.sqrt(2)])
    alpha1 = -np.pi*3/4       
    alpha2 = np.math.asin((hc-rm/np.sqrt(2))/R)
    alpha = np.abs(alpha2-alpha1)
    
    A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
    b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
    C = np.linalg.solve(A,b)
    
    knots1 = np.array([[Do,Do * np.tan(np.pi/8)],[Do/np.sqrt(2),Do/np.sqrt(2)],[rm/np.sqrt(2),rm/np.sqrt(2)],[ri/np.sqrt(2),ri/np.sqrt(2)]])
    #knots2 = np.array([[Dc,hc],[Dc+blc,hi],[Di-bli,hi],[Di,hi-bli],[Di,0]])
    knots2 = np.array([[Di,hi-bli],[Di-bli,hi],[Dc+blc,hi],[Dc,hc]])
    knots3 = (knots1+knots2)/2
    knots3[-1,:] = C.flatten()
    knots = np.concatenate((knots1[None,...],knots3[None,...],knots2[None,...]),0)
    weights = np.ones(knots.shape[:2])
    weights[1,-1] = np.sin((np.pi-alpha)/2)
    basis2 = pinns.bspline.BSplineBasis(np.array([-1,-0.33,0.33,1]),1)
    basis1 = pinns.bspline.BSplineBasis(np.array([-1,1]),2)

    geom1 = pinns.geometry.PatchNURBS([basis1, basis2], knots, weights, key)
   
    knots2 = np.array([ [ [Dc,0],[Dc+blc,0],[Di-bli,0],[Di,0] ] , [[Dc,hc],[Dc+blc,hi],[Di-bli,hi],[Di,hi-bli]] ]) 
    knots2 = knots2[:,::-1,:]
    weights = np.ones(knots2.shape[:2])
    
    basis1 = pinns.bspline.BSplineBasis(np.linspace(-1,1,2),1)
    basis2 = pinns.bspline.BSplineBasis(np.array([-1,-0.33,0.33,1]),1)

    geom2 = pinns.geometry.PatchNURBS([basis1, basis2], knots2, weights, key)
   
    knots = np.array([ [ [0,0] , [Dc/2,0] , [Dc,0] ] , [ [ri/np.sqrt(2),ri/np.sqrt(2)] , [C[0,0],C[1,0]] , [Dc,hc] ]])
    
    basis1 = pinns.bspline.BSplineBasis(np.linspace(-1,1,2),1)
    basis2 = pinns.bspline.BSplineBasis(np.array([-1,1]),2)
    
    weights = np.ones(knots.shape[:2])
    weights[1,1] = np.sin((np.pi-alpha)/2)
    geom3 = pinns.geometry.PatchNURBS([basis1, basis2], knots, weights, key)

    knots1 = np.array([[Do,0],[Do,Do * np.tan(np.pi/8)]])
    knots2 = np.array([[Di,0],[Di,hi-bli]])
    knots3 = (knots1+knots2)/2
    knots = np.concatenate((knots1[None,...],knots3[None,...],knots2[None,...]),0)
    weights = np.ones(knots.shape[:2])

    basis2 = pinns.bspline.BSplineBasis(np.linspace(-1,1,2),1)
    basis1 = pinns.bspline.BSplineBasis(np.array([-1,1]),2)

    geom4 = pinns.geometry.PatchNURBS([basis1, basis2], knots, weights, key)
    return  geom1, geom3, geom2, geom4

# %%
geom1, geom2, geom3, geom4 = create_geometry(rnd_key)

pts,_ = geom1.importance_sampling(10000)

plt.figure()
plt.scatter(pts[:,0], pts[:,1], s = 1)

pts,_ = geom2.importance_sampling(10000)
plt.scatter(pts[:,0],pts[:,1], s = 1)

pts,_ = geom3.importance_sampling(10000)
plt.scatter(pts[:,0],pts[:,1], s = 1)

pts,_ = geom4.importance_sampling(10000)
plt.scatter(pts[:,0],pts[:,1], s = 1)
plt.show()

# %%
def interface_function2d(nd, endpositive, endzero, nn):

    faux = lambda x: ((x-endzero)**1/(endpositive-endzero)**1)
    if nd == 0:
        fret = lambda ws, x: (nn(ws, x[...,1][...,None]).flatten()*faux(x[...,0]))[...,None]
    else:
        fret = lambda ws, x: (nn(ws, x[...,0][...,None]).flatten()*faux(x[...,1]))[...,None]
    return fret

def jump_function2d(nd, pos_y, nn):

    faux = lambda x: jnp.exp(-4.0*jnp.abs(x-pos_y))
    if nd == 1:
        fret = lambda ws, x: (nn(ws, x[...,1][...,None]).flatten()*faux(x[...,0]))[...,None]
    else:
        fret = lambda ws, x: (nn(ws, x[...,0][...,None]).flatten()*faux(x[...,1]))[...,None]
    return fret

# def ExpHat(hidden_size, out_dim, W_init=glorot_normal(), b_init=normal()):
#   """Layer constructor function for a dense (fully-connected) layer."""
#   def init_fun(rng, input_shape):
#     output_shape = input_shape[:-1] + (out_dim,)
#     k1, k2 = random.split(rng)
#     W, b = W_init(k1, (input_shape[-1], out_dim)), b_init(k2, (out_dim,))
#     return output_shape, (W, b)
#   def apply_fun(params, inputs, **kwargs):
#     b, b = params
#     return jnp.dot(inputs, W) + b
#   return init_fun, apply_fun
def ExpHat(x, scale = 0.1):
    return jnp.exp(-jnp.abs(x)/scale)

class Model(pinns.PINN):
    def __init__(self, rand_key):
        super().__init__()
        self.key = rand_key

        N = [32,32]
        nl = 8
        acti = stax.Tanh
        # acti =  stax.elementwise(lambda x: jax.nn.leaky_relu(x)**2)
        acti1 = stax.elementwise(lambda x: jax.nn.leaky_relu(x+1)**2)
        acti2 = stax.elementwise(lambda x: jax.nn.leaky_relu(x+0.33)**2)
        acti3 = stax.elementwise(lambda x: jax.nn.leaky_relu(x-0.33)**2)
        acti4 = stax.elementwise(lambda x: jnp.exp(-1.0*jnp.abs(x)))
        
        block_first = stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(nl), acti, stax.Dense(nl), acti),stax.Dense(nl)),stax.FanInSum)
        block = stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(nl), acti, stax.Dense(nl), acti),stax.Dense(nl)),stax.FanInSum)
        block2 = lambda n: stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(n), acti, stax.Dense(n), acti),stax.Dense(n)),stax.FanInSum)
        block3 = stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(nl), acti3, stax.Dense(nl), acti2),stax.Dense(nl)),stax.FanInSum)
        
        self.add_neural_network('u1',stax.serial(block_first,block,block, block, stax.Dense(1)),(-1,2)) # iron
        self.add_neural_network('u4',stax.serial(block_first,block,block, block, stax.Dense(1)),(-1,2)) # iron 2
        self.add_neural_network('u2',stax.serial(block_first,block,block, block, stax.Dense(1)),(-1,2)) # air 
        self.add_neural_network('u3',stax.serial(block_first,block,block, block, stax.Dense(1)),(-1,2)) # copper
        self.add_neural_network('u12',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u13',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        # self.add_neural_network('u13',stax.serial(stax.Dense(1000), acti4, stax.Dense(1)),(-1,1))
        self.add_neural_network('u23',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u14',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u34',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u1_0.3',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_neural_network('u1_0.7',stax.serial(block_first, block, block, stax.Dense(1)),(-1,1))
        self.add_trainable_parameter('u123',(1,))
        self.add_trainable_parameter('u134',(1,))
        self.add_trainable_parameter('u13_p0.33',(1,))
        self.add_trainable_parameter('u13_n0.33',(1,))
        self.init_points(N)
        
        self.interface12 = interface_function2d(1,1.0,-1.0,self.neural_networks['u12'])
        self.interface21 = interface_function2d(0,1.0,-1.0,self.neural_networks['u12'])
        self.interface23 = interface_function2d(1,1.0,-1.0,self.neural_networks['u23'])
        self.interface32 = interface_function2d(1,1.0,-1.0,self.neural_networks['u23'])
        self.interface13 = interface_function2d(0,1.0,-1.0,self.neural_networks['u13'])
        self.interface31 = interface_function2d(0,1.0,-1.0,self.neural_networks['u13'])
        self.interface14 = interface_function2d(1,-1.0,1.0,self.neural_networks['u14'])
        self.interface41 = interface_function2d(1,1.0,-1.0,self.neural_networks['u14'])
        self.interface34 = interface_function2d(1,-1.0,1.0,self.neural_networks['u34'])
        self.interface43 = interface_function2d(0,1.0,-1.0,self.neural_networks['u34'])

        self.jump1 = jump_function2d(0, -0.33, self.neural_networks['u1_0.3'])
        self.jump2 = jump_function2d(0,  0.33, self.neural_networks['u1_0.7'])

        self.mu0 = 0.001
        self.mur = 1000
        self.J0 = 1000000

    def init_points(self, N, quad = 'MC'):        

        self.points = {}

        if quad == 'MC':
            ys = np.random.rand(10000,2)*2-1
            Weights = np.ones((10000,))*4/ys.shape[0]

        # ys = np.meshgrid(np.polynomial.legendre.leggauss(N[0])[0], np.polynomial.legendre.leggauss(N[1])[0])
        # ys = np.concatenate((ys[0].flatten()[:,None], ys[1].flatten()[:,None]), -1)
        # Weights = np.kron(np.polynomial.legendre.leggauss(N[0])[1], np.polynomial.legendre.leggauss(N[1])[1]).flatten()
        if quad=='SG':
            ys,Weights = cp.quadrature.sparse_grid(10,cp.J(cp.Uniform(-1,1),cp.Uniform(-1,1)),rule=["fejer_2", "fejer_2"])
            Weights = Weights*4
            ys = np.transpose(ys)

        if quad == 'TP': ys, Weights = pinns.geometry.tensor_product_integration(geom1.basis, N)
        self.points['ys1'] = ys
        self.points['ws1'] = Weights
        DGys = geom1._eval_omega(ys)
        Inv = np.linalg.inv(DGys)
        det = np.abs(np.linalg.det(DGys))
        self.points['K1'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
        self.points['omega1'] = det
       
        if quad == 'TP': ys, Weights = pinns.geometry.tensor_product_integration(geom2.basis, N)
        self.points['ys2'] = ys
        self.points['ws2'] = Weights
        DGys = geom2._eval_omega(ys)
        Inv = np.linalg.inv(DGys)
        det = np.abs(np.linalg.det(DGys))
        self.points['K2'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
        self.points['omega2'] = det
        
        if quad == 'TP': ys, Weights = pinns.geometry.tensor_product_integration(geom3.basis, N)
        self.points['ys3'] = ys
        self.points['ws3'] = Weights
        DGys = geom3._eval_omega(ys)
        Inv = np.linalg.inv(DGys)
        det = np.abs(np.linalg.det(DGys))
        self.points['K3'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
        self.points['omega3'] = det
       
        if quad == 'TP': ys, Weights = pinns.geometry.tensor_product_integration(geom4.basis, N)
        self.points['ys4'] = ys
        self.points['ws4'] = Weights
        DGys = geom4._eval_omega(ys)
        Inv = np.linalg.inv(DGys)
        det = np.abs(np.linalg.det(DGys))
        self.points['K4'] = np.einsum('mij,mjk,m->mik',Inv,np.transpose(Inv,[0,2,1]),det)
        self.points['omega4'] = det

    def solution1(self, ws, x):
        # iron
        u = self.neural_networks['u1'](ws['u1'],x) + self.jump1(ws['u1_0.3'], x) + self.jump2(ws['u1_0.7'], x)
        v = ((1-x[...,0])*(x[...,0] + 1)*(1-x[...,1])*(x[...,1]+1))[...,None]
        w =  self.interface12(ws['u12'],x)*((1-x[...,0])*(x[...,0] + 1))[...,None] + (self.interface13(ws['u13'],x)+ExpHat(x[...,1]+0.33)[...,None]*ws['u13_n0.33']+ExpHat(x[...,1]-0.33)[...,None]*ws['u13_p0.33'])*(1-x[...,1])[...,None]*(x[...,1] + 1)[...,None] +  self.interface14(ws['u14'],x) * ((1-x[...,0])*(x[...,0] + 1))[...,None]
        w = w + ws['u123']*( (x[...,0]+1) * (x[...,1]+1) )[...,None]**3 + ws['u134'] *  ( (x[...,0] + 1)*(1-x[...,1]) )[...,None]**3
        return u*v+w

    def solution2(self, ws, x):
        
        u = self.neural_networks['u2'](ws['u2'],x)
        v = ((1-x[...,1])*(x[...,1] + 1)*(1-x[...,0]))[...,None]
        w = self.interface21(ws['u12'],x)*((1-x[...,1])*(x[...,1] + 1))[...,None] + self.interface23(ws['u23'],x)*(1-x[...,0])[...,None]
        w = w + ws['u123']*( (x[...,0]+1) * (x[...,1]+1) )[...,None]**3
        return u*v+w
    
    def solution3(self, ws, x):
        
        u = self.neural_networks['u3'](ws['u3'],x)
        v = ((1-x[...,1])*(x[...,1] + 1)*(1-x[...,0]))[...,None]
        w =  self.interface32(ws['u23'],x)*(1-x[...,0])[...,None]+(self.interface31(ws['u13'],x)+ExpHat(x[...,1]+0.33)[...,None]*ws['u13_n0.33']+ExpHat(x[...,1]-0.33)[...,None]*ws['u13_p0.33'])*((1-x[...,1])*(x[...,1] + 1))[...,None]+self.interface34(ws['u34'],x)*(1-x[...,0])[...,None]
        w = w + ws['u123']*( (x[...,0]+1) * (x[...,1]+1) )[...,None]**3 + ws['u134'] *  ( (x[...,0] +1)*(1-x[...,1]) )[...,None]**3
        return u*v + w
        
    def solution4(self, ws, x):
        u = self.neural_networks['u4'](ws['u4'],x)
        v = ((1-x[...,0])*(x[...,0] + 1)*(1-x[...,1]))[...,None]
        w = self.interface41(ws['u14'],x)*((1-x[...,0])*(x[...,0] + 1))[...,None]+self.interface43(ws['u34'],x)*((1-x[...,1]))[...,None]
        w = w + ws['u134'] *  ( (x[...,0]+1) * (x[...,1]+1) )[...,None]**3
        return u*v+w

    def loss_pde(self, ws):
        grad1 = pinns.operators.gradient(lambda x : self.solution1(ws,x))(self.points['ys1'])[...,0,:]
        grad2 = pinns.operators.gradient(lambda x : self.solution2(ws,x))(self.points['ys2'])[...,0,:]
        grad3 = pinns.operators.gradient(lambda x : self.solution3(ws,x))(self.points['ys3'])[...,0,:]
        grad4 = pinns.operators.gradient(lambda x : self.solution4(ws,x))(self.points['ys4'])[...,0,:]
        
        
        # lpde1 = 0.5*1/(self.mu0*self.mur)*jnp.dot(jnp.einsum('mi,mij,mj->m',grad1,self.points['K1'],grad1), self.points['ws1']) 
        # lpde2 = 0.5*1/self.mu0*jnp.dot(jnp.einsum('mi,mij,mj->m',grad2,self.points['K2'],grad2), self.points['ws2'])  
        # lpde3 = 0.5*1/self.mu0*jnp.dot(jnp.einsum('mi,mij,mj->m',grad3,self.points['K3'],grad3), self.points['ws3'])  - jnp.dot(self.J0*self.solution3(ws,self.points['ys3']).flatten()*self.points['omega3']  ,self.points['ws3'])
        # lpde4 = 0.5*1/(self.mu0*self.mur)*jnp.dot(jnp.einsum('mi,mij,mj->m',grad4,self.points['K4'],grad4), self.points['ws4']) 
        lpde1 = 0.5*1/(self.mur)*jnp.dot(jnp.einsum('mi,mij,mj->m',grad1,self.points['K1'],grad1), self.points['ws1']) 
        lpde2 = 0.5*jnp.dot(jnp.einsum('mi,mij,mj->m',grad2,self.points['K2'],grad2), self.points['ws2'])  
        lpde3 = 0.5*jnp.dot(jnp.einsum('mi,mij,mj->m',grad3,self.points['K3'],grad3), self.points['ws3'])  - self.mu0*jnp.dot(self.J0*self.solution3(ws,self.points['ys3']).flatten()*self.points['omega3']  ,self.points['ws3'])
        lpde4 = 0.5*1/(self.mur)*jnp.dot(jnp.einsum('mi,mij,mj->m',grad4,self.points['K4'],grad4), self.points['ws4'])
        return lpde1+lpde2+lpde3+lpde4

    def loss(self, ws):
        lpde = self.loss_pde(ws)
        return lpde

# %%
rnd_key = jax.random.PRNGKey(1235)
model = Model(rnd_key)
w0 = model.init_unravel()
weights = model.weights 

loss_compiled = jax.jit(model.loss_handle, device = jax.devices()[1])
lossgrad_compiled = jax.jit(model.lossgrad_handle, device = jax.devices()[1])

def loss_grad(w):
    l, gr = lossgrad_compiled(jnp.array(w))
    return np.array( l.to_py() ), np.array( gr.to_py() )

opt_type = 'ADAM'
 
if opt_type == 'LBFGS':
    tme = datetime.datetime.now()
    loss_grad(w0.to_py())
    tme = datetime.datetime.now() - tme
    print('Compiled in ',tme)

    print('Starting optimization')

    tme = datetime.datetime.now()
    #results = jax.scipy.optimize.minimize(loss_grad, x0 = weights_vector, method = 'bfgs', options = {'maxiter': 10})
    # result = scipy.optimize.minimize(loss_grad, x0 = w0.to_py(), method = 'BFGS', jac = True, tol = 1e-8, options = {'disp' : True, 'maxiter' : 2000}, callback = None)
    result = scipy.optimize.minimize(loss_grad, x0 = w0.to_py(), method = 'L-BFGS-B', jac = True, tol = 1e-19, options = {'disp' : True, 'maxiter' : 6000, 'iprint': 1})
    tme = datetime.datetime.now() - tme

    weights = model.weights_unravel(jnp.array(result.x))
    model.weights = weights
elif opt_type == 'ADAM':
    opt_init, opt_update, get_params = optimizers.adam(step_size=0.015)
    
    opt_state = opt_init(weights)

    # get initial parameters
    params = get_params(opt_state)

    loss_grad = jax.jit(lambda ws, *args: (model.loss(ws, *args), jax.grad(model.loss)(ws, *args)), device = jax.devices()[1])
    
    def step(params, opt_state):
        loss, grads = loss_grad(params)
        opt_state = opt_update(0, grads, opt_state)

        params = get_params(opt_state)
        
        return params, opt_state, loss
    
    step_compiled = jax.jit(step, device = jax.devices()[1])
    step_compiled(params, opt_state)
    
    n_epochs = 5000

    tme = datetime.datetime.now()
    for k in range(n_epochs):    
        
        params, opt_state, loss = step_compiled(params, opt_state)
        
        print('Epoch %d/%d - loss value %e'%(k+1, n_epochs, loss))
    # update params
    model.weights = params
    tme = datetime.datetime.now() - tme
    print('Elapsed time ', tme)
    
print()
print('Elapsed time', tme)
# Out:
# Epoch 1/5000 - loss value 6.596076e+02
# Epoch 2/5000 - loss value 4.830996e+02
# Epoch 3/5000 - loss value 3.587727e+02
# Epoch 4/5000 - loss value 2.327420e+02
# Epoch 5/5000 - loss value 1.628156e+02
# Epoch 6/5000 - loss value 1.154136e+02
# Epoch 7/5000 - loss value 8.638477e+01
# Epoch 8/5000 - loss value 5.393178e+01
# Epoch 9/5000 - loss value 3.742623e+01
# Epoch 10/5000 - loss value 2.739350e+01
# Epoch 11/5000 - loss value 2.208831e+01
# Epoch 12/5000 - loss value 1.849155e+01
# Epoch 13/5000 - loss value 1.546158e+01
# Epoch 14/5000 - loss value 1.151697e+01
# Epoch 15/5000 - loss value 7.500273e+00
# Epoch 16/5000 - loss value 5.128512e+00
# Epoch 17/5000 - loss value 4.295894e+00
# Epoch 18/5000 - loss value 3.583708e+00
# Epoch 19/5000 - loss value 2.621898e+00
# Epoch 20/5000 - loss value 2.983810e+00
# Epoch 21/5000 - loss value 2.863171e+00
# Epoch 22/5000 - loss value 2.373580e+00
# Epoch 23/5000 - loss value 2.250179e+00
# Epoch 24/5000 - loss value 2.160244e+00
# Epoch 25/5000 - loss value 1.604626e+00
# Epoch 26/5000 - loss value 1.342773e+00
# Epoch 27/5000 - loss value 1.553341e+00
# Epoch 28/5000 - loss value 1.489185e+00
# Epoch 29/5000 - loss value 1.421817e+00
# Epoch 30/5000 - loss value 1.320967e+00
# Epoch 31/5000 - loss value 1.089375e+00
# Epoch 32/5000 - loss value 1.024753e+00
# Epoch 33/5000 - loss value 9.793118e-01
# Epoch 34/5000 - loss value 8.733299e-01
# Epoch 35/5000 - loss value 8.948133e-01
# Epoch 36/5000 - loss value 9.258706e-01
# Epoch 37/5000 - loss value 8.399052e-01
# Epoch 38/5000 - loss value 7.190385e-01
# Epoch 39/5000 - loss value 6.447984e-01
# Epoch 40/5000 - loss value 5.633861e-01
# Epoch 41/5000 - loss value 4.536261e-01
# Epoch 42/5000 - loss value 4.162748e-01
# Epoch 43/5000 - loss value 4.422644e-01
# Epoch 44/5000 - loss value 4.298177e-01
# Epoch 45/5000 - loss value 3.630583e-01
# Epoch 46/5000 - loss value 2.964524e-01
# Epoch 47/5000 - loss value 2.436355e-01
# Epoch 48/5000 - loss value 1.929002e-01
# Epoch 49/5000 - loss value 1.582640e-01
# Epoch 50/5000 - loss value 1.480334e-01
# Epoch 51/5000 - loss value 1.440689e-01
# Epoch 52/5000 - loss value 1.280943e-01
# Epoch 53/5000 - loss value 1.011320e-01
# Epoch 54/5000 - loss value 7.621563e-02
# Epoch 55/5000 - loss value 5.743598e-02
# Epoch 56/5000 - loss value 4.365517e-02
# Epoch 57/5000 - loss value 3.731492e-02
# Epoch 58/5000 - loss value 3.331683e-02
# Epoch 59/5000 - loss value 2.703214e-02
# Epoch 60/5000 - loss value 2.217455e-02
# Epoch 61/5000 - loss value 1.698830e-02
# Epoch 62/5000 - loss value 7.603253e-03
# Epoch 63/5000 - loss value -1.735536e-03
# Epoch 64/5000 - loss value -4.967403e-03
# Epoch 65/5000 - loss value -3.054443e-03
# Epoch 66/5000 - loss value -2.714056e-03
# Epoch 67/5000 - loss value -5.349469e-03
# Epoch 68/5000 - loss value -7.122973e-03
# Epoch 69/5000 - loss value -9.241391e-03
# Epoch 70/5000 - loss value -1.418009e-02
# Epoch 71/5000 - loss value -1.941647e-02
# Epoch 72/5000 - loss value -2.238002e-02
# Epoch 73/5000 - loss value -2.365345e-02
# Epoch 74/5000 - loss value -2.495233e-02
# Epoch 75/5000 - loss value -2.702315e-02
# Epoch 76/5000 - loss value -2.955745e-02
# Epoch 77/5000 - loss value -3.247216e-02
# Epoch 78/5000 - loss value -3.547284e-02
# Epoch 79/5000 - loss value -3.788789e-02
# Epoch 80/5000 - loss value -3.981959e-02
# Epoch 81/5000 - loss value -4.141829e-02
# Epoch 82/5000 - loss value -4.238902e-02
# Epoch 83/5000 - loss value -4.317313e-02
# Epoch 84/5000 - loss value -4.454615e-02
# Epoch 85/5000 - loss value -4.637287e-02
# Epoch 86/5000 - loss value -4.798986e-02
# Epoch 87/5000 - loss value -4.918609e-02
# Epoch 88/5000 - loss value -5.029166e-02
# Epoch 89/5000 - loss value -5.144571e-02
# Epoch 90/5000 - loss value -5.236017e-02
# Epoch 91/5000 - loss value -5.305134e-02
# Epoch 92/5000 - loss value -5.392426e-02
# Epoch 93/5000 - loss value -5.500683e-02
# Epoch 94/5000 - loss value -5.596988e-02
# Epoch 95/5000 - loss value -5.670569e-02
# Epoch 96/5000 - loss value -5.732327e-02
# Epoch 97/5000 - loss value -5.788090e-02
# Epoch 98/5000 - loss value -5.837269e-02
# Epoch 99/5000 - loss value -5.881995e-02
# Epoch 100/5000 - loss value -5.928234e-02
# Epoch 101/5000 - loss value -5.977669e-02
# Epoch 102/5000 - loss value -6.025847e-02
# Epoch 103/5000 - loss value -6.069578e-02
# Epoch 104/5000 - loss value -6.106945e-02
# Epoch 105/5000 - loss value -6.136630e-02
# Epoch 106/5000 - loss value -6.163429e-02
# Epoch 107/5000 - loss value -6.192966e-02
# Epoch 108/5000 - loss value -6.223159e-02
# Epoch 109/5000 - loss value -6.251050e-02
# Epoch 110/5000 - loss value -6.278977e-02
# Epoch 111/5000 - loss value -6.307964e-02
# Epoch 112/5000 - loss value -6.334495e-02
# Epoch 113/5000 - loss value -6.356474e-02
# Epoch 114/5000 - loss value -6.376598e-02
# Epoch 115/5000 - loss value -6.398095e-02
# Epoch 116/5000 - loss value -6.420218e-02
# Epoch 117/5000 - loss value -6.440770e-02
# Epoch 118/5000 - loss value -6.460287e-02
# Epoch 119/5000 - loss value -6.479845e-02
# Epoch 120/5000 - loss value -6.498233e-02
# Epoch 121/5000 - loss value -6.514472e-02
# Epoch 122/5000 - loss value -6.529589e-02
# Epoch 123/5000 - loss value -6.544637e-02
# Epoch 124/5000 - loss value -6.559662e-02
# Epoch 125/5000 - loss value -6.574421e-02
# Epoch 126/5000 - loss value -6.588686e-02
# Epoch 127/5000 - loss value -6.602247e-02
# Epoch 128/5000 - loss value -6.615026e-02
# Epoch 129/5000 - loss value -6.627088e-02
# Epoch 130/5000 - loss value -6.638578e-02
# Epoch 131/5000 - loss value -6.649596e-02
# Epoch 132/5000 - loss value -6.660297e-02
# Epoch 133/5000 - loss value -6.670934e-02
# Epoch 134/5000 - loss value -6.681410e-02
# Epoch 135/5000 - loss value -6.691307e-02
# Epoch 136/5000 - loss value -6.700587e-02
# Epoch 137/5000 - loss value -6.709573e-02
# Epoch 138/5000 - loss value -6.718326e-02
# Epoch 139/5000 - loss value -6.726716e-02
# Epoch 140/5000 - loss value -6.734832e-02
# Epoch 141/5000 - loss value -6.742858e-02
# Epoch 142/5000 - loss value -6.750756e-02
# Epoch 143/5000 - loss value -6.758341e-02
# Epoch 144/5000 - loss value -6.765572e-02
# Epoch 145/5000 - loss value -6.772581e-02
# Epoch 146/5000 - loss value -6.779438e-02
# Epoch 147/5000 - loss value -6.786103e-02
# Epoch 148/5000 - loss value -6.792590e-02
# Epoch 149/5000 - loss value -6.798955e-02
# Epoch 150/5000 - loss value -6.805183e-02
# Epoch 151/5000 - loss value -6.811234e-02
# Epoch 152/5000 - loss value -6.817106e-02
# Epoch 153/5000 - loss value -6.822816e-02
# Epoch 154/5000 - loss value -6.828387e-02
# Epoch 155/5000 - loss value -6.833851e-02
# Epoch 156/5000 - loss value -6.839216e-02
# Epoch 157/5000 - loss value -6.844472e-02
# Epoch 158/5000 - loss value -6.849611e-02
# Epoch 159/5000 - loss value -6.854638e-02
# Epoch 160/5000 - loss value -6.859560e-02
# Epoch 161/5000 - loss value -6.864371e-02
# Epoch 162/5000 - loss value -6.869074e-02
# Epoch 163/5000 - loss value -6.873692e-02
# Epoch 164/5000 - loss value -6.878243e-02
# Epoch 165/5000 - loss value -6.882711e-02
# Epoch 166/5000 - loss value -6.887090e-02
# Epoch 167/5000 - loss value -6.891390e-02
# Epoch 168/5000 - loss value -6.895619e-02
# Epoch 169/5000 - loss value -6.899772e-02
# Epoch 170/5000 - loss value -6.903851e-02
# Epoch 171/5000 - loss value -6.907867e-02
# Epoch 172/5000 - loss value -6.911826e-02
# Epoch 173/5000 - loss value -6.915726e-02
# Epoch 174/5000 - loss value -6.919564e-02
# Epoch 175/5000 - loss value -6.923344e-02
# Epoch 176/5000 - loss value -6.927068e-02
# Epoch 177/5000 - loss value -6.930738e-02
# Epoch 178/5000 - loss value -6.934356e-02
# Epoch 179/5000 - loss value -6.937926e-02
# Epoch 180/5000 - loss value -6.941450e-02
# Epoch 181/5000 - loss value -6.944928e-02
# Epoch 182/5000 - loss value -6.948362e-02
# Epoch 183/5000 - loss value -6.951753e-02
# Epoch 184/5000 - loss value -6.955099e-02
# Epoch 185/5000 - loss value -6.958405e-02
# Epoch 186/5000 - loss value -6.961672e-02
# Epoch 187/5000 - loss value -6.964902e-02
# Epoch 188/5000 - loss value -6.968095e-02
# Epoch 189/5000 - loss value -6.971252e-02
# Epoch 190/5000 - loss value -6.974376e-02
# Epoch 191/5000 - loss value -6.977466e-02
# Epoch 192/5000 - loss value -6.980522e-02
# Epoch 193/5000 - loss value -6.983547e-02
# Epoch 194/5000 - loss value -6.986541e-02
# Epoch 195/5000 - loss value -6.989506e-02
# Epoch 196/5000 - loss value -6.992442e-02
# Epoch 197/5000 - loss value -6.995350e-02
# Epoch 198/5000 - loss value -6.998231e-02
# Epoch 199/5000 - loss value -7.001086e-02
# Epoch 200/5000 - loss value -7.003913e-02
# Epoch 201/5000 - loss value -7.006716e-02
# Epoch 202/5000 - loss value -7.009494e-02
# Epoch 203/5000 - loss value -7.012249e-02
# Epoch 204/5000 - loss value -7.014980e-02
# Epoch 205/5000 - loss value -7.017688e-02
# Epoch 206/5000 - loss value -7.020374e-02
# Epoch 207/5000 - loss value -7.023038e-02
# Epoch 208/5000 - loss value -7.025681e-02
# Epoch 209/5000 - loss value -7.028304e-02
# Epoch 210/5000 - loss value -7.030906e-02
# Epoch 211/5000 - loss value -7.033488e-02
# Epoch 212/5000 - loss value -7.036051e-02
# Epoch 213/5000 - loss value -7.038595e-02
# Epoch 214/5000 - loss value -7.041121e-02
# Epoch 215/5000 - loss value -7.043628e-02
# Epoch 216/5000 - loss value -7.046118e-02
# Epoch 217/5000 - loss value -7.048590e-02
# Epoch 218/5000 - loss value -7.051046e-02
# Epoch 219/5000 - loss value -7.053484e-02
# Epoch 220/5000 - loss value -7.055907e-02
# Epoch 221/5000 - loss value -7.058313e-02
# Epoch 222/5000 - loss value -7.060704e-02
# Epoch 223/5000 - loss value -7.063079e-02
# Epoch 224/5000 - loss value -7.065438e-02
# Epoch 225/5000 - loss value -7.067783e-02
# Epoch 226/5000 - loss value -7.070114e-02
# Epoch 227/5000 - loss value -7.072430e-02
# Epoch 228/5000 - loss value -7.074732e-02
# Epoch 229/5000 - loss value -7.077020e-02
# Epoch 230/5000 - loss value -7.079294e-02
# Epoch 231/5000 - loss value -7.081555e-02
# Epoch 232/5000 - loss value -7.083802e-02
# Epoch 233/5000 - loss value -7.086037e-02
# Epoch 234/5000 - loss value -7.088259e-02
# Epoch 235/5000 - loss value -7.090468e-02
# Epoch 236/5000 - loss value -7.092665e-02
# Epoch 237/5000 - loss value -7.094850e-02
# Epoch 238/5000 - loss value -7.097022e-02
# Epoch 239/5000 - loss value -7.099183e-02
# Epoch 240/5000 - loss value -7.101332e-02
# Epoch 241/5000 - loss value -7.103469e-02
# Epoch 242/5000 - loss value -7.105595e-02
# Epoch 243/5000 - loss value -7.107710e-02
# Epoch 244/5000 - loss value -7.109813e-02
# Epoch 245/5000 - loss value -7.111906e-02
# Epoch 246/5000 - loss value -7.113988e-02
# Epoch 247/5000 - loss value -7.116059e-02
# Epoch 248/5000 - loss value -7.118119e-02
# Epoch 249/5000 - loss value -7.120170e-02
# Epoch 250/5000 - loss value -7.122210e-02
# Epoch 251/5000 - loss value -7.124239e-02
# Epoch 252/5000 - loss value -7.126259e-02
# Epoch 253/5000 - loss value -7.128269e-02
# Epoch 254/5000 - loss value -7.130269e-02
# Epoch 255/5000 - loss value -7.132259e-02
# Epoch 256/5000 - loss value -7.134240e-02
# Epoch 257/5000 - loss value -7.136211e-02
# Epoch 258/5000 - loss value -7.138173e-02
# Epoch 259/5000 - loss value -7.140125e-02
# Epoch 260/5000 - loss value -7.142068e-02
# Epoch 261/5000 - loss value -7.144003e-02
# Epoch 262/5000 - loss value -7.145928e-02
# Epoch 263/5000 - loss value -7.147844e-02
# Epoch 264/5000 - loss value -7.149751e-02
# Epoch 265/5000 - loss value -7.151650e-02
# Epoch 266/5000 - loss value -7.153540e-02
# Epoch 267/5000 - loss value -7.155422e-02
# Epoch 268/5000 - loss value -7.157295e-02
# Epoch 269/5000 - loss value -7.159159e-02
# Epoch 270/5000 - loss value -7.161015e-02
# Epoch 271/5000 - loss value -7.162863e-02
# Epoch 272/5000 - loss value -7.164703e-02
# Epoch 273/5000 - loss value -7.166535e-02
# Epoch 274/5000 - loss value -7.168358e-02
# Epoch 275/5000 - loss value -7.170174e-02
# Epoch 276/5000 - loss value -7.171982e-02
# Epoch 277/5000 - loss value -7.173782e-02
# Epoch 278/5000 - loss value -7.175574e-02
# Epoch 279/5000 - loss value -7.177358e-02
# Epoch 280/5000 - loss value -7.179135e-02
# Epoch 281/5000 - loss value -7.180904e-02
# Epoch 282/5000 - loss value -7.182666e-02
# Epoch 283/5000 - loss value -7.184420e-02
# Epoch 284/5000 - loss value -7.186167e-02
# Epoch 285/5000 - loss value -7.187906e-02
# Epoch 286/5000 - loss value -7.189638e-02
# Epoch 287/5000 - loss value -7.191363e-02
# Epoch 288/5000 - loss value -7.193081e-02
# Epoch 289/5000 - loss value -7.194791e-02
# Epoch 290/5000 - loss value -7.196495e-02
# Epoch 291/5000 - loss value -7.198191e-02
# Epoch 292/5000 - loss value -7.199881e-02
# Epoch 293/5000 - loss value -7.201563e-02
# Epoch 294/5000 - loss value -7.203239e-02
# Epoch 295/5000 - loss value -7.204908e-02
# Epoch 296/5000 - loss value -7.206570e-02
# Epoch 297/5000 - loss value -7.208225e-02
# Epoch 298/5000 - loss value -7.209874e-02
# Epoch 299/5000 - loss value -7.211516e-02
# Epoch 300/5000 - loss value -7.213151e-02
# Epoch 301/5000 - loss value -7.214780e-02
# Epoch 302/5000 - loss value -7.216402e-02
# Epoch 303/5000 - loss value -7.218018e-02
# Epoch 304/5000 - loss value -7.219628e-02
# Epoch 305/5000 - loss value -7.221231e-02
# Epoch 306/5000 - loss value -7.222828e-02
# Epoch 307/5000 - loss value -7.224418e-02
# Epoch 308/5000 - loss value -7.226002e-02
# Epoch 309/5000 - loss value -7.227580e-02
# Epoch 310/5000 - loss value -7.229152e-02
# Epoch 311/5000 - loss value -7.230718e-02
# Epoch 312/5000 - loss value -7.232278e-02
# Epoch 313/5000 - loss value -7.233831e-02
# Epoch 314/5000 - loss value -7.235379e-02
# Epoch 315/5000 - loss value -7.236920e-02
# Epoch 316/5000 - loss value -7.238456e-02
# Epoch 317/5000 - loss value -7.239985e-02
# Epoch 318/5000 - loss value -7.241509e-02
# Epoch 319/5000 - loss value -7.243027e-02
# Epoch 320/5000 - loss value -7.244539e-02
# Epoch 321/5000 - loss value -7.246045e-02
# Epoch 322/5000 - loss value -7.247546e-02
# Epoch 323/5000 - loss value -7.249041e-02
# Epoch 324/5000 - loss value -7.250530e-02
# Epoch 325/5000 - loss value -7.252014e-02
# Epoch 326/5000 - loss value -7.253491e-02
# Epoch 327/5000 - loss value -7.254964e-02
# Epoch 328/5000 - loss value -7.256431e-02
# Epoch 329/5000 - loss value -7.257892e-02
# Epoch 330/5000 - loss value -7.259348e-02
# Epoch 331/5000 - loss value -7.260798e-02
# Epoch 332/5000 - loss value -7.262243e-02
# Epoch 333/5000 - loss value -7.263682e-02
# Epoch 334/5000 - loss value -7.265117e-02
# Epoch 335/5000 - loss value -7.266545e-02
# Epoch 336/5000 - loss value -7.267969e-02
# Epoch 337/5000 - loss value -7.269387e-02
# Epoch 338/5000 - loss value -7.270800e-02
# Epoch 339/5000 - loss value -7.272208e-02
# Epoch 340/5000 - loss value -7.273610e-02
# Epoch 341/5000 - loss value -7.275007e-02
# Epoch 342/5000 - loss value -7.276400e-02
# Epoch 343/5000 - loss value -7.277787e-02
# Epoch 344/5000 - loss value -7.279169e-02
# Epoch 345/5000 - loss value -7.280546e-02
# Epoch 346/5000 - loss value -7.281918e-02
# Epoch 347/5000 - loss value -7.283284e-02
# Epoch 348/5000 - loss value -7.284646e-02
# Epoch 349/5000 - loss value -7.286003e-02
# Epoch 350/5000 - loss value -7.287355e-02
# Epoch 351/5000 - loss value -7.288702e-02
# Epoch 352/5000 - loss value -7.290045e-02
# Epoch 353/5000 - loss value -7.291382e-02
# Epoch 354/5000 - loss value -7.292715e-02
# Epoch 355/5000 - loss value -7.294042e-02
# Epoch 356/5000 - loss value -7.295365e-02
# Epoch 357/5000 - loss value -7.296683e-02
# Epoch 358/5000 - loss value -7.297997e-02
# Epoch 359/5000 - loss value -7.299305e-02
# Epoch 360/5000 - loss value -7.300609e-02
# Epoch 361/5000 - loss value -7.301909e-02
# Epoch 362/5000 - loss value -7.303203e-02
# Epoch 363/5000 - loss value -7.304493e-02
# Epoch 364/5000 - loss value -7.305779e-02
# Epoch 365/5000 - loss value -7.307060e-02
# Epoch 366/5000 - loss value -7.308336e-02
# Epoch 367/5000 - loss value -7.309608e-02
# Epoch 368/5000 - loss value -7.310875e-02
# Epoch 369/5000 - loss value -7.312138e-02
# Epoch 370/5000 - loss value -7.313396e-02
# Epoch 371/5000 - loss value -7.314650e-02
# Epoch 372/5000 - loss value -7.315899e-02
# Epoch 373/5000 - loss value -7.317144e-02
# Epoch 374/5000 - loss value -7.318385e-02
# Epoch 375/5000 - loss value -7.319621e-02
# Epoch 376/5000 - loss value -7.320853e-02
# Epoch 377/5000 - loss value -7.322080e-02
# Epoch 378/5000 - loss value -7.323303e-02
# Epoch 379/5000 - loss value -7.324522e-02
# Epoch 380/5000 - loss value -7.325737e-02
# Epoch 381/5000 - loss value -7.326947e-02
# Epoch 382/5000 - loss value -7.328153e-02
# Epoch 383/5000 - loss value -7.329355e-02
# Epoch 384/5000 - loss value -7.330553e-02
# Epoch 385/5000 - loss value -7.331746e-02
# Epoch 386/5000 - loss value -7.332936e-02
# Epoch 387/5000 - loss value -7.334121e-02
# Epoch 388/5000 - loss value -7.335302e-02
# Epoch 389/5000 - loss value -7.336479e-02
# Epoch 390/5000 - loss value -7.337652e-02
# Epoch 391/5000 - loss value -7.338821e-02
# Epoch 392/5000 - loss value -7.339986e-02
# Epoch 393/5000 - loss value -7.341146e-02
# Epoch 394/5000 - loss value -7.342303e-02
# Epoch 395/5000 - loss value -7.343456e-02
# Epoch 396/5000 - loss value -7.344605e-02
# Epoch 397/5000 - loss value -7.345749e-02
# Epoch 398/5000 - loss value -7.346890e-02
# Epoch 399/5000 - loss value -7.348027e-02
# Epoch 400/5000 - loss value -7.349160e-02
# Epoch 401/5000 - loss value -7.350289e-02
# Epoch 402/5000 - loss value -7.351415e-02
# Epoch 403/5000 - loss value -7.352536e-02
# Epoch 404/5000 - loss value -7.353653e-02
# Epoch 405/5000 - loss value -7.354767e-02
# Epoch 406/5000 - loss value -7.355877e-02
# Epoch 407/5000 - loss value -7.356983e-02
# Epoch 408/5000 - loss value -7.358085e-02
# Epoch 409/5000 - loss value -7.359184e-02
# Epoch 410/5000 - loss value -7.360279e-02
# Epoch 411/5000 - loss value -7.361370e-02
# Epoch 412/5000 - loss value -7.362457e-02
# Epoch 413/5000 - loss value -7.363541e-02
# Epoch 414/5000 - loss value -7.364620e-02
# Epoch 415/5000 - loss value -7.365697e-02
# Epoch 416/5000 - loss value -7.366769e-02
# Epoch 417/5000 - loss value -7.367838e-02
# Epoch 418/5000 - loss value -7.368903e-02
# Epoch 419/5000 - loss value -7.369965e-02
# Epoch 420/5000 - loss value -7.371023e-02
# Epoch 421/5000 - loss value -7.372078e-02
# Epoch 422/5000 - loss value -7.373128e-02
# Epoch 423/5000 - loss value -7.374176e-02
# Epoch 424/5000 - loss value -7.375220e-02
# Epoch 425/5000 - loss value -7.376260e-02
# Epoch 426/5000 - loss value -7.377297e-02
# Epoch 427/5000 - loss value -7.378330e-02
# Epoch 428/5000 - loss value -7.379360e-02
# Epoch 429/5000 - loss value -7.380386e-02
# Epoch 430/5000 - loss value -7.381409e-02
# Epoch 431/5000 - loss value -7.382428e-02
# Epoch 432/5000 - loss value -7.383444e-02
# Epoch 433/5000 - loss value -7.384456e-02
# Epoch 434/5000 - loss value -7.385466e-02
# Epoch 435/5000 - loss value -7.386471e-02
# Epoch 436/5000 - loss value -7.387474e-02
# Epoch 437/5000 - loss value -7.388472e-02
# Epoch 438/5000 - loss value -7.389468e-02
# Epoch 439/5000 - loss value -7.390460e-02
# Epoch 440/5000 - loss value -7.391449e-02
# Epoch 441/5000 - loss value -7.392435e-02
# Epoch 442/5000 - loss value -7.393417e-02
# Epoch 443/5000 - loss value -7.394396e-02
# Epoch 444/5000 - loss value -7.395372e-02
# Epoch 445/5000 - loss value -7.396344e-02
# Epoch 446/5000 - loss value -7.397314e-02
# Epoch 447/5000 - loss value -7.398279e-02
# Epoch 448/5000 - loss value -7.399242e-02
# Epoch 449/5000 - loss value -7.400202e-02
# Epoch 450/5000 - loss value -7.401158e-02
# Epoch 451/5000 - loss value -7.402111e-02
# Epoch 452/5000 - loss value -7.403061e-02
# Epoch 453/5000 - loss value -7.404008e-02
# Epoch 454/5000 - loss value -7.404951e-02
# Epoch 455/5000 - loss value -7.405892e-02
# Epoch 456/5000 - loss value -7.406829e-02
# Epoch 457/5000 - loss value -7.407763e-02
# Epoch 458/5000 - loss value -7.408694e-02
# Epoch 459/5000 - loss value -7.409622e-02
# Epoch 460/5000 - loss value -7.410547e-02
# Epoch 461/5000 - loss value -7.411469e-02
# Epoch 462/5000 - loss value -7.412388e-02
# Epoch 463/5000 - loss value -7.413304e-02
# Epoch 464/5000 - loss value -7.414216e-02
# Epoch 465/5000 - loss value -7.415126e-02
# Epoch 466/5000 - loss value -7.416032e-02
# Epoch 467/5000 - loss value -7.416936e-02
# Epoch 468/5000 - loss value -7.417837e-02
# Epoch 469/5000 - loss value -7.418734e-02
# Epoch 470/5000 - loss value -7.419629e-02
# Epoch 471/5000 - loss value -7.420520e-02
# Epoch 472/5000 - loss value -7.421409e-02
# Epoch 473/5000 - loss value -7.422295e-02
# Epoch 474/5000 - loss value -7.423178e-02
# Epoch 475/5000 - loss value -7.424057e-02
# Epoch 476/5000 - loss value -7.424934e-02
# Epoch 477/5000 - loss value -7.425808e-02
# Epoch 478/5000 - loss value -7.426680e-02
# Epoch 479/5000 - loss value -7.427548e-02
# Epoch 480/5000 - loss value -7.428413e-02
# Epoch 481/5000 - loss value -7.429276e-02
# Epoch 482/5000 - loss value -7.430135e-02
# Epoch 483/5000 - loss value -7.430992e-02
# Epoch 484/5000 - loss value -7.431846e-02
# Epoch 485/5000 - loss value -7.432697e-02
# Epoch 486/5000 - loss value -7.433546e-02
# Epoch 487/5000 - loss value -7.434391e-02
# Epoch 488/5000 - loss value -7.435234e-02
# Epoch 489/5000 - loss value -7.436074e-02
# Epoch 490/5000 - loss value -7.436911e-02
# Epoch 491/5000 - loss value -7.437746e-02
# Epoch 492/5000 - loss value -7.438577e-02
# Epoch 493/5000 - loss value -7.439406e-02
# Epoch 494/5000 - loss value -7.440233e-02
# Epoch 495/5000 - loss value -7.441056e-02
# Epoch 496/5000 - loss value -7.441877e-02
# Epoch 497/5000 - loss value -7.442695e-02
# Epoch 498/5000 - loss value -7.443510e-02
# Epoch 499/5000 - loss value -7.444323e-02
# Epoch 500/5000 - loss value -7.445133e-02
# Epoch 501/5000 - loss value -7.445940e-02
# Epoch 502/5000 - loss value -7.446745e-02
# Epoch 503/5000 - loss value -7.447547e-02
# Epoch 504/5000 - loss value -7.448346e-02
# Epoch 505/5000 - loss value -7.449143e-02
# Epoch 506/5000 - loss value -7.449937e-02
# Epoch 507/5000 - loss value -7.450728e-02
# Epoch 508/5000 - loss value -7.451517e-02
# Epoch 509/5000 - loss value -7.452303e-02
# Epoch 510/5000 - loss value -7.453087e-02
# Epoch 511/5000 - loss value -7.453868e-02
# Epoch 512/5000 - loss value -7.454647e-02
# Epoch 513/5000 - loss value -7.455423e-02
# Epoch 514/5000 - loss value -7.456196e-02
# Epoch 515/5000 - loss value -7.456967e-02
# Epoch 516/5000 - loss value -7.457735e-02
# Epoch 517/5000 - loss value -7.458501e-02
# Epoch 518/5000 - loss value -7.459264e-02
# Epoch 519/5000 - loss value -7.460025e-02
# Epoch 520/5000 - loss value -7.460783e-02
# Epoch 521/5000 - loss value -7.461539e-02
# Epoch 522/5000 - loss value -7.462292e-02
# Epoch 523/5000 - loss value -7.463043e-02
# Epoch 524/5000 - loss value -7.463791e-02
# Epoch 525/5000 - loss value -7.464537e-02
# Epoch 526/5000 - loss value -7.465280e-02
# Epoch 527/5000 - loss value -7.466021e-02
# Epoch 528/5000 - loss value -7.466760e-02
# Epoch 529/5000 - loss value -7.467496e-02
# Epoch 530/5000 - loss value -7.468230e-02
# Epoch 531/5000 - loss value -7.468961e-02
# Epoch 532/5000 - loss value -7.469690e-02
# Epoch 533/5000 - loss value -7.470416e-02
# Epoch 534/5000 - loss value -7.471140e-02
# Epoch 535/5000 - loss value -7.471862e-02
# Epoch 536/5000 - loss value -7.472581e-02
# Epoch 537/5000 - loss value -7.473298e-02
# Epoch 538/5000 - loss value -7.474013e-02
# Epoch 539/5000 - loss value -7.474725e-02
# Epoch 540/5000 - loss value -7.475435e-02
# Epoch 541/5000 - loss value -7.476142e-02
# Epoch 542/5000 - loss value -7.476847e-02
# Epoch 543/5000 - loss value -7.477550e-02
# Epoch 544/5000 - loss value -7.478251e-02
# Epoch 545/5000 - loss value -7.478949e-02
# Epoch 546/5000 - loss value -7.479645e-02
# Epoch 547/5000 - loss value -7.480339e-02
# Epoch 548/5000 - loss value -7.481030e-02
# Epoch 549/5000 - loss value -7.481719e-02
# Epoch 550/5000 - loss value -7.482406e-02
# Epoch 551/5000 - loss value -7.483091e-02
# Epoch 552/5000 - loss value -7.483773e-02
# Epoch 553/5000 - loss value -7.484453e-02
# Epoch 554/5000 - loss value -7.485131e-02
# Epoch 555/5000 - loss value -7.485807e-02
# Epoch 556/5000 - loss value -7.486480e-02
# Epoch 557/5000 - loss value -7.487151e-02
# Epoch 558/5000 - loss value -7.487820e-02
# Epoch 559/5000 - loss value -7.488487e-02
# Epoch 560/5000 - loss value -7.489152e-02
# Epoch 561/5000 - loss value -7.489814e-02
# Epoch 562/5000 - loss value -7.490474e-02
# Epoch 563/5000 - loss value -7.491132e-02
# Epoch 564/5000 - loss value -7.491788e-02
# Epoch 565/5000 - loss value -7.492442e-02
# Epoch 566/5000 - loss value -7.493093e-02
# Epoch 567/5000 - loss value -7.493743e-02
# Epoch 568/5000 - loss value -7.494390e-02
# Epoch 569/5000 - loss value -7.495035e-02
# Epoch 570/5000 - loss value -7.495678e-02
# Epoch 571/5000 - loss value -7.496319e-02
# Epoch 572/5000 - loss value -7.496958e-02
# Epoch 573/5000 - loss value -7.497595e-02
# Epoch 574/5000 - loss value -7.498229e-02
# Epoch 575/5000 - loss value -7.498862e-02
# Epoch 576/5000 - loss value -7.499492e-02
# Epoch 577/5000 - loss value -7.500121e-02
# Epoch 578/5000 - loss value -7.500747e-02
# Epoch 579/5000 - loss value -7.501371e-02
# Epoch 580/5000 - loss value -7.501993e-02
# Epoch 581/5000 - loss value -7.502613e-02
# Epoch 582/5000 - loss value -7.503232e-02
# Epoch 583/5000 - loss value -7.503848e-02
# Epoch 584/5000 - loss value -7.504462e-02
# Epoch 585/5000 - loss value -7.505074e-02
# Epoch 586/5000 - loss value -7.505684e-02
# Epoch 587/5000 - loss value -7.506292e-02
# Epoch 588/5000 - loss value -7.506898e-02
# Epoch 589/5000 - loss value -7.507502e-02
# Epoch 590/5000 - loss value -7.508104e-02
# Epoch 591/5000 - loss value -7.508704e-02
# Epoch 592/5000 - loss value -7.509302e-02
# Epoch 593/5000 - loss value -7.509898e-02
# Epoch 594/5000 - loss value -7.510492e-02
# Epoch 595/5000 - loss value -7.511084e-02
# Epoch 596/5000 - loss value -7.511674e-02
# Epoch 597/5000 - loss value -7.512262e-02
# Epoch 598/5000 - loss value -7.512849e-02
# Epoch 599/5000 - loss value -7.513433e-02
# Epoch 600/5000 - loss value -7.514016e-02
# Epoch 601/5000 - loss value -7.514596e-02
# Epoch 602/5000 - loss value -7.515175e-02
# Epoch 603/5000 - loss value -7.515751e-02
# Epoch 604/5000 - loss value -7.516326e-02
# Epoch 605/5000 - loss value -7.516899e-02
# Epoch 606/5000 - loss value -7.517470e-02
# Epoch 607/5000 - loss value -7.518039e-02
# Epoch 608/5000 - loss value -7.518607e-02
# Epoch 609/5000 - loss value -7.519172e-02
# Epoch 610/5000 - loss value -7.519736e-02
# Epoch 611/5000 - loss value -7.520297e-02
# Epoch 612/5000 - loss value -7.520857e-02
# Epoch 613/5000 - loss value -7.521415e-02
# Epoch 614/5000 - loss value -7.521971e-02
# Epoch 615/5000 - loss value -7.522526e-02
# Epoch 616/5000 - loss value -7.523078e-02
# Epoch 617/5000 - loss value -7.523629e-02
# Epoch 618/5000 - loss value -7.524178e-02
# Epoch 619/5000 - loss value -7.524725e-02
# Epoch 620/5000 - loss value -7.525270e-02
# Epoch 621/5000 - loss value -7.525813e-02
# Epoch 622/5000 - loss value -7.526355e-02
# Epoch 623/5000 - loss value -7.526895e-02
# Epoch 624/5000 - loss value -7.527433e-02
# Epoch 625/5000 - loss value -7.527969e-02
# Epoch 626/5000 - loss value -7.528504e-02
# Epoch 627/5000 - loss value -7.529037e-02
# Epoch 628/5000 - loss value -7.529568e-02
# Epoch 629/5000 - loss value -7.530097e-02
# Epoch 630/5000 - loss value -7.530624e-02
# Epoch 631/5000 - loss value -7.531150e-02
# Epoch 632/5000 - loss value -7.531674e-02
# Epoch 633/5000 - loss value -7.532197e-02
# Epoch 634/5000 - loss value -7.532717e-02
# Epoch 635/5000 - loss value -7.533236e-02
# Epoch 636/5000 - loss value -7.533753e-02
# Epoch 637/5000 - loss value -7.534269e-02
# Epoch 638/5000 - loss value -7.534783e-02
# Epoch 639/5000 - loss value -7.535295e-02
# Epoch 640/5000 - loss value -7.535805e-02
# Epoch 641/5000 - loss value -7.536314e-02
# Epoch 642/5000 - loss value -7.536821e-02
# Epoch 643/5000 - loss value -7.537326e-02
# Epoch 644/5000 - loss value -7.537830e-02
# Epoch 645/5000 - loss value -7.538332e-02
# Epoch 646/5000 - loss value -7.538832e-02
# Epoch 647/5000 - loss value -7.539331e-02
# Epoch 648/5000 - loss value -7.539828e-02
# Epoch 649/5000 - loss value -7.540324e-02
# Epoch 650/5000 - loss value -7.540818e-02
# Epoch 651/5000 - loss value -7.541310e-02
# Epoch 652/5000 - loss value -7.541800e-02
# Epoch 653/5000 - loss value -7.542289e-02
# Epoch 654/5000 - loss value -7.542777e-02
# Epoch 655/5000 - loss value -7.543262e-02
# Epoch 656/5000 - loss value -7.543747e-02
# Epoch 657/5000 - loss value -7.544229e-02
# Epoch 658/5000 - loss value -7.544710e-02
# Epoch 659/5000 - loss value -7.545189e-02
# Epoch 660/5000 - loss value -7.545667e-02
# Epoch 661/5000 - loss value -7.546143e-02
# Epoch 662/5000 - loss value -7.546618e-02
# Epoch 663/5000 - loss value -7.547091e-02
# Epoch 664/5000 - loss value -7.547563e-02
# Epoch 665/5000 - loss value -7.548033e-02
# Epoch 666/5000 - loss value -7.548501e-02
# Epoch 667/5000 - loss value -7.548968e-02
# Epoch 668/5000 - loss value -7.549433e-02
# Epoch 669/5000 - loss value -7.549897e-02
# Epoch 670/5000 - loss value -7.550360e-02
# Epoch 671/5000 - loss value -7.550820e-02
# Epoch 672/5000 - loss value -7.551280e-02
# Epoch 673/5000 - loss value -7.551737e-02
# Epoch 674/5000 - loss value -7.552194e-02
# Epoch 675/5000 - loss value -7.552648e-02
# Epoch 676/5000 - loss value -7.553102e-02
# Epoch 677/5000 - loss value -7.553553e-02
# Epoch 678/5000 - loss value -7.554004e-02
# Epoch 679/5000 - loss value -7.554453e-02
# Epoch 680/5000 - loss value -7.554900e-02
# Epoch 681/5000 - loss value -7.555346e-02
# Epoch 682/5000 - loss value -7.555790e-02
# Epoch 683/5000 - loss value -7.556233e-02
# Epoch 684/5000 - loss value -7.556675e-02
# Epoch 685/5000 - loss value -7.557115e-02
# Epoch 686/5000 - loss value -7.557553e-02
# Epoch 687/5000 - loss value -7.557990e-02
# Epoch 688/5000 - loss value -7.558426e-02
# Epoch 689/5000 - loss value -7.558860e-02
# Epoch 690/5000 - loss value -7.559293e-02
# Epoch 691/5000 - loss value -7.559725e-02
# Epoch 692/5000 - loss value -7.560155e-02
# Epoch 693/5000 - loss value -7.560583e-02
# Epoch 694/5000 - loss value -7.561010e-02
# Epoch 695/5000 - loss value -7.561436e-02
# Epoch 696/5000 - loss value -7.561861e-02
# Epoch 697/5000 - loss value -7.562284e-02
# Epoch 698/5000 - loss value -7.562705e-02
# Epoch 699/5000 - loss value -7.563126e-02
# Epoch 700/5000 - loss value -7.563544e-02
# Epoch 701/5000 - loss value -7.563962e-02
# Epoch 702/5000 - loss value -7.564378e-02
# Epoch 703/5000 - loss value -7.564793e-02
# Epoch 704/5000 - loss value -7.565206e-02
# Epoch 705/5000 - loss value -7.565618e-02
# Epoch 706/5000 - loss value -7.566029e-02
# Epoch 707/5000 - loss value -7.566438e-02
# Epoch 708/5000 - loss value -7.566846e-02
# Epoch 709/5000 - loss value -7.567253e-02
# Epoch 710/5000 - loss value -7.567658e-02
# Epoch 711/5000 - loss value -7.568063e-02
# Epoch 712/5000 - loss value -7.568465e-02
# Epoch 713/5000 - loss value -7.568867e-02
# Epoch 714/5000 - loss value -7.569267e-02
# Epoch 715/5000 - loss value -7.569666e-02
# Epoch 716/5000 - loss value -7.570063e-02
# Epoch 717/5000 - loss value -7.570459e-02
# Epoch 718/5000 - loss value -7.570854e-02
# Epoch 719/5000 - loss value -7.571248e-02
# Epoch 720/5000 - loss value -7.571640e-02
# Epoch 721/5000 - loss value -7.572031e-02
# Epoch 722/5000 - loss value -7.572421e-02
# Epoch 723/5000 - loss value -7.572809e-02
# Epoch 724/5000 - loss value -7.573197e-02
# Epoch 725/5000 - loss value -7.573583e-02
# Epoch 726/5000 - loss value -7.573967e-02
# Epoch 727/5000 - loss value -7.574351e-02
# Epoch 728/5000 - loss value -7.574733e-02
# Epoch 729/5000 - loss value -7.575114e-02
# Epoch 730/5000 - loss value -7.575494e-02
# Epoch 731/5000 - loss value -7.575872e-02
# Epoch 732/5000 - loss value -7.576250e-02
# Epoch 733/5000 - loss value -7.576626e-02
# Epoch 734/5000 - loss value -7.577001e-02
# Epoch 735/5000 - loss value -7.577374e-02
# Epoch 736/5000 - loss value -7.577747e-02
# Epoch 737/5000 - loss value -7.578118e-02
# Epoch 738/5000 - loss value -7.578488e-02
# Epoch 739/5000 - loss value -7.578857e-02
# Epoch 740/5000 - loss value -7.579224e-02
# Epoch 741/5000 - loss value -7.579591e-02
# Epoch 742/5000 - loss value -7.579956e-02
# Epoch 743/5000 - loss value -7.580320e-02
# Epoch 744/5000 - loss value -7.580683e-02
# Epoch 745/5000 - loss value -7.581044e-02
# Epoch 746/5000 - loss value -7.581405e-02
# Epoch 747/5000 - loss value -7.581764e-02
# Epoch 748/5000 - loss value -7.582123e-02
# Epoch 749/5000 - loss value -7.582480e-02
# Epoch 750/5000 - loss value -7.582835e-02
# Epoch 751/5000 - loss value -7.583190e-02
# Epoch 752/5000 - loss value -7.583544e-02
# Epoch 753/5000 - loss value -7.583896e-02
# Epoch 754/5000 - loss value -7.584248e-02
# Epoch 755/5000 - loss value -7.584598e-02
# Epoch 756/5000 - loss value -7.584947e-02
# Epoch 757/5000 - loss value -7.585295e-02
# Epoch 758/5000 - loss value -7.585642e-02
# Epoch 759/5000 - loss value -7.585987e-02
# Epoch 760/5000 - loss value -7.586332e-02
# Epoch 761/5000 - loss value -7.586676e-02
# Epoch 762/5000 - loss value -7.587018e-02
# Epoch 763/5000 - loss value -7.587359e-02
# Epoch 764/5000 - loss value -7.587699e-02
# Epoch 765/5000 - loss value -7.588039e-02
# Epoch 766/5000 - loss value -7.588377e-02
# Epoch 767/5000 - loss value -7.588713e-02
# Epoch 768/5000 - loss value -7.589049e-02
# Epoch 769/5000 - loss value -7.589384e-02
# Epoch 770/5000 - loss value -7.589718e-02
# Epoch 771/5000 - loss value -7.590051e-02
# Epoch 772/5000 - loss value -7.590382e-02
# Epoch 773/5000 - loss value -7.590713e-02
# Epoch 774/5000 - loss value -7.591042e-02
# Epoch 775/5000 - loss value -7.591371e-02
# Epoch 776/5000 - loss value -7.591698e-02
# Epoch 777/5000 - loss value -7.592024e-02
# Epoch 778/5000 - loss value -7.592350e-02
# Epoch 779/5000 - loss value -7.592674e-02
# Epoch 780/5000 - loss value -7.592997e-02
# Epoch 781/5000 - loss value -7.593319e-02
# Epoch 782/5000 - loss value -7.593640e-02
# Epoch 783/5000 - loss value -7.593961e-02
# Epoch 784/5000 - loss value -7.594280e-02
# Epoch 785/5000 - loss value -7.594598e-02
# Epoch 786/5000 - loss value -7.594915e-02
# Epoch 787/5000 - loss value -7.595231e-02
# Epoch 788/5000 - loss value -7.595546e-02
# Epoch 789/5000 - loss value -7.595860e-02
# Epoch 790/5000 - loss value -7.596174e-02
# Epoch 791/5000 - loss value -7.596486e-02
# Epoch 792/5000 - loss value -7.596797e-02
# Epoch 793/5000 - loss value -7.597107e-02
# Epoch 794/5000 - loss value -7.597416e-02
# Epoch 795/5000 - loss value -7.597724e-02
# Epoch 796/5000 - loss value -7.598032e-02
# Epoch 797/5000 - loss value -7.598338e-02
# Epoch 798/5000 - loss value -7.598643e-02
# Epoch 799/5000 - loss value -7.598948e-02
# Epoch 800/5000 - loss value -7.599251e-02
# Epoch 801/5000 - loss value -7.599554e-02
# Epoch 802/5000 - loss value -7.599855e-02
# Epoch 803/5000 - loss value -7.600156e-02
# Epoch 804/5000 - loss value -7.600455e-02
# Epoch 805/5000 - loss value -7.600754e-02
# Epoch 806/5000 - loss value -7.601052e-02
# Epoch 807/5000 - loss value -7.601348e-02
# Epoch 808/5000 - loss value -7.601644e-02
# Epoch 809/5000 - loss value -7.601939e-02
# Epoch 810/5000 - loss value -7.602233e-02
# Epoch 811/5000 - loss value -7.602526e-02
# Epoch 812/5000 - loss value -7.602819e-02
# Epoch 813/5000 - loss value -7.603110e-02
# Epoch 814/5000 - loss value -7.603400e-02
# Epoch 815/5000 - loss value -7.603690e-02
# Epoch 816/5000 - loss value -7.603978e-02
# Epoch 817/5000 - loss value -7.604266e-02
# Epoch 818/5000 - loss value -7.604553e-02
# Epoch 819/5000 - loss value -7.604839e-02
# Epoch 820/5000 - loss value -7.605124e-02
# Epoch 821/5000 - loss value -7.605408e-02
# Epoch 822/5000 - loss value -7.605691e-02
# Epoch 823/5000 - loss value -7.605974e-02
# Epoch 824/5000 - loss value -7.606255e-02
# Epoch 825/5000 - loss value -7.606536e-02
# Epoch 826/5000 - loss value -7.606816e-02
# Epoch 827/5000 - loss value -7.607095e-02
# Epoch 828/5000 - loss value -7.607373e-02
# Epoch 829/5000 - loss value -7.607650e-02
# Epoch 830/5000 - loss value -7.607926e-02
# Epoch 831/5000 - loss value -7.608202e-02
# Epoch 832/5000 - loss value -7.608476e-02
# Epoch 833/5000 - loss value -7.608750e-02
# Epoch 834/5000 - loss value -7.609023e-02
# Epoch 835/5000 - loss value -7.609295e-02
# Epoch 836/5000 - loss value -7.609567e-02
# Epoch 837/5000 - loss value -7.609837e-02
# Epoch 838/5000 - loss value -7.610107e-02
# Epoch 839/5000 - loss value -7.610376e-02
# Epoch 840/5000 - loss value -7.610644e-02
# Epoch 841/5000 - loss value -7.610911e-02
# Epoch 842/5000 - loss value -7.611177e-02
# Epoch 843/5000 - loss value -7.611443e-02
# Epoch 844/5000 - loss value -7.611708e-02
# Epoch 845/5000 - loss value -7.611972e-02
# Epoch 846/5000 - loss value -7.612235e-02
# Epoch 847/5000 - loss value -7.612497e-02
# Epoch 848/5000 - loss value -7.612759e-02
# Epoch 849/5000 - loss value -7.613019e-02
# Epoch 850/5000 - loss value -7.613279e-02
# Epoch 851/5000 - loss value -7.613539e-02
# Epoch 852/5000 - loss value -7.613797e-02
# Epoch 853/5000 - loss value -7.614055e-02
# Epoch 854/5000 - loss value -7.614312e-02
# Epoch 855/5000 - loss value -7.614568e-02
# Epoch 856/5000 - loss value -7.614823e-02
# Epoch 857/5000 - loss value -7.615078e-02
# Epoch 858/5000 - loss value -7.615331e-02
# Epoch 859/5000 - loss value -7.615584e-02
# Epoch 860/5000 - loss value -7.615837e-02
# Epoch 861/5000 - loss value -7.616088e-02
# Epoch 862/5000 - loss value -7.616339e-02
# Epoch 863/5000 - loss value -7.616589e-02
# Epoch 864/5000 - loss value -7.616838e-02
# Epoch 865/5000 - loss value -7.617087e-02
# Epoch 866/5000 - loss value -7.617335e-02
# Epoch 867/5000 - loss value -7.617582e-02
# Epoch 868/5000 - loss value -7.617828e-02
# Epoch 869/5000 - loss value -7.618073e-02
# Epoch 870/5000 - loss value -7.618318e-02
# Epoch 871/5000 - loss value -7.618562e-02
# Epoch 872/5000 - loss value -7.618806e-02
# Epoch 873/5000 - loss value -7.619049e-02
# Epoch 874/5000 - loss value -7.619291e-02
# Epoch 875/5000 - loss value -7.619532e-02
# Epoch 876/5000 - loss value -7.619772e-02
# Epoch 877/5000 - loss value -7.620012e-02
# Epoch 878/5000 - loss value -7.620251e-02
# Epoch 879/5000 - loss value -7.620490e-02
# Epoch 880/5000 - loss value -7.620728e-02
# Epoch 881/5000 - loss value -7.620965e-02
# Epoch 882/5000 - loss value -7.621201e-02
# Epoch 883/5000 - loss value -7.621437e-02
# Epoch 884/5000 - loss value -7.621672e-02
# Epoch 885/5000 - loss value -7.621906e-02
# Epoch 886/5000 - loss value -7.622139e-02
# Epoch 887/5000 - loss value -7.622372e-02
# Epoch 888/5000 - loss value -7.622605e-02
# Epoch 889/5000 - loss value -7.622836e-02
# Epoch 890/5000 - loss value -7.623067e-02
# Epoch 891/5000 - loss value -7.623297e-02
# Epoch 892/5000 - loss value -7.623527e-02
# Epoch 893/5000 - loss value -7.623756e-02
# Epoch 894/5000 - loss value -7.623984e-02
# Epoch 895/5000 - loss value -7.624211e-02
# Epoch 896/5000 - loss value -7.624438e-02
# Epoch 897/5000 - loss value -7.624665e-02
# Epoch 898/5000 - loss value -7.624890e-02
# Epoch 899/5000 - loss value -7.625115e-02
# Epoch 900/5000 - loss value -7.625339e-02
# Epoch 901/5000 - loss value -7.625563e-02
# Epoch 902/5000 - loss value -7.625786e-02
# Epoch 903/5000 - loss value -7.626008e-02
# Epoch 904/5000 - loss value -7.626230e-02
# Epoch 905/5000 - loss value -7.626451e-02
# Epoch 906/5000 - loss value -7.626672e-02
# Epoch 907/5000 - loss value -7.626892e-02
# Epoch 908/5000 - loss value -7.627111e-02
# Epoch 909/5000 - loss value -7.627329e-02
# Epoch 910/5000 - loss value -7.627547e-02
# Epoch 911/5000 - loss value -7.627765e-02
# Epoch 912/5000 - loss value -7.627982e-02
# Epoch 913/5000 - loss value -7.628198e-02
# Epoch 914/5000 - loss value -7.628413e-02
# Epoch 915/5000 - loss value -7.628628e-02
# Epoch 916/5000 - loss value -7.628842e-02
# Epoch 917/5000 - loss value -7.629056e-02
# Epoch 918/5000 - loss value -7.629269e-02
# Epoch 919/5000 - loss value -7.629482e-02
# Epoch 920/5000 - loss value -7.629694e-02
# Epoch 921/5000 - loss value -7.629905e-02
# Epoch 922/5000 - loss value -7.630116e-02
# Epoch 923/5000 - loss value -7.630326e-02
# Epoch 924/5000 - loss value -7.630535e-02
# Epoch 925/5000 - loss value -7.630744e-02
# Epoch 926/5000 - loss value -7.630953e-02
# Epoch 927/5000 - loss value -7.631160e-02
# Epoch 928/5000 - loss value -7.631368e-02
# Epoch 929/5000 - loss value -7.631574e-02
# Epoch 930/5000 - loss value -7.631780e-02
# Epoch 931/5000 - loss value -7.631986e-02
# Epoch 932/5000 - loss value -7.632191e-02
# Epoch 933/5000 - loss value -7.632395e-02
# Epoch 934/5000 - loss value -7.632599e-02
# Epoch 935/5000 - loss value -7.632802e-02
# Epoch 936/5000 - loss value -7.633005e-02
# Epoch 937/5000 - loss value -7.633207e-02
# Epoch 938/5000 - loss value -7.633408e-02
# Epoch 939/5000 - loss value -7.633609e-02
# Epoch 940/5000 - loss value -7.633810e-02
# Epoch 941/5000 - loss value -7.634010e-02
# Epoch 942/5000 - loss value -7.634209e-02
# Epoch 943/5000 - loss value -7.634408e-02
# Epoch 944/5000 - loss value -7.634606e-02
# Epoch 945/5000 - loss value -7.634804e-02
# Epoch 946/5000 - loss value -7.635001e-02
# Epoch 947/5000 - loss value -7.635198e-02
# Epoch 948/5000 - loss value -7.635394e-02
# Epoch 949/5000 - loss value -7.635589e-02
# Epoch 950/5000 - loss value -7.635785e-02
# Epoch 951/5000 - loss value -7.635979e-02
# Epoch 952/5000 - loss value -7.636173e-02
# Epoch 953/5000 - loss value -7.636367e-02
# Epoch 954/5000 - loss value -7.636560e-02
# Epoch 955/5000 - loss value -7.636752e-02
# Epoch 956/5000 - loss value -7.636944e-02
# Epoch 957/5000 - loss value -7.637135e-02
# Epoch 958/5000 - loss value -7.637326e-02
# Epoch 959/5000 - loss value -7.637517e-02
# Epoch 960/5000 - loss value -7.637707e-02
# Epoch 961/5000 - loss value -7.637896e-02
# Epoch 962/5000 - loss value -7.638085e-02
# Epoch 963/5000 - loss value -7.638273e-02
# Epoch 964/5000 - loss value -7.638461e-02
# Epoch 965/5000 - loss value -7.638648e-02
# Epoch 966/5000 - loss value -7.638835e-02
# Epoch 967/5000 - loss value -7.639022e-02
# Epoch 968/5000 - loss value -7.639208e-02
# Epoch 969/5000 - loss value -7.639393e-02
# Epoch 970/5000 - loss value -7.639578e-02
# Epoch 971/5000 - loss value -7.639762e-02
# Epoch 972/5000 - loss value -7.639946e-02
# Epoch 973/5000 - loss value -7.640130e-02
# Epoch 974/5000 - loss value -7.640313e-02
# Epoch 975/5000 - loss value -7.640495e-02
# Epoch 976/5000 - loss value -7.640677e-02
# Epoch 977/5000 - loss value -7.640859e-02
# Epoch 978/5000 - loss value -7.641040e-02
# Epoch 979/5000 - loss value -7.641220e-02
# Epoch 980/5000 - loss value -7.641401e-02
# Epoch 981/5000 - loss value -7.641580e-02
# Epoch 982/5000 - loss value -7.641759e-02
# Epoch 983/5000 - loss value -7.641938e-02
# Epoch 984/5000 - loss value -7.642116e-02
# Epoch 985/5000 - loss value -7.642294e-02
# Epoch 986/5000 - loss value -7.642472e-02
# Epoch 987/5000 - loss value -7.642648e-02
# Epoch 988/5000 - loss value -7.642825e-02
# Epoch 989/5000 - loss value -7.643001e-02
# Epoch 990/5000 - loss value -7.643176e-02
# Epoch 991/5000 - loss value -7.643352e-02
# Epoch 992/5000 - loss value -7.643526e-02
# Epoch 993/5000 - loss value -7.643700e-02
# Epoch 994/5000 - loss value -7.643874e-02
# Epoch 995/5000 - loss value -7.644047e-02
# Epoch 996/5000 - loss value -7.644220e-02
# Epoch 997/5000 - loss value -7.644393e-02
# Epoch 998/5000 - loss value -7.644565e-02
# Epoch 999/5000 - loss value -7.644736e-02
# Epoch 1000/5000 - loss value -7.644907e-02
# Epoch 1001/5000 - loss value -7.645078e-02
# Epoch 1002/5000 - loss value -7.645248e-02
# Epoch 1003/5000 - loss value -7.645418e-02
# Epoch 1004/5000 - loss value -7.645588e-02
# Epoch 1005/5000 - loss value -7.645756e-02
# Epoch 1006/5000 - loss value -7.645925e-02
# Epoch 1007/5000 - loss value -7.646093e-02
# Epoch 1008/5000 - loss value -7.646261e-02
# Epoch 1009/5000 - loss value -7.646428e-02
# Epoch 1010/5000 - loss value -7.646595e-02
# Epoch 1011/5000 - loss value -7.646761e-02
# Epoch 1012/5000 - loss value -7.646928e-02
# Epoch 1013/5000 - loss value -7.647093e-02
# Epoch 1014/5000 - loss value -7.647258e-02
# Epoch 1015/5000 - loss value -7.647423e-02
# Epoch 1016/5000 - loss value -7.647588e-02
# Epoch 1017/5000 - loss value -7.647752e-02
# Epoch 1018/5000 - loss value -7.647915e-02
# Epoch 1019/5000 - loss value -7.648078e-02
# Epoch 1020/5000 - loss value -7.648241e-02
# Epoch 1021/5000 - loss value -7.648404e-02
# Epoch 1022/5000 - loss value -7.648565e-02
# Epoch 1023/5000 - loss value -7.648727e-02
# Epoch 1024/5000 - loss value -7.648888e-02
# Epoch 1025/5000 - loss value -7.649049e-02
# Epoch 1026/5000 - loss value -7.649209e-02
# Epoch 1027/5000 - loss value -7.649370e-02
# Epoch 1028/5000 - loss value -7.649529e-02
# Epoch 1029/5000 - loss value -7.649688e-02
# Epoch 1030/5000 - loss value -7.649847e-02
# Epoch 1031/5000 - loss value -7.650006e-02
# Epoch 1032/5000 - loss value -7.650164e-02
# Epoch 1033/5000 - loss value -7.650322e-02
# Epoch 1034/5000 - loss value -7.650479e-02
# Epoch 1035/5000 - loss value -7.650636e-02
# Epoch 1036/5000 - loss value -7.650792e-02
# Epoch 1037/5000 - loss value -7.650949e-02
# Epoch 1038/5000 - loss value -7.651104e-02
# Epoch 1039/5000 - loss value -7.651260e-02
# Epoch 1040/5000 - loss value -7.651415e-02
# Epoch 1041/5000 - loss value -7.651570e-02
# Epoch 1042/5000 - loss value -7.651724e-02
# Epoch 1043/5000 - loss value -7.651878e-02
# Epoch 1044/5000 - loss value -7.652031e-02
# Epoch 1045/5000 - loss value -7.652185e-02
# Epoch 1046/5000 - loss value -7.652338e-02
# Epoch 1047/5000 - loss value -7.652490e-02
# Epoch 1048/5000 - loss value -7.652642e-02
# Epoch 1049/5000 - loss value -7.652794e-02
# Epoch 1050/5000 - loss value -7.652945e-02
# Epoch 1051/5000 - loss value -7.653097e-02
# Epoch 1052/5000 - loss value -7.653247e-02
# Epoch 1053/5000 - loss value -7.653398e-02
# Epoch 1054/5000 - loss value -7.653548e-02
# Epoch 1055/5000 - loss value -7.653697e-02
# Epoch 1056/5000 - loss value -7.653847e-02
# Epoch 1057/5000 - loss value -7.653996e-02
# Epoch 1058/5000 - loss value -7.654144e-02
# Epoch 1059/5000 - loss value -7.654293e-02
# Epoch 1060/5000 - loss value -7.654440e-02
# Epoch 1061/5000 - loss value -7.654588e-02
# Epoch 1062/5000 - loss value -7.654735e-02
# Epoch 1063/5000 - loss value -7.654882e-02
# Epoch 1064/5000 - loss value -7.655029e-02
# Epoch 1065/5000 - loss value -7.655175e-02
# Epoch 1066/5000 - loss value -7.655321e-02
# Epoch 1067/5000 - loss value -7.655466e-02
# Epoch 1068/5000 - loss value -7.655612e-02
# Epoch 1069/5000 - loss value -7.655757e-02
# Epoch 1070/5000 - loss value -7.655901e-02
# Epoch 1071/5000 - loss value -7.656045e-02
# Epoch 1072/5000 - loss value -7.656189e-02
# Epoch 1073/5000 - loss value -7.656333e-02
# Epoch 1074/5000 - loss value -7.656476e-02
# Epoch 1075/5000 - loss value -7.656619e-02
# Epoch 1076/5000 - loss value -7.656762e-02
# Epoch 1077/5000 - loss value -7.656904e-02
# Epoch 1078/5000 - loss value -7.657046e-02
# Epoch 1079/5000 - loss value -7.657187e-02
# Epoch 1080/5000 - loss value -7.657329e-02
# Epoch 1081/5000 - loss value -7.657470e-02
# Epoch 1082/5000 - loss value -7.657610e-02
# Epoch 1083/5000 - loss value -7.657751e-02
# Epoch 1084/5000 - loss value -7.657891e-02
# Epoch 1085/5000 - loss value -7.658030e-02
# Epoch 1086/5000 - loss value -7.658170e-02
# Epoch 1087/5000 - loss value -7.658309e-02
# Epoch 1088/5000 - loss value -7.658448e-02
# Epoch 1089/5000 - loss value -7.658586e-02
# Epoch 1090/5000 - loss value -7.658724e-02
# Epoch 1091/5000 - loss value -7.658862e-02
# Epoch 1092/5000 - loss value -7.659000e-02
# Epoch 1093/5000 - loss value -7.659137e-02
# Epoch 1094/5000 - loss value -7.659274e-02
# Epoch 1095/5000 - loss value -7.659411e-02
# Epoch 1096/5000 - loss value -7.659547e-02
# Epoch 1097/5000 - loss value -7.659683e-02
# Epoch 1098/5000 - loss value -7.659819e-02
# Epoch 1099/5000 - loss value -7.659954e-02
# Epoch 1100/5000 - loss value -7.660089e-02
# Epoch 1101/5000 - loss value -7.660224e-02
# Epoch 1102/5000 - loss value -7.660359e-02
# Epoch 1103/5000 - loss value -7.660493e-02
# Epoch 1104/5000 - loss value -7.660627e-02
# Epoch 1105/5000 - loss value -7.660761e-02
# Epoch 1106/5000 - loss value -7.660894e-02
# Epoch 1107/5000 - loss value -7.661027e-02
# Epoch 1108/5000 - loss value -7.661160e-02
# Epoch 1109/5000 - loss value -7.661292e-02
# Epoch 1110/5000 - loss value -7.661425e-02
# Epoch 1111/5000 - loss value -7.661557e-02
# Epoch 1112/5000 - loss value -7.661688e-02
# Epoch 1113/5000 - loss value -7.661820e-02
# Epoch 1114/5000 - loss value -7.661951e-02
# Epoch 1115/5000 - loss value -7.662082e-02
# Epoch 1116/5000 - loss value -7.662212e-02
# Epoch 1117/5000 - loss value -7.662342e-02
# Epoch 1118/5000 - loss value -7.662472e-02
# Epoch 1119/5000 - loss value -7.662602e-02
# Epoch 1120/5000 - loss value -7.662731e-02
# Epoch 1121/5000 - loss value -7.662861e-02
# Epoch 1122/5000 - loss value -7.662989e-02
# Epoch 1123/5000 - loss value -7.663118e-02
# Epoch 1124/5000 - loss value -7.663246e-02
# Epoch 1125/5000 - loss value -7.663374e-02
# Epoch 1126/5000 - loss value -7.663502e-02
# Epoch 1127/5000 - loss value -7.663630e-02
# Epoch 1128/5000 - loss value -7.663757e-02
# Epoch 1129/5000 - loss value -7.663884e-02
# Epoch 1130/5000 - loss value -7.664010e-02
# Epoch 1131/5000 - loss value -7.664137e-02
# Epoch 1132/5000 - loss value -7.664263e-02
# Epoch 1133/5000 - loss value -7.664389e-02
# Epoch 1134/5000 - loss value -7.664515e-02
# Epoch 1135/5000 - loss value -7.664640e-02
# Epoch 1136/5000 - loss value -7.664765e-02
# Epoch 1137/5000 - loss value -7.664890e-02
# Epoch 1138/5000 - loss value -7.665014e-02
# Epoch 1139/5000 - loss value -7.665139e-02
# Epoch 1140/5000 - loss value -7.665263e-02
# Epoch 1141/5000 - loss value -7.665387e-02
# Epoch 1142/5000 - loss value -7.665510e-02
# Epoch 1143/5000 - loss value -7.665634e-02
# ...
# Epoch 4631/5000 - loss value -7.762566e-02
# Epoch 4632/5000 - loss value -7.762578e-02
# Epoch 4633/5000 - loss value -7.762590e-02
# Epoch 4634/5000 - loss value -7.762602e-02
# Epoch 4635/5000 - loss value -7.762614e-02
# Epoch 4636/5000 - loss value -7.762626e-02
# Epoch 4637/5000 - loss value -7.762638e-02
# Epoch 4638/5000 - loss value -7.762650e-02
# Epoch 4639/5000 - loss value -7.762662e-02
# Epoch 4640/5000 - loss value -7.762674e-02
# Epoch 4641/5000 - loss value -7.762686e-02
# Epoch 4642/5000 - loss value -7.762698e-02
# Epoch 4643/5000 - loss value -7.762710e-02
# Epoch 4644/5000 - loss value -7.762722e-02
# Epoch 4645/5000 - loss value -7.762733e-02
# Epoch 4646/5000 - loss value -7.762745e-02
# Epoch 4647/5000 - loss value -7.762757e-02
# Epoch 4648/5000 - loss value -7.762769e-02
# Epoch 4649/5000 - loss value -7.762780e-02
# Epoch 4650/5000 - loss value -7.762792e-02
# Epoch 4651/5000 - loss value -7.762804e-02
# Epoch 4652/5000 - loss value -7.762815e-02
# Epoch 4653/5000 - loss value -7.762827e-02
# Epoch 4654/5000 - loss value -7.762839e-02
# Epoch 4655/5000 - loss value -7.762850e-02
# Epoch 4656/5000 - loss value -7.762862e-02
# Epoch 4657/5000 - loss value -7.762874e-02
# Epoch 4658/5000 - loss value -7.762885e-02
# Epoch 4659/5000 - loss value -7.762897e-02
# Epoch 4660/5000 - loss value -7.762908e-02
# Epoch 4661/5000 - loss value -7.762920e-02
# Epoch 4662/5000 - loss value -7.762931e-02
# Epoch 4663/5000 - loss value -7.762943e-02
# Epoch 4664/5000 - loss value -7.762954e-02
# Epoch 4665/5000 - loss value -7.762966e-02
# Epoch 4666/5000 - loss value -7.762977e-02
# Epoch 4667/5000 - loss value -7.762988e-02
# Epoch 4668/5000 - loss value -7.763000e-02
# Epoch 4669/5000 - loss value -7.763011e-02
# Epoch 4670/5000 - loss value -7.763023e-02
# Epoch 4671/5000 - loss value -7.763034e-02
# Epoch 4672/5000 - loss value -7.763045e-02
# Epoch 4673/5000 - loss value -7.763057e-02
# Epoch 4674/5000 - loss value -7.763068e-02
# Epoch 4675/5000 - loss value -7.763079e-02
# Epoch 4676/5000 - loss value -7.763090e-02
# Epoch 4677/5000 - loss value -7.763102e-02
# Epoch 4678/5000 - loss value -7.763113e-02
# Epoch 4679/5000 - loss value -7.763124e-02
# Epoch 4680/5000 - loss value -7.763135e-02
# Epoch 4681/5000 - loss value -7.763147e-02
# Epoch 4682/5000 - loss value -7.763158e-02
# Epoch 4683/5000 - loss value -7.763169e-02
# Epoch 4684/5000 - loss value -7.763180e-02
# Epoch 4685/5000 - loss value -7.763191e-02
# Epoch 4686/5000 - loss value -7.763202e-02
# Epoch 4687/5000 - loss value -7.763213e-02
# Epoch 4688/5000 - loss value -7.763224e-02
# Epoch 4689/5000 - loss value -7.763236e-02
# Epoch 4690/5000 - loss value -7.763247e-02
# Epoch 4691/5000 - loss value -7.763258e-02
# Epoch 4692/5000 - loss value -7.763269e-02
# Epoch 4693/5000 - loss value -7.763280e-02
# Epoch 4694/5000 - loss value -7.763291e-02
# Epoch 4695/5000 - loss value -7.763302e-02
# Epoch 4696/5000 - loss value -7.763313e-02
# Epoch 4697/5000 - loss value -7.763324e-02
# Epoch 4698/5000 - loss value -7.763335e-02
# Epoch 4699/5000 - loss value -7.763346e-02
# Epoch 4700/5000 - loss value -7.763356e-02
# Epoch 4701/5000 - loss value -7.763367e-02
# Epoch 4702/5000 - loss value -7.763378e-02
# Epoch 4703/5000 - loss value -7.763389e-02
# Epoch 4704/5000 - loss value -7.763400e-02
# Epoch 4705/5000 - loss value -7.763411e-02
# Epoch 4706/5000 - loss value -7.763422e-02
# Epoch 4707/5000 - loss value -7.763433e-02
# Epoch 4708/5000 - loss value -7.763443e-02
# Epoch 4709/5000 - loss value -7.763454e-02
# Epoch 4710/5000 - loss value -7.763465e-02
# Epoch 4711/5000 - loss value -7.763476e-02
# Epoch 4712/5000 - loss value -7.763487e-02
# Epoch 4713/5000 - loss value -7.763497e-02
# Epoch 4714/5000 - loss value -7.763508e-02
# Epoch 4715/5000 - loss value -7.763519e-02
# Epoch 4716/5000 - loss value -7.763530e-02
# Epoch 4717/5000 - loss value -7.763540e-02
# Epoch 4718/5000 - loss value -7.763551e-02
# Epoch 4719/5000 - loss value -7.763562e-02
# Epoch 4720/5000 - loss value -7.763572e-02
# Epoch 4721/5000 - loss value -7.763583e-02
# Epoch 4722/5000 - loss value -7.763594e-02
# Epoch 4723/5000 - loss value -7.763604e-02
# Epoch 4724/5000 - loss value -7.763615e-02
# Epoch 4725/5000 - loss value -7.763626e-02
# Epoch 4726/5000 - loss value -7.763636e-02
# Epoch 4727/5000 - loss value -7.763647e-02
# Epoch 4728/5000 - loss value -7.763657e-02
# Epoch 4729/5000 - loss value -7.763668e-02
# Epoch 4730/5000 - loss value -7.763678e-02
# Epoch 4731/5000 - loss value -7.763689e-02
# Epoch 4732/5000 - loss value -7.763699e-02
# Epoch 4733/5000 - loss value -7.763710e-02
# Epoch 4734/5000 - loss value -7.763721e-02
# Epoch 4735/5000 - loss value -7.763731e-02
# Epoch 4736/5000 - loss value -7.763742e-02
# Epoch 4737/5000 - loss value -7.763752e-02
# Epoch 4738/5000 - loss value -7.763762e-02
# Epoch 4739/5000 - loss value -7.763773e-02
# Epoch 4740/5000 - loss value -7.763783e-02
# Epoch 4741/5000 - loss value -7.763794e-02
# Epoch 4742/5000 - loss value -7.763804e-02
# Epoch 4743/5000 - loss value -7.763815e-02
# Epoch 4744/5000 - loss value -7.763825e-02
# Epoch 4745/5000 - loss value -7.763835e-02
# Epoch 4746/5000 - loss value -7.763846e-02
# Epoch 4747/5000 - loss value -7.763856e-02
# Epoch 4748/5000 - loss value -7.763867e-02
# Epoch 4749/5000 - loss value -7.763877e-02
# Epoch 4750/5000 - loss value -7.763887e-02
# Epoch 4751/5000 - loss value -7.763898e-02
# Epoch 4752/5000 - loss value -7.763908e-02
# Epoch 4753/5000 - loss value -7.763918e-02
# Epoch 4754/5000 - loss value -7.763929e-02
# Epoch 4755/5000 - loss value -7.763939e-02
# Epoch 4756/5000 - loss value -7.763949e-02
# Epoch 4757/5000 - loss value -7.763959e-02
# Epoch 4758/5000 - loss value -7.763970e-02
# Epoch 4759/5000 - loss value -7.763980e-02
# Epoch 4760/5000 - loss value -7.763990e-02
# Epoch 4761/5000 - loss value -7.764000e-02
# Epoch 4762/5000 - loss value -7.764011e-02
# Epoch 4763/5000 - loss value -7.764021e-02
# Epoch 4764/5000 - loss value -7.764031e-02
# Epoch 4765/5000 - loss value -7.764041e-02
# Epoch 4766/5000 - loss value -7.764051e-02
# Epoch 4767/5000 - loss value -7.764062e-02
# Epoch 4768/5000 - loss value -7.764072e-02
# Epoch 4769/5000 - loss value -7.764082e-02
# Epoch 4770/5000 - loss value -7.764092e-02
# Epoch 4771/5000 - loss value -7.764102e-02
# Epoch 4772/5000 - loss value -7.764112e-02
# Epoch 4773/5000 - loss value -7.764122e-02
# Epoch 4774/5000 - loss value -7.764132e-02
# Epoch 4775/5000 - loss value -7.764143e-02
# Epoch 4776/5000 - loss value -7.764153e-02
# Epoch 4777/5000 - loss value -7.764163e-02
# Epoch 4778/5000 - loss value -7.764173e-02
# Epoch 4779/5000 - loss value -7.764183e-02
# Epoch 4780/5000 - loss value -7.764193e-02
# Epoch 4781/5000 - loss value -7.764203e-02
# Epoch 4782/5000 - loss value -7.764213e-02
# Epoch 4783/5000 - loss value -7.764223e-02
# Epoch 4784/5000 - loss value -7.764233e-02
# Epoch 4785/5000 - loss value -7.764243e-02
# Epoch 4786/5000 - loss value -7.764253e-02
# Epoch 4787/5000 - loss value -7.764263e-02
# Epoch 4788/5000 - loss value -7.764273e-02
# Epoch 4789/5000 - loss value -7.764283e-02
# Epoch 4790/5000 - loss value -7.764293e-02
# Epoch 4791/5000 - loss value -7.764303e-02
# Epoch 4792/5000 - loss value -7.764313e-02
# Epoch 4793/5000 - loss value -7.764323e-02
# Epoch 4794/5000 - loss value -7.764333e-02
# Epoch 4795/5000 - loss value -7.764343e-02
# Epoch 4796/5000 - loss value -7.764352e-02
# Epoch 4797/5000 - loss value -7.764362e-02
# Epoch 4798/5000 - loss value -7.764372e-02
# Epoch 4799/5000 - loss value -7.764382e-02
# Epoch 4800/5000 - loss value -7.764392e-02
# Epoch 4801/5000 - loss value -7.764402e-02
# Epoch 4802/5000 - loss value -7.764412e-02
# Epoch 4803/5000 - loss value -7.764422e-02
# Epoch 4804/5000 - loss value -7.764431e-02
# Epoch 4805/5000 - loss value -7.764441e-02
# Epoch 4806/5000 - loss value -7.764451e-02
# Epoch 4807/5000 - loss value -7.764461e-02
# Epoch 4808/5000 - loss value -7.764471e-02
# Epoch 4809/5000 - loss value -7.764480e-02
# Epoch 4810/5000 - loss value -7.764490e-02
# Epoch 4811/5000 - loss value -7.764500e-02
# Epoch 4812/5000 - loss value -7.764510e-02
# Epoch 4813/5000 - loss value -7.764520e-02
# Epoch 4814/5000 - loss value -7.764529e-02
# Epoch 4815/5000 - loss value -7.764539e-02
# Epoch 4816/5000 - loss value -7.764549e-02
# Epoch 4817/5000 - loss value -7.764558e-02
# Epoch 4818/5000 - loss value -7.764568e-02
# Epoch 4819/5000 - loss value -7.764578e-02
# Epoch 4820/5000 - loss value -7.764588e-02
# Epoch 4821/5000 - loss value -7.764597e-02
# Epoch 4822/5000 - loss value -7.764607e-02
# Epoch 4823/5000 - loss value -7.764617e-02
# Epoch 4824/5000 - loss value -7.764626e-02
# Epoch 4825/5000 - loss value -7.764636e-02
# Epoch 4826/5000 - loss value -7.764646e-02
# Epoch 4827/5000 - loss value -7.764655e-02
# Epoch 4828/5000 - loss value -7.764665e-02
# Epoch 4829/5000 - loss value -7.764675e-02
# Epoch 4830/5000 - loss value -7.764684e-02
# Epoch 4831/5000 - loss value -7.764694e-02
# Epoch 4832/5000 - loss value -7.764703e-02
# Epoch 4833/5000 - loss value -7.764713e-02
# Epoch 4834/5000 - loss value -7.764723e-02
# Epoch 4835/5000 - loss value -7.764732e-02
# Epoch 4836/5000 - loss value -7.764742e-02
# Epoch 4837/5000 - loss value -7.764751e-02
# Epoch 4838/5000 - loss value -7.764761e-02
# Epoch 4839/5000 - loss value -7.764770e-02
# Epoch 4840/5000 - loss value -7.764780e-02
# Epoch 4841/5000 - loss value -7.764790e-02
# Epoch 4842/5000 - loss value -7.764799e-02
# Epoch 4843/5000 - loss value -7.764809e-02
# Epoch 4844/5000 - loss value -7.764818e-02
# Epoch 4845/5000 - loss value -7.764828e-02
# Epoch 4846/5000 - loss value -7.764837e-02
# Epoch 4847/5000 - loss value -7.764847e-02
# Epoch 4848/5000 - loss value -7.764856e-02
# Epoch 4849/5000 - loss value -7.764866e-02
# Epoch 4850/5000 - loss value -7.764875e-02
# Epoch 4851/5000 - loss value -7.764885e-02
# Epoch 4852/5000 - loss value -7.764894e-02
# Epoch 4853/5000 - loss value -7.764903e-02
# Epoch 4854/5000 - loss value -7.764913e-02
# Epoch 4855/5000 - loss value -7.764922e-02
# Epoch 4856/5000 - loss value -7.764932e-02
# Epoch 4857/5000 - loss value -7.764941e-02
# Epoch 4858/5000 - loss value -7.764951e-02
# Epoch 4859/5000 - loss value -7.764960e-02
# Epoch 4860/5000 - loss value -7.764969e-02
# Epoch 4861/5000 - loss value -7.764979e-02
# Epoch 4862/5000 - loss value -7.764988e-02
# Epoch 4863/5000 - loss value -7.764997e-02
# Epoch 4864/5000 - loss value -7.765007e-02
# Epoch 4865/5000 - loss value -7.765016e-02
# Epoch 4866/5000 - loss value -7.765026e-02
# Epoch 4867/5000 - loss value -7.765035e-02
# Epoch 4868/5000 - loss value -7.765044e-02
# Epoch 4869/5000 - loss value -7.765054e-02
# Epoch 4870/5000 - loss value -7.765063e-02
# Epoch 4871/5000 - loss value -7.765072e-02
# Epoch 4872/5000 - loss value -7.765082e-02
# Epoch 4873/5000 - loss value -7.765091e-02
# Epoch 4874/5000 - loss value -7.765100e-02
# Epoch 4875/5000 - loss value -7.765109e-02
# Epoch 4876/5000 - loss value -7.765119e-02
# Epoch 4877/5000 - loss value -7.765128e-02
# Epoch 4878/5000 - loss value -7.765137e-02
# Epoch 4879/5000 - loss value -7.765147e-02
# Epoch 4880/5000 - loss value -7.765156e-02
# Epoch 4881/5000 - loss value -7.765165e-02
# Epoch 4882/5000 - loss value -7.765174e-02
# Epoch 4883/5000 - loss value -7.765184e-02
# Epoch 4884/5000 - loss value -7.765193e-02
# Epoch 4885/5000 - loss value -7.765202e-02
# Epoch 4886/5000 - loss value -7.765211e-02
# Epoch 4887/5000 - loss value -7.765220e-02
# Epoch 4888/5000 - loss value -7.765230e-02
# Epoch 4889/5000 - loss value -7.765239e-02
# Epoch 4890/5000 - loss value -7.765248e-02
# Epoch 4891/5000 - loss value -7.765257e-02
# Epoch 4892/5000 - loss value -7.765266e-02
# Epoch 4893/5000 - loss value -7.765276e-02
# Epoch 4894/5000 - loss value -7.765285e-02
# Epoch 4895/5000 - loss value -7.765294e-02
# Epoch 4896/5000 - loss value -7.765303e-02
# Epoch 4897/5000 - loss value -7.765312e-02
# Epoch 4898/5000 - loss value -7.765321e-02
# Epoch 4899/5000 - loss value -7.765330e-02
# Epoch 4900/5000 - loss value -7.765340e-02
# Epoch 4901/5000 - loss value -7.765349e-02
# Epoch 4902/5000 - loss value -7.765358e-02
# Epoch 4903/5000 - loss value -7.765367e-02
# Epoch 4904/5000 - loss value -7.765376e-02
# Epoch 4905/5000 - loss value -7.765385e-02
# Epoch 4906/5000 - loss value -7.765394e-02
# Epoch 4907/5000 - loss value -7.765403e-02
# Epoch 4908/5000 - loss value -7.765412e-02
# Epoch 4909/5000 - loss value -7.765421e-02
# Epoch 4910/5000 - loss value -7.765430e-02
# Epoch 4911/5000 - loss value -7.765439e-02
# Epoch 4912/5000 - loss value -7.765448e-02
# Epoch 4913/5000 - loss value -7.765458e-02
# Epoch 4914/5000 - loss value -7.765467e-02
# Epoch 4915/5000 - loss value -7.765476e-02
# Epoch 4916/5000 - loss value -7.765485e-02
# Epoch 4917/5000 - loss value -7.765494e-02
# Epoch 4918/5000 - loss value -7.765503e-02
# Epoch 4919/5000 - loss value -7.765512e-02
# Epoch 4920/5000 - loss value -7.765521e-02
# Epoch 4921/5000 - loss value -7.765530e-02
# Epoch 4922/5000 - loss value -7.765539e-02
# Epoch 4923/5000 - loss value -7.765548e-02
# Epoch 4924/5000 - loss value -7.765557e-02
# Epoch 4925/5000 - loss value -7.765566e-02
# Epoch 4926/5000 - loss value -7.765574e-02
# Epoch 4927/5000 - loss value -7.765583e-02
# Epoch 4928/5000 - loss value -7.765592e-02
# Epoch 4929/5000 - loss value -7.765601e-02
# Epoch 4930/5000 - loss value -7.765610e-02
# Epoch 4931/5000 - loss value -7.765619e-02
# Epoch 4932/5000 - loss value -7.765628e-02
# Epoch 4933/5000 - loss value -7.765637e-02
# Epoch 4934/5000 - loss value -7.765646e-02
# Epoch 4935/5000 - loss value -7.765655e-02
# Epoch 4936/5000 - loss value -7.765664e-02
# Epoch 4937/5000 - loss value -7.765673e-02
# Epoch 4938/5000 - loss value -7.765682e-02
# Epoch 4939/5000 - loss value -7.765690e-02
# Epoch 4940/5000 - loss value -7.765699e-02
# Epoch 4941/5000 - loss value -7.765708e-02
# Epoch 4942/5000 - loss value -7.765717e-02
# Epoch 4943/5000 - loss value -7.765726e-02
# Epoch 4944/5000 - loss value -7.765735e-02
# Epoch 4945/5000 - loss value -7.765744e-02
# Epoch 4946/5000 - loss value -7.765752e-02
# Epoch 4947/5000 - loss value -7.765761e-02
# Epoch 4948/5000 - loss value -7.765770e-02
# Epoch 4949/5000 - loss value -7.765779e-02
# Epoch 4950/5000 - loss value -7.765788e-02
# Epoch 4951/5000 - loss value -7.765797e-02
# Epoch 4952/5000 - loss value -7.765805e-02
# Epoch 4953/5000 - loss value -7.765814e-02
# Epoch 4954/5000 - loss value -7.765823e-02
# Epoch 4955/5000 - loss value -7.765832e-02
# Epoch 4956/5000 - loss value -7.765840e-02
# Epoch 4957/5000 - loss value -7.765849e-02
# Epoch 4958/5000 - loss value -7.765858e-02
# Epoch 4959/5000 - loss value -7.765867e-02
# Epoch 4960/5000 - loss value -7.765876e-02
# Epoch 4961/5000 - loss value -7.765884e-02
# Epoch 4962/5000 - loss value -7.765893e-02
# Epoch 4963/5000 - loss value -7.765902e-02
# Epoch 4964/5000 - loss value -7.765911e-02
# Epoch 4965/5000 - loss value -7.765919e-02
# Epoch 4966/5000 - loss value -7.765928e-02
# Epoch 4967/5000 - loss value -7.765937e-02
# Epoch 4968/5000 - loss value -7.765945e-02
# Epoch 4969/5000 - loss value -7.765954e-02
# Epoch 4970/5000 - loss value -7.765963e-02
# Epoch 4971/5000 - loss value -7.765972e-02
# Epoch 4972/5000 - loss value -7.765980e-02
# Epoch 4973/5000 - loss value -7.765989e-02
# Epoch 4974/5000 - loss value -7.765998e-02
# Epoch 4975/5000 - loss value -7.766006e-02
# Epoch 4976/5000 - loss value -7.766015e-02
# Epoch 4977/5000 - loss value -7.766024e-02
# Epoch 4978/5000 - loss value -7.766032e-02
# Epoch 4979/5000 - loss value -7.766041e-02
# Epoch 4980/5000 - loss value -7.766050e-02
# Epoch 4981/5000 - loss value -7.766058e-02
# Epoch 4982/5000 - loss value -7.766067e-02
# Epoch 4983/5000 - loss value -7.766075e-02
# Epoch 4984/5000 - loss value -7.766084e-02
# Epoch 4985/5000 - loss value -7.766093e-02
# Epoch 4986/5000 - loss value -7.766101e-02
# Epoch 4987/5000 - loss value -7.766110e-02
# Epoch 4988/5000 - loss value -7.766119e-02
# Epoch 4989/5000 - loss value -7.766127e-02
# Epoch 4990/5000 - loss value -7.766136e-02
# Epoch 4991/5000 - loss value -7.766144e-02
# Epoch 4992/5000 - loss value -7.766153e-02
# Epoch 4993/5000 - loss value -7.766161e-02
# Epoch 4994/5000 - loss value -7.766170e-02
# Epoch 4995/5000 - loss value -7.766179e-02
# Epoch 4996/5000 - loss value -7.766187e-02
# Epoch 4997/5000 - loss value -7.766196e-02
# Epoch 4998/5000 - loss value -7.766204e-02
# Epoch 4999/5000 - loss value -7.766213e-02
# Epoch 5000/5000 - loss value -7.766221e-02
# Elapsed time  0:04:46.125282
#
# Elapsed time 0:04:46.125282

# %%
x,y = np.meshgrid(np.linspace(-1,1,100),np.linspace(-1,1,100))
ys = np.concatenate((x.flatten()[:,None],y.flatten()[:,None]),1)
xy1 = geom1(ys)
xy2 = geom2(ys)
xy3 = geom3(ys)
xy4 = geom4(ys)

u1 = model.solution1(weights, ys).reshape(x.shape)
u2 = model.solution2(weights, ys).reshape(x.shape)
u3 = model.solution3(weights, ys).reshape(x.shape)
u4 = model.solution4(weights, ys).reshape(x.shape)

plt.figure(figsize = (20,12))
ax = plt.gca()
plt.contourf(xy1[:,0].reshape(x.shape), xy1[:,1].reshape(x.shape), u1, levels = 100, vmin = min([u1.min(),u2.min(),u3.min(),u4.min()]), vmax = max([u1.max(),u2.max(),u3.max(),u4.max()]))
plt.contourf(xy2[:,0].reshape(x.shape), xy2[:,1].reshape(x.shape), u2, levels = 100, vmin = min([u1.min(),u2.min(),u3.min(),u4.min()]), vmax = max([u1.max(),u2.max(),u3.max(),u4.max()]))
plt.contourf(xy3[:,0].reshape(x.shape), xy3[:,1].reshape(x.shape), u3, levels = 100, vmin = min([u1.min(),u2.min(),u3.min(),u4.min()]), vmax = max([u1.max(),u2.max(),u3.max(),u4.max()]))
plt.contourf(xy4[:,0].reshape(x.shape), xy4[:,1].reshape(x.shape), u4, levels = 100, vmin = min([u1.min(),u2.min(),u3.min(),u4.min()]), vmax = max([u1.max(),u2.max(),u3.max(),u4.max()]))
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
# Out:
# Text(0, 0.5, '$x_2$')

# %%
fem = FEM(mu0=model.mu0,mur=model.mur,J0 = model.J0,meshsize = 0.0002)

u1_ref = fem.call_A(xy1[:,0],xy1[:,1]).reshape(x.shape)
u2_ref = fem.call_A(xy2[:,0],xy2[:,1]).reshape(x.shape)
u3_ref = fem.call_A(xy3[:,0],xy3[:,1]).reshape(x.shape)
u4_ref = fem.call_A(xy4[:,0],xy4[:,1]).reshape(x.shape)

plt.figure()
ax = plt.gca()
plt.contourf(xy1[:,0].reshape(x.shape), xy1[:,1].reshape(x.shape), u1_ref, levels = 100, vmin = min([u1_ref.min(),u2_ref.min(),u3_ref.min(),u4_ref.min()]), vmax = max([u1_ref.max(),u2_ref.max(),u3_ref.max(),u4_ref.max()]))
plt.contourf(xy2[:,0].reshape(x.shape), xy2[:,1].reshape(x.shape), u2_ref, levels = 100, vmin = min([u1_ref.min(),u2_ref.min(),u3_ref.min(),u4_ref.min()]), vmax = max([u1_ref.max(),u2_ref.max(),u3_ref.max(),u4_ref.max()]))
plt.contourf(xy3[:,0].reshape(x.shape), xy3[:,1].reshape(x.shape), u3_ref, levels = 100, vmin = min([u1_ref.min(),u2_ref.min(),u3_ref.min(),u4_ref.min()]), vmax = max([u1_ref.max(),u2_ref.max(),u3_ref.max(),u4_ref.max()]))
plt.contourf(xy4[:,0].reshape(x.shape), xy4[:,1].reshape(x.shape), u4_ref, levels = 100, vmin = min([u1_ref.min(),u2_ref.min(),u3_ref.min(),u4_ref.min()]), vmax = max([u1_ref.max(),u2_ref.max(),u3_ref.max(),u4_ref.max()]))
plt.colorbar()

delta1 = np.abs(u1-u1_ref)
delta2 = np.abs(u2-u2_ref)
delta3 = np.abs(u3-u3_ref)
delta4 = np.abs(u4-u4_ref)

plt.figure()
ax = plt.gca()
plt.contourf(xy2[:,0].reshape(x.shape), xy2[:,1].reshape(x.shape), delta2, levels = 100, vmin = min([delta1.min(),delta2.min(),delta3.min(),delta4.min()]), vmax = max([delta1.max(),delta2.max(),delta3.max(),delta4.max()]))
plt.contourf(xy3[:,0].reshape(x.shape), xy3[:,1].reshape(x.shape), delta3, levels = 100, vmin = min([delta1.min(),delta2.min(),delta3.min(),delta4.min()]), vmax = max([delta1.max(),delta2.max(),delta3.max(),delta4.max()]))
plt.contourf(xy4[:,0].reshape(x.shape), xy4[:,1].reshape(x.shape), delta4, levels = 100, vmin = min([delta1.min(),delta2.min(),delta3.min(),delta4.min()]), vmax = max([delta1.max(),delta2.max(),delta3.max(),delta4.max()]))
plt.contourf(xy1[:,0].reshape(x.shape), xy1[:,1].reshape(x.shape), delta1, levels = 100, vmin = min([delta1.min(),delta2.min(),delta3.min(),delta4.min()]), vmax = max([delta1.max(),delta2.max(),delta3.max(),delta4.max()]))
plt.colorbar()
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
print(max([np.max(delta1),np.max(delta2),np.max(delta3),np.max(delta4)]))

# %%
xs1 = geom1(model.points['ys1'])
xs2 = geom2(model.points['ys2'])
xs3 = geom3(model.points['ys3'])
xs4 = geom4(model.points['ys4'])

u1_ref = fem.call_A(xs1[:,0],xs1[:,1]).flatten()
u2_ref = fem.call_A(xs2[:,0],xs2[:,1]).flatten()
u3_ref = fem.call_A(xs3[:,0],xs3[:,1]).flatten()
u4_ref = fem.call_A(xs4[:,0],xs4[:,1]).flatten()

u1 = model.solution1(weights, model.points['ys1']).flatten()
u2 = model.solution2(weights, model.points['ys2']).flatten()
u3 = model.solution3(weights, model.points['ys3']).flatten()
u4 = model.solution4(weights, model.points['ys4']).flatten()

int1 = jnp.dot((u1-u1_ref)**2,model.points['omega1']*model.points['ws1']) / jnp.dot((u1_ref)**2,model.points['omega1']*model.points['ws1'])
int2 = jnp.dot((u2-u2_ref)**2,model.points['omega2']*model.points['ws2']) / jnp.dot((u2_ref)**2,model.points['omega2']*model.points['ws2'])
int3 = jnp.dot((u3-u3_ref)**2,model.points['omega3']*model.points['ws3']) / jnp.dot((u3_ref)**2,model.points['omega3']*model.points['ws3'])
int4 = jnp.dot((u4-u4_ref)**2,model.points['omega4']*model.points['ws4']) / jnp.dot((u4_ref)**2,model.points['omega4']*model.points['ws4'])

print(int1, int2, int3, int4)

# %%
print(np.mean(delta1)/np.max(u1))
print('Surface copper', np.sum(model.points['omega3']*model.points['ws3']))
print('J0 ',50/np.sum(model.points['omega3']*model.points['ws3'])*24)

# %%
plt.figure()
plt.scatter(xs1[:,0],xs1[:,1], s= 1)
plt.scatter(xs2[:,0],xs2[:,1], s= 1)
plt.scatter(xs3[:,0],xs3[:,1], s= 1)
plt.scatter(xs4[:,0],xs4[:,1], s= 1)

plt.figure()
fn.plot(fem.mesh)

# %%
plt.figure()
t = np.linspace(-1,1,1000).reshape([-1,1])
plt.plot(t.flatten(),model.solution3(weights,np.concatenate((t*0+1,t),-1)))

xy = geom3(np.concatenate((t*0+1,t),-1))
plt.plot(t.flatten(),fem.call_A(xy[:,0],xy[:,1]))
plt.legend(['PINN', 'FEM'])

# %%
model.points['ys1'].max(), np.sum(model.points['ys1'][:,1]*model.points['ws1'])
jax.devices()[0]
print(model.points['ws1'].shape)
print(np.sum(model.points['ws3']))
print(model.weights['u13'])
