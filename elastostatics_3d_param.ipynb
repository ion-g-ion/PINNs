# %% [markdown]
# # 3d elastostatics
#
# Imports:

# %%
import os 
os.environ['XLA_PYTHON_CLIENT_ALLOCATOR'] = 'platform'
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'
import numpy as np

import jax
import jax.numpy as jnp
from jax.example_libraries import stax, optimizers
import matplotlib.pyplot as plt
import pinns 
import datetime
import jax.scipy.optimize
import jax.flatten_util
import scipy
import scipy.optimize

# %% [markdown]
# Convince JAX to use `float64` and create the random key.

# %%
from jax.config import config
config.update("jax_enable_x64", True)
rnd_key = jax.random.PRNGKey(1234)

# %% [markdown]
# ### Geometry construction
#
# The domain consists of 4 subdomains parametrized using NURBS.

# %%
def create_geometry(key, scale = 1):
    R = 2
    r = 1
    Rp = 2
    d = 0.5
    
    knots = np.array( [ [[[r,0,0], [r,0,r], [0,0,r]], [[r,d,0], [r,d,r], [0,d,r]]], [[[R,0,0], [R,0,R], [0,0,R]], [[R,d,0], [R,d,R], [0,d,R]]] ])
    weights = np.ones(knots.shape[:3])
    weights[:,:,1] = 1/np.sqrt(2)
    
    basis1 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),1)
    basis2 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),1)
    basis3 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),2)

    geom1 = pinns.geometry.PatchNURBSParam([basis1, basis2, basis3], knots, weights, 0, 3, key)
    
    knots = np.array( [[[[0,0,r],[-(R-r),0,r]], [[0,d,r],[-(R-r),d,r]]], [[[0,0,R],[-(R-r),0,R]], [[0,d,R],[-(R-r),d,R]]]] )
    weights = np.ones(knots.shape[:3])
    
    basis1 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),1)
    basis2 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),1)
    basis3 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),1)

    geom2 = pinns.geometry.PatchNURBSParam([basis1, basis2, basis3], knots, weights, 0, 3, key)
    
    knots = np.array( [[[[r+Rp,-R,r], [-(R-r),-R,r], [-(R-r),0,r]], [[r+Rp,-r,r], [0,-r,r], [0,0,r]]], [[[r+Rp,-R,R], [-(R-r),-R,R], [-(R-r),0,R]], [[r+Rp,-r,R], [0,-r,R], [0,0,R]]]] )
    knots = np.transpose(knots,[0,2,1,3])
    knots = knots[:,:,::-1,:]
    weights = np.ones(knots.shape[:3])
    weights[:,1,:] = 1/np.sqrt(2)
    
    basis1 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),1)
    basis3 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),1)
    basis2 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),2)

    geom3 = pinns.geometry.PatchNURBSParam([basis1, basis2, basis3], knots, weights, 0, 3, key)
    
    
    knots = np.array( [[[[r+Rp,R+d,r], [-(R-r),R+d,r], [-(R-r),d,r]], [[r+Rp,r+d,r], [0,r+d,r], [0,d,r]]], [[[r+Rp,R+d,R], [-(R-r),R+d,R], [-(R-r),d,R]], [[r+Rp,r+d,R], [0,r+d,R], [0,d,R]]]] )
    knots = np.transpose(knots,[0,2,1,3])
    knots = knots[:,::-1,...]
    knots = knots[:,:,::-1,:]
    weights = np.ones(knots.shape[:3])
    weights[:,1,:] = 1/np.sqrt(2)
    
    
    basis1 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),1)
    basis2 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),2)
    basis3 = pinns.bspline.BSplineBasisJAX(np.array([-1,1]),1)

    geom4 = pinns.geometry.PatchNURBSParam([basis1, basis2, basis3], knots, weights, 0, 3, key)
    
    return  geom1, geom2, geom3, geom4

# %% [markdown]
# Display the geometry. First, some random points are plotted and then the axis of the reference domains are shown in the physical domain.

# %%
geom1, geom2, geom3, geom4 = create_geometry(rnd_key)
geoms = [geom1, geom2, geom3, geom4]

pts1,_ = geom1.importance_sampling(1000)
pts2,_ = geom2.importance_sampling(1000)
pts3,_ = geom3.importance_sampling(1000)
pts4,_ = geom4.importance_sampling(1000)

plt.figure(figsize=(7,7))
ax = plt.axes(projection ="3d")
ax.scatter3D(pts1[:,0], pts1[:,1], pts1[:,2], s = 1)
ax.scatter3D(pts2[:,0], pts2[:,1], pts2[:,2], s = 1)
ax.scatter3D(pts3[:,0], pts3[:,1], pts3[:,2], s = 1)
ax.scatter3D(pts4[:,0], pts4[:,1], pts4[:,2], s = 1)
ax.axes.set_xlim3d(-1,3)
ax.axes.set_ylim3d(-2,2)
ax.axes.set_zlim3d(0,2)
ax.view_init(45,45)

yspace= np.linspace(-1,-0.5,100)

plt.figure(figsize=(7,7))
ax = plt.axes(projection ="3d")
for g in geoms:
    ys = np.concatenate((yspace[...,None], yspace[...,None]*0-1, yspace[...,None]*0-1),-1)
    Xs = g(ys)
    ax.plot(Xs[:,0], Xs[:,1], Xs[:,2],'red')
    
    ys = np.concatenate((yspace[...,None]*0-1, yspace[...,None], yspace[...,None]*0-1),-1)
    Xs = g(ys)
    ax.plot(Xs[:,0], Xs[:,1], Xs[:,2],'green')
    
    ys = np.concatenate((yspace[...,None]*0-1, yspace[...,None]*0-1, yspace[...,None]),-1)
    Xs = g(ys)
    ax.plot(Xs[:,0], Xs[:,1], Xs[:,2],'blue')
    
ax.axes.set_xlim3d(-1,3)
ax.axes.set_ylim3d(-2,2)
ax.axes.set_zlim3d(0,2)
ax.view_init(45,45)

# %% [markdown]
# ### Construct the neural network model
#
# For every of the 4 subdomain, a neural network is used. Moreover, for the 3 interfaces, additional neural networks are defined.

# %%
def interface_function3d(nd, endpositive, endzero, nn):

    faux = lambda x: ((x-endzero)**1/(endpositive-endzero)**1)
    if nd == 0:
        fret = lambda ws, x, *params: (nn(ws, jnp.concatenate((x[...,1][...,None],x[...,2][...,None]),-1), *params)*faux(x[...,0])[...,None])
    elif nd==1:
        fret = lambda ws, x, *params: (nn(ws, jnp.concatenate((x[...,0][...,None],x[...,2][...,None]),-1), *params)*faux(x[...,1])[...,None])
    elif nd==2:
        fret = lambda ws, x, *params: (nn(ws, jnp.concatenate((x[...,0][...,None],x[...,1][...,None]),-1), *params)*faux(x[...,2])[...,None])
    else: 
        raise Exception("nd must be 0,1 or 2.")
    return fret

def interface_function1d(dembedding: int, dim: int, zeros: list[int], ones: list[int], nn: callable, alpha: float = 1.0) -> callable:

    faux = lambda y,one,zero: ((y-zero)**alpha/(one-zero)**alpha)

    if dembedding==3:
        dims = list(set(range(dembedding)) - {dim})
        fret = lambda ws, x, *params: (nn(ws, x[...,dim][...,None], *params)*faux(x[...,dims[0]],ones[0],zeros[0])[...,None]*faux(x[...,dims[1]],ones[1],zeros[1])[...,None])

    return fret


def jump_function3d(nd, pos_y, nn):

    faux = lambda x: jnp.exp(-4.0*jnp.abs(x-pos_y))
    if nd == 1:
        fret = lambda ws, x: (nn(ws, x[...,1][...,None]).flatten()*faux(x[...,0]))[...,None]
    else:
        fret = lambda ws, x: (nn(ws, x[...,0][...,None]).flatten()*faux(x[...,1]))[...,None]
    return fret

def monom(x: jax.numpy.array, d: int, bound: float, deg: float = 1.0, out_dims: int = 1):
    return jnp.tile(((x[...,d]-bound)**deg)[...,None],out_dims)

# def ExpHat(hidden_size, out_dim, W_init=glorot_normal(), b_init=normal()):
#   """Layer constructor function for a dense (fully-connected) layer."""
#   def init_fun(rng, input_shape):
#     output_shape = input_shape[:-1] + (out_dim,)
#     k1, k2 = random.split(rng)
#     W, b = W_init(k1, (input_shape[-1], out_dim)), b_init(k2, (out_dim,))
#     return output_shape, (W, b)
#   def apply_fun(params, inputs, **kwargs):
#     b, b = params
#     return jnp.dot(inputs, W) + b
#   return init_fun, apply_fun
def ExpHat(x, scale = 0.1):
    return jnp.exp(-jnp.abs(x)/scale)

class Model(pinns.PINN):
    def __init__(self, rand_key):
        super().__init__()
        self.key = rand_key

        nl = 10
        NP = 6
        acti =  stax.elementwise(lambda x: jax.nn.leaky_relu(x)**2)

        w_init = jax.nn.initializers.normal()
        
        block_first = stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(nl,W_init = w_init), acti, stax.Dense(nl,W_init = w_init), acti),stax.Dense(nl,W_init = w_init)),stax.FanInSum)
        block_first = stax.serial(stax.FanInConcat(),stax.Dense(nl, W_init = w_init,b_init=jax.nn.initializers.zeros),acti)
        block = stax.serial(stax.FanOut(2),stax.parallel(stax.serial(stax.Dense(nl,W_init = w_init), acti, stax.Dense(nl,W_init = w_init), acti),stax.Dense(nl,W_init = w_init)),stax.FanInSum)
        
        self.add_neural_network_param('u1',stax.serial(block_first,block,block, block, stax.Dense(3)), ((-1,3),(-1,NP))) # leg
        self.add_neural_network_param('u2',stax.serial(block_first,block,block, block, stax.Dense(3)), ((-1,3),(-1,NP))) # split
        self.add_neural_network_param('u3',stax.serial(block_first,block,block, block, stax.Dense(3)), ((-1,3),(-1,NP))) # arm left
        self.add_neural_network_param('u4',stax.serial(block_first,block,block, block, stax.Dense(3)), ((-1,3),(-1,NP))) # arm right
        self.add_neural_network_param('u12',stax.serial(block_first,block,block, block, stax.Dense(3)),((-1,2),(-1,NP))) 
        self.add_neural_network_param('u23',stax.serial(block_first,block,block, block, stax.Dense(3)),((-1,2),(-1,NP))) 
        self.add_neural_network_param('u24',stax.serial(block_first,block,block, block, stax.Dense(3)),((-1,2),(-1,NP))) 
        
        self.interface12 = interface_function3d(2, 1.0, -1.0, self.neural_networks['u12'])
        self.interface21 = interface_function3d(2, -1.0, 1.0, self.neural_networks['u12'])
        self.interface123 = interface_function1d(3, 0, [-1,1],[1,-1], lambda ws, y, *extra: self.neural_networks['u12'](ws, jnp.concatenate((y,y*0-1),-1), *extra))
        self.interface124 = interface_function1d(3, 0, [1,1],[-1,-1], lambda ws, y, *extra: self.neural_networks['u12'](ws, jnp.concatenate((y,y*0+1),-1), *extra))

        self.interface23 = interface_function3d(1, -1.0, 1.0, self.neural_networks['u23'])
        self.interface32 = interface_function3d(1, 1.0, -1.0, self.neural_networks['u23'])
        self.interface231 = interface_function1d(3, 0, [1,-1],[-1,1], lambda ws, y, *extra: self.neural_networks['u23'](ws, jnp.concatenate((y,y*0-1),-1), *extra))

        self.interface24 = interface_function3d(1, 1.0, -1.0, self.neural_networks['u24'])
        self.interface42 = interface_function3d(1, -1.0, 1.0, self.neural_networks['u24'])
        self.interface241 = interface_function1d(3, 0, [-1,-1],[1,1], lambda ws, y, *extra: self.neural_networks['u24'](ws, jnp.concatenate((y,y*0-1),-1), *extra))

        self.points = self.get_points_MC(10000, self.key)
        
        E = 0.02e5
        nu = 0.1
        self.E = E
        self.nu = nu
        
        self.lamda = E*nu/(1+nu)/(1-2*nu)
        self.mu = E/2/(1+nu)
        
        rho = 0.1
        g = 9.81
        self.rho = rho
        
        self.f = np.array([0,0,-g*rho])
        
        
    def get_points_MC(self, N, key):        

        points = {}

        NP = 6

        ys = jax.random.uniform(key ,(N,3))*2-1
        Weights = jnp.ones((N,))*4/ys.shape[0]
        ps = jax.random.uniform(key ,(N,NP))*2-1
        
        # ys = np.array(jax.random.uniform(self.key, (N,2)))*2-1
        # Weights = jnp.ones((N,))*4/ys.shape[0]

        points['ps'] = ps
        
        points['ys1'] = ys
        points['ws1'] = Weights
        points['omega1'], points['G1'], points['K1'] = geom1.GetMetricTensors(ys,ps)
       
        points['ys2'] = ys
        points['ws2'] = Weights
        points['omega2'], points['G2'], points['K2'] = geom2.GetMetricTensors(ys,ps)
        
        points['ys3'] = ys
        points['ws3'] = Weights
        points['omega3'], points['G3'], points['K3'] = geom3.GetMetricTensors(ys,ps)
        
        points['ys4'] = ys
        points['ws4'] = Weights
        points['omega4'], points['G4'], points['K4'] = geom4.GetMetricTensors(ys,ps)

        return points


    def solution1(self, ws, y, ps):
        # iron
        u = self.neural_networks['u1'](ws['u1'],y,ps)
        v = monom(y,2,-1,out_dims = 3)*monom(y,2,1, out_dims = 3)
        w = self.interface12(ws['u12'],y,ps)+self.interface231(ws['u23'], y, ps)+self.interface241(ws['u24'], y, ps)
        
        return u*v+w

    def solution2(self, ws, y, ps):
        # iron
        u = self.neural_networks['u2'](ws['u2'],y, ps)
        v = monom(y,1,-1,out_dims = 3)*monom(y,1,1, out_dims = 3)*monom(y,2,-1, out_dims = 3)
        w =   self.interface21(ws['u12'],y, ps)+self.interface23(ws['u23'],y, ps)+self.interface24(ws['u24'],y, ps)
        
        
        return u*v+w

    def solution3(self, ws, y, ps):
        # iron
        u = self.neural_networks['u3'](ws['u3'],y, ps)
        v = monom(y,1,1,out_dims = 3)
        w = self.interface32(ws['u23'],y, ps)+self.interface123(ws['u12'], y, ps)
        
        return u*v+w
    
    def solution4(self, ws, y, ps):
        # iron
        u = self.neural_networks['u4'](ws['u4'],y, ps)
        v = monom(y,1,-1,out_dims = 3)
        w = self.interface42(ws['u24'],y, ps)+self.interface124(ws['u12'], y, ps)
        
        return u*v+w


    def loss_pde(self, ws, points):
        jacs1 = pinns.operators.jacobian(lambda x,p : self.solution1(ws,x,p))(points['ys1'], points['ps'])
        jacs2 = pinns.operators.jacobian(lambda x,p : self.solution2(ws,x,p))(points['ys2'], points['ps'])
        jacs3 = pinns.operators.jacobian(lambda x,p : self.solution3(ws,x,p))(points['ys3'], points['ps'])
        jacs4 = pinns.operators.jacobian(lambda x,p : self.solution4(ws,x,p))(points['ys4'], points['ps'])
        
        jacs_x1 = jnp.einsum('mij,mjk->mik', jacs1, points['G1'])
        jacs_x2 = jnp.einsum('mij,mjk->mik', jacs2, points['G2'])
        jacs_x3 = jnp.einsum('mij,mjk->mik', jacs3, points['G3'])
        jacs_x4 = jnp.einsum('mij,mjk->mik', jacs4, points['G4'])

        divs_x1 = (jacs_x1[...,0,0] + jacs_x1[...,1,1] + jacs_x1[...,2,2])[...,None]
        divs_x2 = (jacs_x2[...,0,0] + jacs_x2[...,1,1] + jacs_x2[...,2,2])[...,None]
        divs_x3 = (jacs_x3[...,0,0] + jacs_x3[...,1,1] + jacs_x3[...,2,2])[...,None]
        divs_x4 = (jacs_x4[...,0,0] + jacs_x4[...,1,1] + jacs_x4[...,2,2])[...,None]
        
        strain1 = 0.5 * (jacs_x1 + jnp.transpose(jacs_x1,[0,2,1]))
        strain2 = 0.5 * (jacs_x2 + jnp.transpose(jacs_x2,[0,2,1]))
        strain3 = 0.5 * (jacs_x3 + jnp.transpose(jacs_x3,[0,2,1]))
        strain4 = 0.5 * (jacs_x4 + jnp.transpose(jacs_x4,[0,2,1]))
        
        stress1 = self.lamda * (1+points['ps'][...,0]*0.1)[...,None,None] * jnp.einsum('ij,jkl->ikl', divs_x1, jnp.eye(3)[None,...]) + 2 * self.mu * (1+points['ps'][...,1]*0.1)[...,None,None] * strain1
        stress2 = self.lamda * (1+points['ps'][...,0]*0.1)[...,None,None] * jnp.einsum('ij,jkl->ikl', divs_x2, jnp.eye(3)[None,...]) + 2 * self.mu * (1+points['ps'][...,1]*0.1)[...,None,None] * strain2
        stress3 = self.lamda * (1+points['ps'][...,2]*0.1)[...,None,None] * jnp.einsum('ij,jkl->ikl', divs_x3, jnp.eye(3)[None,...]) + 2 * self.mu * (1+points['ps'][...,3]*0.1)[...,None,None] * strain3
        stress4 = self.lamda * (1+points['ps'][...,4]*0.1)[...,None,None] * jnp.einsum('ij,jkl->ikl', divs_x4, jnp.eye(3)[None,...]) + 2 * self.mu * (1+points['ps'][...,5]*0.1)[...,None,None] * strain4
        
        

        a1 = 0.5*jnp.dot(jnp.einsum('mij,mij->m', stress1, strain1), points['ws1'] * points['omega1']) 
        a2 = 0.5*jnp.dot(jnp.einsum('mij,mij->m', stress2, strain2), points['ws2'] * points['omega2']) 
        a3 = 0.5*jnp.dot(jnp.einsum('mij,mij->m', stress3, strain3), points['ws3'] * points['omega3']) 
        a4 = 0.5*jnp.dot(jnp.einsum('mij,mij->m', stress4, strain4), points['ws4'] * points['omega4']) 
        rhs1 = jnp.dot(jnp.einsum('k,mk->m', self.f, self.solution1(ws,points['ys1'], points['ps'])), points['omega1'] * points['ws1'])
        rhs2 = jnp.dot(jnp.einsum('k,mk->m', self.f, self.solution2(ws,points['ys2'], points['ps'])), points['omega2'] * points['ws2'])
        rhs3 = jnp.dot(jnp.einsum('k,mk->m', self.f, self.solution3(ws,points['ys3'], points['ps'])), points['omega3'] * points['ws3'])
        rhs4 = jnp.dot(jnp.einsum('k,mk->m', self.f, self.solution4(ws,points['ys4'], points['ps'])), points['omega4'] * points['ws4'])
        
        return a1+a2+a3+a4-rhs1-rhs2-rhs3-rhs4

    def loss(self, ws, pts):
        lpde = self.loss_pde(ws, pts)
        return lpde

# %% [markdown]
# ### Train the model
#
# The user can choose between the ADAM and the LBFGS optimizers by setting the `opt_type` variable.

# %%
rnd_key = jax.random.PRNGKey(1235)
model = Model(rnd_key)
w0 = model.init_unravel()
weights = model.weights 

dev = jax.devices('gpu')[1]

# loss_compiled = jax.jit(model.loss_handle, device = jax.devices()[0])
# lossgrad_compiled = jax.jit(model.lossgrad_handle, device = jax.devices()[0])
# 
# def loss_grad(w):
#     l, gr = lossgrad_compiled(jnp.array(w))
#     return np.array( l.to_py() ), np.array( gr.to_py() )



batch_size = 10000

get_compiled = jax.jit(lambda key: model.get_points_MC(batch_size, key), device = dev)
# %time pts = get_compiled(jax.random.PRNGKey(1235))
# %time pts = get_compiled(jax.random.PRNGKey(1111))

lr_opti = optimizers.piecewise_constant([2000,4000,6000,8000,12000], [0.01, 0.005, 0.001, 0.0005,0.0001,0.00001])
opt_init, opt_update, get_params = optimizers.adam(lr_opti)

opt_state = opt_init(weights)

# get initial parameters
params = get_params(opt_state)

loss_grad = jax.jit(lambda ws, pts: (model.loss(ws, pts), jax.grad(model.loss)(ws, pts)), device = dev)

def step(params, opt_state, key):
    # points = model.get_points_MC(5000)
    points = model.get_points_MC(batch_size, key)
    loss, grads = loss_grad(params, points)
    opt_state = opt_update(0, grads, opt_state)

    params = get_params(opt_state)
    
    return params, opt_state, loss

step_compiled = jax.jit(step, device = dev)
step_compiled(params, opt_state, rnd_key)

n_epochs = 5000

hist = []

tme = datetime.datetime.now()
for k in range(n_epochs):    
    params, opt_state, loss = step_compiled(params, opt_state, jax.random.PRNGKey(np.random.randint(32131233123)))
    
    hist.append(loss)
    
    print('Epoch %d/%d - loss value %e'%(k+1, n_epochs, loss))
# update params
model.weights = params
weights = params
tme = datetime.datetime.now() - tme
print('Elapsed time ', tme)
# Out:
# CPU times: user 29.9 s, sys: 307 ms, total: 30.2 s
# Wall time: 26.4 s
# CPU times: user 12.4 ms, sys: 0 ns, total: 12.4 ms
# Wall time: 11.2 ms
# Epoch 1/5000 - loss value 6.480821e+00
# Epoch 2/5000 - loss value 1.772240e+01
# Epoch 3/5000 - loss value 2.271715e+01
# Epoch 4/5000 - loss value 9.652979e+00
# Epoch 5/5000 - loss value 7.040941e+00
# Epoch 6/5000 - loss value 9.183461e+00
# Epoch 7/5000 - loss value 2.623694e+00
# Epoch 8/5000 - loss value 7.671777e+00
# Epoch 9/5000 - loss value 2.716477e+00
# Epoch 10/5000 - loss value 2.632055e+00
# Epoch 11/5000 - loss value 4.416726e+00
# Epoch 12/5000 - loss value 2.548229e+00
# Epoch 13/5000 - loss value 1.592962e+00
# Epoch 14/5000 - loss value 1.732726e+00
# Epoch 15/5000 - loss value 1.993932e+00
# Epoch 16/5000 - loss value 1.580386e+00
# Epoch 17/5000 - loss value 1.137125e+00
# Epoch 18/5000 - loss value 9.194421e-01
# Epoch 19/5000 - loss value 8.377336e-01
# Epoch 20/5000 - loss value 1.028506e+00
# Epoch 21/5000 - loss value 8.800015e-01
# Epoch 22/5000 - loss value 4.695822e-01
# Epoch 23/5000 - loss value 4.362845e-01
# Epoch 24/5000 - loss value 6.085962e-01
# Epoch 25/5000 - loss value 5.142270e-01
# Epoch 26/5000 - loss value 2.285515e-01
# Epoch 27/5000 - loss value 2.181768e-01
# Epoch 28/5000 - loss value 3.576271e-01
# Epoch 29/5000 - loss value 3.320885e-01
# Epoch 30/5000 - loss value 1.900228e-01
# Epoch 31/5000 - loss value 9.459774e-02
# Epoch 32/5000 - loss value 9.803091e-02
# Epoch 33/5000 - loss value 1.416451e-01
# Epoch 34/5000 - loss value 1.694828e-01
# Epoch 35/5000 - loss value 1.069234e-01
# Epoch 36/5000 - loss value 4.555623e-03
# Epoch 37/5000 - loss value 6.313307e-03
# Epoch 38/5000 - loss value 6.142083e-02
# Epoch 39/5000 - loss value 7.097105e-02
# Epoch 40/5000 - loss value 1.402552e-02
# Epoch 41/5000 - loss value -2.862223e-02
# Epoch 42/5000 - loss value -1.485023e-02
# Epoch 43/5000 - loss value 3.858765e-03
# Epoch 44/5000 - loss value -1.337587e-03
# Epoch 45/5000 - loss value -1.912699e-02
# Epoch 46/5000 - loss value -3.553328e-02
# Epoch 47/5000 - loss value -4.815017e-02
# Epoch 48/5000 - loss value -4.546476e-02
# Epoch 49/5000 - loss value -3.747637e-02
# Epoch 50/5000 - loss value -3.503679e-02
# Epoch 51/5000 - loss value -4.672902e-02
# Epoch 52/5000 - loss value -6.048795e-02
# Epoch 53/5000 - loss value -6.023571e-02
# Epoch 54/5000 - loss value -5.598506e-02
# Epoch 55/5000 - loss value -5.590052e-02
# Epoch 56/5000 - loss value -6.002829e-02
# Epoch 57/5000 - loss value -6.269832e-02
# Epoch 58/5000 - loss value -6.376222e-02
# Epoch 59/5000 - loss value -6.757037e-02
# Epoch 60/5000 - loss value -6.817741e-02
# Epoch 61/5000 - loss value -6.693879e-02
# Epoch 62/5000 - loss value -6.790862e-02
# Epoch 63/5000 - loss value -7.050413e-02
# Epoch 64/5000 - loss value -7.213279e-02
# Epoch 65/5000 - loss value -7.146561e-02
# Epoch 66/5000 - loss value -7.233673e-02
# Epoch 67/5000 - loss value -7.424886e-02
# Epoch 68/5000 - loss value -7.548902e-02
# Epoch 69/5000 - loss value -7.456516e-02
# Epoch 70/5000 - loss value -7.453476e-02
# Epoch 71/5000 - loss value -7.559375e-02
# Epoch 72/5000 - loss value -7.694957e-02
# Epoch 73/5000 - loss value -7.763504e-02
# Epoch 74/5000 - loss value -7.835548e-02
# Epoch 75/5000 - loss value -7.857436e-02
# Epoch 76/5000 - loss value -7.886427e-02
# Epoch 77/5000 - loss value -7.859858e-02
# Epoch 78/5000 - loss value -7.909895e-02
# Epoch 79/5000 - loss value -7.962827e-02
# Epoch 80/5000 - loss value -8.009492e-02
# Epoch 81/5000 - loss value -8.008932e-02
# Epoch 82/5000 - loss value -8.065730e-02
# Epoch 83/5000 - loss value -8.098444e-02
# Epoch 84/5000 - loss value -8.088738e-02
# Epoch 85/5000 - loss value -8.119821e-02
# Epoch 86/5000 - loss value -8.124926e-02
# Epoch 87/5000 - loss value -8.266515e-02
# Epoch 88/5000 - loss value -8.210646e-02
# Epoch 89/5000 - loss value -8.248528e-02
# Epoch 90/5000 - loss value -8.349364e-02
# Epoch 91/5000 - loss value -8.285755e-02
# Epoch 92/5000 - loss value -8.320300e-02
# Epoch 93/5000 - loss value -8.378336e-02
# Epoch 94/5000 - loss value -8.354949e-02
# Epoch 95/5000 - loss value -8.418256e-02
# Epoch 96/5000 - loss value -8.402917e-02
# Epoch 97/5000 - loss value -8.430741e-02
# Epoch 98/5000 - loss value -8.531967e-02
# Epoch 99/5000 - loss value -8.486927e-02
# Epoch 100/5000 - loss value -8.583677e-02
# Epoch 101/5000 - loss value -8.550620e-02
# Epoch 102/5000 - loss value -8.580686e-02
# Epoch 103/5000 - loss value -8.616012e-02
# Epoch 104/5000 - loss value -8.581928e-02
# Epoch 105/5000 - loss value -8.672295e-02
# Epoch 106/5000 - loss value -8.700955e-02
# Epoch 107/5000 - loss value -8.795400e-02
# Epoch 108/5000 - loss value -8.865373e-02
# Epoch 109/5000 - loss value -8.858566e-02
# Epoch 110/5000 - loss value -8.965456e-02
# Epoch 111/5000 - loss value -8.857026e-02
# Epoch 112/5000 - loss value -8.719033e-02
# Epoch 113/5000 - loss value -9.037346e-02
# Epoch 114/5000 - loss value -9.039819e-02
# Epoch 115/5000 - loss value -9.053945e-02
# Epoch 116/5000 - loss value -9.281321e-02
# Epoch 117/5000 - loss value -9.191911e-02
# Epoch 118/5000 - loss value -9.464969e-02
# Epoch 119/5000 - loss value -9.651038e-02
# Epoch 120/5000 - loss value -9.648853e-02
# Epoch 121/5000 - loss value -9.856505e-02
# Epoch 122/5000 - loss value -1.001207e-01
# Epoch 123/5000 - loss value -1.004257e-01
# Epoch 124/5000 - loss value -9.965547e-02
# Epoch 125/5000 - loss value -8.827733e-02
# Epoch 126/5000 - loss value -7.716447e-02
# Epoch 127/5000 - loss value -1.025160e-01
# Epoch 128/5000 - loss value -9.112143e-02
# Epoch 129/5000 - loss value -1.030823e-01
# Epoch 130/5000 - loss value -9.835538e-02
# Epoch 131/5000 - loss value -1.012547e-01
# Epoch 132/5000 - loss value -1.031771e-01
# Epoch 133/5000 - loss value -1.037505e-01
# Epoch 134/5000 - loss value -1.016839e-01
# Epoch 135/5000 - loss value -1.070922e-01
# Epoch 136/5000 - loss value -1.055387e-01
# Epoch 137/5000 - loss value -1.064802e-01
# Epoch 138/5000 - loss value -1.083866e-01
# Epoch 139/5000 - loss value -1.095538e-01
# Epoch 140/5000 - loss value -1.107144e-01
# Epoch 141/5000 - loss value -1.110403e-01
# Epoch 142/5000 - loss value -1.145084e-01
# Epoch 143/5000 - loss value -1.132796e-01
# Epoch 144/5000 - loss value -1.149858e-01
# Epoch 145/5000 - loss value -1.155825e-01
# Epoch 146/5000 - loss value -1.177097e-01
# Epoch 147/5000 - loss value -1.188406e-01
# Epoch 148/5000 - loss value -1.203086e-01
# Epoch 149/5000 - loss value -1.210598e-01
# Epoch 150/5000 - loss value -1.210357e-01
# Epoch 151/5000 - loss value -1.214375e-01
# Epoch 152/5000 - loss value -1.240145e-01
# Epoch 153/5000 - loss value -1.227110e-01
# Epoch 154/5000 - loss value -1.255592e-01
# Epoch 155/5000 - loss value -1.276004e-01
# Epoch 156/5000 - loss value -1.273322e-01
# Epoch 157/5000 - loss value -1.286595e-01
# Epoch 158/5000 - loss value -1.277537e-01
# Epoch 159/5000 - loss value -1.299288e-01
# Epoch 160/5000 - loss value -1.284696e-01
# Epoch 161/5000 - loss value -1.312249e-01
# Epoch 162/5000 - loss value -1.315783e-01
# Epoch 163/5000 - loss value -1.300301e-01
# Epoch 164/5000 - loss value -1.334718e-01
# Epoch 165/5000 - loss value -1.344935e-01
# Epoch 166/5000 - loss value -1.352416e-01
# Epoch 167/5000 - loss value -1.335430e-01
# Epoch 168/5000 - loss value -1.356363e-01
# Epoch 169/5000 - loss value -1.363657e-01
# Epoch 170/5000 - loss value -1.361623e-01
# Epoch 171/5000 - loss value -1.379386e-01
# Epoch 172/5000 - loss value -1.375605e-01
# Epoch 173/5000 - loss value -1.392549e-01
# Epoch 174/5000 - loss value -1.405411e-01
# Epoch 175/5000 - loss value -1.416056e-01
# Epoch 176/5000 - loss value -1.405411e-01
# Epoch 177/5000 - loss value -1.423504e-01
# Epoch 178/5000 - loss value -1.428247e-01
# Epoch 179/5000 - loss value -1.419116e-01
# Epoch 180/5000 - loss value -1.429834e-01
# Epoch 181/5000 - loss value -1.458564e-01
# Epoch 182/5000 - loss value -1.461792e-01
# Epoch 183/5000 - loss value -1.486613e-01
# Epoch 184/5000 - loss value -1.467058e-01
# Epoch 185/5000 - loss value -1.488277e-01
# Epoch 186/5000 - loss value -1.479908e-01
# Epoch 187/5000 - loss value -1.503920e-01
# Epoch 188/5000 - loss value -1.516391e-01
# Epoch 189/5000 - loss value -1.493736e-01
# Epoch 190/5000 - loss value -1.527902e-01
# Epoch 191/5000 - loss value -1.541072e-01
# Epoch 192/5000 - loss value -1.547156e-01
# Epoch 193/5000 - loss value -1.566195e-01
# Epoch 194/5000 - loss value -1.576433e-01
# Epoch 195/5000 - loss value -1.589042e-01
# Epoch 196/5000 - loss value -1.622549e-01
# Epoch 197/5000 - loss value -1.642945e-01
# Epoch 198/5000 - loss value -1.644643e-01
# Epoch 199/5000 - loss value -1.625904e-01
# Epoch 200/5000 - loss value -1.648124e-01
# Epoch 201/5000 - loss value -1.644149e-01
# Epoch 202/5000 - loss value -1.646469e-01
# Epoch 203/5000 - loss value -1.627683e-01
# Epoch 204/5000 - loss value -1.603438e-01
# Epoch 205/5000 - loss value -1.656299e-01
# Epoch 206/5000 - loss value -1.695963e-01
# Epoch 207/5000 - loss value -1.682088e-01
# Epoch 208/5000 - loss value -1.743865e-01
# Epoch 209/5000 - loss value -1.739291e-01
# Epoch 210/5000 - loss value -1.760919e-01
# Epoch 211/5000 - loss value -1.780950e-01
# Epoch 212/5000 - loss value -1.778564e-01
# Epoch 213/5000 - loss value -1.822321e-01
# Epoch 214/5000 - loss value -1.824636e-01
# Epoch 215/5000 - loss value -1.882196e-01
# Epoch 216/5000 - loss value -1.867178e-01
# Epoch 217/5000 - loss value -1.904160e-01
# Epoch 218/5000 - loss value -1.947491e-01
# Epoch 219/5000 - loss value -1.941302e-01
# Epoch 220/5000 - loss value -1.979152e-01
# Epoch 221/5000 - loss value -1.985711e-01
# Epoch 222/5000 - loss value -2.016357e-01
# Epoch 223/5000 - loss value -2.042296e-01
# Epoch 224/5000 - loss value -2.062269e-01
# Epoch 225/5000 - loss value -2.116965e-01
# Epoch 226/5000 - loss value -2.084880e-01
# Epoch 227/5000 - loss value -2.103319e-01
# Epoch 228/5000 - loss value -2.131372e-01
# Epoch 229/5000 - loss value -2.167735e-01
# Epoch 230/5000 - loss value -2.176984e-01
# Epoch 231/5000 - loss value -2.166148e-01
# Epoch 232/5000 - loss value -2.143298e-01
# Epoch 233/5000 - loss value -1.926218e-01
# Epoch 234/5000 - loss value -1.540949e-01
# Epoch 235/5000 - loss value -2.124559e-01
# Epoch 236/5000 - loss value -1.809103e-01
# Epoch 237/5000 - loss value -2.185705e-01
# Epoch 238/5000 - loss value -1.994800e-01
# Epoch 239/5000 - loss value -2.122847e-01
# Epoch 240/5000 - loss value -2.127055e-01
# Epoch 241/5000 - loss value -2.145290e-01
# Epoch 242/5000 - loss value -2.225772e-01
# Epoch 243/5000 - loss value -2.160060e-01
# Epoch 244/5000 - loss value -2.177813e-01
# Epoch 245/5000 - loss value -2.235535e-01
# Epoch 246/5000 - loss value -2.172382e-01
# Epoch 247/5000 - loss value -2.258398e-01
# Epoch 248/5000 - loss value -2.301056e-01
# Epoch 249/5000 - loss value -2.253785e-01
# Epoch 250/5000 - loss value -2.316778e-01
# Epoch 251/5000 - loss value -2.312891e-01
# Epoch 252/5000 - loss value -2.309233e-01
# Epoch 253/5000 - loss value -2.348870e-01
# Epoch 254/5000 - loss value -2.346583e-01
# Epoch 255/5000 - loss value -2.377632e-01
# Epoch 256/5000 - loss value -2.375364e-01
# Epoch 257/5000 - loss value -2.405089e-01
# Epoch 258/5000 - loss value -2.423063e-01
# Epoch 259/5000 - loss value -2.400242e-01
# Epoch 260/5000 - loss value -2.478456e-01
# Epoch 261/5000 - loss value -2.457197e-01
# Epoch 262/5000 - loss value -2.469071e-01
# Epoch 263/5000 - loss value -2.481600e-01
# Epoch 264/5000 - loss value -2.493942e-01
# Epoch 265/5000 - loss value -2.463631e-01
# Epoch 266/5000 - loss value -2.495396e-01
# Epoch 267/5000 - loss value -2.484874e-01
# Epoch 268/5000 - loss value -2.503720e-01
# Epoch 269/5000 - loss value -2.517510e-01
# Epoch 270/5000 - loss value -2.505445e-01
# Epoch 271/5000 - loss value -2.504347e-01
# Epoch 272/5000 - loss value -2.522534e-01
# Epoch 273/5000 - loss value -2.535581e-01
# Epoch 274/5000 - loss value -2.516662e-01
# Epoch 275/5000 - loss value -2.522838e-01
# Epoch 276/5000 - loss value -2.556112e-01
# Epoch 277/5000 - loss value -2.559815e-01
# Epoch 278/5000 - loss value -2.577699e-01
# Epoch 279/5000 - loss value -2.518449e-01
# Epoch 280/5000 - loss value -2.541609e-01
# Epoch 281/5000 - loss value -2.539555e-01
# Epoch 282/5000 - loss value -2.596202e-01
# Epoch 283/5000 - loss value -2.610766e-01
# Epoch 284/5000 - loss value -2.587765e-01
# Epoch 285/5000 - loss value -2.579837e-01
# Epoch 286/5000 - loss value -2.590284e-01
# Epoch 287/5000 - loss value -2.624107e-01
# Epoch 288/5000 - loss value -2.603688e-01
# Epoch 289/5000 - loss value -2.590066e-01
# Epoch 290/5000 - loss value -2.637598e-01
# Epoch 291/5000 - loss value -2.578600e-01
# Epoch 292/5000 - loss value -2.649404e-01
# Epoch 293/5000 - loss value -2.628372e-01
# Epoch 294/5000 - loss value -2.666899e-01
# Epoch 295/5000 - loss value -2.647094e-01
# Epoch 296/5000 - loss value -2.658387e-01
# Epoch 297/5000 - loss value -2.708999e-01
# Epoch 298/5000 - loss value -2.658190e-01
# Epoch 299/5000 - loss value -2.655313e-01
# Epoch 300/5000 - loss value -2.707912e-01
# Epoch 301/5000 - loss value -2.744580e-01
# Epoch 302/5000 - loss value -2.685222e-01
# Epoch 303/5000 - loss value -2.746844e-01
# Epoch 304/5000 - loss value -2.726875e-01
# Epoch 305/5000 - loss value -2.745623e-01
# Epoch 306/5000 - loss value -2.765718e-01
# Epoch 307/5000 - loss value -2.798602e-01
# Epoch 308/5000 - loss value -2.797219e-01
# Epoch 309/5000 - loss value -2.805412e-01
# Epoch 310/5000 - loss value -2.815638e-01
# Epoch 311/5000 - loss value -2.849298e-01
# Epoch 312/5000 - loss value -2.760815e-01
# Epoch 313/5000 - loss value -2.728919e-01
# Epoch 314/5000 - loss value -2.552353e-01
# Epoch 315/5000 - loss value -2.702226e-01
# Epoch 316/5000 - loss value -2.803779e-01
# Epoch 317/5000 - loss value -2.676678e-01
# Epoch 318/5000 - loss value -2.823517e-01
# Epoch 319/5000 - loss value -2.852744e-01
# Epoch 320/5000 - loss value -2.816277e-01
# Epoch 321/5000 - loss value -2.820339e-01
# Epoch 322/5000 - loss value -2.786919e-01
# Epoch 323/5000 - loss value -2.856943e-01
# Epoch 324/5000 - loss value -2.906851e-01
# Epoch 325/5000 - loss value -2.878646e-01
# Epoch 326/5000 - loss value -2.911187e-01
# Epoch 327/5000 - loss value -2.917077e-01
# Epoch 328/5000 - loss value -2.888641e-01
# Epoch 329/5000 - loss value -2.930478e-01
# Epoch 330/5000 - loss value -2.911677e-01
# Epoch 331/5000 - loss value -2.843026e-01
# Epoch 332/5000 - loss value -2.863714e-01
# Epoch 333/5000 - loss value -2.941981e-01
# Epoch 334/5000 - loss value -2.905376e-01
# Epoch 335/5000 - loss value -2.856738e-01
# Epoch 336/5000 - loss value -2.961833e-01
# Epoch 337/5000 - loss value -2.954568e-01
# Epoch 338/5000 - loss value -2.921218e-01
# Epoch 339/5000 - loss value -2.999070e-01
# Epoch 340/5000 - loss value -2.984277e-01
# Epoch 341/5000 - loss value -2.956205e-01
# Epoch 342/5000 - loss value -2.963292e-01
# Epoch 343/5000 - loss value -2.999921e-01
# Epoch 344/5000 - loss value -3.017116e-01
# Epoch 345/5000 - loss value -2.975482e-01
# Epoch 346/5000 - loss value -2.982363e-01
# Epoch 347/5000 - loss value -2.992463e-01
# Epoch 348/5000 - loss value -2.984883e-01
# Epoch 349/5000 - loss value -3.071270e-01
# Epoch 350/5000 - loss value -3.012071e-01
# Epoch 351/5000 - loss value -2.974792e-01
# Epoch 352/5000 - loss value -2.983719e-01
# Epoch 353/5000 - loss value -2.901917e-01
# Epoch 354/5000 - loss value -2.922556e-01
# Epoch 355/5000 - loss value -2.939101e-01
# Epoch 356/5000 - loss value -2.867429e-01
# Epoch 357/5000 - loss value -2.846878e-01
# Epoch 358/5000 - loss value -2.917688e-01
# Epoch 359/5000 - loss value -3.080865e-01
# Epoch 360/5000 - loss value -2.996705e-01
# Epoch 361/5000 - loss value -2.957227e-01
# Epoch 362/5000 - loss value -3.049404e-01
# Epoch 363/5000 - loss value -3.032041e-01
# Epoch 364/5000 - loss value -3.042328e-01
# Epoch 365/5000 - loss value -3.104480e-01
# Epoch 366/5000 - loss value -3.018194e-01
# Epoch 367/5000 - loss value -3.058681e-01
# Epoch 368/5000 - loss value -3.122262e-01
# Epoch 369/5000 - loss value -3.075575e-01
# Epoch 370/5000 - loss value -3.035074e-01
# Epoch 371/5000 - loss value -3.087679e-01
# Epoch 372/5000 - loss value -3.057023e-01
# Epoch 373/5000 - loss value -3.072072e-01
# Epoch 374/5000 - loss value -3.122906e-01
# Epoch 375/5000 - loss value -3.095061e-01
# Epoch 376/5000 - loss value -3.144819e-01
# Epoch 377/5000 - loss value -3.133567e-01
# Epoch 378/5000 - loss value -3.161704e-01
# Epoch 379/5000 - loss value -3.154240e-01
# Epoch 380/5000 - loss value -3.177509e-01
# Epoch 381/5000 - loss value -3.133056e-01
# Epoch 382/5000 - loss value -3.168477e-01
# Epoch 383/5000 - loss value -3.170190e-01
# Epoch 384/5000 - loss value -3.145452e-01
# Epoch 385/5000 - loss value -3.101388e-01
# Epoch 386/5000 - loss value -3.145269e-01
# Epoch 387/5000 - loss value -3.202598e-01
# Epoch 388/5000 - loss value -3.149248e-01
# Epoch 389/5000 - loss value -3.142195e-01
# Epoch 390/5000 - loss value -3.120570e-01
# Epoch 391/5000 - loss value -3.224954e-01
# Epoch 392/5000 - loss value -3.224904e-01
# Epoch 393/5000 - loss value -3.226262e-01
# Epoch 394/5000 - loss value -3.238154e-01
# Epoch 395/5000 - loss value -3.211529e-01
# Epoch 396/5000 - loss value -3.175125e-01
# Epoch 397/5000 - loss value -3.200036e-01
# Epoch 398/5000 - loss value -3.219537e-01
# Epoch 399/5000 - loss value -3.237076e-01
# Epoch 400/5000 - loss value -3.255842e-01
# Epoch 401/5000 - loss value -3.254113e-01
# Epoch 402/5000 - loss value -3.216571e-01
# Epoch 403/5000 - loss value -3.215345e-01
# Epoch 404/5000 - loss value -3.129354e-01
# Epoch 405/5000 - loss value -3.095724e-01
# Epoch 406/5000 - loss value -3.113598e-01
# Epoch 407/5000 - loss value -3.079703e-01
# Epoch 408/5000 - loss value -3.189532e-01
# Epoch 409/5000 - loss value -3.168483e-01
# Epoch 410/5000 - loss value -3.222166e-01
# Epoch 411/5000 - loss value -3.141536e-01
# Epoch 412/5000 - loss value -3.158540e-01
# Epoch 413/5000 - loss value -3.164617e-01
# Epoch 414/5000 - loss value -3.231649e-01
# Epoch 415/5000 - loss value -3.216124e-01
# Epoch 416/5000 - loss value -3.140971e-01
# Epoch 417/5000 - loss value -3.209569e-01
# Epoch 418/5000 - loss value -3.210902e-01
# Epoch 419/5000 - loss value -3.191549e-01
# Epoch 420/5000 - loss value -3.247614e-01
# Epoch 421/5000 - loss value -3.234890e-01
# Epoch 422/5000 - loss value -3.230493e-01
# Epoch 423/5000 - loss value -3.232908e-01
# Epoch 424/5000 - loss value -3.264435e-01
# Epoch 425/5000 - loss value -3.235000e-01
# Epoch 426/5000 - loss value -3.243641e-01
# Epoch 427/5000 - loss value -3.277627e-01
# Epoch 428/5000 - loss value -3.257892e-01
# Epoch 429/5000 - loss value -3.257796e-01
# Epoch 430/5000 - loss value -3.256474e-01
# Epoch 431/5000 - loss value -3.265515e-01
# Epoch 432/5000 - loss value -3.274163e-01
# Epoch 433/5000 - loss value -3.263240e-01
# Epoch 434/5000 - loss value -3.295217e-01
# Epoch 435/5000 - loss value -3.223543e-01
# Epoch 436/5000 - loss value -3.312045e-01
# Epoch 437/5000 - loss value -3.325505e-01
# Epoch 438/5000 - loss value -3.321665e-01
# Epoch 439/5000 - loss value -3.314967e-01
# Epoch 440/5000 - loss value -3.259021e-01
# Epoch 441/5000 - loss value -3.280889e-01
# Epoch 442/5000 - loss value -3.337345e-01
# Epoch 443/5000 - loss value -3.247451e-01
# Epoch 444/5000 - loss value -3.290940e-01
# Epoch 445/5000 - loss value -3.252846e-01
# Epoch 446/5000 - loss value -3.378751e-01
# Epoch 447/5000 - loss value -3.288637e-01
# Epoch 448/5000 - loss value -3.328059e-01
# Epoch 449/5000 - loss value -3.366579e-01
# Epoch 450/5000 - loss value -3.295566e-01
# Epoch 451/5000 - loss value -3.312303e-01
# Epoch 452/5000 - loss value -3.312948e-01
# Epoch 453/5000 - loss value -3.283098e-01
# Epoch 454/5000 - loss value -3.297210e-01
# Epoch 455/5000 - loss value -3.275147e-01
# Epoch 456/5000 - loss value -3.337517e-01
# Epoch 457/5000 - loss value -3.325529e-01
# Epoch 458/5000 - loss value -3.376610e-01
# Epoch 459/5000 - loss value -3.352700e-01
# Epoch 460/5000 - loss value -3.295310e-01
# Epoch 461/5000 - loss value -3.371936e-01
# Epoch 462/5000 - loss value -3.337930e-01
# Epoch 463/5000 - loss value -3.332981e-01
# Epoch 464/5000 - loss value -3.313894e-01
# Epoch 465/5000 - loss value -3.368766e-01
# Epoch 466/5000 - loss value -3.392970e-01
# Epoch 467/5000 - loss value -3.381880e-01
# Epoch 468/5000 - loss value -3.359081e-01
# Epoch 469/5000 - loss value -3.356585e-01
# Epoch 470/5000 - loss value -3.407347e-01
# Epoch 471/5000 - loss value -3.407719e-01
# Epoch 472/5000 - loss value -3.354405e-01
# Epoch 473/5000 - loss value -3.361891e-01
# Epoch 474/5000 - loss value -3.380577e-01
# Epoch 475/5000 - loss value -3.325546e-01
# Epoch 476/5000 - loss value -3.320974e-01
# Epoch 477/5000 - loss value -3.406818e-01
# Epoch 478/5000 - loss value -3.422884e-01
# Epoch 479/5000 - loss value -3.367936e-01
# Epoch 480/5000 - loss value -3.326311e-01
# Epoch 481/5000 - loss value -3.389225e-01
# Epoch 482/5000 - loss value -3.371120e-01
# Epoch 483/5000 - loss value -3.355513e-01
# Epoch 484/5000 - loss value -3.342995e-01
# Epoch 485/5000 - loss value -3.422412e-01
# Epoch 486/5000 - loss value -3.374182e-01
# Epoch 487/5000 - loss value -3.365644e-01
# Epoch 488/5000 - loss value -3.411518e-01
# Epoch 489/5000 - loss value -3.345227e-01
# Epoch 490/5000 - loss value -3.311173e-01
# Epoch 491/5000 - loss value -3.417637e-01
# Epoch 492/5000 - loss value -3.342064e-01
# Epoch 493/5000 - loss value -3.313150e-01
# Epoch 494/5000 - loss value -3.415582e-01
# Epoch 495/5000 - loss value -3.414986e-01
# Epoch 496/5000 - loss value -3.358233e-01
# Epoch 497/5000 - loss value -3.435174e-01
# Epoch 498/5000 - loss value -3.445917e-01
# Epoch 499/5000 - loss value -3.370891e-01
# Epoch 500/5000 - loss value -3.393169e-01
# Epoch 501/5000 - loss value -3.401002e-01
# Epoch 502/5000 - loss value -3.400333e-01
# Epoch 503/5000 - loss value -3.436794e-01
# Epoch 504/5000 - loss value -3.443057e-01
# Epoch 505/5000 - loss value -3.469747e-01
# Epoch 506/5000 - loss value -3.350362e-01
# Epoch 507/5000 - loss value -3.373476e-01
# Epoch 508/5000 - loss value -3.346838e-01
# Epoch 509/5000 - loss value -3.350361e-01
# Epoch 510/5000 - loss value -3.489200e-01
# Epoch 511/5000 - loss value -3.448731e-01
# Epoch 512/5000 - loss value -3.459143e-01
# Epoch 513/5000 - loss value -3.474331e-01
# Epoch 514/5000 - loss value -3.365703e-01
# Epoch 515/5000 - loss value -3.384401e-01
# Epoch 516/5000 - loss value -3.395191e-01
# Epoch 517/5000 - loss value -3.491161e-01
# Epoch 518/5000 - loss value -3.443872e-01
# Epoch 519/5000 - loss value -3.457736e-01
# Epoch 520/5000 - loss value -3.464984e-01
# Epoch 521/5000 - loss value -3.507876e-01
# Epoch 522/5000 - loss value -3.490417e-01
# Epoch 523/5000 - loss value -3.440834e-01
# Epoch 524/5000 - loss value -3.419294e-01
# Epoch 525/5000 - loss value -3.456061e-01
# Epoch 526/5000 - loss value -3.505692e-01
# Epoch 527/5000 - loss value -3.471119e-01
# Epoch 528/5000 - loss value -3.449033e-01
# Epoch 529/5000 - loss value -3.438335e-01
# Epoch 530/5000 - loss value -3.475999e-01
# Epoch 531/5000 - loss value -3.448698e-01
# Epoch 532/5000 - loss value -3.439973e-01
# Epoch 533/5000 - loss value -3.527496e-01
# Epoch 534/5000 - loss value -3.461923e-01
# Epoch 535/5000 - loss value -3.473511e-01
# Epoch 536/5000 - loss value -3.440242e-01
# Epoch 537/5000 - loss value -3.465925e-01
# Epoch 538/5000 - loss value -3.466296e-01
# Epoch 539/5000 - loss value -3.457543e-01
# Epoch 540/5000 - loss value -3.498857e-01
# Epoch 541/5000 - loss value -3.536090e-01
# Epoch 542/5000 - loss value -3.481825e-01
# Epoch 543/5000 - loss value -3.492830e-01
# Epoch 544/5000 - loss value -3.492196e-01
# Epoch 545/5000 - loss value -3.517354e-01
# Epoch 546/5000 - loss value -3.456803e-01
# Epoch 547/5000 - loss value -3.509940e-01
# Epoch 548/5000 - loss value -3.500601e-01
# Epoch 549/5000 - loss value -3.513452e-01
# Epoch 550/5000 - loss value -3.523955e-01
# Epoch 551/5000 - loss value -3.482805e-01
# Epoch 552/5000 - loss value -3.446849e-01
# Epoch 553/5000 - loss value -3.572248e-01
# Epoch 554/5000 - loss value -3.550315e-01
# Epoch 555/5000 - loss value -3.471249e-01
# Epoch 556/5000 - loss value -3.444852e-01
# Epoch 557/5000 - loss value -3.486422e-01
# Epoch 558/5000 - loss value -3.460557e-01
# Epoch 559/5000 - loss value -3.478838e-01
# Epoch 560/5000 - loss value -3.503471e-01
# Epoch 561/5000 - loss value -3.567236e-01
# Epoch 562/5000 - loss value -3.543904e-01
# Epoch 563/5000 - loss value -3.479621e-01
# Epoch 564/5000 - loss value -3.508206e-01
# Epoch 565/5000 - loss value -3.562679e-01
# Epoch 566/5000 - loss value -3.465022e-01
# Epoch 567/5000 - loss value -3.525724e-01
# Epoch 568/5000 - loss value -3.527958e-01
# Epoch 569/5000 - loss value -3.564591e-01
# Epoch 570/5000 - loss value -3.497777e-01
# Epoch 571/5000 - loss value -3.528867e-01
# Epoch 572/5000 - loss value -3.596668e-01
# Epoch 573/5000 - loss value -3.529729e-01
# Epoch 574/5000 - loss value -3.455798e-01
# Epoch 575/5000 - loss value -3.495410e-01
# Epoch 576/5000 - loss value -3.538155e-01
# Epoch 577/5000 - loss value -3.520188e-01
# Epoch 578/5000 - loss value -3.490433e-01
# Epoch 579/5000 - loss value -3.561032e-01
# Epoch 580/5000 - loss value -3.544738e-01
# Epoch 581/5000 - loss value -3.518998e-01
# Epoch 582/5000 - loss value -3.509259e-01
# Epoch 583/5000 - loss value -3.539047e-01
# Epoch 584/5000 - loss value -3.510481e-01
# Epoch 585/5000 - loss value -3.518125e-01
# Epoch 586/5000 - loss value -3.562791e-01
# Epoch 587/5000 - loss value -3.482035e-01
# Epoch 588/5000 - loss value -3.510116e-01
# Epoch 589/5000 - loss value -3.499484e-01
# Epoch 590/5000 - loss value -3.560940e-01
# Epoch 591/5000 - loss value -3.503209e-01
# Epoch 592/5000 - loss value -3.575930e-01
# Epoch 593/5000 - loss value -3.542692e-01
# Epoch 594/5000 - loss value -3.512070e-01
# Epoch 595/5000 - loss value -3.660197e-01
# Epoch 596/5000 - loss value -3.540982e-01
# Epoch 597/5000 - loss value -3.489326e-01
# Epoch 598/5000 - loss value -3.566937e-01
# Epoch 599/5000 - loss value -3.550129e-01
# Epoch 600/5000 - loss value -3.507215e-01
# Epoch 601/5000 - loss value -3.516068e-01
# Epoch 602/5000 - loss value -3.490961e-01
# Epoch 603/5000 - loss value -3.512203e-01
# Epoch 604/5000 - loss value -3.592494e-01
# Epoch 605/5000 - loss value -3.535497e-01
# Epoch 606/5000 - loss value -3.573104e-01
# Epoch 607/5000 - loss value -3.530811e-01
# Epoch 608/5000 - loss value -3.576091e-01
# Epoch 609/5000 - loss value -3.589658e-01
# Epoch 610/5000 - loss value -3.576900e-01
# Epoch 611/5000 - loss value -3.605984e-01
# Epoch 612/5000 - loss value -3.523477e-01
# Epoch 613/5000 - loss value -3.497627e-01
# Epoch 614/5000 - loss value -3.510222e-01
# Epoch 615/5000 - loss value -3.534913e-01
# Epoch 616/5000 - loss value -3.574698e-01
# Epoch 617/5000 - loss value -3.574451e-01
# Epoch 618/5000 - loss value -3.567839e-01
# Epoch 619/5000 - loss value -3.509706e-01
# Epoch 620/5000 - loss value -3.521228e-01
# Epoch 621/5000 - loss value -3.486953e-01
# Epoch 622/5000 - loss value -3.547267e-01
# Epoch 623/5000 - loss value -3.544514e-01
# Epoch 624/5000 - loss value -3.598783e-01
# Epoch 625/5000 - loss value -3.619790e-01
# Epoch 626/5000 - loss value -3.563635e-01
# Epoch 627/5000 - loss value -3.564330e-01
# Epoch 628/5000 - loss value -3.591193e-01
# Epoch 629/5000 - loss value -3.649679e-01
# Epoch 630/5000 - loss value -3.503001e-01
# Epoch 631/5000 - loss value -3.554340e-01
# Epoch 632/5000 - loss value -3.598067e-01
# Epoch 633/5000 - loss value -3.517732e-01
# Epoch 634/5000 - loss value -3.512853e-01
# Epoch 635/5000 - loss value -3.618645e-01
# Epoch 636/5000 - loss value -3.537290e-01
# Epoch 637/5000 - loss value -3.521487e-01
# Epoch 638/5000 - loss value -3.569581e-01
# Epoch 639/5000 - loss value -3.508887e-01
# Epoch 640/5000 - loss value -3.622051e-01
# Epoch 641/5000 - loss value -3.580704e-01
# Epoch 642/5000 - loss value -3.561681e-01
# Epoch 643/5000 - loss value -3.628312e-01
# Epoch 644/5000 - loss value -3.682022e-01
# Epoch 645/5000 - loss value -3.563717e-01
# Epoch 646/5000 - loss value -3.591615e-01
# Epoch 647/5000 - loss value -3.581957e-01
# Epoch 648/5000 - loss value -3.561038e-01
# Epoch 649/5000 - loss value -3.566905e-01
# Epoch 650/5000 - loss value -3.592252e-01
# Epoch 651/5000 - loss value -3.577845e-01
# Epoch 652/5000 - loss value -3.611225e-01
# Epoch 653/5000 - loss value -3.652880e-01
# Epoch 654/5000 - loss value -3.570270e-01
# Epoch 655/5000 - loss value -3.646801e-01
# Epoch 656/5000 - loss value -3.526348e-01
# Epoch 657/5000 - loss value -3.631674e-01
# Epoch 658/5000 - loss value -3.631838e-01
# Epoch 659/5000 - loss value -3.560639e-01
# Epoch 660/5000 - loss value -3.577181e-01
# Epoch 661/5000 - loss value -3.603017e-01
# Epoch 662/5000 - loss value -3.632701e-01
# Epoch 663/5000 - loss value -3.500958e-01
# Epoch 664/5000 - loss value -3.307435e-01
# Epoch 665/5000 - loss value -3.500691e-01
# Epoch 666/5000 - loss value -3.499948e-01
# Epoch 667/5000 - loss value -3.474930e-01
# Epoch 668/5000 - loss value -3.504207e-01
# Epoch 669/5000 - loss value -3.487607e-01
# Epoch 670/5000 - loss value -3.525330e-01
# Epoch 671/5000 - loss value -3.556110e-01
# Epoch 672/5000 - loss value -3.553563e-01
# Epoch 673/5000 - loss value -3.613824e-01
# Epoch 674/5000 - loss value -3.547360e-01
# Epoch 675/5000 - loss value -3.533246e-01
# Epoch 676/5000 - loss value -3.497903e-01
# Epoch 677/5000 - loss value -3.594500e-01
# Epoch 678/5000 - loss value -3.507249e-01
# Epoch 679/5000 - loss value -3.562981e-01
# Epoch 680/5000 - loss value -3.518190e-01
# Epoch 681/5000 - loss value -3.565192e-01
# Epoch 682/5000 - loss value -3.527128e-01
# Epoch 683/5000 - loss value -3.662312e-01
# Epoch 684/5000 - loss value -3.507318e-01
# Epoch 685/5000 - loss value -3.620514e-01
# Epoch 686/5000 - loss value -3.606547e-01
# Epoch 687/5000 - loss value -3.612554e-01
# Epoch 688/5000 - loss value -3.645987e-01
# Epoch 689/5000 - loss value -3.600802e-01
# Epoch 690/5000 - loss value -3.624485e-01
# Epoch 691/5000 - loss value -3.594245e-01
# Epoch 692/5000 - loss value -3.631394e-01
# Epoch 693/5000 - loss value -3.644025e-01
# Epoch 694/5000 - loss value -3.627793e-01
# Epoch 695/5000 - loss value -3.636680e-01
# Epoch 696/5000 - loss value -3.644410e-01
# Epoch 697/5000 - loss value -3.516836e-01
# Epoch 698/5000 - loss value -3.624823e-01
# Epoch 699/5000 - loss value -3.689344e-01
# Epoch 700/5000 - loss value -3.661514e-01
# Epoch 701/5000 - loss value -3.620159e-01
# Epoch 702/5000 - loss value -3.651013e-01
# Epoch 703/5000 - loss value -3.637606e-01
# Epoch 704/5000 - loss value -3.594187e-01
# Epoch 705/5000 - loss value -3.638746e-01
# Epoch 706/5000 - loss value -3.657013e-01
# Epoch 707/5000 - loss value -3.629681e-01
# Epoch 708/5000 - loss value -3.617951e-01
# Epoch 709/5000 - loss value -3.607964e-01
# Epoch 710/5000 - loss value -3.626422e-01
# Epoch 711/5000 - loss value -3.648421e-01
# Epoch 712/5000 - loss value -3.647150e-01
# Epoch 713/5000 - loss value -3.568150e-01
# Epoch 714/5000 - loss value -3.664629e-01
# Epoch 715/5000 - loss value -3.592827e-01
# Epoch 716/5000 - loss value -3.670912e-01
# Epoch 717/5000 - loss value -3.555300e-01
# Epoch 718/5000 - loss value -3.640135e-01
# Epoch 719/5000 - loss value -3.628420e-01
# Epoch 720/5000 - loss value -3.549114e-01
# Epoch 721/5000 - loss value -3.643280e-01
# Epoch 722/5000 - loss value -3.592490e-01
# Epoch 723/5000 - loss value -3.669153e-01
# Epoch 724/5000 - loss value -3.688475e-01
# Epoch 725/5000 - loss value -3.666144e-01
# Epoch 726/5000 - loss value -3.637511e-01
# Epoch 727/5000 - loss value -3.624365e-01
# Epoch 728/5000 - loss value -3.676809e-01
# Epoch 729/5000 - loss value -3.681438e-01
# Epoch 730/5000 - loss value -3.646251e-01
# Epoch 731/5000 - loss value -3.637949e-01
# Epoch 732/5000 - loss value -3.642945e-01
# Epoch 733/5000 - loss value -3.551972e-01
# Epoch 734/5000 - loss value -3.625307e-01
# Epoch 735/5000 - loss value -3.608994e-01
# Epoch 736/5000 - loss value -3.625610e-01
# Epoch 737/5000 - loss value -3.625182e-01
# Epoch 738/5000 - loss value -3.651522e-01
# Epoch 739/5000 - loss value -3.689497e-01
# Epoch 740/5000 - loss value -3.664180e-01
# Epoch 741/5000 - loss value -3.636767e-01
# Epoch 742/5000 - loss value -3.741106e-01
# Epoch 743/5000 - loss value -3.621398e-01
# Epoch 744/5000 - loss value -3.672459e-01
# Epoch 745/5000 - loss value -3.640281e-01
# Epoch 746/5000 - loss value -3.655835e-01
# Epoch 747/5000 - loss value -3.638426e-01
# Epoch 748/5000 - loss value -3.619497e-01
# Epoch 749/5000 - loss value -3.592319e-01
# Epoch 750/5000 - loss value -3.599328e-01
# Epoch 751/5000 - loss value -3.698134e-01
# Epoch 752/5000 - loss value -3.605441e-01
# Epoch 753/5000 - loss value -3.640889e-01
# Epoch 754/5000 - loss value -3.625892e-01
# Epoch 755/5000 - loss value -3.723318e-01
# Epoch 756/5000 - loss value -3.707510e-01
# Epoch 757/5000 - loss value -3.591494e-01
# Epoch 758/5000 - loss value -3.674209e-01
# Epoch 759/5000 - loss value -3.654279e-01
# Epoch 760/5000 - loss value -3.589575e-01
# Epoch 761/5000 - loss value -3.628085e-01
# Epoch 762/5000 - loss value -3.598471e-01
# Epoch 763/5000 - loss value -3.690030e-01
# Epoch 764/5000 - loss value -3.600323e-01
# Epoch 765/5000 - loss value -3.666155e-01
# Epoch 766/5000 - loss value -3.695532e-01
# Epoch 767/5000 - loss value -3.671624e-01
# Epoch 768/5000 - loss value -3.636128e-01
# Epoch 769/5000 - loss value -3.668906e-01
# Epoch 770/5000 - loss value -3.641401e-01
# Epoch 771/5000 - loss value -3.671633e-01
# Epoch 772/5000 - loss value -3.646518e-01
# Epoch 773/5000 - loss value -3.680939e-01
# Epoch 774/5000 - loss value -3.671243e-01
# Epoch 775/5000 - loss value -3.622271e-01
# Epoch 776/5000 - loss value -3.692552e-01
# Epoch 777/5000 - loss value -3.671686e-01
# Epoch 778/5000 - loss value -3.695151e-01
# Epoch 779/5000 - loss value -3.619044e-01
# Epoch 780/5000 - loss value -3.556679e-01
# Epoch 781/5000 - loss value -3.681296e-01
# Epoch 782/5000 - loss value -3.705006e-01
# Epoch 783/5000 - loss value -3.700685e-01
# Epoch 784/5000 - loss value -3.623974e-01
# Epoch 785/5000 - loss value -3.688923e-01
# Epoch 786/5000 - loss value -3.672041e-01
# Epoch 787/5000 - loss value -3.631851e-01
# Epoch 788/5000 - loss value -3.660034e-01
# Epoch 789/5000 - loss value -3.674172e-01
# Epoch 790/5000 - loss value -3.643185e-01
# Epoch 791/5000 - loss value -3.681024e-01
# Epoch 792/5000 - loss value -3.585023e-01
# Epoch 793/5000 - loss value -3.671587e-01
# Epoch 794/5000 - loss value -3.689546e-01
# Epoch 795/5000 - loss value -3.660934e-01
# Epoch 796/5000 - loss value -3.737370e-01
# Epoch 797/5000 - loss value -3.690461e-01
# Epoch 798/5000 - loss value -3.600146e-01
# Epoch 799/5000 - loss value -3.595621e-01
# Epoch 800/5000 - loss value -3.563321e-01
# Epoch 801/5000 - loss value -3.581908e-01
# Epoch 802/5000 - loss value -3.664950e-01
# Epoch 803/5000 - loss value -3.657086e-01
# Epoch 804/5000 - loss value -3.699989e-01
# Epoch 805/5000 - loss value -3.662071e-01
# Epoch 806/5000 - loss value -3.653956e-01
# Epoch 807/5000 - loss value -3.673587e-01
# Epoch 808/5000 - loss value -3.630848e-01
# Epoch 809/5000 - loss value -3.692599e-01
# Epoch 810/5000 - loss value -3.646204e-01
# Epoch 811/5000 - loss value -3.616048e-01
# Epoch 812/5000 - loss value -3.628625e-01
# Epoch 813/5000 - loss value -3.579165e-01
# Epoch 814/5000 - loss value -3.675481e-01
# Epoch 815/5000 - loss value -3.709061e-01
# Epoch 816/5000 - loss value -3.693452e-01
# Epoch 817/5000 - loss value -3.636089e-01
# Epoch 818/5000 - loss value -3.718578e-01
# Epoch 819/5000 - loss value -3.616977e-01
# Epoch 820/5000 - loss value -3.695950e-01
# Epoch 821/5000 - loss value -3.626774e-01
# Epoch 822/5000 - loss value -3.712293e-01
# Epoch 823/5000 - loss value -3.718285e-01
# Epoch 824/5000 - loss value -3.693720e-01
# Epoch 825/5000 - loss value -3.763698e-01
# Epoch 826/5000 - loss value -3.670591e-01
# Epoch 827/5000 - loss value -3.645192e-01
# Epoch 828/5000 - loss value -3.720752e-01
# Epoch 829/5000 - loss value -3.612440e-01
# Epoch 830/5000 - loss value -3.701193e-01
# Epoch 831/5000 - loss value -3.704415e-01
# Epoch 832/5000 - loss value -3.679255e-01
# Epoch 833/5000 - loss value -3.687958e-01
# Epoch 834/5000 - loss value -3.645789e-01
# Epoch 835/5000 - loss value -3.657871e-01
# Epoch 836/5000 - loss value -3.708022e-01
# Epoch 837/5000 - loss value -3.666695e-01
# Epoch 838/5000 - loss value -3.712275e-01
# Epoch 839/5000 - loss value -3.708935e-01
# Epoch 840/5000 - loss value -3.691490e-01
# Epoch 841/5000 - loss value -3.713414e-01
# Epoch 842/5000 - loss value -3.665530e-01
# Epoch 843/5000 - loss value -3.647768e-01
# Epoch 844/5000 - loss value -3.737921e-01
# Epoch 845/5000 - loss value -3.652004e-01
# Epoch 846/5000 - loss value -3.687424e-01
# Epoch 847/5000 - loss value -3.691590e-01
# Epoch 848/5000 - loss value -3.660656e-01
# Epoch 849/5000 - loss value -3.691998e-01
# Epoch 850/5000 - loss value -3.733459e-01
# Epoch 851/5000 - loss value -3.701303e-01
# Epoch 852/5000 - loss value -3.702406e-01
# Epoch 853/5000 - loss value -3.760746e-01
# Epoch 854/5000 - loss value -3.677173e-01
# Epoch 855/5000 - loss value -3.735903e-01
# Epoch 856/5000 - loss value -3.713539e-01
# Epoch 857/5000 - loss value -3.713408e-01
# Epoch 858/5000 - loss value -3.661390e-01
# Epoch 859/5000 - loss value -3.697956e-01
# Epoch 860/5000 - loss value -3.655200e-01
# Epoch 861/5000 - loss value -3.680287e-01
# Epoch 862/5000 - loss value -3.775547e-01
# Epoch 863/5000 - loss value -3.670958e-01
# Epoch 864/5000 - loss value -3.722322e-01
# Epoch 865/5000 - loss value -3.654715e-01
# Epoch 866/5000 - loss value -3.654811e-01
# Epoch 867/5000 - loss value -3.734849e-01
# Epoch 868/5000 - loss value -3.707125e-01
# Epoch 869/5000 - loss value -3.725947e-01
# Epoch 870/5000 - loss value -3.713394e-01
# Epoch 871/5000 - loss value -3.634261e-01
# Epoch 872/5000 - loss value -3.614938e-01
# Epoch 873/5000 - loss value -3.667367e-01
# Epoch 874/5000 - loss value -3.670700e-01
# Epoch 875/5000 - loss value -3.668906e-01
# Epoch 876/5000 - loss value -3.685965e-01
# Epoch 877/5000 - loss value -3.669273e-01
# Epoch 878/5000 - loss value -3.716074e-01
# Epoch 879/5000 - loss value -3.707589e-01
# Epoch 880/5000 - loss value -3.707501e-01
# Epoch 881/5000 - loss value -3.705115e-01
# Epoch 882/5000 - loss value -3.712888e-01
# Epoch 883/5000 - loss value -3.695701e-01
# Epoch 884/5000 - loss value -3.703659e-01
# Epoch 885/5000 - loss value -3.744702e-01
# Epoch 886/5000 - loss value -3.735634e-01
# Epoch 887/5000 - loss value -3.757157e-01
# Epoch 888/5000 - loss value -3.694112e-01
# Epoch 889/5000 - loss value -3.749003e-01
# Epoch 890/5000 - loss value -3.715829e-01
# Epoch 891/5000 - loss value -3.766360e-01
# Epoch 892/5000 - loss value -3.756064e-01
# Epoch 893/5000 - loss value -3.827362e-01
# Epoch 894/5000 - loss value -3.731762e-01
# Epoch 895/5000 - loss value -3.771096e-01
# Epoch 896/5000 - loss value -3.740061e-01
# Epoch 897/5000 - loss value -3.745796e-01
# Epoch 898/5000 - loss value -3.798967e-01
# Epoch 899/5000 - loss value -3.730941e-01
# Epoch 900/5000 - loss value -3.713889e-01
# Epoch 901/5000 - loss value -3.714967e-01
# Epoch 902/5000 - loss value -3.742067e-01
# Epoch 903/5000 - loss value -3.705482e-01
# Epoch 904/5000 - loss value -3.688336e-01
# Epoch 905/5000 - loss value -3.705556e-01
# Epoch 906/5000 - loss value -3.671410e-01
# Epoch 907/5000 - loss value -3.625049e-01
# Epoch 908/5000 - loss value -3.746732e-01
# Epoch 909/5000 - loss value -3.686232e-01
# Epoch 910/5000 - loss value -3.763546e-01
# Epoch 911/5000 - loss value -3.681299e-01
# Epoch 912/5000 - loss value -3.678408e-01
# Epoch 913/5000 - loss value -3.698612e-01
# Epoch 914/5000 - loss value -3.724471e-01
# Epoch 915/5000 - loss value -3.693350e-01
# Epoch 916/5000 - loss value -3.773680e-01
# Epoch 917/5000 - loss value -3.631167e-01
# Epoch 918/5000 - loss value -3.702794e-01
# Epoch 919/5000 - loss value -3.664029e-01
# Epoch 920/5000 - loss value -3.712833e-01
# Epoch 921/5000 - loss value -3.699580e-01
# Epoch 922/5000 - loss value -3.771752e-01
# Epoch 923/5000 - loss value -3.693132e-01
# Epoch 924/5000 - loss value -3.781048e-01
# Epoch 925/5000 - loss value -3.753424e-01
# Epoch 926/5000 - loss value -3.792422e-01
# Epoch 927/5000 - loss value -3.810896e-01
# Epoch 928/5000 - loss value -3.774146e-01
# Epoch 929/5000 - loss value -3.735663e-01
# Epoch 930/5000 - loss value -3.702734e-01
# Epoch 931/5000 - loss value -3.688159e-01
# Epoch 932/5000 - loss value -3.697392e-01
# Epoch 933/5000 - loss value -3.814185e-01
# Epoch 934/5000 - loss value -3.684065e-01
# Epoch 935/5000 - loss value -3.760024e-01
# Epoch 936/5000 - loss value -3.827723e-01
# Epoch 937/5000 - loss value -3.771548e-01
# Epoch 938/5000 - loss value -3.750792e-01
# Epoch 939/5000 - loss value -3.692363e-01
# Epoch 940/5000 - loss value -3.767074e-01
# Epoch 941/5000 - loss value -3.722396e-01
# Epoch 942/5000 - loss value -3.706101e-01
# Epoch 943/5000 - loss value -3.730415e-01
# Epoch 944/5000 - loss value -3.741401e-01
# Epoch 945/5000 - loss value -3.753691e-01
# Epoch 946/5000 - loss value -3.780608e-01
# Epoch 947/5000 - loss value -3.766896e-01
# Epoch 948/5000 - loss value -3.681696e-01
# Epoch 949/5000 - loss value -3.754189e-01
# Epoch 950/5000 - loss value -3.819865e-01
# Epoch 951/5000 - loss value -3.743677e-01
# Epoch 952/5000 - loss value -3.731250e-01
# Epoch 953/5000 - loss value -3.776613e-01
# Epoch 954/5000 - loss value -3.766259e-01
# Epoch 955/5000 - loss value -3.756199e-01
# Epoch 956/5000 - loss value -3.799845e-01
# Epoch 957/5000 - loss value -3.797026e-01
# Epoch 958/5000 - loss value -3.778391e-01
# Epoch 959/5000 - loss value -3.806463e-01
# Epoch 960/5000 - loss value -3.766317e-01
# Epoch 961/5000 - loss value -3.699731e-01
# Epoch 962/5000 - loss value -3.698166e-01
# Epoch 963/5000 - loss value -3.715677e-01
# Epoch 964/5000 - loss value -3.758613e-01
# Epoch 965/5000 - loss value -3.760151e-01
# Epoch 966/5000 - loss value -3.781523e-01
# Epoch 967/5000 - loss value -3.799581e-01
# Epoch 968/5000 - loss value -3.729777e-01
# Epoch 969/5000 - loss value -3.685719e-01
# Epoch 970/5000 - loss value -3.765700e-01
# Epoch 971/5000 - loss value -3.777333e-01
# Epoch 972/5000 - loss value -3.776763e-01
# Epoch 973/5000 - loss value -3.845563e-01
# Epoch 974/5000 - loss value -3.800853e-01
# Epoch 975/5000 - loss value -3.727153e-01
# Epoch 976/5000 - loss value -3.786859e-01
# Epoch 977/5000 - loss value -3.774196e-01
# Epoch 978/5000 - loss value -3.947444e-01
# Epoch 979/5000 - loss value -3.799542e-01
# Epoch 980/5000 - loss value -3.787696e-01
# Epoch 981/5000 - loss value -3.802330e-01
# Epoch 982/5000 - loss value -3.827378e-01
# Epoch 983/5000 - loss value -3.815034e-01
# Epoch 984/5000 - loss value -3.813462e-01
# Epoch 985/5000 - loss value -3.829056e-01
# Epoch 986/5000 - loss value -3.783210e-01
# Epoch 987/5000 - loss value -3.813715e-01
# Epoch 988/5000 - loss value -3.873515e-01
# Epoch 989/5000 - loss value -3.743012e-01
# Epoch 990/5000 - loss value -3.836734e-01
# Epoch 991/5000 - loss value -3.828595e-01
# Epoch 992/5000 - loss value -3.778516e-01
# Epoch 993/5000 - loss value -3.808044e-01
# Epoch 994/5000 - loss value -3.754530e-01
# Epoch 995/5000 - loss value -3.809308e-01
# Epoch 996/5000 - loss value -3.810749e-01
# Epoch 997/5000 - loss value -3.870123e-01
# Epoch 998/5000 - loss value -3.815368e-01
# Epoch 999/5000 - loss value -3.819352e-01
# Epoch 1000/5000 - loss value -3.837641e-01
# Epoch 1001/5000 - loss value -3.825909e-01
# Epoch 1002/5000 - loss value -3.786008e-01
# Epoch 1003/5000 - loss value -3.786673e-01
# Epoch 1004/5000 - loss value -3.790421e-01
# Epoch 1005/5000 - loss value -3.737382e-01
# Epoch 1006/5000 - loss value -3.849662e-01
# Epoch 1007/5000 - loss value -3.742827e-01
# Epoch 1008/5000 - loss value -3.792633e-01
# Epoch 1009/5000 - loss value -3.760254e-01
# Epoch 1010/5000 - loss value -3.778884e-01
# Epoch 1011/5000 - loss value -3.817059e-01
# Epoch 1012/5000 - loss value -3.813135e-01
# Epoch 1013/5000 - loss value -3.833899e-01
# Epoch 1014/5000 - loss value -3.833473e-01
# Epoch 1015/5000 - loss value -3.891616e-01
# Epoch 1016/5000 - loss value -3.871207e-01
# Epoch 1017/5000 - loss value -3.817814e-01
# Epoch 1018/5000 - loss value -3.777153e-01
# Epoch 1019/5000 - loss value -3.785840e-01
# Epoch 1020/5000 - loss value -3.838732e-01
# Epoch 1021/5000 - loss value -3.857197e-01
# Epoch 1022/5000 - loss value -3.857762e-01
# Epoch 1023/5000 - loss value -3.763506e-01
# Epoch 1024/5000 - loss value -3.865726e-01
# Epoch 1025/5000 - loss value -3.929966e-01
# Epoch 1026/5000 - loss value -3.777519e-01
# Epoch 1027/5000 - loss value -3.785713e-01
# Epoch 1028/5000 - loss value -3.740391e-01
# Epoch 1029/5000 - loss value -3.813486e-01
# Epoch 1030/5000 - loss value -3.813297e-01
# Epoch 1031/5000 - loss value -3.869828e-01
# Epoch 1032/5000 - loss value -3.847828e-01
# Epoch 1033/5000 - loss value -3.853472e-01
# Epoch 1034/5000 - loss value -3.772282e-01
# Epoch 1035/5000 - loss value -3.772082e-01
# Epoch 1036/5000 - loss value -3.785702e-01
# Epoch 1037/5000 - loss value -3.770350e-01
# Epoch 1038/5000 - loss value -3.798935e-01
# Epoch 1039/5000 - loss value -3.810992e-01
# Epoch 1040/5000 - loss value -3.792662e-01
# Epoch 1041/5000 - loss value -3.768960e-01
# Epoch 1042/5000 - loss value -3.805076e-01
# Epoch 1043/5000 - loss value -3.816609e-01
# Epoch 1044/5000 - loss value -3.785244e-01
# Epoch 1045/5000 - loss value -3.844514e-01
# Epoch 1046/5000 - loss value -3.795068e-01
# Epoch 1047/5000 - loss value -3.837669e-01
# Epoch 1048/5000 - loss value -3.866315e-01
# Epoch 1049/5000 - loss value -3.751965e-01
# Epoch 1050/5000 - loss value -3.833498e-01
# Epoch 1051/5000 - loss value -3.825584e-01
# Epoch 1052/5000 - loss value -3.844713e-01
# Epoch 1053/5000 - loss value -3.809358e-01
# Epoch 1054/5000 - loss value -3.863020e-01
# Epoch 1055/5000 - loss value -3.845111e-01
# Epoch 1056/5000 - loss value -3.792630e-01
# Epoch 1057/5000 - loss value -3.783147e-01
# Epoch 1058/5000 - loss value -3.828622e-01
# Epoch 1059/5000 - loss value -3.865717e-01
# Epoch 1060/5000 - loss value -3.851544e-01
# Epoch 1061/5000 - loss value -3.874883e-01
# Epoch 1062/5000 - loss value -3.858288e-01
# Epoch 1063/5000 - loss value -3.837425e-01
# Epoch 1064/5000 - loss value -3.862779e-01
# Epoch 1065/5000 - loss value -3.914444e-01
# Epoch 1066/5000 - loss value -3.892009e-01
# Epoch 1067/5000 - loss value -3.812357e-01
# Epoch 1068/5000 - loss value -3.772255e-01
# Epoch 1069/5000 - loss value -3.831953e-01
# Epoch 1070/5000 - loss value -3.825457e-01
# Epoch 1071/5000 - loss value -3.845593e-01
# Epoch 1072/5000 - loss value -3.809540e-01
# Epoch 1073/5000 - loss value -3.892891e-01
# Epoch 1074/5000 - loss value -3.799456e-01
# Epoch 1075/5000 - loss value -3.814426e-01
# Epoch 1076/5000 - loss value -3.853868e-01
# Epoch 1077/5000 - loss value -3.783044e-01
# Epoch 1078/5000 - loss value -3.822827e-01
# Epoch 1079/5000 - loss value -3.818261e-01
# Epoch 1080/5000 - loss value -3.844108e-01
# Epoch 1081/5000 - loss value -3.913695e-01
# Epoch 1082/5000 - loss value -3.799713e-01
# Epoch 1083/5000 - loss value -3.832869e-01
# Epoch 1084/5000 - loss value -3.835108e-01
# Epoch 1085/5000 - loss value -3.699969e-01
# Epoch 1086/5000 - loss value -3.544156e-01
# Epoch 1087/5000 - loss value -3.564043e-01
# Epoch 1088/5000 - loss value -3.737986e-01
# Epoch 1089/5000 - loss value -3.808127e-01
# Epoch 1090/5000 - loss value -3.750694e-01
# Epoch 1091/5000 - loss value -3.767590e-01
# Epoch 1092/5000 - loss value -3.873825e-01
# Epoch 1093/5000 - loss value -3.802894e-01
# Epoch 1094/5000 - loss value -3.845512e-01
# Epoch 1095/5000 - loss value -3.844185e-01
# Epoch 1096/5000 - loss value -3.825346e-01
# Epoch 1097/5000 - loss value -3.756245e-01
# Epoch 1098/5000 - loss value -3.886836e-01
# Epoch 1099/5000 - loss value -3.778940e-01
# Epoch 1100/5000 - loss value -3.843333e-01
# Epoch 1101/5000 - loss value -3.752627e-01
# Epoch 1102/5000 - loss value -3.823121e-01
# Epoch 1103/5000 - loss value -3.884533e-01
# Epoch 1104/5000 - loss value -3.842652e-01
# Epoch 1105/5000 - loss value -3.850517e-01
# Epoch 1106/5000 - loss value -3.825950e-01
# Epoch 1107/5000 - loss value -3.861666e-01
# Epoch 1108/5000 - loss value -3.840489e-01
# Epoch 1109/5000 - loss value -3.849278e-01
# Epoch 1110/5000 - loss value -3.869891e-01
# Epoch 1111/5000 - loss value -3.857618e-01
# Epoch 1112/5000 - loss value -3.874965e-01
# Epoch 1113/5000 - loss value -3.840377e-01
# Epoch 1114/5000 - loss value -3.833950e-01
# Epoch 1115/5000 - loss value -3.818556e-01
# Epoch 1116/5000 - loss value -3.777198e-01
# Epoch 1117/5000 - loss value -3.783571e-01
# Epoch 1118/5000 - loss value -3.820062e-01
# Epoch 1119/5000 - loss value -3.795745e-01
# Epoch 1120/5000 - loss value -3.835924e-01
# Epoch 1121/5000 - loss value -3.890090e-01
# Epoch 1122/5000 - loss value -3.894465e-01
# Epoch 1123/5000 - loss value -3.812182e-01
# Epoch 1124/5000 - loss value -3.832935e-01
# Epoch 1125/5000 - loss value -3.839586e-01
# Epoch 1126/5000 - loss value -3.915596e-01
# Epoch 1127/5000 - loss value -3.890472e-01
# Epoch 1128/5000 - loss value -3.907696e-01
# Epoch 1129/5000 - loss value -3.851501e-01
# Epoch 1130/5000 - loss value -3.845234e-01
# Epoch 1131/5000 - loss value -3.864862e-01
# Epoch 1132/5000 - loss value -3.867279e-01
# Epoch 1133/5000 - loss value -3.875059e-01
# Epoch 1134/5000 - loss value -3.861259e-01
# Epoch 1135/5000 - loss value -3.833346e-01
# Epoch 1136/5000 - loss value -3.920349e-01
# Epoch 1137/5000 - loss value -3.844016e-01
# Epoch 1138/5000 - loss value -3.864908e-01
# Epoch 1139/5000 - loss value -3.898868e-01
# ...
# Epoch 4630/5000 - loss value -3.998424e-01
# Epoch 4631/5000 - loss value -3.954032e-01
# Epoch 4632/5000 - loss value -4.042966e-01
# Epoch 4633/5000 - loss value -3.907788e-01
# Epoch 4634/5000 - loss value -4.071197e-01
# Epoch 4635/5000 - loss value -4.034882e-01
# Epoch 4636/5000 - loss value -4.013763e-01
# Epoch 4637/5000 - loss value -3.990901e-01
# Epoch 4638/5000 - loss value -3.977271e-01
# Epoch 4639/5000 - loss value -4.122697e-01
# Epoch 4640/5000 - loss value -4.055328e-01
# Epoch 4641/5000 - loss value -3.990217e-01
# Epoch 4642/5000 - loss value -3.950391e-01
# Epoch 4643/5000 - loss value -3.985207e-01
# Epoch 4644/5000 - loss value -4.014769e-01
# Epoch 4645/5000 - loss value -4.053092e-01
# Epoch 4646/5000 - loss value -3.972144e-01
# Epoch 4647/5000 - loss value -3.969567e-01
# Epoch 4648/5000 - loss value -3.994794e-01
# Epoch 4649/5000 - loss value -4.008378e-01
# Epoch 4650/5000 - loss value -4.015153e-01
# Epoch 4651/5000 - loss value -4.076585e-01
# Epoch 4652/5000 - loss value -4.075262e-01
# Epoch 4653/5000 - loss value -4.057829e-01
# Epoch 4654/5000 - loss value -4.061879e-01
# Epoch 4655/5000 - loss value -4.129044e-01
# Epoch 4656/5000 - loss value -4.086228e-01
# Epoch 4657/5000 - loss value -4.061048e-01
# Epoch 4658/5000 - loss value -4.064001e-01
# Epoch 4659/5000 - loss value -4.048228e-01
# Epoch 4660/5000 - loss value -4.042048e-01
# Epoch 4661/5000 - loss value -4.070638e-01
# Epoch 4662/5000 - loss value -4.083309e-01
# Epoch 4663/5000 - loss value -4.065021e-01
# Epoch 4664/5000 - loss value -4.011403e-01
# Epoch 4665/5000 - loss value -4.053941e-01
# Epoch 4666/5000 - loss value -4.041109e-01
# Epoch 4667/5000 - loss value -4.021384e-01
# Epoch 4668/5000 - loss value -3.970527e-01
# Epoch 4669/5000 - loss value -3.992793e-01
# Epoch 4670/5000 - loss value -4.058033e-01
# Epoch 4671/5000 - loss value -4.082362e-01
# Epoch 4672/5000 - loss value -4.062255e-01
# Epoch 4673/5000 - loss value -4.053180e-01
# Epoch 4674/5000 - loss value -3.983414e-01
# Epoch 4675/5000 - loss value -3.998872e-01
# Epoch 4676/5000 - loss value -4.002231e-01
# Epoch 4677/5000 - loss value -4.043773e-01
# Epoch 4678/5000 - loss value -4.043262e-01
# Epoch 4679/5000 - loss value -4.025696e-01
# Epoch 4680/5000 - loss value -3.983862e-01
# Epoch 4681/5000 - loss value -4.008646e-01
# Epoch 4682/5000 - loss value -4.036410e-01
# Epoch 4683/5000 - loss value -4.045473e-01
# Epoch 4684/5000 - loss value -3.985511e-01
# Epoch 4685/5000 - loss value -4.074206e-01
# Epoch 4686/5000 - loss value -4.020289e-01
# Epoch 4687/5000 - loss value -4.065716e-01
# Epoch 4688/5000 - loss value -4.021504e-01
# Epoch 4689/5000 - loss value -4.006167e-01
# Epoch 4690/5000 - loss value -3.940883e-01
# Epoch 4691/5000 - loss value -4.054919e-01
# Epoch 4692/5000 - loss value -3.964195e-01
# Epoch 4693/5000 - loss value -4.030444e-01
# Epoch 4694/5000 - loss value -4.007800e-01
# Epoch 4695/5000 - loss value -4.059935e-01
# Epoch 4696/5000 - loss value -4.126315e-01
# Epoch 4697/5000 - loss value -3.962090e-01
# Epoch 4698/5000 - loss value -3.982320e-01
# Epoch 4699/5000 - loss value -4.041947e-01
# Epoch 4700/5000 - loss value -3.995251e-01
# Epoch 4701/5000 - loss value -4.005942e-01
# Epoch 4702/5000 - loss value -4.009060e-01
# Epoch 4703/5000 - loss value -4.030247e-01
# Epoch 4704/5000 - loss value -4.110136e-01
# Epoch 4705/5000 - loss value -3.994500e-01
# Epoch 4706/5000 - loss value -4.073105e-01
# Epoch 4707/5000 - loss value -4.052188e-01
# Epoch 4708/5000 - loss value -4.005135e-01
# Epoch 4709/5000 - loss value -4.006750e-01
# Epoch 4710/5000 - loss value -4.017627e-01
# Epoch 4711/5000 - loss value -4.016410e-01
# Epoch 4712/5000 - loss value -4.073136e-01
# Epoch 4713/5000 - loss value -4.024063e-01
# Epoch 4714/5000 - loss value -4.016939e-01
# Epoch 4715/5000 - loss value -3.945788e-01
# Epoch 4716/5000 - loss value -4.037492e-01
# Epoch 4717/5000 - loss value -3.963589e-01
# Epoch 4718/5000 - loss value -3.933471e-01
# Epoch 4719/5000 - loss value -3.938078e-01
# Epoch 4720/5000 - loss value -3.906941e-01
# Epoch 4721/5000 - loss value -3.917297e-01
# Epoch 4722/5000 - loss value -3.931535e-01
# Epoch 4723/5000 - loss value -4.027161e-01
# Epoch 4724/5000 - loss value -4.005193e-01
# Epoch 4725/5000 - loss value -4.035414e-01
# Epoch 4726/5000 - loss value -4.014127e-01
# Epoch 4727/5000 - loss value -3.944651e-01
# Epoch 4728/5000 - loss value -3.962674e-01
# Epoch 4729/5000 - loss value -4.068028e-01
# Epoch 4730/5000 - loss value -3.983464e-01
# Epoch 4731/5000 - loss value -3.990111e-01
# Epoch 4732/5000 - loss value -3.997725e-01
# Epoch 4733/5000 - loss value -4.001855e-01
# Epoch 4734/5000 - loss value -4.007733e-01
# Epoch 4735/5000 - loss value -4.065331e-01
# Epoch 4736/5000 - loss value -4.081722e-01
# Epoch 4737/5000 - loss value -3.987220e-01
# Epoch 4738/5000 - loss value -4.108026e-01
# Epoch 4739/5000 - loss value -4.034333e-01
# Epoch 4740/5000 - loss value -4.059706e-01
# Epoch 4741/5000 - loss value -4.093747e-01
# Epoch 4742/5000 - loss value -4.043785e-01
# Epoch 4743/5000 - loss value -3.984661e-01
# Epoch 4744/5000 - loss value -3.996967e-01
# Epoch 4745/5000 - loss value -4.047862e-01
# Epoch 4746/5000 - loss value -3.995370e-01
# Epoch 4747/5000 - loss value -4.051264e-01
# Epoch 4748/5000 - loss value -4.013084e-01
# Epoch 4749/5000 - loss value -4.040296e-01
# Epoch 4750/5000 - loss value -4.005877e-01
# Epoch 4751/5000 - loss value -3.969785e-01
# Epoch 4752/5000 - loss value -3.901463e-01
# Epoch 4753/5000 - loss value -3.996059e-01
# Epoch 4754/5000 - loss value -3.982412e-01
# Epoch 4755/5000 - loss value -3.967066e-01
# Epoch 4756/5000 - loss value -3.994677e-01
# Epoch 4757/5000 - loss value -3.971311e-01
# Epoch 4758/5000 - loss value -4.029404e-01
# Epoch 4759/5000 - loss value -4.016739e-01
# Epoch 4760/5000 - loss value -4.001283e-01
# Epoch 4761/5000 - loss value -4.051762e-01
# Epoch 4762/5000 - loss value -4.037788e-01
# Epoch 4763/5000 - loss value -4.051742e-01
# Epoch 4764/5000 - loss value -4.072376e-01
# Epoch 4765/5000 - loss value -4.063403e-01
# Epoch 4766/5000 - loss value -4.027343e-01
# Epoch 4767/5000 - loss value -4.023600e-01
# Epoch 4768/5000 - loss value -4.095810e-01
# Epoch 4769/5000 - loss value -4.046472e-01
# Epoch 4770/5000 - loss value -4.044941e-01
# Epoch 4771/5000 - loss value -4.048829e-01
# Epoch 4772/5000 - loss value -4.040764e-01
# Epoch 4773/5000 - loss value -4.050291e-01
# Epoch 4774/5000 - loss value -4.086733e-01
# Epoch 4775/5000 - loss value -4.005679e-01
# Epoch 4776/5000 - loss value -3.959232e-01
# Epoch 4777/5000 - loss value -3.955615e-01
# Epoch 4778/5000 - loss value -3.999212e-01
# Epoch 4779/5000 - loss value -4.054437e-01
# Epoch 4780/5000 - loss value -3.989393e-01
# Epoch 4781/5000 - loss value -3.910876e-01
# Epoch 4782/5000 - loss value -4.041104e-01
# Epoch 4783/5000 - loss value -3.992258e-01
# Epoch 4784/5000 - loss value -3.989725e-01
# Epoch 4785/5000 - loss value -4.007546e-01
# Epoch 4786/5000 - loss value -4.025408e-01
# Epoch 4787/5000 - loss value -3.921629e-01
# Epoch 4788/5000 - loss value -3.895998e-01
# Epoch 4789/5000 - loss value -3.913998e-01
# Epoch 4790/5000 - loss value -3.974998e-01
# Epoch 4791/5000 - loss value -3.997966e-01
# Epoch 4792/5000 - loss value -4.009396e-01
# Epoch 4793/5000 - loss value -3.985559e-01
# Epoch 4794/5000 - loss value -4.005887e-01
# Epoch 4795/5000 - loss value -3.949276e-01
# Epoch 4796/5000 - loss value -4.011067e-01
# Epoch 4797/5000 - loss value -3.918465e-01
# Epoch 4798/5000 - loss value -3.958410e-01
# Epoch 4799/5000 - loss value -3.816217e-01
# Epoch 4800/5000 - loss value -3.918272e-01
# Epoch 4801/5000 - loss value -3.962301e-01
# Epoch 4802/5000 - loss value -3.985642e-01
# Epoch 4803/5000 - loss value -3.977242e-01
# Epoch 4804/5000 - loss value -3.939168e-01
# Epoch 4805/5000 - loss value -3.856260e-01
# Epoch 4806/5000 - loss value -4.009756e-01
# Epoch 4807/5000 - loss value -3.938783e-01
# Epoch 4808/5000 - loss value -4.005369e-01
# Epoch 4809/5000 - loss value -4.014806e-01
# Epoch 4810/5000 - loss value -4.057706e-01
# Epoch 4811/5000 - loss value -3.999285e-01
# Epoch 4812/5000 - loss value -3.961855e-01
# Epoch 4813/5000 - loss value -3.968111e-01
# Epoch 4814/5000 - loss value -4.068938e-01
# Epoch 4815/5000 - loss value -4.115646e-01
# Epoch 4816/5000 - loss value -4.023771e-01
# Epoch 4817/5000 - loss value -3.977744e-01
# Epoch 4818/5000 - loss value -4.088741e-01
# Epoch 4819/5000 - loss value -4.019480e-01
# Epoch 4820/5000 - loss value -3.965265e-01
# Epoch 4821/5000 - loss value -3.960473e-01
# Epoch 4822/5000 - loss value -4.014455e-01
# Epoch 4823/5000 - loss value -3.932978e-01
# Epoch 4824/5000 - loss value -4.013850e-01
# Epoch 4825/5000 - loss value -4.004355e-01
# Epoch 4826/5000 - loss value -3.981467e-01
# Epoch 4827/5000 - loss value -4.064236e-01
# Epoch 4828/5000 - loss value -4.019566e-01
# Epoch 4829/5000 - loss value -3.986285e-01
# Epoch 4830/5000 - loss value -3.967375e-01
# Epoch 4831/5000 - loss value -3.970433e-01
# Epoch 4832/5000 - loss value -3.930128e-01
# Epoch 4833/5000 - loss value -3.960239e-01
# Epoch 4834/5000 - loss value -4.016872e-01
# Epoch 4835/5000 - loss value -3.988521e-01
# Epoch 4836/5000 - loss value -4.039989e-01
# Epoch 4837/5000 - loss value -4.051087e-01
# Epoch 4838/5000 - loss value -4.029112e-01
# Epoch 4839/5000 - loss value -4.007782e-01
# Epoch 4840/5000 - loss value -4.044197e-01
# Epoch 4841/5000 - loss value -4.001225e-01
# Epoch 4842/5000 - loss value -4.012322e-01
# Epoch 4843/5000 - loss value -4.001753e-01
# Epoch 4844/5000 - loss value -4.043708e-01
# Epoch 4845/5000 - loss value -4.025585e-01
# Epoch 4846/5000 - loss value -4.005085e-01
# Epoch 4847/5000 - loss value -4.065579e-01
# Epoch 4848/5000 - loss value -4.046528e-01
# Epoch 4849/5000 - loss value -4.022092e-01
# Epoch 4850/5000 - loss value -4.064137e-01
# Epoch 4851/5000 - loss value -4.105779e-01
# Epoch 4852/5000 - loss value -4.004393e-01
# Epoch 4853/5000 - loss value -3.937432e-01
# Epoch 4854/5000 - loss value -4.022899e-01
# Epoch 4855/5000 - loss value -4.044749e-01
# Epoch 4856/5000 - loss value -4.039163e-01
# Epoch 4857/5000 - loss value -4.015280e-01
# Epoch 4858/5000 - loss value -4.156091e-01
# Epoch 4859/5000 - loss value -3.953014e-01
# Epoch 4860/5000 - loss value -3.974473e-01
# Epoch 4861/5000 - loss value -3.917383e-01
# Epoch 4862/5000 - loss value -3.933155e-01
# Epoch 4863/5000 - loss value -3.944638e-01
# Epoch 4864/5000 - loss value -3.916660e-01
# Epoch 4865/5000 - loss value -3.931158e-01
# Epoch 4866/5000 - loss value -3.883857e-01
# Epoch 4867/5000 - loss value -3.875169e-01
# Epoch 4868/5000 - loss value -3.946125e-01
# Epoch 4869/5000 - loss value -3.940406e-01
# Epoch 4870/5000 - loss value -3.934014e-01
# Epoch 4871/5000 - loss value -4.017766e-01
# Epoch 4872/5000 - loss value -3.971643e-01
# Epoch 4873/5000 - loss value -4.025829e-01
# Epoch 4874/5000 - loss value -3.994225e-01
# Epoch 4875/5000 - loss value -4.039270e-01
# Epoch 4876/5000 - loss value -3.978838e-01
# Epoch 4877/5000 - loss value -4.025975e-01
# Epoch 4878/5000 - loss value -4.021790e-01
# Epoch 4879/5000 - loss value -4.053868e-01
# Epoch 4880/5000 - loss value -4.082025e-01
# Epoch 4881/5000 - loss value -4.017151e-01
# Epoch 4882/5000 - loss value -3.989086e-01
# Epoch 4883/5000 - loss value -4.069115e-01
# Epoch 4884/5000 - loss value -4.049665e-01
# Epoch 4885/5000 - loss value -3.954165e-01
# Epoch 4886/5000 - loss value -4.054009e-01
# Epoch 4887/5000 - loss value -4.041005e-01
# Epoch 4888/5000 - loss value -4.120802e-01
# Epoch 4889/5000 - loss value -4.013305e-01
# Epoch 4890/5000 - loss value -4.076526e-01
# Epoch 4891/5000 - loss value -4.046142e-01
# Epoch 4892/5000 - loss value -3.979740e-01
# Epoch 4893/5000 - loss value -4.013668e-01
# Epoch 4894/5000 - loss value -3.945776e-01
# Epoch 4895/5000 - loss value -4.022426e-01
# Epoch 4896/5000 - loss value -3.888027e-01
# Epoch 4897/5000 - loss value -4.021059e-01
# Epoch 4898/5000 - loss value -4.021842e-01
# Epoch 4899/5000 - loss value -4.073492e-01
# Epoch 4900/5000 - loss value -3.982750e-01
# Epoch 4901/5000 - loss value -4.019324e-01
# Epoch 4902/5000 - loss value -3.952005e-01
# Epoch 4903/5000 - loss value -4.039580e-01
# Epoch 4904/5000 - loss value -3.984181e-01
# Epoch 4905/5000 - loss value -3.919475e-01
# Epoch 4906/5000 - loss value -3.980723e-01
# Epoch 4907/5000 - loss value -3.941178e-01
# Epoch 4908/5000 - loss value -4.046996e-01
# Epoch 4909/5000 - loss value -3.988114e-01
# Epoch 4910/5000 - loss value -4.072375e-01
# Epoch 4911/5000 - loss value -3.994988e-01
# Epoch 4912/5000 - loss value -4.077540e-01
# Epoch 4913/5000 - loss value -4.055898e-01
# Epoch 4914/5000 - loss value -4.022054e-01
# Epoch 4915/5000 - loss value -4.027329e-01
# Epoch 4916/5000 - loss value -4.036898e-01
# Epoch 4917/5000 - loss value -4.042880e-01
# Epoch 4918/5000 - loss value -4.067780e-01
# Epoch 4919/5000 - loss value -4.036981e-01
# Epoch 4920/5000 - loss value -4.097658e-01
# Epoch 4921/5000 - loss value -4.059676e-01
# Epoch 4922/5000 - loss value -3.998953e-01
# Epoch 4923/5000 - loss value -4.123540e-01
# Epoch 4924/5000 - loss value -4.097641e-01
# Epoch 4925/5000 - loss value -4.057336e-01
# Epoch 4926/5000 - loss value -4.102951e-01
# Epoch 4927/5000 - loss value -4.048144e-01
# Epoch 4928/5000 - loss value -3.990680e-01
# Epoch 4929/5000 - loss value -4.019083e-01
# Epoch 4930/5000 - loss value -3.957137e-01
# Epoch 4931/5000 - loss value -4.089261e-01
# Epoch 4932/5000 - loss value -4.053791e-01
# Epoch 4933/5000 - loss value -4.044071e-01
# Epoch 4934/5000 - loss value -4.016743e-01
# Epoch 4935/5000 - loss value -3.965866e-01
# Epoch 4936/5000 - loss value -4.036502e-01
# Epoch 4937/5000 - loss value -4.005187e-01
# Epoch 4938/5000 - loss value -4.078595e-01
# Epoch 4939/5000 - loss value -4.092904e-01
# Epoch 4940/5000 - loss value -4.063979e-01
# Epoch 4941/5000 - loss value -3.977134e-01
# Epoch 4942/5000 - loss value -4.032842e-01
# Epoch 4943/5000 - loss value -4.059979e-01
# Epoch 4944/5000 - loss value -4.050071e-01
# Epoch 4945/5000 - loss value -3.972155e-01
# Epoch 4946/5000 - loss value -4.005608e-01
# Epoch 4947/5000 - loss value -3.952212e-01
# Epoch 4948/5000 - loss value -4.011370e-01
# Epoch 4949/5000 - loss value -4.080623e-01
# Epoch 4950/5000 - loss value -4.009573e-01
# Epoch 4951/5000 - loss value -4.023350e-01
# Epoch 4952/5000 - loss value -3.990786e-01
# Epoch 4953/5000 - loss value -3.994217e-01
# Epoch 4954/5000 - loss value -4.118511e-01
# Epoch 4955/5000 - loss value -4.111827e-01
# Epoch 4956/5000 - loss value -4.113576e-01
# Epoch 4957/5000 - loss value -4.099135e-01
# Epoch 4958/5000 - loss value -4.069982e-01
# Epoch 4959/5000 - loss value -4.075857e-01
# Epoch 4960/5000 - loss value -4.096298e-01
# Epoch 4961/5000 - loss value -4.048590e-01
# Epoch 4962/5000 - loss value -4.064568e-01
# Epoch 4963/5000 - loss value -4.090787e-01
# Epoch 4964/5000 - loss value -4.017221e-01
# Epoch 4965/5000 - loss value -4.021892e-01
# Epoch 4966/5000 - loss value -4.064202e-01
# Epoch 4967/5000 - loss value -4.039263e-01
# Epoch 4968/5000 - loss value -4.027373e-01
# Epoch 4969/5000 - loss value -4.019367e-01
# Epoch 4970/5000 - loss value -3.948111e-01
# Epoch 4971/5000 - loss value -3.856438e-01
# Epoch 4972/5000 - loss value -3.931494e-01
# Epoch 4973/5000 - loss value -3.944664e-01
# Epoch 4974/5000 - loss value -3.984772e-01
# Epoch 4975/5000 - loss value -3.920746e-01
# Epoch 4976/5000 - loss value -4.006514e-01
# Epoch 4977/5000 - loss value -4.078749e-01
# Epoch 4978/5000 - loss value -3.999094e-01
# Epoch 4979/5000 - loss value -4.032870e-01
# Epoch 4980/5000 - loss value -4.063051e-01
# Epoch 4981/5000 - loss value -4.050404e-01
# Epoch 4982/5000 - loss value -3.971444e-01
# Epoch 4983/5000 - loss value -3.955263e-01
# Epoch 4984/5000 - loss value -3.946809e-01
# Epoch 4985/5000 - loss value -4.004042e-01
# Epoch 4986/5000 - loss value -4.053534e-01
# Epoch 4987/5000 - loss value -3.970635e-01
# Epoch 4988/5000 - loss value -4.032269e-01
# Epoch 4989/5000 - loss value -3.944986e-01
# Epoch 4990/5000 - loss value -4.001598e-01
# Epoch 4991/5000 - loss value -4.001961e-01
# Epoch 4992/5000 - loss value -4.000847e-01
# Epoch 4993/5000 - loss value -4.050472e-01
# Epoch 4994/5000 - loss value -3.978328e-01
# Epoch 4995/5000 - loss value -3.993337e-01
# Epoch 4996/5000 - loss value -4.048856e-01
# Epoch 4997/5000 - loss value -3.999129e-01
# Epoch 4998/5000 - loss value -4.067556e-01
# Epoch 4999/5000 - loss value -3.985186e-01
# Epoch 5000/5000 - loss value -4.056426e-01
# Elapsed time  0:11:26.994624

# %% [markdown]
# ### Post-processing
#
# Plot the absolute value of the strain along the $y_2y_3$-planes.

# %%
from matplotlib import cm
YS = np.meshgrid(np.linspace(-1,1,100), np.linspace(-1,1,100))
ps = jnp.zeros((100**2,6))


ys = np.concatenate((YS[0].flatten()[...,None]*0, YS[0].flatten()[...,None], YS[1].flatten()[...,None]),-1)
Xs1 = geom1(ys)
Us1 = model.solution1(weights, ys, ps)
Z1 = np.linalg.norm(Us1,axis=-1).reshape(YS[0].shape)

ys = np.concatenate((YS[0].flatten()[...,None]*0, YS[0].flatten()[...,None], YS[1].flatten()[...,None]),-1)
Xs2 = geom2(ys)
Us2 = model.solution2(weights, ys, ps)
Z2 = np.linalg.norm(Us2,axis=-1).reshape(YS[0].shape)

ys = np.concatenate((YS[0].flatten()[...,None]*0, YS[0].flatten()[...,None], YS[1].flatten()[...,None]),-1)
Xs3 = geom3(ys)
Us3 = model.solution3(weights, ys, ps)
Z3 = np.linalg.norm(Us3,axis=-1).reshape(YS[0].shape)

ys = np.concatenate((YS[0].flatten()[...,None]*0, YS[0].flatten()[...,None], YS[1].flatten()[...,None]),-1)
Xs4 = geom4(ys)
Us4 = model.solution4(weights, ys, ps)
Z4 = np.linalg.norm(Us4,axis=-1).reshape(YS[0].shape)

Zmax = max([np.amax(Z1), np.amax(Z2), np.amax(Z3), np.amax(Z4)])

plt.figure(figsize=(7,7))
ax = plt.axes(projection ="3d")
my_col = cm.jet(Z1/Zmax)
ax.plot_surface(Xs1[:,0].reshape(YS[0].shape), Xs1[:,1].reshape(YS[0].shape), Xs1[:,2].reshape(YS[0].shape),facecolors = my_col, linewidth=0, antialiased=False)

my_col = cm.jet(Z2/Zmax)
ax.plot_surface(Xs2[:,0].reshape(YS[0].shape), Xs2[:,1].reshape(YS[0].shape), Xs2[:,2].reshape(YS[0].shape),facecolors = my_col, linewidth=0, antialiased=False)

my_col = cm.jet(Z3/Zmax)
ax.plot_surface(Xs3[:,0].reshape(YS[0].shape), Xs3[:,1].reshape(YS[0].shape), Xs3[:,2].reshape(YS[0].shape),facecolors = my_col, linewidth=0, antialiased=False)

my_col = cm.jet(Z4/Zmax)
ax.plot_surface(Xs4[:,0].reshape(YS[0].shape), Xs4[:,1].reshape(YS[0].shape), Xs4[:,2].reshape(YS[0].shape),facecolors = my_col, linewidth=0, antialiased=False)


plt.figure(figsize=(7,7))
ax = plt.axes(projection ="3d")
my_col = cm.jet(Z1/Zmax)
ax.plot_surface((Xs1+Us1)[:,0].reshape(YS[0].shape), (Xs1+Us1)[:,1].reshape(YS[0].shape), (Xs1+Us1)[:,2].reshape(YS[0].shape),facecolors = my_col, linewidth=0, antialiased=False)

my_col = cm.jet(Z2/Zmax)
ax.plot_surface((Xs2+Us2)[:,0].reshape(YS[0].shape), (Xs2+Us2)[:,1].reshape(YS[0].shape), (Xs2+Us2)[:,2].reshape(YS[0].shape),facecolors = my_col, linewidth=0, antialiased=False)

my_col = cm.jet(Z3/Zmax)
ax.plot_surface((Xs3+Us3)[:,0].reshape(YS[0].shape), (Xs3+Us3)[:,1].reshape(YS[0].shape), (Xs3+Us3)[:,2].reshape(YS[0].shape),facecolors = my_col, linewidth=0, antialiased=False)

my_col = cm.jet(Z4/Zmax)
ax.plot_surface((Xs4+Us4)[:,0].reshape(YS[0].shape), (Xs4+Us4)[:,1].reshape(YS[0].shape), (Xs4+Us4)[:,2].reshape(YS[0].shape),facecolors = my_col, linewidth=0, antialiased=False)

# ys = np.concatenate((YS[0].flatten()[...,None], YS[0].flatten()[...,None]*0, YS[1].flatten()[...,None]),-1)
# Us = model.solution2(weights, ys)
# Us2 = Us
# ax.plot(Xs[:,0], Xs[:,1], Xs[:,2],'gray')
# ax.plot(Xs[:,0]+Us[:,0], Xs[:,1]+Us[:,1], Xs[:,2]+Us[:,2],'blue')
# 
# Xs = geom3(ys)
# Us = model.solution3(weights, ys)
# ax.plot(Xs[:,0], Xs[:,1], Xs[:,2],'gray')
# ax.plot(Xs[:,0]+Us[:,0], Xs[:,1]+Us[:,1], Xs[:,2]+Us[:,2],'blue')
# 
# Xs = geom4(ys)
# Us = model.solution4(weights, ys)
# ax.plot(Xs[:,0], Xs[:,1], Xs[:,2],'gray')
# #ax.plot(Xs[:,0]+Us[:,0], Xs[:,1]+Us[:,1], Xs[:,2]+Us[:,2],'blue')

# %% [markdown]
# Plot the deformation of the domains. The solutions and the geometry objects are JITed first.

# %%
solutions = [jax.jit(model.solution1), jax.jit(model.solution2), jax.jit(model.solution3), jax.jit(model.solution4)]
geoms = [jax.jit(g) for g in geoms]

# %%
ys = jnp.linspace(-1,1,100)[...,None]
Ys  = [jnp.concatenate((ys,ys*0-1,ys*0-1), -1)]
Ys += [jnp.concatenate((ys,ys*0-1,ys*0+1), -1)]
Ys += [jnp.concatenate((ys,ys*0+1,ys*0-1), -1)]
Ys += [jnp.concatenate((ys,ys*0+1,ys*0+1), -1)]
Ys += [jnp.concatenate((ys*0-1,ys,ys*0-1), -1)]
Ys += [jnp.concatenate((ys*0-1,ys,ys*0+1), -1)]
Ys += [jnp.concatenate((ys*0+1,ys,ys*0-1), -1)]
Ys += [jnp.concatenate((ys*0+1,ys,ys*0+1), -1)]
Ys += [jnp.concatenate((ys*0-1,ys*0-1,ys), -1)]
Ys += [jnp.concatenate((ys*0-1,ys*0+1,ys), -1)]
Ys += [jnp.concatenate((ys*0+1,ys*0-1,ys), -1)]
Ys += [jnp.concatenate((ys*0+1,ys*0+1,ys), -1)]

plt.figure()
ax = plt.axes(projection ="3d")




for i in range(4):
    for k in range(12):
        Xs = geoms[i](Ys[k])
        Us = solutions[i](weights, Ys[k], jnp.zeros((Ys[k].shape[0],6)))
        ax.plot(Xs[:,0], Xs[:,1], Xs[:,2],'red',linewidth = 1,alpha=0.2)
        ax.plot(Xs[:,0]+Us[:,0], Xs[:,1]+Us[:,1], Xs[:,2]+Us[:,2],'blue',linewidth = 1)
      
ax.grid(False)  
ax.axes.set_xlim3d(-1,3)
ax.axes.set_ylim3d(-3,3)
ax.axes.set_zlim3d(0,2)
ax.set_xlabel(r'$x_1$')
ax.set_ylabel(r'$x_2$')
ax.set_zlabel(r'$x_3$')
ax.set_zticks([0,1,2])
ax.set_xticks([-1,0,1,2,3])
ax.set_yticks([-3,-1.5,0,1.5,3])
ax.view_init(25,10)
ax.set_box_aspect(aspect = (4,6,2))
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.savefig('./elasto_3d.pdf',bbox_inches='tight')
